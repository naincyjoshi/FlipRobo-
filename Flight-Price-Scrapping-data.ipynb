# %%
# Importing Libraries
import selenium
import pandas as pd
import time
from bs4 import BeautifulSoup

# Importing selenium webdriver 
from selenium import webdriver

# Importing required Exceptions which needs to handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

#Importing requests
import requests

# importing regex
import re

# %%
# !pip install webdriver-manager

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 95.0.4638
# Get LATEST driver version for 95.0.4638
# There is no [win32] chromedriver for browser 95.0.4638 in cache
# Get LATEST driver version for 95.0.4638
# Trying to download new driver from https://chromedriver.storage.googleapis.com/95.0.4638.17/chromedriver_win32.zip
# Driver has been saved in cache [C:\Users\monish\.wdm\drivers\chromedriver\win32\95.0.4638.17]

# %% [markdown]
# ## Detail from Yatra.com

# %%
url ="https://www.yatra.com"
driver.get(url)
time.sleep(6)

# %%
search=driver.find_element_by_xpath("//*[@id='BE_flight_flsearch_btn']")
search.click()

# %%
dept_time=driver.find_elements_by_xpath("//div[@class='i-b pr']")
dept_time
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="4bb4e82bb55b3a1083e29b2246c35c89", element="36c6405b-83c2-4060-8de6-334d90449668")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4bb4e82bb55b3a1083e29b2246c35c89", element="4ef8a7d6-11b0-4682-8946-f786d270a160")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4bb4e82bb55b3a1083e29b2246c35c89", element="ae028e0b-a5cb-4e5e-8e40-12c51c02a616")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4bb4e82bb55b3a1083e29b2246c35c89", element="80ab35ad-6635-4592-96a1-ba743b99e195")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4bb4e82bb55b3a1083e29b2246c35c89", element="3c85140f-d574-4021-b535-19a8e8a17be9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4bb4e82bb55b3a1083e29b2246c35c89", element="cea7b546-1b31-46e0-859d-19c897475f9e")>,
# ...

# %%
departure_time=[]
for d in dept_time:
    departure_time.append(d.text)
departure_time
# Out:
# ['12:40',
#  '11:55',
#  '08:00',
#  '16:15',
#  '18:50',
#  '09:05',
#  '06:15',
#  '14:20',
#  '20:30',
#  '22:45',
#  '17:45',
#  '08:10',
#  '10:40',
#  '15:30',
#  '12:20',
#  '08:10',
#  '10:40',
#  '08:50',
#  '11:20',
#  '15:30',
#  '08:10',
#  '09:10',
#  '08:10',
#  '06:00',
#  '07:00',
#  '14:00',
#  '15:10',
#  '05:00',
#  '08:00',
#  '09:30',
#  '10:20',
#  '12:45',
#  '16:55',
#  '21:40',
#  '21:55',
#  '06:50',
#  '07:30',
#  '09:00',
#  '15:35',
#  '08:50',
#  '17:45',
#  '18:55',
#  '15:05',
#  '06:35',
#  '17:50',
#  '13:45',
#  '08:55',
#  '18:10',
#  '08:10',
#  '09:35',
#  '13:10',
#  '13:50',
#  '07:20',
#  '11:30',
#  '13:50',
#  '08:55',
#  '09:35',
#  '07:20',
#  '08:10',
#  '08:10',
#  '08:55',
#  '11:20',
#  '19:55',
#  '18:40',
#  '19:45',
#  '20:20',
#  '19:05',
#  '11:00',
#  '12:00',
#  '13:10',
#  '20:30',
#  '06:10',
#  '08:55',
#  '10:10',
#  '17:45',
#  '07:40',
#  '12:25',
#  '20:00',
#  '12:25',
#  '12:00',
#  '13:00',
#  '13:20',
#  '12:30',
# ...

# %%
arr_time=driver.find_elements_by_xpath("//p[@class='bold fs-15 mb-2 pr time']")
arr_time
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="4bb4e82bb55b3a1083e29b2246c35c89", element="f0af5b7f-b6bb-48eb-9e4d-a3774fda9e38")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4bb4e82bb55b3a1083e29b2246c35c89", element="c7dcdee9-d9da-431e-991d-0e8b38ca82f6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4bb4e82bb55b3a1083e29b2246c35c89", element="19ad2f06-1590-410f-8311-7e2b166dc5a1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4bb4e82bb55b3a1083e29b2246c35c89", element="5949ba7f-9088-4ab3-9988-f5551730a419")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4bb4e82bb55b3a1083e29b2246c35c89", element="5f64a312-5532-4c47-9be1-23ebc7898846")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4bb4e82bb55b3a1083e29b2246c35c89", element="20b9a4a1-f25f-4288-b713-9a3283a0adce")>,
# ...

# %%
arrival_time=[]
for a in arr_time:
    arrival_time.append(a.text)
arrival_time
# Out:
# ['20:15',
#  '20:15',
#  '16:35',
#  '06:20\n+ 1 day',
#  '20:45',
#  '11:05',
#  '08:20',
#  '16:25',
#  '22:35',
#  '01:00\n+ 1 day',
#  '22:25',
#  '13:00',
#  '15:40',
#  '21:05',
#  '18:15',
#  '14:55',
#  '17:30',
#  '15:45',
#  '18:15',
#  '22:45',
#  '15:40',
#  '18:15',
#  '17:30',
#  '08:00',
#  '09:05',
#  '16:05',
#  '17:15',
#  '07:10',
#  '10:10',
#  '11:40',
#  '12:30',
#  '14:55',
#  '19:05',
#  '23:50',
#  '00:05\n+ 1 day',
#  '09:05',
#  '09:45',
#  '11:15',
#  '17:50',
#  '11:10',
#  '20:05',
#  '21:15',
#  '18:15',
#  '10:10',
#  '21:35',
#  '17:45',
#  '13:10',
#  '22:35',
#  '13:10',
#  '14:50',
#  '18:35',
#  '19:30',
#  '13:10',
#  '18:45',
#  '21:30',
#  '16:40',
#  '18:35',
#  '16:40',
#  '17:45',
#  '18:45',
#  '19:30',
#  '11:30\n+ 1 day',
#  '22:15',
#  '20:40',
#  '22:00',
#  '22:40',
#  '21:05',
#  '13:05',
#  '14:05',
#  '15:15',
#  '22:35',
#  '08:20',
#  '11:05',
#  '12:25',
#  '20:10',
#  '16:50',
#  '23:25',
#  '09:40\n+ 1 day',
# ...

# %%
durr=driver.find_elements_by_xpath("//p[@class='fs-12 bold du mb-2']")
durr
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="4bb4e82bb55b3a1083e29b2246c35c89", element="3807acf3-ed9e-4ab8-922b-5dbe2d89e497")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4bb4e82bb55b3a1083e29b2246c35c89", element="59b52673-63d7-46ca-b5bf-e041d26fab96")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4bb4e82bb55b3a1083e29b2246c35c89", element="4f4f7101-17ee-417c-a6d0-7a00f038fc79")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4bb4e82bb55b3a1083e29b2246c35c89", element="319ff885-83f9-497e-8478-78398c83c209")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4bb4e82bb55b3a1083e29b2246c35c89", element="506a5866-3054-442a-8c22-bd0ee27f8793")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4bb4e82bb55b3a1083e29b2246c35c89", element="d31a41b8-be43-4de5-99ce-fd84e7b87885")>,
# ...

# %%
duration=[]
for r in durr:
    duration.append(r.text)
duration
# Out:
# ['7h 35m',
#  '8h 20m',
#  '8h 35m',
#  '14h 05m',
#  '1h 55m',
#  '2h 00m',
#  '2h 05m',
#  '2h 05m',
#  '2h 05m',
#  '2h 15m',
#  '4h 40m',
#  '4h 50m',
#  '5h 00m',
#  '5h 35m',
#  '5h 55m',
#  '6h 45m',
#  '6h 50m',
#  '6h 55m',
#  '6h 55m',
#  '7h 15m',
#  '7h 30m',
#  '9h 05m',
#  '9h 20m',
#  '2h 00m',
#  '2h 05m',
#  '2h 05m',
#  '2h 05m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 20m',
#  '2h 20m',
#  '2h 20m',
#  '3h 10m',
#  '3h 35m',
#  '3h 45m',
#  '4h 00m',
#  '4h 15m',
#  '4h 25m',
#  '5h 00m',
#  '5h 15m',
#  '5h 25m',
#  '5h 40m',
#  '5h 50m',
#  '7h 15m',
#  '7h 40m',
#  '7h 45m',
#  '9h 00m',
#  '9h 20m',
#  '9h 35m',
#  '10h 35m',
#  '10h 35m',
#  '24h 10m',
#  '2h 20m',
#  '2h 00m',
#  '2h 15m',
#  '2h 20m',
#  '2h 00m',
#  '2h 05m',
#  '2h 05m',
#  '2h 05m',
#  '2h 05m',
#  '2h 10m',
#  '2h 10m',
#  '2h 15m',
#  '2h 25m',
#  '9h 10m',
# ...

# %%
stops=driver.find_elements_by_xpath("//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']")
stops
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="4bb4e82bb55b3a1083e29b2246c35c89", element="23cef73c-a1ea-4052-aa1c-5013acebbdc6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4bb4e82bb55b3a1083e29b2246c35c89", element="823de662-214c-400e-8ce6-d4dfd22e6e69")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4bb4e82bb55b3a1083e29b2246c35c89", element="50990b1b-2b9c-4afb-b4f2-9c895badacb4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4bb4e82bb55b3a1083e29b2246c35c89", element="016bc14c-7ab8-44d1-81f3-3a12dbb7d103")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4bb4e82bb55b3a1083e29b2246c35c89", element="df554f62-ea4e-4f01-aa2b-0d7e7c51fa52")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4bb4e82bb55b3a1083e29b2246c35c89", element="c1c7fee0-b49e-4b8a-9cb4-6676b936e397")>,
# ...

# %%
stoppage=[]
for s in stops:
    stoppage.append(s.text)
stoppage
# Out:
# ['1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
# ...

# %%
flight=driver.find_elements_by_xpath("//span[@class='i-b text ellipsis']")
flight
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="4bb4e82bb55b3a1083e29b2246c35c89", element="ead7a2f7-dafc-4bc3-bb49-ed3789346828")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4bb4e82bb55b3a1083e29b2246c35c89", element="e29ea871-0417-40f1-9a7e-d20a20964b26")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4bb4e82bb55b3a1083e29b2246c35c89", element="13efe745-d4df-4bd1-a96b-05647671d396")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4bb4e82bb55b3a1083e29b2246c35c89", element="fa6841f3-d7a9-4c7f-bbeb-224f8d19cec1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4bb4e82bb55b3a1083e29b2246c35c89", element="1e60c245-3a90-47fe-8569-09334385085b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4bb4e82bb55b3a1083e29b2246c35c89", element="2fff5beb-d99d-4420-a35f-73fcb6179b4b")>,
# ...

# %%
flight_name=[]
for f in flight:
    flight_name.append(f.text)
flight_name
# Out:
# ['Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Vistara',
#  'Air India',
#  'IndiGo',
#  'Vistara',
#  'IndiGo',
#  'Air India',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'IndiGo',
#  'SpiceJet',
#  'Vistara',
#  'Air India',
#  'IndiGo',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Air India',
#  'SpiceJet',
#  'Air India',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'SpiceJet',
#  'Air Asia',
#  'SpiceJet',
#  'Vistara',
#  'SpiceJet',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
# ...

# %%
prices=driver.find_elements_by_xpath("//div[@class='i-b tipsy fare-summary-tooltip fs-18']")
prices
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="4bb4e82bb55b3a1083e29b2246c35c89", element="40966914-c5ab-472f-92e0-b5d93e0e56a8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4bb4e82bb55b3a1083e29b2246c35c89", element="34c6ea19-ca68-469c-9e79-be4f87eb65a6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4bb4e82bb55b3a1083e29b2246c35c89", element="098866c9-5072-47e8-91c0-c4bdd3ade64d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4bb4e82bb55b3a1083e29b2246c35c89", element="0067e5af-fbf9-4c85-8186-a1bebbbd7c31")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4bb4e82bb55b3a1083e29b2246c35c89", element="4b825547-770c-4977-b1ee-dc70efd0fe36")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4bb4e82bb55b3a1083e29b2246c35c89", element="4ed321eb-c809-48bb-9169-e29695d47392")>,
# ...

# %%
price=[]
for p in prices:
    price.append(p.text)
price
# Out:
# ['5,953',
#  '5,953',
#  '5,953',
#  '5,953',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,956',
#  '6,060',
#  '6,060',
#  '6,060',
#  '6,165',
#  '6,165',
#  '6,165',
#  '6,165',
#  '6,165',
#  '6,165',
#  '6,165',
#  '6,165',
#  '6,165',
#  '6,443',
#  '7,468',
#  '7,468',
#  '7,468',
#  '8,160',
#  '8,160',
#  '8,370',
#  '8,528',
# ...

# %%
source_=driver.find_elements_by_xpath("//p[@class='fs-10 font-lightgrey no-wrap city ellipsis']")
source_
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="4bb4e82bb55b3a1083e29b2246c35c89", element="75701928-8887-4c1a-93a1-0daff7dbfe33")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4bb4e82bb55b3a1083e29b2246c35c89", element="7a9f942f-6808-403e-b9cf-78a42722e99d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4bb4e82bb55b3a1083e29b2246c35c89", element="131184b0-33cf-44d5-9568-286b1e70c427")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4bb4e82bb55b3a1083e29b2246c35c89", element="26b73ecf-3186-454a-b020-d3588c2a3d7e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4bb4e82bb55b3a1083e29b2246c35c89", element="870eae58-13cd-45ce-a9fa-0b3faf78fa5f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4bb4e82bb55b3a1083e29b2246c35c89", element="ab1b188f-87de-4e40-8cf2-15f690bbb7c7")>,
# ...

# %%
source=[]
for s in source_:
    source.append(s.text)
source
# Out:
# ['New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
# ...

# %%
destination=[]
for d in range(1,len(source),2):
    destination.append(source[d])
destination
# Out:
# ['Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
# ...

# %%
source1=[]
for s in range(0,len(source),2):
    source1.append(source[s])
source1
# Out:
# ['New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
# ...

# %%
import pandas as pd
flight_detail=pd.DataFrame({})
flight_detail['Departure Time']=departure_time[:127]
flight_detail['Arrival Time']=arrival_time[:127]
flight_detail['Source']=source1[:127]
flight_detail['Destination']=destination[:127]
flight_detail['Duration']=duration[:127]
flight_detail['Stoppage']=stoppage[:127]
flight_detail['Flight Name']=flight_name[:127]
flight_detail['Price']=price[:127]
flight_detail
# Out:
#     Departure Time    Arrival Time     Source Destination Duration  Stoppage  \
# 0            12:40           20:15  New Delhi      Mumbai   7h 35m    1 Stop
# 1            11:55           20:15  New Delhi      Mumbai   8h 20m    1 Stop
# 2            08:00           16:35  New Delhi      Mumbai   8h 35m    1 Stop
# 3            16:15  06:20\n+ 1 day  New Delhi      Mumbai  14h 05m    1 Stop
# 4            18:50           20:45  New Delhi      Mumbai   1h 55m  Non Stop
# ..             ...             ...        ...         ...      ...       ...
# 122          06:20           13:00  New Delhi      Mumbai   6h 40m    1 Stop
# 123          07:30           20:20  New Delhi      Mumbai  12h 50m    1 Stop
# 124          06:20           20:20  New Delhi      Mumbai  14h 00m    1 Stop
# 125          07:30           23:15  New Delhi      Mumbai  15h 45m    1 Stop
# 126          19:55  11:50\n+ 1 day  New Delhi      Mumbai  15h 55m    1 Stop
#
#     Flight Name   Price
# ...

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 95.0.4638
# Get LATEST driver version for 95.0.4638
# Driver [C:\Users\monish\.wdm\drivers\chromedriver\win32\95.0.4638.17\chromedriver.exe] found in cache

# %%
url ="https://www.yatra.com"
driver.get(url)

# %%
search=driver.find_element_by_xpath("//*[@id='BE_flight_flsearch_btn']")
search.click()

# %%
dept_time=driver.find_elements_by_xpath("//div[@class='i-b pr']")
dept_time
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="d67e8caa6ecba536c8519ba82734bf17", element="722b6c1e-c9bd-439c-8a27-fb996378626b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d67e8caa6ecba536c8519ba82734bf17", element="8a7be72e-75f2-4e06-8461-6f2093acc8d4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d67e8caa6ecba536c8519ba82734bf17", element="65cb2991-464d-4447-83d0-3f8358f5efb4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d67e8caa6ecba536c8519ba82734bf17", element="552789ae-918d-4d5e-9d67-01baaebfd624")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d67e8caa6ecba536c8519ba82734bf17", element="85af3f3f-1d91-4ec3-a1bf-94e5dd7f8b00")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d67e8caa6ecba536c8519ba82734bf17", element="1b50393d-3365-40d5-a849-0a86126d73c8")>,
# ...

# %%
departure=[]
for d in dept_time:
    departure.append(d.text)
departure
# Out:
# ['16:05',
#  '09:25',
#  '15:25',
#  '15:40',
#  '05:00',
#  '07:10',
#  '07:10',
#  '09:25',
#  '16:50',
#  '06:05',
#  '18:40',
#  '02:00',
#  '10:30',
#  '18:05',
#  '12:45',
#  '12:45',
#  '15:00',
#  '08:00',
#  '14:20',
#  '22:30',
#  '05:35',
#  '06:10',
#  '20:40',
#  '06:10',
#  '06:15',
#  '08:05',
#  '16:05',
#  '17:20',
#  '20:10',
#  '22:10',
#  '14:15',
#  '17:35',
#  '19:50',
#  '02:30',
#  '04:15',
#  '07:20',
#  '08:20',
#  '09:15',
#  '12:00',
#  '21:25',
#  '22:50',
#  '15:30',
#  '19:50',
#  '06:45',
#  '17:45',
#  '13:00',
#  '13:50',
#  '07:55',
#  '19:30',
#  '06:20',
#  '13:40',
#  '06:30',
#  '10:15',
#  '06:45',
#  '13:00',
#  '11:00',
#  '08:25',
#  '17:45',
#  '07:25',
#  '08:40',
#  '13:00',
#  '23:05',
#  '09:40',
#  '15:00',
#  '11:00',
#  '11:10',
#  '06:05',
#  '05:15',
#  '23:05',
#  '11:00',
#  '13:00',
#  '13:40',
#  '09:40',
#  '21:40',
#  '06:15',
#  '16:20',
#  '15:00',
#  '12:00',
#  '17:45',
#  '13:05',
#  '11:55',
#  '18:25',
#  '09:25',
# ...

# %%
arr_time=driver.find_elements_by_xpath("//p[@class='bold fs-15 mb-2 pr time']")
arr_time
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="d67e8caa6ecba536c8519ba82734bf17", element="c6def962-9260-429c-8cac-39362bb065ef")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d67e8caa6ecba536c8519ba82734bf17", element="a7941083-f978-471c-b11e-4abf226dd9a2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d67e8caa6ecba536c8519ba82734bf17", element="faac0c43-7062-4821-bd56-23a495c06991")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d67e8caa6ecba536c8519ba82734bf17", element="790a8ebc-53ee-4532-9d01-fecfe0d66dba")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d67e8caa6ecba536c8519ba82734bf17", element="4bed5dce-36ca-4269-8bed-b359f023f5d4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d67e8caa6ecba536c8519ba82734bf17", element="65e0e31b-ddc8-4d4b-98cd-8b042daeabb4")>,
# ...

# %%
arrival_time=[]
for a in arr_time:
    arrival_time.append(a.text)
arrival_time
# Out:
# ['20:40',
#  '14:40',
#  '20:40',
#  '21:30',
#  '11:35',
#  '14:00',
#  '14:10',
#  '17:00',
#  '00:25\n+ 1 day',
#  '08:40',
#  '21:25',
#  '07:40',
#  '16:10',
#  '00:35\n+ 1 day',
#  '19:20',
#  '20:30',
#  '22:45',
#  '16:10',
#  '22:45',
#  '07:40\n+ 1 day',
#  '08:05',
#  '08:50',
#  '23:20',
#  '08:55',
#  '09:00',
#  '10:50',
#  '18:50',
#  '20:05',
#  '22:55',
#  '00:55\n+ 1 day',
#  '17:05',
#  '20:25',
#  '22:40',
#  '05:25',
#  '07:10',
#  '10:15',
#  '11:15',
#  '12:10',
#  '14:55',
#  '00:20\n+ 1 day',
#  '01:45\n+ 1 day',
#  '18:30',
#  '22:50',
#  '11:50',
#  '22:50',
#  '18:10',
#  '19:00',
#  '13:20',
#  '01:05\n+ 1 day',
#  '12:00',
#  '19:50',
#  '12:50',
#  '16:40',
#  '13:20',
#  '19:35',
#  '18:10',
#  '15:40',
#  '01:05\n+ 1 day',
#  '14:50',
#  '16:25',
#  '20:45',
#  '06:55\n+ 1 day',
#  '18:10',
#  '23:30',
#  '19:35',
#  '19:50',
#  '14:50',
#  '14:20',
#  '08:15\n+ 1 day',
#  '20:45',
#  '22:50',
#  '23:30',
#  '19:35',
#  '07:45\n+ 1 day',
#  '21:10',
# ...

# %%
durr=driver.find_elements_by_xpath("//p[@class='fs-12 bold du mb-2']")
durr
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="d67e8caa6ecba536c8519ba82734bf17", element="f4c19078-6260-4450-b312-39adb7ece4ba")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d67e8caa6ecba536c8519ba82734bf17", element="91af4ff1-e4f8-4996-988d-2e3ad0017223")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d67e8caa6ecba536c8519ba82734bf17", element="9cd9875b-43bf-402e-b6c1-8babc368b7c8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d67e8caa6ecba536c8519ba82734bf17", element="1c78f76c-d14a-4c1b-8ffd-f5ea10defc09")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d67e8caa6ecba536c8519ba82734bf17", element="66805503-0e29-41b1-b5ed-e967deae3858")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d67e8caa6ecba536c8519ba82734bf17", element="7220ea1e-50ef-4827-ab74-6aaf154e6cbf")>,
# ...

# %%
duration=[]
for r in durr:
    duration.append(r.text)
duration
# Out:
# ['4h 35m',
#  '5h 15m',
#  '5h 15m',
#  '5h 50m',
#  '6h 35m',
#  '6h 50m',
#  '7h 00m',
#  '7h 35m',
#  '7h 35m',
#  '2h 35m',
#  '2h 45m',
#  '5h 40m',
#  '5h 40m',
#  '6h 30m',
#  '6h 35m',
#  '7h 45m',
#  '7h 45m',
#  '8h 10m',
#  '8h 25m',
#  '9h 10m',
#  '2h 30m',
#  '2h 40m',
#  '2h 40m',
#  '2h 45m',
#  '2h 45m',
#  '2h 45m',
#  '2h 45m',
#  '2h 45m',
#  '2h 45m',
#  '2h 45m',
#  '2h 50m',
#  '2h 50m',
#  '2h 50m',
#  '2h 55m',
#  '2h 55m',
#  '2h 55m',
#  '2h 55m',
#  '2h 55m',
#  '2h 55m',
#  '2h 55m',
#  '2h 55m',
#  '3h 00m',
#  '3h 00m',
#  '5h 05m',
#  '5h 05m',
#  '5h 10m',
#  '5h 10m',
#  '5h 25m',
#  '5h 35m',
#  '5h 40m',
#  '6h 10m',
#  '6h 20m',
#  '6h 25m',
#  '6h 35m',
#  '6h 35m',
#  '7h 10m',
#  '7h 15m',
#  '7h 20m',
#  '7h 25m',
#  '7h 45m',
#  '7h 45m',
#  '7h 50m',
#  '8h 30m',
#  '8h 30m',
#  '8h 35m',
#  '8h 40m',
#  '8h 45m',
#  '9h 05m',
#  '9h 10m',
#  '9h 45m',
#  '9h 50m',
#  '9h 50m',
#  '9h 55m',
#  '10h 05m',
#  '14h 55m',
#  '16h 40m',
# ...

# %%
stops=driver.find_elements_by_xpath("//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']")
stops
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="d67e8caa6ecba536c8519ba82734bf17", element="bcef854b-ba0b-41d8-b03c-eebcaf6f37d4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d67e8caa6ecba536c8519ba82734bf17", element="13ad53bc-204a-4e43-801d-daf97d9974dc")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d67e8caa6ecba536c8519ba82734bf17", element="ff2ad871-ec94-4405-a1e3-15c372303b31")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d67e8caa6ecba536c8519ba82734bf17", element="6f201f22-71ba-498c-87a1-6aff07a24a7a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d67e8caa6ecba536c8519ba82734bf17", element="560bf37f-c65b-4bcc-8da1-7d153a32fe56")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d67e8caa6ecba536c8519ba82734bf17", element="1795b0d1-8d30-40d7-bf9d-3ca07cf5ce8c")>,
# ...

# %%
stoppage=[]
for s in stops:
    stoppage.append(s.text)
stoppage
# Out:
# ['1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '1 Stop',
#  'Non Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
# ...

# %%
flight=driver.find_elements_by_xpath("//span[@class='i-b text ellipsis']")
flight
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="d67e8caa6ecba536c8519ba82734bf17", element="5240a01e-9073-4521-9e8b-4a54a5fe5e92")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d67e8caa6ecba536c8519ba82734bf17", element="f68b0fc2-b538-4af1-96cd-64c3638099aa")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d67e8caa6ecba536c8519ba82734bf17", element="589c99c4-35da-4121-b2b3-ccb0c89cba88")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d67e8caa6ecba536c8519ba82734bf17", element="04beb34d-e75b-47b7-938f-93e0d109f64d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d67e8caa6ecba536c8519ba82734bf17", element="6b2aa93d-6e96-4f4a-bfb2-7eacfe79c901")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d67e8caa6ecba536c8519ba82734bf17", element="6402c2bf-8da4-4436-91a3-b13bb85fdc33")>,
# ...

# %%
flight_name=[]
for f in flight:
    flight_name.append(f.text)
flight_name
# Out:
# ['Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'SpiceJet',
#  'IndiGo',
#  'Vistara',
#  'Air India',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Air India',
#  'SpiceJet',
#  'SpiceJet',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'SpiceJet',
#  'IndiGo',
#  'SpiceJet',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'SpiceJet',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
# ...

# %%
prices=driver.find_elements_by_xpath("//div[@class='i-b tipsy fare-summary-tooltip fs-18']")
prices
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="d67e8caa6ecba536c8519ba82734bf17", element="36d08b77-37c2-4cb2-bf35-7262d579b8df")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d67e8caa6ecba536c8519ba82734bf17", element="ace74934-dcdf-4d58-bb91-87bb0801194f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d67e8caa6ecba536c8519ba82734bf17", element="20fed6c1-68fc-49f3-a967-c5a14c3dc3dc")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d67e8caa6ecba536c8519ba82734bf17", element="efcace24-ed39-4e8b-96f6-b8201516d16c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d67e8caa6ecba536c8519ba82734bf17", element="62436503-abcf-441a-8a28-2dbab8a2b464")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d67e8caa6ecba536c8519ba82734bf17", element="c4661b0f-e3df-430b-9fed-8e19fe46f82a")>,
# ...

# %%
price=[]
for p in prices:
    price.append(p.text)
price
# Out:
# ['7,423',
#  '7,423',
#  '7,423',
#  '7,423',
#  '7,423',
#  '7,423',
#  '7,423',
#  '7,423',
#  '7,423',
#  '7,424',
#  '7,424',
#  '7,424',
#  '7,424',
#  '7,424',
#  '7,424',
#  '7,424',
#  '7,424',
#  '7,424',
#  '7,424',
#  '7,424',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
#  '7,425',
# ...

# %%
source_=driver.find_elements_by_xpath("//p[@class='fs-10 font-lightgrey no-wrap city ellipsis']")
source_
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="d67e8caa6ecba536c8519ba82734bf17", element="38e0c9c7-3d00-474a-9d76-181905da818a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d67e8caa6ecba536c8519ba82734bf17", element="436ce52a-fe7c-4b98-9271-f7157421e5da")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d67e8caa6ecba536c8519ba82734bf17", element="3e66451d-8542-42ba-a4b0-e8844644a5ce")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d67e8caa6ecba536c8519ba82734bf17", element="4fd8d657-2e26-40af-ae57-27fd06e15b34")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d67e8caa6ecba536c8519ba82734bf17", element="b367f2a0-1575-4fd6-a60e-9df444ff6ffa")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d67e8caa6ecba536c8519ba82734bf17", element="333a5ac3-b9f4-4286-97bc-7339e07088bb")>,
# ...

# %%
source=[]
for s in source_:
    source.append(s.text)
source
# Out:
# ['New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
# ...

# %%
destination=[]
for d in range(1,len(source),2):
    destination.append(source[d])
destination
# Out:
# ['Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
# ...

# %%
source1=[]
for s in range(0,len(source),2):
    source1.append(source[s])
source1
# Out:
# ['New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
# ...

# %%
import pandas as pd
df1=pd.DataFrame({})
df1['Departure Time']=departure
df1['Arrival Time']=arrival_time
df1['Source']=source1
df1['Destination']=destination
df1['Duration']=duration
df1['Stoppage']=stoppage
df1['Flight Name']=flight_name
df1['Price']=price
df1
# Out:
#     Departure Time    Arrival Time     Source Destination Duration   Stoppage  \
# 0            16:05           20:40  New Delhi   Bangalore   4h 35m     1 Stop
# 1            09:25           14:40  New Delhi   Bangalore   5h 15m     1 Stop
# 2            15:25           20:40  New Delhi   Bangalore   5h 15m     1 Stop
# 3            15:40           21:30  New Delhi   Bangalore   5h 50m     1 Stop
# 4            05:00           11:35  New Delhi   Bangalore   6h 35m     1 Stop
# ..             ...             ...        ...         ...      ...        ...
# 163          09:00           17:10  New Delhi   Bangalore   8h 10m     1 Stop
# 164          18:15  13:00\n+ 1 day  New Delhi   Bangalore  18h 45m     1 Stop
# 165          13:15           21:45  New Delhi   Bangalore   8h 30m  2 Stop(s)
# 166          10:45           15:10  New Delhi   Bangalore   4h 25m     1 Stop
# 167          09:25           23:20  New Delhi   Bangalore  13h 55m  2 Stop(s)
#
#     Flight Name   Price
# ...

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 95.0.4638
# Get LATEST driver version for 95.0.4638
# Driver [C:\Users\monish\.wdm\drivers\chromedriver\win32\95.0.4638.17\chromedriver.exe] found in cache

# %%
url ="https://www.easemytrip.com/"
driver.get(url)

# %%
search=driver.find_element_by_xpath("//div[@class='s_col_v4 ripplen']")
search.click()

# %%
flight_name=driver.find_elements_by_xpath("//span[@class='txt-r4 ng-binding']")
flight_name
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="a4e8f7ce91bb6ad9aa70050431d953f9", element="ba5a10ff-48fb-4ea9-a6f1-b8a4bb9e60ea")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a4e8f7ce91bb6ad9aa70050431d953f9", element="dc45c4aa-0b4a-4e66-93ed-03d49a10a408")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a4e8f7ce91bb6ad9aa70050431d953f9", element="0dda3726-f571-4f43-bfcf-13d32b782b73")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a4e8f7ce91bb6ad9aa70050431d953f9", element="9fa7b933-c290-41c7-96f8-99223dbabcd0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a4e8f7ce91bb6ad9aa70050431d953f9", element="d1c4a6ed-c5bc-4ceb-84bb-9320cc1e745e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a4e8f7ce91bb6ad9aa70050431d953f9", element="f9312c38-b69e-42d8-93c3-67fcc4407fb5")>,
# ...

# %%
flightname=[]
for f in flight_name:
    flightname.append(f.text)
flightname
# Out:
# ['SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'GO FIRST',
#  'GO FIRST',
#  'GO FIRST',
#  'GO FIRST',
#  'GO FIRST',
#  'GO FIRST',
#  'GO FIRST',
#  'GO FIRST',
#  'GO FIRST',
#  'Indigo',
#  'Indigo',
#  'Indigo',
#  'Indigo',
#  'AirAsia',
#  'AirAsia',
#  'Indigo',
#  'Indigo',
#  'Indigo',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'GO FIRST',
#  'Indigo',
#  'Indigo',
#  'Indigo',
#  'Indigo',
#  'Indigo',
#  'SpiceJet',
#  'SpiceJet',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'AirAsia',
#  'AirAsia',
#  'AirAsia',
#  'AirAsia',
#  'AirAsia',
#  'AirAsia',
#  'AirAsia',
#  'AirAsia',
#  'AirAsia',
#  'Indigo',
#  'Indigo',
#  'Indigo',
#  'Vistara',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'GO FIRST',
#  'GO FIRST',
#  'GO FIRST',
#  'GO FIRST',
#  'GO FIRST',
#  'GO FIRST',
#  'Air India',
# ...

# %%
departure=driver.find_elements_by_xpath("//div[@class='col-md-2 col-sm-2 col-xs-4 top5 ']")
departure
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="a4e8f7ce91bb6ad9aa70050431d953f9", element="1afd2d83-54cc-4829-b454-f83024ab5648")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a4e8f7ce91bb6ad9aa70050431d953f9", element="392cd554-24d5-4fef-a00f-99b3394c1665")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a4e8f7ce91bb6ad9aa70050431d953f9", element="39a43ce9-da72-47ae-bec3-9395a8ecb685")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a4e8f7ce91bb6ad9aa70050431d953f9", element="42e448d3-0709-421e-ba80-c5c820bc2463")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a4e8f7ce91bb6ad9aa70050431d953f9", element="ae974da0-61a9-4981-bf4e-4447c3fbb926")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a4e8f7ce91bb6ad9aa70050431d953f9", element="c1d3a0e2-b469-4116-b24c-b0567dcc5a2f")>,
# ...

# %%
departure_time=[]
for d in departure:
    departure_time.append(d.text.split("\n")[0])
departure_time
# Out:
# ['18:55',
#  '07:20',
#  '06:20',
#  '19:45',
#  '07:00',
#  '08:00',
#  '22:30',
#  '02:00',
#  '15:00',
#  '19:40',
#  '21:00',
#  '10:30',
#  '18:05',
#  '06:30',
#  '07:15',
#  '10:45',
#  '04:45',
#  '04:25',
#  '20:00',
#  '17:15',
#  '01:05',
#  '16:00',
#  '06:00',
#  '09:30',
#  '16:55',
#  '19:50',
#  '20:40',
#  '21:40',
#  '10:20',
#  '11:40',
#  '14:20',
#  '08:10',
#  '12:00',
#  '14:20',
#  '20:00',
#  '08:45',
#  '19:00',
#  '19:00',
#  '15:30',
#  '07:30',
#  '08:50',
#  '17:45',
#  '18:55',
#  '21:25',
#  '21:25',
#  '20:45',
#  '20:45',
#  '09:35',
#  '18:35',
#  '08:00',
#  '18:35',
#  '22:10',
#  '23:15',
#  '09:30',
#  '18:35',
#  '12:50',
#  '07:00',
#  '08:00',
#  '10:40',
#  '17:50',
#  '20:00',
#  '19:00',
#  '12:20',
#  '11:50',
#  '06:00',
#  '06:25',
#  '18:40',
#  '06:00',
#  '15:05',
#  '11:20',
#  '15:00',
#  '21:15',
#  '06:05',
#  '07:25',
#  '12:55',
#  '21:50',
#  '12:55',
#  '08:40',
#  '05:55',
#  '08:40',
#  '06:00',
#  '15:30',
#  '06:00',
# ...

# %%
source=[]
for s in departure:
    source.append(s.text.split("\n")[-1])
source
# Out:
# ['Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
# ...

# %%
arrival=driver.find_elements_by_xpath("//div[@class='col-md-2 col-sm-2 col-xs-3 top5']")
arrival
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="a4e8f7ce91bb6ad9aa70050431d953f9", element="25de0461-b25b-40f9-8745-7528510bdbb4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a4e8f7ce91bb6ad9aa70050431d953f9", element="0b80513b-0a19-4828-9da9-1dfa863b43db")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a4e8f7ce91bb6ad9aa70050431d953f9", element="993ea4d2-1ffe-48ac-aacb-310f8c8374d8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a4e8f7ce91bb6ad9aa70050431d953f9", element="a2789aee-aab3-4516-aacc-ed45d04a0868")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a4e8f7ce91bb6ad9aa70050431d953f9", element="f1c35912-3f4b-4efc-88e5-8b311a8cae76")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a4e8f7ce91bb6ad9aa70050431d953f9", element="c318bbca-fb72-480f-84b2-423ec242fe55")>,
# ...

# %%
arrival_time=[]
for a in arrival:
    arrival_time.append(a.text.split("\n")[0])
arrival_time
# Out:
# ['21:05',
#  '09:35',
#  '08:40',
#  '22:05',
#  '09:10',
#  '10:10',
#  '00:40',
#  '04:15',
#  '17:15',
#  '21:55',
#  '23:15',
#  '12:50',
#  '20:25',
#  '08:40',
#  '09:25',
#  '13:05',
#  '07:10',
#  '06:35',
#  '22:15',
#  '19:25',
#  '03:20',
#  '18:15',
#  '08:00',
#  '11:40',
#  '19:05',
#  '22:00',
#  '22:50',
#  '23:50',
#  '12:35',
#  '14:00',
#  '16:35',
#  '10:20',
#  '14:10',
#  '16:35',
#  '22:15',
#  '11:05',
#  '23:50',
#  '10:35',
#  '17:40',
#  '09:45',
#  '11:10',
#  '20:05',
#  '21:15',
#  '06:45',
#  '07:15',
#  '06:45',
#  '07:15',
#  '20:35',
#  '06:45',
#  '20:35',
#  '07:15',
#  '12:25',
#  '01:25',
#  '11:45',
#  '20:50',
#  '15:00',
#  '09:05',
#  '10:10',
#  '12:50',
#  '20:00',
#  '22:10',
#  '21:15',
#  '18:10',
#  '18:10',
#  '15:45',
#  '18:10',
#  '07:20',
#  '20:20',
#  '18:15',
#  '18:00',
#  '12:35',
#  '23:30',
#  '16:05',
#  '16:05',
#  '20:45',
#  '08:15',
#  '23:25',
#  '23:25',
#  '23:25',
#  '09:45',
#  '10:40',
#  '21:25',
#  '12:30',
# ...

# %%
destination=[]
for d in arrival:
    destination.append(d.text.split("\n")[-1])
destination
# Out:
# ['Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
# ...

# %%
duration=driver.find_elements_by_xpath("//div[@class='col-md-2 col-sm-2 col-xs-5 non-st']")
duration
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="a4e8f7ce91bb6ad9aa70050431d953f9", element="9bfe9823-0563-464d-b187-123b8b874bc6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a4e8f7ce91bb6ad9aa70050431d953f9", element="dd2aa722-39d0-4bb6-a493-8ae971de3d08")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a4e8f7ce91bb6ad9aa70050431d953f9", element="539414b9-70df-4663-8802-de2b426d14fb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a4e8f7ce91bb6ad9aa70050431d953f9", element="80e40aff-06cd-489d-9bc5-f83db202da7c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a4e8f7ce91bb6ad9aa70050431d953f9", element="e8cead36-73c4-4a8e-9762-152ed7ba3814")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a4e8f7ce91bb6ad9aa70050431d953f9", element="a23a9360-7f38-4423-967d-4807fff74f9f")>,
# ...

# %%
durations=[]
for d in duration:
    durations.append(d.text.split("\n")[0])
durations
# Out:
# ['02h 10m',
#  '02h 15m',
#  '02h 20m',
#  '02h 20m',
#  '02h 10m',
#  '02h 10m',
#  '02h 10m',
#  '02h 15m',
#  '02h 15m',
#  '02h 15m',
#  '02h 15m',
#  '02h 20m',
#  '02h 20m',
#  '02h 10m',
#  '02h 10m',
#  '02h 20m',
#  '02h 25m',
#  '02h 10m',
#  '02h 15m',
#  '02h 10m',
#  '02h 15m',
#  '02h 15m',
#  '02h 00m',
#  '02h 10m',
#  '02h 10m',
#  '02h 10m',
#  '02h 10m',
#  '02h 10m',
#  '02h 15m',
#  '02h 20m',
#  '02h 15m',
#  '02h 10m',
#  '02h 10m',
#  '02h 15m',
#  '02h 15m',
#  '02h 20m',
#  '04h 50m',
#  '15h 35m',
#  '02h 10m',
#  '02h 15m',
#  '02h 20m',
#  '02h 20m',
#  '02h 20m',
#  '09h 20m',
#  '09h 50m',
#  '10h 00m',
#  '10h 30m',
#  '11h 00m',
#  '12h 10m',
#  '12h 35m',
#  '12h 40m',
#  '14h 15m',
#  '02h 10m',
#  '02h 15m',
#  '02h 15m',
#  '02h 10m',
#  '02h 05m',
#  '02h 10m',
#  '02h 10m',
#  '02h 10m',
#  '02h 10m',
#  '02h 15m',
#  '05h 50m',
#  '06h 20m',
#  '09h 45m',
#  '11h 45m',
#  '12h 40m',
#  '14h 20m',
#  '03h 10m',
#  '06h 40m',
#  '21h 35m',
# ...

# %%
stoppage=[]
for s in duration:
    stoppage.append(s.text.split("\n")[-1])
stoppage
# Out:
# ['non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  '1-stop',
#  '1-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
# ...

# %%
price=driver.find_elements_by_xpath("//div[@class='col-md-8 col-sm-8 col-xs-9 txt-r6-n ng-binding']")
price
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="a4e8f7ce91bb6ad9aa70050431d953f9", element="d8109121-75eb-410a-9608-ffae6ae61ba8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a4e8f7ce91bb6ad9aa70050431d953f9", element="f0bfd124-9b0b-402e-8522-4bf0fb96842c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a4e8f7ce91bb6ad9aa70050431d953f9", element="8d041eda-112d-407d-a7c8-3dee54e0e824")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a4e8f7ce91bb6ad9aa70050431d953f9", element="53b451a0-0261-4247-980c-b1cdcf670e31")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a4e8f7ce91bb6ad9aa70050431d953f9", element="d7237198-ea62-422f-856f-67b09c30a22e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a4e8f7ce91bb6ad9aa70050431d953f9", element="e4198dee-310e-4bbc-8182-80ea15a194b8")>,
# ...

# %%
prices=[]
for p in price:
    prices.append(p.text)
prices
# Out:
# ['5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,956',
#  '5,956',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,954',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,953',
#  '5,953',
#  '5,953',
#  '5,953',
#  '5,953',
#  '5,953',
#  '5,953',
#  '5,953',
#  '5,953',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,955',
#  '5,955',
#  '5,955',
#  '6,165',
#  '8,055',
#  '8,055',
#  '8,055',
#  '8,055',
#  '8,055',
#  '7,468',
#  '7,468',
#  '7,468',
#  '8,869',
#  '8,869',
#  '8,869',
# ...

# %%
import pandas as pd
df2=pd.DataFrame({})
df2['Departure Time']=departure_time
df2['Arrival Time']=arrival_time
df2['Source']=source
df2['Destination']=destination
df2['Duration']=durations
df2['Stoppage']=stoppage
df2['Flight Name']=flightname
df2['Price']=prices
df2
# Out:
#     Departure Time Arrival Time Source Destination Duration  Stoppage  \
# 0            18:55        21:05  Delhi      Mumbai  02h 10m  non-stop
# 1            07:20        09:35  Delhi      Mumbai  02h 15m  non-stop
# 2            06:20        08:40  Delhi      Mumbai  02h 20m  non-stop
# 3            19:45        22:05  Delhi      Mumbai  02h 20m  non-stop
# 4            07:00        09:10  Delhi      Mumbai  02h 10m  non-stop
# ..             ...          ...    ...         ...      ...       ...
# 202          18:40        14:45  Delhi      Mumbai  20h 05m    1-stop
# 203          11:10        14:45  Delhi      Mumbai  27h 35m    1-stop
# 204          12:00        13:15  Delhi      Mumbai  25h 15m    1-stop
# 205          12:45        13:35  Delhi      Mumbai  24h 50m    1-stop
# 206          10:35        16:45  Delhi      Mumbai  06h 10m    1-stop
#
#     Flight Name   Price
# 0      SpiceJet   5,955
# 1      SpiceJet   5,955
# 2      SpiceJet   5,955
# 3      SpiceJet   5,955
# ...

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 95.0.4638
# Get LATEST driver version for 95.0.4638
# Driver [C:\Users\monish\.wdm\drivers\chromedriver\win32\95.0.4638.17\chromedriver.exe] found in cache

# %%
url ="https://www.easemytrip.com/"
driver.get(url)

# %%
search=driver.find_element_by_xpath("//div[@class='s_col_v4 ripplen']")
search.click()

# %%
flight_name=driver.find_elements_by_xpath("//span[@class='txt-r4 ng-binding']")
flight_name
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="01f768a793c497f3b1ad05897ea605c4", element="c98e3dda-c2e6-4745-b584-318616a7fce2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="01f768a793c497f3b1ad05897ea605c4", element="ddaa7ce4-57b7-4990-8dfc-d8520e60a93a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="01f768a793c497f3b1ad05897ea605c4", element="b3d3f9e4-073f-4bd2-bb56-5d127bebb071")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="01f768a793c497f3b1ad05897ea605c4", element="36cba5db-750b-4338-89d9-3f15ac23f701")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="01f768a793c497f3b1ad05897ea605c4", element="03908ae4-f098-4ad0-aeeb-0252fccaffbc")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="01f768a793c497f3b1ad05897ea605c4", element="afc0459e-cf44-4c58-ae5f-5544d854e8f8")>,
# ...

# %%
flight=[]
for f in flight_name:
    flight.append(f.text)
flight
# Out:
# ['Indigo',
#  'Indigo',
#  'Indigo',
#  'Indigo',
#  'AirAsia',
#  'AirAsia',
#  'AirAsia',
#  'Vistara',
#  'Vistara',
#  'GO FIRST',
#  'GO FIRST',
#  'GO FIRST',
#  'GO FIRST',
#  'Air India',
#  'AirAsia',
#  'AirAsia',
#  'AirAsia',
#  'AirAsia',
#  'AirAsia',
#  'AirAsia',
#  'AirAsia',
#  'GO FIRST',
#  'GO FIRST',
#  'GO FIRST',
#  'GO FIRST',
#  'GO FIRST',
#  'GO FIRST',
#  'GO FIRST',
#  'GO FIRST',
#  'GO FIRST',
#  'GO FIRST',
#  'Indigo',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Indigo',
#  'Indigo',
#  'Vistara',
#  'Vistara',
#  'Indigo',
#  'Indigo',
#  'Vistara',
#  'Indigo',
#  'Indigo',
#  'Indigo',
#  'Indigo',
#  'Indigo',
#  'Indigo',
#  'AirAsia',
#  'Indigo',
#  'Indigo',
#  'Indigo',
#  'Indigo',
#  'Indigo',
#  'Vistara',
#  'GO FIRST',
#  'Indigo',
#  'Indigo',
#  'Indigo',
#  'Indigo',
#  'Indigo',
#  'Vistara',
#  'Indigo',
#  'Vistara',
#  'Air India',
#  'Air India',
#  'Indigo',
#  'Indigo',
#  'Indigo',
#  'Indigo',
#  'Air India',
# ...

# %%
departure=driver.find_elements_by_xpath("//div[@class='col-md-2 col-sm-2 col-xs-4 top5 ']")
departure
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="01f768a793c497f3b1ad05897ea605c4", element="86c4d107-a84b-4893-a942-0a6a715acd59")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="01f768a793c497f3b1ad05897ea605c4", element="c6d5c3a5-233d-4324-95ce-7dc359bad34e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="01f768a793c497f3b1ad05897ea605c4", element="e9fa374d-9c41-4be4-a037-43fd8c422a30")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="01f768a793c497f3b1ad05897ea605c4", element="cf9b0840-6795-4a33-a18a-1e8a7b12ff46")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="01f768a793c497f3b1ad05897ea605c4", element="ef14d189-bcb6-4edc-8d2e-d7c232eef35c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="01f768a793c497f3b1ad05897ea605c4", element="83e99803-5313-4076-ab40-bea386525a75")>,
# ...

# %%
departure_time=[]
for d in departure:
    departure_time.append(d.text.split("\n")[0])
departure_time
# Out:
# ['04:30',
#  '06:00',
#  '07:00',
#  '08:05',
#  '05:35',
#  '18:50',
#  '04:50',
#  '06:40',
#  '08:30',
#  '08:10',
#  '05:45',
#  '22:00',
#  '20:00',
#  '06:45',
#  '00:45',
#  '13:15',
#  '00:10',
#  '13:10',
#  '22:10',
#  '05:40',
#  '05:25',
#  '14:00',
#  '07:40',
#  '20:00',
#  '21:00',
#  '07:40',
#  '21:00',
#  '07:40',
#  '08:15',
#  '07:40',
#  '21:00',
#  '22:40',
#  '18:25',
#  '09:30',
#  '11:30',
#  '18:00',
#  '10:30',
#  '21:40',
#  '19:55',
#  '19:35',
#  '12:40',
#  '19:25',
#  '06:10',
#  '18:45',
#  '06:10',
#  '23:45',
#  '21:55',
#  '22:55',
#  '06:15',
#  '16:20',
#  '07:10',
#  '13:05',
#  '16:20',
#  '13:05',
#  '19:25',
#  '15:45',
#  '15:45',
#  '14:50',
#  '07:05',
#  '18:15',
#  '09:20',
#  '12:20',
#  '10:15',
#  '12:20',
#  '18:50',
#  '15:15',
#  '15:45',
#  '14:50',
#  '06:50',
#  '16:50',
#  '06:10',
#  '13:20',
#  '10:25',
#  '10:25',
#  '11:20',
#  '06:10',
#  '21:00',
#  '06:10',
#  '17:50',
#  '13:20',
#  '10:25',
#  '06:10',
#  '06:15',
# ...

# %%
source=[]
for s in departure:
    source.append(s.text.split("\n")[-1])
source
# Out:
# ['Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
# ...

# %%
arrival=driver.find_elements_by_xpath("//div[@class='col-md-2 col-sm-2 col-xs-3 top5']")
arrival
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="01f768a793c497f3b1ad05897ea605c4", element="e5f68fd7-d99a-4455-bc12-a27c115c92c6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="01f768a793c497f3b1ad05897ea605c4", element="e6632de1-eafe-482a-acf5-27d2492b3256")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="01f768a793c497f3b1ad05897ea605c4", element="d12c1656-8c29-440f-941c-0c830a2ab14a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="01f768a793c497f3b1ad05897ea605c4", element="8368ad2a-def7-4a5c-a951-821c1a1f3927")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="01f768a793c497f3b1ad05897ea605c4", element="c33ebfba-afe5-4fa3-a22e-a7c8d262a05c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="01f768a793c497f3b1ad05897ea605c4", element="25e36307-f424-4c50-95b9-f2347bff27f5")>,
# ...

# %%
arrival_time=[]
for a in arrival:
    arrival_time.append(a.text.split("\n")[0])
arrival_time
# Out:
# ['06:10',
#  '07:50',
#  '08:50',
#  '09:55',
#  '07:15',
#  '20:35',
#  '06:45',
#  '08:15',
#  '10:15',
#  '09:50',
#  '07:20',
#  '23:55',
#  '21:50',
#  '08:35',
#  '06:35',
#  '19:35',
#  '06:35',
#  '19:35',
#  '06:35',
#  '19:35',
#  '19:35',
#  '20:20',
#  '17:15',
#  '07:45',
#  '09:10',
#  '20:25',
#  '10:10',
#  '21:55',
#  '23:30',
#  '23:15',
#  '12:50',
#  '00:35',
#  '20:15',
#  '11:25',
#  '13:15',
#  '19:50',
#  '12:25',
#  '23:25',
#  '21:50',
#  '21:35',
#  '14:30',
#  '23:00',
#  '10:05',
#  '23:25',
#  '12:15',
#  '05:50',
#  '05:50',
#  '06:35',
#  '22:15',
#  '20:45',
#  '12:15',
#  '19:15',
#  '23:25',
#  '20:45',
#  '10:00',
#  '19:40',
#  '22:10',
#  '22:10',
#  '11:35',
#  '00:20',
#  '16:35',
#  '23:10',
#  '16:35',
#  '16:55',
#  '09:40',
#  '09:40',
#  '20:45',
#  '20:45',
#  '11:35',
#  '18:35',
#  '12:50',
#  '20:00',
#  '18:15',
#  '20:00',
#  '22:15',
#  '18:15',
#  '10:10',
#  '20:00',
#  '10:10',
#  '10:10',
#  '10:10',
#  '10:10',
#  '10:15',
# ...

# %%
destination=[]
for d in arrival:
    destination.append(d.text.split("\n")[-1])
destination
# Out:
# ['Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
# ...

# %%
duration=driver.find_elements_by_xpath("//div[@class='col-md-2 col-sm-2 col-xs-5 non-st']")
duration
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="01f768a793c497f3b1ad05897ea605c4", element="a2c67d07-9377-4d45-80ac-cc717e364acc")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="01f768a793c497f3b1ad05897ea605c4", element="6a3c9f9d-e953-4338-a2ea-92de143e44d9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="01f768a793c497f3b1ad05897ea605c4", element="c2089e85-0f61-4d47-9953-36db1010c63f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="01f768a793c497f3b1ad05897ea605c4", element="4a50234a-10bd-489a-ae71-befe3bdc27c0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="01f768a793c497f3b1ad05897ea605c4", element="aca2e6b8-95b4-4a1e-950d-5ed037feb9a8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="01f768a793c497f3b1ad05897ea605c4", element="b7e0870d-b07c-47c1-ae4d-b52ac25e9bdd")>,
# ...

# %%
durations=[]
for d in duration:
    durations.append(d.text.split("\n")[0])
durations
# Out:
# ['01h 40m',
#  '01h 50m',
#  '01h 50m',
#  '01h 50m',
#  '01h 40m',
#  '01h 45m',
#  '01h 55m',
#  '01h 35m',
#  '01h 45m',
#  '01h 40m',
#  '01h 35m',
#  '01h 55m',
#  '01h 50m',
#  '01h 50m',
#  '05h 50m',
#  '06h 20m',
#  '06h 25m',
#  '06h 25m',
#  '08h 25m',
#  '13h 55m',
#  '14h 10m',
#  '06h 20m',
#  '09h 35m',
#  '11h 45m',
#  '12h 10m',
#  '12h 45m',
#  '13h 10m',
#  '14h 15m',
#  '15h 15m',
#  '15h 35m',
#  '15h 50m',
#  '01h 55m',
#  '01h 50m',
#  '01h 55m',
#  '01h 45m',
#  '01h 50m',
#  '01h 55m',
#  '01h 45m',
#  '01h 55m',
#  '02h 00m',
#  '01h 50m',
#  '03h 35m',
#  '03h 55m',
#  '04h 40m',
#  '06h 05m',
#  '06h 05m',
#  '07h 55m',
#  '07h 40m',
#  '16h 00m',
#  '04h 25m',
#  '05h 05m',
#  '06h 10m',
#  '07h 05m',
#  '07h 40m',
#  '14h 35m',
#  '03h 55m',
#  '06h 25m',
#  '07h 20m',
#  '04h 30m',
#  '06h 05m',
#  '07h 15m',
#  '10h 50m',
#  '06h 20m',
#  '04h 35m',
#  '14h 50m',
#  '18h 25m',
#  '05h 00m',
#  '05h 55m',
#  '04h 45m',
#  '01h 45m',
#  '06h 40m',
# ...

# %%
stoppage=[]
for s in duration:
    stoppage.append(s.text.split("\n")[-1])
stoppage
# Out:
# ['non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  'non-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
# ...

# %%
price=driver.find_elements_by_xpath("//div[@class='col-md-8 col-sm-8 col-xs-9 txt-r6-n ng-binding']")
price
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="01f768a793c497f3b1ad05897ea605c4", element="e6575a18-a729-44ea-83a9-bd07a513e663")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="01f768a793c497f3b1ad05897ea605c4", element="248149dc-8497-48c1-ba61-17ed8fb06cd9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="01f768a793c497f3b1ad05897ea605c4", element="db77b13b-64bb-4790-851f-943223e3476d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="01f768a793c497f3b1ad05897ea605c4", element="b2b61d87-8698-4355-9fcb-a340597fe5af")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="01f768a793c497f3b1ad05897ea605c4", element="ecaadfaf-4486-453b-b0e2-b9b90c12879f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="01f768a793c497f3b1ad05897ea605c4", element="831f9aa0-d743-478c-b5df-73b80b1de055")>,
# ...

# %%
prices=[]
for p in price:
    prices.append(p.text)
prices
# Out:
# ['5,178',
#  '5,178',
#  '5,178',
#  '5,178',
#  '5,179',
#  '5,179',
#  '5,179',
#  '5,179',
#  '5,179',
#  '5,177',
#  '5,177',
#  '5,177',
#  '5,177',
#  '5,179',
#  '5,176',
#  '5,176',
#  '5,176',
#  '5,176',
#  '5,176',
#  '5,176',
#  '5,176',
#  '5,177',
#  '5,177',
#  '5,177',
#  '5,177',
#  '5,177',
#  '5,177',
#  '5,177',
#  '5,177',
#  '5,177',
#  '5,177',
#  '5,283',
#  '5,284',
#  '5,284',
#  '5,494',
#  '5,703',
#  '5,703',
#  '5,757',
#  '6,072',
#  '6,123',
#  '6,333',
#  '8,224',
#  '8,066',
#  '8,066',
#  '8,066',
#  '8,066',
#  '8,066',
#  '8,958',
#  '8,065',
#  '8,066',
#  '8,066',
#  '8,066',
#  '8,066',
#  '8,066',
#  '8,224',
#  '8,276',
#  '8,958',
#  '8,958',
#  '9,011',
#  '9,011',
#  '8,433',
#  '8,539',
#  '8,696',
#  '8,854',
#  '8,854',
#  '8,854',
#  '9,536',
#  '9,536',
#  '9,011',
#  '9,168',
#  '9,277',
#  '9,277',
#  '9,277',
#  '9,277',
#  '9,277',
#  '9,277',
#  '9,277',
#  '9,277',
#  '9,277',
#  '9,277',
#  '9,277',
#  '9,277',
#  '9,326',
# ...

# %%
import pandas as pd
df3=pd.DataFrame({})
df3['Departure Time']=departure_time
df3['Arrival Time']=arrival_time
df3['Source']=source
df3['Destination']=destination
df3['Duration']=durations
df3['Stoppage']=stoppage
df3['Flight Name']=flight
df3['Price']=prices
df3
# Out:
#     Departure Time Arrival Time     Source Destination Duration  Stoppage  \
# 0            04:30        06:10  Bangalore      Mumbai  01h 40m  non-stop
# 1            06:00        07:50  Bangalore      Mumbai  01h 50m  non-stop
# 2            07:00        08:50  Bangalore      Mumbai  01h 50m  non-stop
# 3            08:05        09:55  Bangalore      Mumbai  01h 50m  non-stop
# 4            05:35        07:15  Bangalore      Mumbai  01h 40m  non-stop
# ..             ...          ...        ...         ...      ...       ...
# 163          07:00        09:00  Bangalore      Mumbai  26h 00m    1-stop
# 164          11:30        09:00  Bangalore      Mumbai  21h 30m    1-stop
# 165          09:45        09:00  Bangalore      Mumbai  23h 15m    1-stop
# 166          08:00        09:00  Bangalore      Mumbai  25h 00m    1-stop
# 167          10:15        21:35  Bangalore      Mumbai  11h 20m    1-stop
#
#     Flight Name   Price
# 0        Indigo   5,178
# 1        Indigo   5,178
# ...

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 95.0.4638
# Get LATEST driver version for 95.0.4638
# Driver [C:\Users\monish\.wdm\drivers\chromedriver\win32\95.0.4638.17\chromedriver.exe] found in cache

# %%
url ="https://www.yatra.com"
driver.get(url)

# %%
search=driver.find_element_by_xpath("//*[@id='BE_flight_flsearch_btn']")
search.click()

# %%
dept_time=driver.find_elements_by_xpath("//div[@class='i-b pr']")
dept_time
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="f9fb454c6e0665998257b2ff02976f42", element="47175e3a-fd18-4371-9988-bde1f59c9f27")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f9fb454c6e0665998257b2ff02976f42", element="10486ef8-94f6-42be-a767-9fefb4869ee3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f9fb454c6e0665998257b2ff02976f42", element="28dd2585-35f9-42fc-8b40-f2d49d86fc0c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f9fb454c6e0665998257b2ff02976f42", element="04d29c57-c5c1-4178-b5a3-07524cf07040")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f9fb454c6e0665998257b2ff02976f42", element="7f0fe014-37f5-4b1b-9c7b-143c4669eefd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f9fb454c6e0665998257b2ff02976f42", element="7cd66fdb-a434-4212-ac2c-616048d82602")>,
# ...

# %%
departure_time=[]
for d in dept_time:
    departure_time.append(d.text)
departure_time
# Out:
# ['15:20',
#  '11:30',
#  '16:20',
#  '11:15',
#  '15:30',
#  '07:30',
#  '14:05',
#  '05:40',
#  '05:30',
#  '13:25',
#  '10:15',
#  '11:30',
#  '16:55',
#  '13:35',
#  '11:25',
#  '02:35',
#  '13:05',
#  '22:55',
#  '21:20',
#  '22:55',
#  '22:55',
#  '02:35',
#  '06:05',
#  '09:05',
#  '07:00',
#  '06:00',
#  '21:00',
#  '19:10',
#  '17:30',
#  '16:00',
#  '19:20',
#  '06:20',
#  '05:45',
#  '19:05',
#  '06:00',
#  '07:00',
#  '07:30',
#  '14:40',
#  '06:30',
#  '06:00',
#  '11:55',
#  '10:25',
#  '08:45',
#  '07:30',
#  '06:30',
#  '06:00',
#  '22:45',
#  '21:55',
#  '20:55',
#  '19:45',
#  '18:30',
#  '17:30',
#  '22:45',
#  '21:55',
#  '20:55',
#  '19:45',
#  '18:30',
#  '17:30',
#  '15:45',
#  '19:20',
#  '06:20',
#  '06:20',
#  '06:20',
#  '06:20',
#  '08:00',
#  '07:00',
#  '23:45',
#  '22:40',
#  '21:15',
#  '19:20',
#  '12:15',
#  '19:20',
#  '06:20',
#  '06:20',
#  '06:20',
#  '12:15',
#  '21:30',
#  '07:20',
#  '07:20',
#  '16:00',
#  '19:00',
#  '16:00']

# %%
arr_time=driver.find_elements_by_xpath("//p[@class='bold fs-15 mb-2 pr time']")
arr_time
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="f9fb454c6e0665998257b2ff02976f42", element="9c113bcf-2382-4cea-b0da-c5a53f219127")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f9fb454c6e0665998257b2ff02976f42", element="eb5a4872-70f0-42cd-ac77-a69aa7958341")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f9fb454c6e0665998257b2ff02976f42", element="de86ab4e-38b5-47a0-9394-90c34c2fbc7d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f9fb454c6e0665998257b2ff02976f42", element="47e84394-545d-48b9-974e-06dfc7c4e8da")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f9fb454c6e0665998257b2ff02976f42", element="95b317e8-98db-4f8a-8edb-8d37d832ce84")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f9fb454c6e0665998257b2ff02976f42", element="f94f5ff6-c821-4f88-94bf-ea120a14048d")>,
# ...

# %%
arrival_time=[]
for a in arr_time:
    arrival_time.append(a.text)
arrival_time
# Out:
# ['16:30',
#  '12:45',
#  '17:45',
#  '12:50',
#  '17:05',
#  '08:40',
#  '15:15',
#  '06:55',
#  '06:50',
#  '14:45',
#  '11:20',
#  '12:35',
#  '18:00',
#  '14:55',
#  '12:45',
#  '07:00',
#  '19:35',
#  '07:50\n+ 1 day',
#  '07:00\n+ 1 day',
#  '14:55\n+ 1 day',
#  '15:25\n+ 1 day',
#  '19:35',
#  '17:10',
#  '13:50',
#  '13:50',
#  '13:50',
#  '13:50\n+ 1 day',
#  '13:50\n+ 1 day',
#  '13:50\n+ 1 day',
#  '13:50\n+ 1 day',
#  '13:50\n+ 1 day',
#  '13:50\n+ 1 day',
#  '10:15\n+ 1 day',
#  '20:30',
#  '13:30',
#  '13:15',
#  '13:50',
#  '21:20',
#  '13:50',
#  '13:50',
#  '21:20',
#  '21:20',
#  '21:20',
#  '21:20',
#  '21:20',
#  '21:20',
#  '21:20\n+ 1 day',
#  '21:20\n+ 1 day',
#  '21:20\n+ 1 day',
#  '21:20\n+ 1 day',
#  '21:20\n+ 1 day',
#  '21:20\n+ 1 day',
#  '13:50\n+ 1 day',
#  '13:50\n+ 1 day',
#  '13:50\n+ 1 day',
#  '13:50\n+ 1 day',
#  '13:50\n+ 1 day',
#  '13:50\n+ 1 day',
#  '13:50\n+ 1 day',
#  '21:20\n+ 1 day',
#  '21:20\n+ 1 day',
#  '21:20\n+ 1 day',
# ...

# %%
durr=driver.find_elements_by_xpath("//p[@class='fs-12 bold du mb-2']")
durr
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="f9fb454c6e0665998257b2ff02976f42", element="a8c22951-9c38-4e43-98f1-eed4cb752fff")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f9fb454c6e0665998257b2ff02976f42", element="94d1c56d-5188-4ef8-b188-dcc4c180de03")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f9fb454c6e0665998257b2ff02976f42", element="448b9ccd-c49a-4a9c-bf51-704f8d02aabd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f9fb454c6e0665998257b2ff02976f42", element="86089fea-891b-4eab-bf90-3b4eab1db838")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f9fb454c6e0665998257b2ff02976f42", element="84bbd003-4e81-4966-8f9e-c317b6f09f9c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f9fb454c6e0665998257b2ff02976f42", element="8de2f9c3-dc2c-402d-b9f1-a9c04dd387af")>,
# ...

# %%
duration=[]
for r in durr:
    duration.append(r.text)
duration
# Out:
# ['1h 10m',
#  '1h 15m',
#  '1h 25m',
#  '1h 35m',
#  '1h 35m',
#  '1h 10m',
#  '1h 10m',
#  '1h 15m',
#  '1h 20m',
#  '1h 20m',
#  '1h 05m',
#  '1h 05m',
#  '1h 05m',
#  '1h 20m',
#  '1h 20m',
#  '4h 25m',
#  '6h 30m',
#  '8h 55m',
#  '9h 40m',
#  '16h 00m',
#  '16h 30m',
#  '17h 00m',
#  '11h 05m',
#  '4h 45m',
#  '6h 50m',
#  '7h 50m',
#  '16h 50m',
#  '18h 40m',
#  '20h 20m',
#  '21h 50m',
#  '18h 30m',
#  '31h 30m',
#  '28h 30m',
#  '1h 25m',
#  '7h 30m',
#  '6h 15m',
#  '6h 20m',
#  '6h 40m',
#  '7h 20m',
#  '7h 50m',
#  '9h 25m',
#  '10h 55m',
#  '12h 35m',
#  '13h 50m',
#  '14h 50m',
#  '15h 20m',
#  '22h 35m',
#  '23h 25m',
#  '24h 25m',
#  '25h 35m',
#  '26h 50m',
#  '27h 50m',
#  '15h 05m',
#  '15h 55m',
#  '16h 55m',
#  '18h 05m',
#  '19h 20m',
#  '20h 20m',
#  '22h 05m',
#  '26h 00m',
#  '39h 00m',
#  '39h 00m',
#  '39h 00m',
#  '15h 00m',
#  '26h 15m',
#  '27h 15m',
#  '13h 45m',
#  '14h 50m',
#  '16h 15m',
#  '26h 00m',
#  '9h 05m',
#  '18h 30m',
#  '31h 30m',
# ...

# %%
stops=driver.find_elements_by_xpath("//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']")
stops
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="f9fb454c6e0665998257b2ff02976f42", element="c020ff50-ddbc-4a07-8cf4-3453f4f81142")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f9fb454c6e0665998257b2ff02976f42", element="4aef3793-5675-4faf-9fbb-f675350234f9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f9fb454c6e0665998257b2ff02976f42", element="4a70b062-7904-4940-8e5a-33d4d6bbc676")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f9fb454c6e0665998257b2ff02976f42", element="7621d348-95e3-4421-aaf7-c260e038e801")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f9fb454c6e0665998257b2ff02976f42", element="23f16353-c0b2-4514-a196-95e5dca14420")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f9fb454c6e0665998257b2ff02976f42", element="b2b78723-06b8-4efd-94fa-e38130d1c1ef")>,
# ...

# %%
stoppage=[]
for s in stops:
    stoppage.append(s.text)
stoppage
# Out:
# ['Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '3 Stop(s)',
#  '3 Stop(s)',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '2 Stop(s)',
# ...

# %%
flight=driver.find_elements_by_xpath("//span[@class='i-b text ellipsis']")
flight
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="f9fb454c6e0665998257b2ff02976f42", element="4b5adfbf-53d1-4eb5-aa59-516ea3fb9bde")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f9fb454c6e0665998257b2ff02976f42", element="67b981de-ea95-47ac-a5dc-0a0f7bcc1e2e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f9fb454c6e0665998257b2ff02976f42", element="8107f918-fd96-49c0-94ab-5eb3c3f4a2af")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f9fb454c6e0665998257b2ff02976f42", element="844cdce4-6b3d-4b93-ae17-1832506908d2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f9fb454c6e0665998257b2ff02976f42", element="1b4ffccb-4908-4aed-b329-565b30224a16")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f9fb454c6e0665998257b2ff02976f42", element="396aad59-93e1-47cc-aea6-e556e83345c3")>,
# ...

# %%
flight_name=[]
for f in flight:
    flight_name.append(f.text)
flight_name
# Out:
# ['Go First',
#  'Go First',
#  'Go First',
#  'SpiceJet',
#  'SpiceJet',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Air India',
#  'Air India',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Vistara',
#  'Vistara',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Go First',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Air India',
#  'Air India',
#  'Go First',
#  'Air India',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Air India',
#  'Air India',
#  'Go First',
#  'Go First',
#  'Go First',
# ...

# %%
prices=driver.find_elements_by_xpath("//div[@class='i-b tipsy fare-summary-tooltip fs-18']")
prices
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="f9fb454c6e0665998257b2ff02976f42", element="cae30612-0ef7-43fa-a6f2-5656434ca7d0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f9fb454c6e0665998257b2ff02976f42", element="fa595ac4-b433-412e-b213-2db2a1538fae")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f9fb454c6e0665998257b2ff02976f42", element="e863b7d8-d8b6-47b0-8f9d-954fde79c441")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f9fb454c6e0665998257b2ff02976f42", element="c50c25ff-b122-46a5-afe9-b4f84816f01d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f9fb454c6e0665998257b2ff02976f42", element="5501d995-3c21-41b6-89da-56811dc61a65")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f9fb454c6e0665998257b2ff02976f42", element="8c865cf5-5897-486a-9524-0cc89c1c1513")>,
# ...

# %%
price=[]
for p in prices:
    price.append(p.text)
price
# Out:
# ['4,262',
#  '4,262',
#  '4,262',
#  '4,262',
#  '4,262',
#  '4,263',
#  '4,263',
#  '4,263',
#  '4,263',
#  '4,263',
#  '4,368',
#  '4,368',
#  '4,368',
#  '4,998',
#  '5,471',
#  '8,857',
#  '8,857',
#  '8,857',
#  '8,857',
#  '8,857',
#  '8,857',
#  '8,857',
#  '8,883',
#  '9,041',
#  '9,041',
#  '9,041',
#  '9,723',
#  '9,723',
#  '9,723',
#  '9,723',
#  '10,813',
#  '10,813',
#  '11,561',
#  '11,928',
#  '12,847',
#  '12,978',
#  '12,978',
#  '12,978',
#  '12,978',
#  '12,978',
#  '12,978',
#  '12,978',
#  '12,978',
#  '12,978',
#  '12,978',
#  '12,978',
#  '12,978',
#  '12,978',
#  '12,978',
#  '12,978',
#  '12,978',
#  '12,978',
#  '13,818',
#  '13,818',
#  '13,818',
#  '13,818',
#  '13,818',
#  '13,818',
#  '13,818',
#  '14,398',
#  '14,398',
#  '14,398',
#  '14,398',
#  '14,566',
#  '14,882',
#  '14,882',
#  '14,999',
#  '14,999',
#  '14,999',
#  '15,070',
#  '15,329',
#  '15,658',
#  '15,658',
#  '15,658',
#  '15,658',
#  '15,864',
#  '22,008',
#  '22,665',
#  '22,665',
# ...

# %%
source_=driver.find_elements_by_xpath("//p[@class='fs-10 font-lightgrey no-wrap city ellipsis']")
source_
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="f9fb454c6e0665998257b2ff02976f42", element="f4c5591e-7c8f-41d9-b0e3-f50c76f4482a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f9fb454c6e0665998257b2ff02976f42", element="4f4962d5-f50a-4318-afa4-e63edeff42bd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f9fb454c6e0665998257b2ff02976f42", element="e6a812f2-6e6c-43ca-a39c-6d73e8b76138")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f9fb454c6e0665998257b2ff02976f42", element="b94d0d3f-4617-4607-ac2f-596ff97b6714")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f9fb454c6e0665998257b2ff02976f42", element="bf723369-9c9e-41c2-a921-d1297a63e5a2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f9fb454c6e0665998257b2ff02976f42", element="14511fcf-1772-45ae-9d0c-05f95443f1bb")>,
# ...

# %%
source=[]
for s in source_:
    source.append(s.text)
source
# Out:
# ['Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
# ...

# %%
destination=[]
for d in range(1,len(source),2):
    destination.append(source[d])
destination
# Out:
# ['Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa']

# %%
source1=[]
for s in range(0,len(source),2):
    source1.append(source[s])
source1
# Out:
# ['Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
# ...

# %%
import pandas as pd
df4=pd.DataFrame({})
df4['Departure Time']=departure_time
df4['Arrival Time']=arrival_time
df4['Source']=source1
df4['Destination']=destination
df4['Duration']=duration
df4['Stoppage']=stoppage
df4['Flight Name']=flight_name
df4['Price']=price
df4
# Out:
#    Departure Time    Arrival Time  Source Destination Duration   Stoppage  \
# 0           15:20           16:30  Mumbai         Goa   1h 10m   Non Stop
# 1           11:30           12:45  Mumbai         Goa   1h 15m   Non Stop
# 2           16:20           17:45  Mumbai         Goa   1h 25m   Non Stop
# 3           11:15           12:50  Mumbai         Goa   1h 35m   Non Stop
# 4           15:30           17:05  Mumbai         Goa   1h 35m   Non Stop
# ..            ...             ...     ...         ...      ...        ...
# 77          07:20           14:55  Mumbai         Goa   7h 35m     1 Stop
# 78          07:20           15:25  Mumbai         Goa   8h 05m     1 Stop
# 79          16:00  10:15\n+ 1 day  Mumbai         Goa  18h 15m  3 Stop(s)
# 80          19:00  13:15\n+ 1 day  Mumbai         Goa  18h 15m     1 Stop
# 81          16:00  13:15\n+ 1 day  Mumbai         Goa  21h 15m     1 Stop
#
#    Flight Name   Price
# 0     Go First   4,262
# 1     Go First   4,262
# ...

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 95.0.4638
# Get LATEST driver version for 95.0.4638
# Driver [C:\Users\monish\.wdm\drivers\chromedriver\win32\95.0.4638.17\chromedriver.exe] found in cache

# %%
url ="https://www.yatra.com"
driver.get(url)

# %%
search=driver.find_element_by_xpath("//*[@id='BE_flight_flsearch_btn']")
search.click()

# %%
dept_time=driver.find_elements_by_xpath("//div[@class='i-b pr']")
dept_time
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="e0f7af7f7c8349040f3e0099275ae1a9", element="49b7b832-231b-4f39-a315-d212de3f779d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e0f7af7f7c8349040f3e0099275ae1a9", element="b6786bbf-aeb3-4f39-936f-3fda5c10adb5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e0f7af7f7c8349040f3e0099275ae1a9", element="f893946b-0b5f-4950-9d18-708c5767acbe")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e0f7af7f7c8349040f3e0099275ae1a9", element="7e85245f-30f2-4464-8b08-65b683e789df")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e0f7af7f7c8349040f3e0099275ae1a9", element="036733d6-61dc-4ecb-943b-d597c316bf65")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e0f7af7f7c8349040f3e0099275ae1a9", element="67715f9a-8de5-43d3-8555-e8a9b3d613c8")>,
# ...

# %%
departure_time=[]
for d in dept_time:
    departure_time.append(d.text)
departure_time
# Out:
# ['23:30',
#  '22:35',
#  '18:25',
#  '06:15',
#  '09:10',
#  '08:30',
#  '21:10',
#  '23:30',
#  '22:35',
#  '14:20',
#  '14:20',
#  '12:30',
#  '09:45',
#  '20:30',
#  '07:00',
#  '12:30',
#  '09:45',
#  '07:00',
#  '20:30',
#  '10:50',
#  '10:50',
#  '10:50',
#  '10:50',
#  '21:05',
#  '21:05']

# %%
arr_time=driver.find_elements_by_xpath("//p[@class='bold fs-15 mb-2 pr time']")
arr_time
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="e0f7af7f7c8349040f3e0099275ae1a9", element="1a215ce7-7cbc-47f8-bbf1-df63faab953a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e0f7af7f7c8349040f3e0099275ae1a9", element="40856fa0-7dad-445d-9edc-99b7227425b4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e0f7af7f7c8349040f3e0099275ae1a9", element="789bb785-7cd2-4c92-a6c7-a343cb34497d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e0f7af7f7c8349040f3e0099275ae1a9", element="ac5f5b69-831d-4b85-9759-6bf4b5007f72")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e0f7af7f7c8349040f3e0099275ae1a9", element="d5ee766e-e1c2-49da-b9b9-a85d0bba5a05")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e0f7af7f7c8349040f3e0099275ae1a9", element="132afbcb-06af-442a-9da5-0b06197eb244")>,
# ...

# %%
arrival_time=[]
for a in arr_time:
    arrival_time.append(a.text)
arrival_time
# Out:
# ['06:35\n+ 1 day',
#  '06:35\n+ 1 day',
#  '19:30',
#  '18:10',
#  '19:35',
#  '22:20',
#  '07:30',
#  '20:55',
#  '13:10',
#  '17:05',
#  '10:20',
#  '09:50',
#  '22:35',
#  '11:05',
#  '23:55',
#  '07:45',
#  '08:45\n+ 1 day',
#  '08:45\n+ 1 day',
#  '20:05',
#  '21:30',
#  '22:50',
#  '01:00\n+ 1 day',
#  '17:50',
#  '21:30',
#  '14:15']

# %%
durr=driver.find_elements_by_xpath("//p[@class='fs-12 bold du mb-2']")
durr
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="e0f7af7f7c8349040f3e0099275ae1a9", element="cb183abd-c1b0-47f1-9c4a-f86c7cbfefee")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e0f7af7f7c8349040f3e0099275ae1a9", element="299d313a-b3b7-4b62-9a8f-7fa1c1d8dafa")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e0f7af7f7c8349040f3e0099275ae1a9", element="d768547b-30b2-4e2d-86f3-b8a04e760ce9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e0f7af7f7c8349040f3e0099275ae1a9", element="8fb21d5f-8c95-4d8e-aad1-33c330f9f74b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e0f7af7f7c8349040f3e0099275ae1a9", element="252aa0d6-7b29-4e25-9c3d-305b620e5f36")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e0f7af7f7c8349040f3e0099275ae1a9", element="1d4f4d95-26a1-4ef2-899e-3b1aea7fa4a2")>,
# ...

# %%
duration=[]
for r in durr:
    duration.append(r.text)
duration
# Out:
# ['7h 05m',
#  '8h 00m',
#  '1h 00m',
#  '1h 05m',
#  '1h 10m',
#  '1h 10m',
#  '1h 15m',
#  '1h 15m',
#  '1h 20m',
#  '1h 20m',
#  '1h 10m',
#  '1h 20m',
#  '1h 25m',
#  '1h 10m',
#  '1h 10m',
#  '1h 10m',
#  '9h 15m',
#  '10h 10m',
#  '3h 35m',
#  '3h 55m',
#  '4h 10m',
#  '4h 10m',
#  '4h 45m',
#  '5h 00m',
#  '5h 15m']

# %%
stops=driver.find_elements_by_xpath("//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']")
stops
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="e0f7af7f7c8349040f3e0099275ae1a9", element="62a14d20-d0f8-4487-9680-4611f792e9da")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e0f7af7f7c8349040f3e0099275ae1a9", element="8e5ed698-189b-4bdc-93f2-399acdecb268")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e0f7af7f7c8349040f3e0099275ae1a9", element="2edc61f4-a021-4598-830c-648a5a2ae929")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e0f7af7f7c8349040f3e0099275ae1a9", element="a68ea41a-e695-4a9a-83da-687eea0fac67")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e0f7af7f7c8349040f3e0099275ae1a9", element="bba4bbe8-fad3-4e6b-9a47-c55caaea7254")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e0f7af7f7c8349040f3e0099275ae1a9", element="d37c93d2-2c04-415c-910a-40464b5dc3f2")>,
# ...

# %%
stoppage=[]
for s in stops:
    stoppage.append(s.text)
stoppage
# Out:
# ['1 Stop',
#  '1 Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop']

# %%
flight=driver.find_elements_by_xpath("//span[@class='i-b text ellipsis']")
flight
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="e0f7af7f7c8349040f3e0099275ae1a9", element="e04f2965-0bb1-46e9-857f-7e98f3417ac2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e0f7af7f7c8349040f3e0099275ae1a9", element="ffbfc847-72c9-4694-958c-65af1bbbafdd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e0f7af7f7c8349040f3e0099275ae1a9", element="af2e1d12-b2bc-42b2-994c-b416a46408e9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e0f7af7f7c8349040f3e0099275ae1a9", element="ac88d04c-874d-45a9-a8c9-4ccb4e860b1d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e0f7af7f7c8349040f3e0099275ae1a9", element="5811e96a-c11b-40e3-9a9d-55e842079571")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e0f7af7f7c8349040f3e0099275ae1a9", element="13c4f354-f86c-45e6-927e-b81b3d7823bf")>,
# ...

# %%
flight_name=[]
for f in flight:
    flight_name.append(f.text)
flight_name
# Out:
# ['Air Asia',
#  'Air Asia',
#  'IndiGo',
#  'IndiGo',
#  'SpiceJet',
#  'IndiGo',
#  'SpiceJet',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Air Asia',
#  'Air India',
#  'Air Asia',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Air Asia',
#  'Air Asia',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo']

# %%
prices=driver.find_elements_by_xpath("//div[@class='i-b tipsy fare-summary-tooltip fs-18']")
prices
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="e0f7af7f7c8349040f3e0099275ae1a9", element="e81e286e-ce1f-4d4a-9a04-3c21e586b980")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e0f7af7f7c8349040f3e0099275ae1a9", element="e6a33c44-85b1-4cbf-ab1d-aad701432409")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e0f7af7f7c8349040f3e0099275ae1a9", element="d73a6cbb-0c03-4893-bc9a-0721cdcf4378")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e0f7af7f7c8349040f3e0099275ae1a9", element="cb911e61-29bc-4245-b85d-1193a2028fc1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e0f7af7f7c8349040f3e0099275ae1a9", element="3d3371ed-9a19-484d-89ef-cd7db2c74dfe")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e0f7af7f7c8349040f3e0099275ae1a9", element="716f2439-07a5-4f1f-a7b3-184a19239897")>,
# ...

# %%
price=[]
for p in prices:
    price.append(p.text)
price
# Out:
# ['4,200',
#  '4,200',
#  '4,202',
#  '4,202',
#  '4,202',
#  '4,202',
#  '4,202',
#  '4,202',
#  '4,202',
#  '4,202',
#  '4,203',
#  '4,203',
#  '4,203',
#  '4,307',
#  '4,307',
#  '5,252',
#  '6,052',
#  '6,052',
#  '7,142',
#  '7,142',
#  '7,142',
#  '7,142',
#  '7,142',
#  '7,142',
#  '7,142']

# %%
source_=driver.find_elements_by_xpath("//p[@class='fs-10 font-lightgrey no-wrap city ellipsis']")
source_
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="e0f7af7f7c8349040f3e0099275ae1a9", element="4637130c-98d3-496e-a348-dbefc900c28e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e0f7af7f7c8349040f3e0099275ae1a9", element="e984b9a6-8211-4fc6-82ab-901f168fb745")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e0f7af7f7c8349040f3e0099275ae1a9", element="50b77e4c-5211-47dc-af4b-b3c70a9a0325")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e0f7af7f7c8349040f3e0099275ae1a9", element="361b8a45-8f7b-4937-861b-242cfc1f0374")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e0f7af7f7c8349040f3e0099275ae1a9", element="edd43ef6-944f-4880-9fac-892cfb8c37ed")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e0f7af7f7c8349040f3e0099275ae1a9", element="ef6375a9-bd37-4bc0-aea8-cc3982b1735b")>,
# ...

# %%
source=[]
for s in source_:
    source.append(s.text)
source
# Out:
# ['Chennai',
#  'Hyderabad',
#  'Chennai',
#  'Hyderabad',
#  'Chennai',
#  'Hyderabad',
#  'Chennai',
#  'Hyderabad',
#  'Chennai',
#  'Hyderabad',
#  'Chennai',
#  'Hyderabad',
#  'Chennai',
#  'Hyderabad',
#  'Chennai',
#  'Hyderabad',
#  'Chennai',
#  'Hyderabad',
#  'Chennai',
#  'Hyderabad',
#  'Chennai',
#  'Hyderabad',
#  'Chennai',
#  'Hyderabad',
#  'Chennai',
#  'Hyderabad',
#  'Chennai',
#  'Hyderabad',
#  'Chennai',
#  'Hyderabad',
#  'Chennai',
#  'Hyderabad',
#  'Chennai',
#  'Hyderabad',
#  'Chennai',
#  'Hyderabad',
#  'Chennai',
#  'Hyderabad',
#  'Chennai',
#  'Hyderabad',
#  'Chennai',
#  'Hyderabad',
#  'Chennai',
#  'Hyderabad',
#  'Chennai',
#  'Hyderabad',
#  'Chennai',
#  'Hyderabad',
#  'Chennai',
#  'Hyderabad']

# %%
destination=[]
for d in range(1,len(source),2):
    destination.append(source[d])
destination
# Out:
# ['Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad']

# %%
source1=[]
for s in range(0,len(source),2):
    source1.append(source[s])
source1
# Out:
# ['Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai']

# %%
import pandas as pd
df5=pd.DataFrame({})
df5['Departure Time']=departure_time
df5['Arrival Time']=arrival_time
df5['Source']=source1
df5['Destination']=destination
df5['Duration']=duration
df5['Stoppage']=stoppage
df5['Flight Name']=flight_name
df5['Price']=price
df5
# Out:
#    Departure Time    Arrival Time   Source Destination Duration  Stoppage  \
# 0           23:30  06:35\n+ 1 day  Chennai   Hyderabad   7h 05m    1 Stop
# 1           22:35  06:35\n+ 1 day  Chennai   Hyderabad   8h 00m    1 Stop
# 2           18:25           19:30  Chennai   Hyderabad   1h 00m  Non Stop
# 3           06:15           18:10  Chennai   Hyderabad   1h 05m  Non Stop
# 4           09:10           19:35  Chennai   Hyderabad   1h 10m  Non Stop
# 5           08:30           22:20  Chennai   Hyderabad   1h 10m  Non Stop
# 6           21:10           07:30  Chennai   Hyderabad   1h 15m  Non Stop
# 7           23:30           20:55  Chennai   Hyderabad   1h 15m  Non Stop
# 8           22:35           13:10  Chennai   Hyderabad   1h 20m  Non Stop
# 9           14:20           17:05  Chennai   Hyderabad   1h 20m  Non Stop
# 10          14:20           10:20  Chennai   Hyderabad   1h 10m  Non Stop
# 11          12:30           09:50  Chennai   Hyderabad   1h 20m  Non Stop
# ...

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 95.0.4638
# Get LATEST driver version for 95.0.4638
# Driver [C:\Users\monish\.wdm\drivers\chromedriver\win32\95.0.4638.17\chromedriver.exe] found in cache

# %%
url ="https://www.yatra.com"
driver.get(url)

# %%
search=driver.find_element_by_xpath("//*[@id='BE_flight_flsearch_btn']")
search.click()

# %%
dept_time=driver.find_elements_by_xpath("//div[@class='i-b pr']")
dept_time
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="18845b55f37c26c15577f3faade6e9f1", element="870c7553-42f2-43c1-9672-fe1308be4c3f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="18845b55f37c26c15577f3faade6e9f1", element="fd54354d-c3ba-4408-b278-117cd62e6cd4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="18845b55f37c26c15577f3faade6e9f1", element="0ecb5467-4571-47f4-bc52-82385b028608")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="18845b55f37c26c15577f3faade6e9f1", element="a02172d2-bb94-4669-bb5d-a4db65ed06f7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="18845b55f37c26c15577f3faade6e9f1", element="da0c413d-9106-4926-b18c-4b18bf489d69")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="18845b55f37c26c15577f3faade6e9f1", element="957d293f-8728-4679-821b-3adada088edb")>,
# ...

# %%
departure_time=[]
for d in dept_time:
    departure_time.append(d.text)
departure_time
# Out:
# ['06:00',
#  '14:30',
#  '16:00',
#  '06:15',
#  '08:20',
#  '15:30',
#  '07:25',
#  '16:20',
#  '12:45',
#  '17:45',
#  '07:20',
#  '04:15',
#  '06:40',
#  '14:20',
#  '15:30',
#  '06:10',
#  '10:00',
#  '05:15',
#  '22:50',
#  '02:30',
#  '12:00',
#  '08:40',
#  '04:15',
#  '12:45',
#  '21:25',
#  '08:35',
#  '10:45',
#  '07:15',
#  '23:05',
#  '12:00',
#  '04:55',
#  '20:00',
#  '16:05',
#  '15:25',
#  '06:00',
#  '22:30',
#  '10:30',
#  '21:25',
#  '21:00',
#  '20:45',
#  '09:35',
#  '08:00',
#  '19:40',
#  '09:35',
#  '07:00',
#  '18:35',
#  '09:35',
#  '08:00',
#  '18:05',
#  '08:00',
#  '15:00',
#  '14:20',
#  '19:30',
#  '06:00',
#  '12:00',
#  '17:20',
#  '09:30',
#  '21:15',
#  '20:00',
#  '19:00',
#  '17:50',
#  '15:05',
#  '07:15',
#  '06:30',
#  '04:45',
#  '08:40',
#  '08:40',
#  '05:55',
#  '10:40',
#  '08:00',
#  '07:00',
#  '11:55',
#  '06:05',
#  '07:05',
#  '21:15',
#  '18:30']

# %%
arr_time=driver.find_elements_by_xpath("//p[@class='bold fs-15 mb-2 pr time']")
arr_time
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="18845b55f37c26c15577f3faade6e9f1", element="0a4fb729-8e22-4abd-9339-d82601c96f56")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="18845b55f37c26c15577f3faade6e9f1", element="eb3ffb51-cdff-440e-be56-d07b0b8be8ea")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="18845b55f37c26c15577f3faade6e9f1", element="4b759e9e-f56b-402f-b0de-2afbac3b0d48")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="18845b55f37c26c15577f3faade6e9f1", element="e36f3943-930f-4410-81ec-14f0c1e5bdbe")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="18845b55f37c26c15577f3faade6e9f1", element="46a44f7a-87ab-4ccc-b7c9-7896b5d3cbae")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="18845b55f37c26c15577f3faade6e9f1", element="6525703b-7818-41cc-b819-b0d5529cd049")>,
# ...

# %%
arrival_time=[]
for a in arr_time:
    arrival_time.append(a.text)
arrival_time
# Out:
# ['09:05',
#  '17:40',
#  '19:10',
#  '09:30',
#  '13:35',
#  '20:50',
#  '13:10',
#  '22:10',
#  '18:40',
#  '23:40',
#  '13:35',
#  '10:55',
#  '13:20',
#  '21:05',
#  '22:35',
#  '13:35',
#  '17:45',
#  '13:20',
#  '07:00\n+ 1 day',
#  '10:55',
#  '20:50',
#  '17:45',
#  '13:35',
#  '22:10',
#  '07:00\n+ 1 day',
#  '18:40',
#  '21:05',
#  '17:45',
#  '09:35\n+ 1 day',
#  '22:35',
#  '08:05',
#  '23:10',
#  '22:20',
#  '22:20',
#  '13:15',
#  '07:10\n+ 1 day',
#  '19:25',
#  '07:00\n+ 1 day',
#  '07:10\n+ 1 day',
#  '07:00\n+ 1 day',
#  '20:55',
#  '19:25',
#  '07:10\n+ 1 day',
#  '21:55',
#  '19:25',
#  '07:00\n+ 1 day',
#  '22:20',
#  '20:55',
#  '07:10\n+ 1 day',
#  '21:55',
#  '07:10\n+ 1 day',
#  '19:25',
#  '22:45',
#  '17:50',
#  '21:05',
#  '11:25\n+ 1 day',
#  '11:25\n+ 1 day',
#  '11:25\n+ 1 day',
#  '19:15\n+ 1 day',
#  '19:15\n+ 1 day',
#  '19:15\n+ 1 day',
#  '19:15\n+ 1 day',
#  '13:10',
#  '13:10',
#  '13:10',
#  '19:15\n+ 1 day',
#  '19:15\n+ 1 day',
# ...

# %%
durr=driver.find_elements_by_xpath("//p[@class='fs-12 bold du mb-2']")
durr
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="18845b55f37c26c15577f3faade6e9f1", element="4c8bdf51-b5e2-4359-bfa1-562017070974")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="18845b55f37c26c15577f3faade6e9f1", element="1763647e-7d07-4b32-9399-1059c8e62e21")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="18845b55f37c26c15577f3faade6e9f1", element="f1db1d5b-a516-493c-8d09-8b7549f0a964")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="18845b55f37c26c15577f3faade6e9f1", element="0d91def6-c60d-41f0-a5af-57b3642ed96b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="18845b55f37c26c15577f3faade6e9f1", element="4ab9a042-207b-406c-b245-c35e4aa594fb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="18845b55f37c26c15577f3faade6e9f1", element="4c8e0d98-85c7-4d95-b91f-7cbdc8eee793")>,
# ...

# %%
duration=[]
for r in durr:
    duration.append(r.text)
duration
# Out:
# ['3h 05m',
#  '3h 10m',
#  '3h 10m',
#  '3h 15m',
#  '5h 15m',
#  '5h 20m',
#  '5h 45m',
#  '5h 50m',
#  '5h 55m',
#  '5h 55m',
#  '6h 15m',
#  '6h 40m',
#  '6h 40m',
#  '6h 45m',
#  '7h 05m',
#  '7h 25m',
#  '7h 45m',
#  '8h 05m',
#  '8h 10m',
#  '8h 25m',
#  '8h 50m',
#  '9h 05m',
#  '9h 20m',
#  '9h 25m',
#  '9h 35m',
#  '10h 05m',
#  '10h 20m',
#  '10h 30m',
#  '10h 30m',
#  '10h 35m',
#  '3h 10m',
#  '3h 10m',
#  '6h 15m',
#  '6h 55m',
#  '7h 15m',
#  '8h 40m',
#  '8h 55m',
#  '9h 35m',
#  '10h 10m',
#  '10h 15m',
#  '11h 20m',
#  '11h 25m',
#  '11h 30m',
#  '12h 20m',
#  '12h 25m',
#  '12h 25m',
#  '12h 45m',
#  '12h 55m',
#  '13h 05m',
#  '13h 55m',
#  '16h 10m',
#  '5h 05m',
#  '3h 15m',
#  '11h 50m',
#  '9h 05m',
#  '18h 05m',
#  '25h 55m',
#  '14h 10m',
#  '23h 15m',
#  '24h 15m',
#  '25h 25m',
#  '28h 10m',
#  '5h 55m',
#  '6h 40m',
#  '8h 25m',
#  '34h 35m',
#  '34h 35m',
#  '37h 20m',
#  '8h 35m',
#  '11h 15m',
#  '12h 15m',
#  '7h 20m',
#  '13h 10m',
#  '12h 10m',
# ...

# %%
stops=driver.find_elements_by_xpath("//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']")
stops
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="18845b55f37c26c15577f3faade6e9f1", element="570f49d5-4697-4d67-97b4-17b69c093a2e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="18845b55f37c26c15577f3faade6e9f1", element="7f3176c8-16a6-41d6-a2b5-44c3b2db7004")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="18845b55f37c26c15577f3faade6e9f1", element="dfcb1998-2389-4ba6-826d-26c5a49275e5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="18845b55f37c26c15577f3faade6e9f1", element="11bcbfb5-0cf4-4652-abdd-c1c16705719c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="18845b55f37c26c15577f3faade6e9f1", element="8d2f9bd6-3c85-408c-b363-5239d2f28222")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="18845b55f37c26c15577f3faade6e9f1", element="bc9d7741-1bd0-413a-a6ca-e405fa27aecd")>,
# ...

# %%
stoppage=[]
for s in stops:
    stoppage.append(s.text)
stoppage
# Out:
# ['Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  'Non Stop',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '2 Stop(s)',
# ...

# %%
flight=driver.find_elements_by_xpath("//span[@class='i-b text ellipsis']")
flight
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="18845b55f37c26c15577f3faade6e9f1", element="c07311d7-007c-40a7-ad54-d96fd223b066")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="18845b55f37c26c15577f3faade6e9f1", element="9abb2e10-a864-41bb-9ac1-13437bddb041")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="18845b55f37c26c15577f3faade6e9f1", element="21fb4adb-fe15-478f-b62a-54337ddf0bff")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="18845b55f37c26c15577f3faade6e9f1", element="6fd8ca42-6df5-4cf4-84b0-10a7adf08f6f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="18845b55f37c26c15577f3faade6e9f1", element="14c03915-99b4-4675-8498-751bb09b752f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="18845b55f37c26c15577f3faade6e9f1", element="610a0eb3-c691-4fd6-8a31-3548aebe3a07")>,
# ...

# %%
flight_name=[]
for f in flight:
    flight_name.append(f.text)
flight_name
# Out:
# ['Vistara',
#  'Air India',
#  'Vistara',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Air Asia',
#  'Go First',
#  'Air Asia',
#  'Air Asia',
#  'Go First',
#  'Go First',
#  'Air Asia',
#  'Go First',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Go First',
#  'Air Asia',
#  'Go First',
#  'Go First',
#  'IndiGo',
#  'Go First',
#  'IndiGo',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
# ...

# %%
prices=driver.find_elements_by_xpath("//div[@class='i-b tipsy fare-summary-tooltip fs-18']")
prices
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="18845b55f37c26c15577f3faade6e9f1", element="f8c1832c-6b3f-4c85-98a5-b1275f7b0ed6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="18845b55f37c26c15577f3faade6e9f1", element="732eb2ea-2935-49be-93c8-319a617a1ae3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="18845b55f37c26c15577f3faade6e9f1", element="af99cd02-0ee5-4aaa-9b32-9446c3e70fc8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="18845b55f37c26c15577f3faade6e9f1", element="9a67a543-e7ac-46cf-a48d-da3c84a35300")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="18845b55f37c26c15577f3faade6e9f1", element="fb5aff45-833e-43ad-bb02-ba3d61b16227")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="18845b55f37c26c15577f3faade6e9f1", element="f43ab4c3-c5f0-4516-9591-f556b8ec278a")>,
# ...

# %%
price=[]
for p in prices:
    price.append(p.text)
price
# Out:
# ['9,105',
#  '9,105',
#  '9,105',
#  '9,105',
#  '9,105',
#  '9,105',
#  '9,105',
#  '9,105',
#  '9,105',
#  '9,105',
#  '9,105',
#  '9,105',
#  '9,105',
#  '9,105',
#  '9,105',
#  '9,105',
#  '9,105',
#  '9,105',
#  '9,105',
#  '9,105',
#  '9,105',
#  '9,105',
#  '9,105',
#  '9,105',
#  '9,105',
#  '9,105',
#  '9,105',
#  '9,105',
#  '9,105',
#  '9,105',
#  '9,106',
#  '9,106',
#  '9,106',
#  '9,106',
#  '9,106',
#  '9,106',
#  '9,106',
#  '9,106',
#  '9,106',
#  '9,106',
#  '9,106',
#  '9,106',
#  '9,106',
#  '9,106',
#  '9,106',
#  '9,106',
#  '9,106',
#  '9,106',
#  '9,106',
#  '9,106',
#  '9,106',
#  '9,472',
#  '9,630',
#  '9,709',
#  '9,877',
#  '10,103',
#  '10,523',
#  '12,308',
#  '12,360',
#  '12,360',
#  '12,360',
#  '12,360',
#  '12,964',
#  '12,964',
#  '12,964',
#  '13,327',
#  '13,327',
#  '13,327',
#  '14,355',
#  '14,355',
#  '14,355',
#  '16,560',
#  '16,560',
#  '19,815',
#  '19,862',
#  '20,445']

# %%
source_=driver.find_elements_by_xpath("//p[@class='fs-10 font-lightgrey no-wrap city ellipsis']")
source_
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="18845b55f37c26c15577f3faade6e9f1", element="5f79f804-b7bb-4676-ae36-093d77206dd8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="18845b55f37c26c15577f3faade6e9f1", element="7c718929-0bbe-41db-acf4-823b1d30d13a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="18845b55f37c26c15577f3faade6e9f1", element="6faca6ba-1921-41f2-a4b0-b5d94e20dbc4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="18845b55f37c26c15577f3faade6e9f1", element="75abe38d-2f07-4356-8d1c-a7688e3afe92")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="18845b55f37c26c15577f3faade6e9f1", element="81930327-7f1a-4195-9ec1-6f2e3236294f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="18845b55f37c26c15577f3faade6e9f1", element="45eadbb2-4fd1-49aa-8772-d2083de51124")>,
# ...

# %%
source=[]
for s in source_:
    source.append(s.text)
source
# Out:
# ['New Delhi',
#  'Kochi',
#  'New Delhi',
#  'Kochi',
#  'New Delhi',
#  'Kochi',
#  'New Delhi',
#  'Kochi',
#  'New Delhi',
#  'Kochi',
#  'New Delhi',
#  'Kochi',
#  'New Delhi',
#  'Kochi',
#  'New Delhi',
#  'Kochi',
#  'New Delhi',
#  'Kochi',
#  'New Delhi',
#  'Kochi',
#  'New Delhi',
#  'Kochi',
#  'New Delhi',
#  'Kochi',
#  'New Delhi',
#  'Kochi',
#  'New Delhi',
#  'Kochi',
#  'New Delhi',
#  'Kochi',
#  'New Delhi',
#  'Kochi',
#  'New Delhi',
#  'Kochi',
#  'New Delhi',
#  'Kochi',
#  'New Delhi',
#  'Kochi',
#  'New Delhi',
#  'Kochi',
#  'New Delhi',
#  'Kochi',
#  'New Delhi',
#  'Kochi',
#  'New Delhi',
#  'Kochi',
#  'New Delhi',
#  'Kochi',
#  'New Delhi',
#  'Kochi',
#  'New Delhi',
#  'Kochi',
#  'New Delhi',
#  'Kochi',
#  'New Delhi',
#  'Kochi',
#  'New Delhi',
#  'Kochi',
#  'New Delhi',
#  'Kochi',
#  'New Delhi',
#  'Kochi',
#  'New Delhi',
#  'Kochi',
#  'New Delhi',
#  'Kochi',
#  'New Delhi',
#  'Kochi',
#  'New Delhi',
#  'Kochi',
#  'New Delhi',
# ...

# %%
destination=[]
for d in range(1,len(source),2):
    destination.append(source[d])
destination
# Out:
# ['Kochi',
#  'Kochi',
#  'Kochi',
#  'Kochi',
#  'Kochi',
#  'Kochi',
#  'Kochi',
#  'Kochi',
#  'Kochi',
#  'Kochi',
#  'Kochi',
#  'Kochi',
#  'Kochi',
#  'Kochi',
#  'Kochi',
#  'Kochi',
#  'Kochi',
#  'Kochi',
#  'Kochi',
#  'Kochi',
#  'Kochi',
#  'Kochi',
#  'Kochi',
#  'Kochi',
#  'Kochi',
#  'Kochi',
#  'Kochi',
#  'Kochi',
#  'Kochi',
#  'Kochi',
#  'Kochi',
#  'Kochi',
#  'Kochi',
#  'Kochi',
#  'Kochi',
#  'Kochi',
#  'Kochi',
#  'Kochi',
#  'Kochi',
#  'Kochi',
#  'Kochi',
#  'Kochi',
#  'Kochi',
#  'Kochi',
#  'Kochi',
#  'Kochi',
#  'Kochi',
#  'Kochi',
#  'Kochi',
#  'Kochi',
#  'Kochi',
#  'Kochi',
#  'Kochi',
#  'Kochi',
#  'Kochi',
#  'Kochi',
#  'Kochi',
#  'Kochi',
#  'Kochi',
#  'Kochi',
#  'Kochi',
#  'Kochi',
#  'Kochi',
#  'Kochi',
#  'Kochi',
#  'Kochi',
#  'Kochi',
#  'Kochi',
#  'Kochi',
#  'Kochi',
#  'Kochi',
#  'Kochi',
#  'Kochi',
#  'Kochi',
#  'Kochi',
#  'Kochi']

# %%
source1=[]
for s in range(0,len(source),2):
    source1.append(source[s])
source1
# Out:
# ['New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
# ...

# %%
import pandas as pd
df6=pd.DataFrame({})
df6['Departure Time']=departure_time
df6['Arrival Time']=arrival_time
df6['Source']=source1
df6['Destination']=destination
df6['Duration']=duration
df6['Stoppage']=stoppage
df6['Flight Name']=flight_name
df6['Price']=price
df6
# Out:
#    Departure Time    Arrival Time     Source Destination Duration   Stoppage  \
# 0           06:00           09:05  New Delhi       Kochi   3h 05m   Non Stop
# 1           14:30           17:40  New Delhi       Kochi   3h 10m   Non Stop
# 2           16:00           19:10  New Delhi       Kochi   3h 10m   Non Stop
# 3           06:15           09:30  New Delhi       Kochi   3h 15m   Non Stop
# 4           08:20           13:35  New Delhi       Kochi   5h 15m     1 Stop
# ..            ...             ...        ...         ...      ...        ...
# 71          11:55           19:15  New Delhi       Kochi   7h 20m  2 Stop(s)
# 72          06:05           19:15  New Delhi       Kochi  13h 10m  2 Stop(s)
# 73          07:05           19:15  New Delhi       Kochi  12h 10m  2 Stop(s)
# 74          21:15  19:15\n+ 1 day  New Delhi       Kochi  22h 00m  2 Stop(s)
# 75          18:30  19:15\n+ 1 day  New Delhi       Kochi  24h 45m  2 Stop(s)
#
#    Flight Name   Price
# ...

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 95.0.4638
# Get LATEST driver version for 95.0.4638
# Driver [C:\Users\monish\.wdm\drivers\chromedriver\win32\95.0.4638.17\chromedriver.exe] found in cache

# %%
url ="https://www.yatra.com"
driver.get(url)

# %%
search=driver.find_element_by_xpath("//*[@id='BE_flight_flsearch_btn']")
search.click()

# %%
dept_time=driver.find_elements_by_xpath("//div[@class='i-b pr']")
dept_time
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="73e8930f18629c6b4393b3f85c339bc9", element="5fa58ee7-0a24-45ca-b03f-806e972e82f7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="73e8930f18629c6b4393b3f85c339bc9", element="78f280b0-426c-4846-a465-f0a9b8749381")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="73e8930f18629c6b4393b3f85c339bc9", element="80055f29-58b2-4d33-837b-2c0d8eed37d0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="73e8930f18629c6b4393b3f85c339bc9", element="93140fbd-1441-4d45-b32d-ccce9ace9f17")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="73e8930f18629c6b4393b3f85c339bc9", element="1ce841c6-5bd6-4d81-bda9-362f3805862d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="73e8930f18629c6b4393b3f85c339bc9", element="3a0bcd87-0925-479c-a417-8f3aa47b929e")>,
# ...

# %%
departure_time=[]
for d in dept_time:
    departure_time.append(d.text)
departure_time
# Out:
# ['21:45',
#  '08:30',
#  '08:45',
#  '21:30',
#  '09:05',
#  '19:50',
#  '21:30',
#  '06:20',
#  '21:35',
#  '14:15',
#  '19:00',
#  '22:15',
#  '10:25',
#  '20:25',
#  '13:30',
#  '13:30',
#  '13:30',
#  '13:30',
#  '13:30',
#  '13:30',
#  '11:20',
#  '11:20',
#  '07:40',
#  '19:30',
#  '07:40',
#  '21:30',
#  '07:40',
#  '21:30',
#  '23:50',
#  '07:35',
#  '07:35',
#  '20:35',
#  '07:35',
#  '14:00',
#  '21:30',
#  '19:30',
#  '14:20',
#  '14:20',
#  '14:20',
#  '07:40',
#  '08:50',
#  '14:20',
#  '07:35',
#  '06:30',
#  '12:40',
#  '12:40',
#  '14:20',
#  '20:35',
#  '07:35',
#  '07:35',
#  '07:35',
#  '20:35',
#  '20:35',
#  '13:30',
#  '12:40',
#  '12:40',
#  '12:40',
#  '20:35',
#  '07:35',
#  '20:35',
#  '13:30',
#  '11:50',
#  '21:05',
#  '13:30',
#  '17:15',
#  '17:15',
#  '13:30',
#  '20:35',
#  '20:10',
#  '20:10',
#  '13:30',
#  '07:35',
#  '07:35',
#  '13:30',
#  '07:35',
#  '13:30',
#  '13:30']

# %%
arr_time=driver.find_elements_by_xpath("//p[@class='bold fs-15 mb-2 pr time']")
arr_time
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="73e8930f18629c6b4393b3f85c339bc9", element="4eb75c64-1b7e-4511-bc46-e41a0ee10630")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="73e8930f18629c6b4393b3f85c339bc9", element="9de28520-4585-4b7a-9a7c-23024f9995b9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="73e8930f18629c6b4393b3f85c339bc9", element="0182d02f-6d79-4d24-84db-c8245639f5ff")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="73e8930f18629c6b4393b3f85c339bc9", element="7bdfc821-357f-4883-9f86-27d8d9bdbd97")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="73e8930f18629c6b4393b3f85c339bc9", element="4fe1a332-a2d4-4402-9f86-2062cba45deb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="73e8930f18629c6b4393b3f85c339bc9", element="8ef4bf92-d55a-4b47-ad1d-1cb83f26d91a")>,
# ...

# %%
arrival_time=[]
for a in arr_time:
    arrival_time.append(a.text)
arrival_time
# Out:
# ['23:30',
#  '10:35',
#  '10:55',
#  '07:20\n+ 1 day',
#  '20:20',
#  '07:45\n+ 1 day',
#  '09:50\n+ 1 day',
#  '08:15',
#  '23:25',
#  '16:05',
#  '20:45',
#  '23:50',
#  '12:25',
#  '22:25',
#  '20:00',
#  '10:10\n+ 1 day',
#  '21:15',
#  '22:10',
#  '09:05\n+ 1 day',
#  '11:15\n+ 1 day',
#  '21:25',
#  '02:00\n+ 1 day',
#  '13:05',
#  '01:25\n+ 1 day',
#  '16:35',
#  '07:10\n+ 1 day',
#  '18:15',
#  '08:40\n+ 1 day',
#  '06:35\n+ 1 day',
#  '12:50',
#  '20:00',
#  '10:10\n+ 1 day',
#  '10:10\n+ 1 day',
#  '15:50',
#  '03:20\n+ 1 day',
#  '03:20\n+ 1 day',
#  '20:50',
#  '22:15',
#  '01:25\n+ 1 day',
#  '14:10',
#  '18:05',
#  '23:30',
#  '18:15',
#  '12:35',
#  '21:25',
#  '02:00\n+ 1 day',
#  '19:25',
#  '09:05\n+ 1 day',
#  '21:15',
#  '22:10',
#  '09:05\n+ 1 day',
#  '11:15\n+ 1 day',
#  '20:00\n+ 1 day',
#  '12:50\n+ 1 day',
#  '22:15',
#  '20:20',
#  '23:10',
#  '12:50\n+ 1 day',
#  '17:25',
#  '22:10\n+ 1 day',
#  '17:25\n+ 1 day',
#  '20:35',
#  '05:55\n+ 1 day',
# ...

# %%
durr=driver.find_elements_by_xpath("//p[@class='fs-12 bold du mb-2']")
durr
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="73e8930f18629c6b4393b3f85c339bc9", element="730f3771-701e-4aa5-8710-aef80b1330e0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="73e8930f18629c6b4393b3f85c339bc9", element="697fabca-7f77-44d7-a547-c91253d2b43b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="73e8930f18629c6b4393b3f85c339bc9", element="4b9d1b7e-c4e6-47e7-9956-40d623d02a81")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="73e8930f18629c6b4393b3f85c339bc9", element="4d227d0f-d2a7-4475-a60c-647e34c8c71b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="73e8930f18629c6b4393b3f85c339bc9", element="e2ad869c-0e42-4229-bba6-1f4365be1b33")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="73e8930f18629c6b4393b3f85c339bc9", element="41d00df9-1ccd-4daa-b429-d0b46ad3e676")>,
# ...

# %%
duration=[]
for r in durr:
    duration.append(r.text)
duration
# Out:
# ['1h 45m',
#  '2h 05m',
#  '2h 10m',
#  '9h 50m',
#  '11h 15m',
#  '11h 55m',
#  '12h 20m',
#  '1h 55m',
#  '1h 50m',
#  '1h 50m',
#  '1h 45m',
#  '1h 35m',
#  '2h 00m',
#  '2h 00m',
#  '6h 30m',
#  '20h 40m',
#  '7h 45m',
#  '8h 40m',
#  '19h 35m',
#  '21h 45m',
#  '10h 05m',
#  '14h 40m',
#  '5h 25m',
#  '5h 55m',
#  '8h 55m',
#  '9h 40m',
#  '10h 35m',
#  '11h 10m',
#  '6h 45m',
#  '5h 15m',
#  '12h 25m',
#  '13h 35m',
#  '26h 35m',
#  '1h 50m',
#  '5h 50m',
#  '7h 50m',
#  '6h 30m',
#  '7h 55m',
#  '11h 05m',
#  '6h 30m',
#  '9h 15m',
#  '9h 10m',
#  '10h 40m',
#  '6h 05m',
#  '8h 45m',
#  '13h 20m',
#  '5h 05m',
#  '12h 30m',
#  '13h 40m',
#  '14h 35m',
#  '25h 30m',
#  '14h 40m',
#  '23h 25m',
#  '23h 20m',
#  '9h 35m',
#  '7h 40m',
#  '10h 30m',
#  '16h 15m',
#  '9h 50m',
#  '25h 35m',
#  '27h 55m',
#  '8h 45m',
#  '8h 50m',
#  '33h 35m',
#  '13h 30m',
#  '14h 00m',
#  '27h 55m',
#  '24h 40m',
#  '10h 35m',
#  '11h 05m',
#  '18h 35m',
#  '8h 05m',
#  '14h 50m',
#  '27h 15m',
# ...

# %%
stops=driver.find_elements_by_xpath("//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']")
stops
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="73e8930f18629c6b4393b3f85c339bc9", element="e3967173-1a25-4f31-b59c-246b581fd3c2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="73e8930f18629c6b4393b3f85c339bc9", element="f770c026-6784-4fe1-b918-c50063d802c5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="73e8930f18629c6b4393b3f85c339bc9", element="6507426e-12e9-4264-8e01-97c7f8df97b0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="73e8930f18629c6b4393b3f85c339bc9", element="2396683e-6d2f-43b8-8eec-9421f270ea0e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="73e8930f18629c6b4393b3f85c339bc9", element="0cbc9136-f454-4468-9286-b3d91cce6743")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="73e8930f18629c6b4393b3f85c339bc9", element="c287d550-5656-4813-a7aa-2d8789c07727")>,
# ...

# %%
stoppage=[]
for s in stops:
    stoppage.append(s.text)
stoppage
# Out:
# ['Non Stop',
#  'Non Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '1 Stop',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '1 Stop',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '1 Stop',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
# ...

# %%
flight=driver.find_elements_by_xpath("//span[@class='i-b text ellipsis']")
flight
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="73e8930f18629c6b4393b3f85c339bc9", element="9cb41f30-18d8-4f1f-adfc-4ba801303dd8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="73e8930f18629c6b4393b3f85c339bc9", element="531ec35e-91d2-4073-a6d7-07b718fae350")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="73e8930f18629c6b4393b3f85c339bc9", element="05faa47b-de08-414e-91ce-89012189a33d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="73e8930f18629c6b4393b3f85c339bc9", element="28e30aab-53c0-42e8-8d7a-e5494639efde")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="73e8930f18629c6b4393b3f85c339bc9", element="71dd33ae-a4cb-440e-b2a2-8b5cc050c677")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="73e8930f18629c6b4393b3f85c339bc9", element="7eb185dd-3b8a-4535-a498-c3a990031e12")>,
# ...

# %%
flight_name=[]
for f in flight:
    flight_name.append(f.text)
flight_name
# Out:
# ['Go First',
#  'SpiceJet',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'SpiceJet',
#  'Air Asia',
#  'Air Asia',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Go First',
#  'Go First',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Air Asia',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Air India',
#  'SpiceJet',
#  'Go First',
#  'Go First',
#  'IndiGo',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air Asia',
#  'IndiGo',
#  'Air India',
#  'Air Asia',
#  'Air Asia',
#  'Air India',
#  'Air India',
# ...

# %%
prices=driver.find_elements_by_xpath("//div[@class='i-b tipsy fare-summary-tooltip fs-18']")
prices
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="73e8930f18629c6b4393b3f85c339bc9", element="00a59c5e-1dd4-4605-b610-83bf261673d9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="73e8930f18629c6b4393b3f85c339bc9", element="25895b57-a957-4e6f-b520-6df2fb74b4a0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="73e8930f18629c6b4393b3f85c339bc9", element="c91522c5-acf9-41ab-b3b1-e039548b0da6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="73e8930f18629c6b4393b3f85c339bc9", element="2e8fe2bc-ac7b-4e6c-a4d5-02e6d6e18f5d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="73e8930f18629c6b4393b3f85c339bc9", element="78a630a7-9417-46d3-a83d-0121922ffb28")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="73e8930f18629c6b4393b3f85c339bc9", element="6320c3f5-61eb-4c0d-baec-e9fed5a7b626")>,
# ...

# %%
price=[]
for p in prices:
    price.append(p.text)
price
# Out:
# ['5,425',
#  '5,425',
#  '5,425',
#  '5,425',
#  '5,425',
#  '5,425',
#  '5,425',
#  '5,426',
#  '5,794',
#  '6,371',
#  '6,581',
#  '6,791',
#  '7,107',
#  '7,818',
#  '7,907',
#  '7,907',
#  '8,369',
#  '8,369',
#  '8,369',
#  '8,831',
#  '9,022',
#  '9,022',
#  '9,206',
#  '9,206',
#  '9,206',
#  '9,206',
#  '9,206',
#  '9,206',
#  '9,232',
#  '9,311',
#  '9,311',
#  '9,311',
#  '9,311',
#  '9,521',
#  '9,679',
#  '9,679',
#  '9,836',
#  '9,836',
#  '9,836',
#  '9,889',
#  '9,941',
#  '10,099',
#  '10,151',
#  '10,465',
#  '10,492',
#  '10,492',
#  '10,519',
#  '10,571',
#  '10,571',
#  '10,571',
#  '10,571',
#  '10,991',
#  '10,991',
#  '11,719',
#  '12,409',
#  '12,724',
#  '13,354',
#  '13,616',
#  '14,036',
#  '15,926',
#  '16,727',
#  '17,474',
#  '17,764',
#  '18,302',
#  '18,524',
#  '18,524',
#  '18,922',
#  '19,076',
#  '19,890',
#  '19,890',
#  '20,770',
#  '23,276',
#  '27,634',
#  '30,052',
#  '31,046',
#  '33,566',
#  '33,566']

# %%
source_=driver.find_elements_by_xpath("//p[@class='fs-10 font-lightgrey no-wrap city ellipsis']")
source_
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="73e8930f18629c6b4393b3f85c339bc9", element="4286975d-a7b0-40af-829a-ecbdd25d442e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="73e8930f18629c6b4393b3f85c339bc9", element="ddc290f3-9834-44f5-b6bb-88f231cf9879")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="73e8930f18629c6b4393b3f85c339bc9", element="80db563c-8e6f-472f-93a5-6128290d6e2d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="73e8930f18629c6b4393b3f85c339bc9", element="7c1fc097-e467-48b5-9873-f4a00d159e34")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="73e8930f18629c6b4393b3f85c339bc9", element="427ce65b-dae0-4dcb-8619-210011b4bb37")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="73e8930f18629c6b4393b3f85c339bc9", element="8bbbe946-c5a0-4f51-863b-28004a5f7df2")>,
# ...

# %%
source=[]
for s in source_:
    source.append(s.text)
source
# Out:
# ['Jaipur',
#  'Mumbai',
#  'Jaipur',
#  'Mumbai',
#  'Jaipur',
#  'Mumbai',
#  'Jaipur',
#  'Mumbai',
#  'Jaipur',
#  'Mumbai',
#  'Jaipur',
#  'Mumbai',
#  'Jaipur',
#  'Mumbai',
#  'Jaipur',
#  'Mumbai',
#  'Jaipur',
#  'Mumbai',
#  'Jaipur',
#  'Mumbai',
#  'Jaipur',
#  'Mumbai',
#  'Jaipur',
#  'Mumbai',
#  'Jaipur',
#  'Mumbai',
#  'Jaipur',
#  'Mumbai',
#  'Jaipur',
#  'Mumbai',
#  'Jaipur',
#  'Mumbai',
#  'Jaipur',
#  'Mumbai',
#  'Jaipur',
#  'Mumbai',
#  'Jaipur',
#  'Mumbai',
#  'Jaipur',
#  'Mumbai',
#  'Jaipur',
#  'Mumbai',
#  'Jaipur',
#  'Mumbai',
#  'Jaipur',
#  'Mumbai',
#  'Jaipur',
#  'Mumbai',
#  'Jaipur',
#  'Mumbai',
#  'Jaipur',
#  'Mumbai',
#  'Jaipur',
#  'Mumbai',
#  'Jaipur',
#  'Mumbai',
#  'Jaipur',
#  'Mumbai',
#  'Jaipur',
#  'Mumbai',
#  'Jaipur',
#  'Mumbai',
#  'Jaipur',
#  'Mumbai',
#  'Jaipur',
#  'Mumbai',
#  'Jaipur',
#  'Mumbai',
#  'Jaipur',
#  'Mumbai',
#  'Jaipur',
#  'Mumbai',
#  'Jaipur',
#  'Mumbai',
#  'Jaipur',
#  'Mumbai',
# ...

# %%
destination=[]
for d in range(1,len(source),2):
    destination.append(source[d])
destination
# Out:
# ['Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
# ...

# %%
source1=[]
for s in range(0,len(source),2):
    source1.append(source[s])
source1
# Out:
# ['Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
#  'Jaipur',
# ...

# %%
import pandas as pd
df7=pd.DataFrame({})
df7['Departure Time']=departure_time
df7['Arrival Time']=arrival_time
df7['Source']=source1
df7['Destination']=destination
df7['Duration']=duration
df7['Stoppage']=stoppage
df7['Flight Name']=flight_name
df7['Price']=price
df7
# Out:
#    Departure Time    Arrival Time  Source Destination Duration   Stoppage  \
# 0           21:45           23:30  Jaipur      Mumbai   1h 45m   Non Stop
# 1           08:30           10:35  Jaipur      Mumbai   2h 05m   Non Stop
# 2           08:45           10:55  Jaipur      Mumbai   2h 10m   Non Stop
# 3           21:30  07:20\n+ 1 day  Jaipur      Mumbai   9h 50m     1 Stop
# 4           09:05           20:20  Jaipur      Mumbai  11h 15m     1 Stop
# ..            ...             ...     ...         ...      ...        ...
# 72          07:35           22:25  Jaipur      Mumbai  14h 50m  2 Stop(s)
# 73          13:30  16:45\n+ 1 day  Jaipur      Mumbai  27h 15m  3 Stop(s)
# 74          07:35           16:35  Jaipur      Mumbai   9h 00m  2 Stop(s)
# 75          13:30  16:45\n+ 1 day  Jaipur      Mumbai  27h 15m  3 Stop(s)
# 76          13:30  16:45\n+ 1 day  Jaipur      Mumbai  27h 15m  3 Stop(s)
#
#    Flight Name   Price
# 0     Go First   5,425
# 1     SpiceJet   5,425
# ...

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 95.0.4638
# Get LATEST driver version for 95.0.4638
# Driver [C:\Users\monish\.wdm\drivers\chromedriver\win32\95.0.4638.17\chromedriver.exe] found in cache

# %%
url ="https://www.yatra.com"
driver.get(url)

# %%
search=driver.find_element_by_xpath("//*[@id='BE_flight_flsearch_btn']")
search.click()

# %%
dept_time=driver.find_elements_by_xpath("//div[@class='i-b pr']")
dept_time
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="e35c193fe1b213132808b7af45afd4a6", element="0da40493-6dc0-4c75-8640-418400f60363")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e35c193fe1b213132808b7af45afd4a6", element="3e21e173-16a8-4784-9b90-6f7a6e3b939d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e35c193fe1b213132808b7af45afd4a6", element="729a98df-9937-4e51-b68e-052e6b9848e7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e35c193fe1b213132808b7af45afd4a6", element="ec2049d7-8277-40bd-9806-61ff01e4f308")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e35c193fe1b213132808b7af45afd4a6", element="8d346085-e3c8-4e7d-b511-c4a192c7cb41")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e35c193fe1b213132808b7af45afd4a6", element="08726e5c-2828-4959-9f10-a9141579fab6")>,
# ...

# %%
departure_time=[]
for d in dept_time:
    departure_time.append(d.text)
departure_time
# Out:
# ['07:30',
#  '10:45',
#  '06:05',
#  '18:25',
#  '06:30',
#  '06:30',
#  '07:50',
#  '17:35',
#  '20:35',
#  '06:40',
#  '10:40',
#  '13:00',
#  '22:55',
#  '09:15',
#  '15:25',
#  '17:05',
#  '14:10',
#  '20:15',
#  '08:55',
#  '08:05',
#  '18:10',
#  '18:10',
#  '06:30',
#  '06:30',
#  '13:50',
#  '18:10',
#  '13:30',
#  '13:30',
#  '13:30',
#  '13:30',
#  '13:30',
#  '11:05',
#  '11:05',
#  '11:05',
#  '11:05',
#  '11:05',
#  '11:05',
#  '11:05']

# %%
arr_time=driver.find_elements_by_xpath("//p[@class='bold fs-15 mb-2 pr time']")
arr_time
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="e35c193fe1b213132808b7af45afd4a6", element="a82ae994-8aa1-4237-8e04-705eda7d097a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e35c193fe1b213132808b7af45afd4a6", element="fc69979b-27b5-4441-bd18-17e25a3dcffa")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e35c193fe1b213132808b7af45afd4a6", element="8a310296-9cd4-40d6-89df-f8dc8f753baa")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e35c193fe1b213132808b7af45afd4a6", element="f009be7f-a1c3-4d19-9e05-9d30de00d184")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e35c193fe1b213132808b7af45afd4a6", element="2d5a2b34-fe4d-4f28-8e29-f51c560ca269")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e35c193fe1b213132808b7af45afd4a6", element="2fc54e9f-189c-457f-b0cb-7056fa4e1156")>,
# ...

# %%
arrival_time=[]
for a in arr_time:
    arrival_time.append(a.text)
arrival_time
# Out:
# ['08:40',
#  '11:55',
#  '07:20',
#  '19:55',
#  '14:30',
#  '20:10',
#  '08:35',
#  '18:45',
#  '21:45',
#  '07:55',
#  '11:55',
#  '14:15',
#  '00:10\n+ 1 day',
#  '10:30',
#  '16:35',
#  '20:40',
#  '19:40',
#  '21:35',
#  '10:15',
#  '16:55',
#  '00:50\n+ 1 day',
#  '02:00\n+ 1 day',
#  '12:10',
#  '15:45',
#  '23:50',
#  '08:10\n+ 1 day',
#  '20:10',
#  '22:25',
#  '23:30',
#  '00:50\n+ 1 day',
#  '02:00\n+ 1 day',
#  '20:30',
#  '23:30',
#  '08:55\n+ 1 day',
#  '21:15',
#  '10:15\n+ 1 day',
#  '12:15\n+ 1 day',
#  '18:15']

# %%
durr=driver.find_elements_by_xpath("//p[@class='fs-12 bold du mb-2']")
durr
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="e35c193fe1b213132808b7af45afd4a6", element="ebbc7297-05e6-4a69-b5a0-32913b72e8c8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e35c193fe1b213132808b7af45afd4a6", element="8b497edf-4371-4062-84d2-83fbf0a2ab87")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e35c193fe1b213132808b7af45afd4a6", element="01693f44-665d-4b1a-a3e7-9155c2bab823")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e35c193fe1b213132808b7af45afd4a6", element="6902f920-5e30-4aef-a005-72f052991a67")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e35c193fe1b213132808b7af45afd4a6", element="df9652dd-2a94-47b5-bbcf-78a03fa957e4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e35c193fe1b213132808b7af45afd4a6", element="60b8ca7a-200b-49b6-9540-c4bf2908760a")>,
# ...

# %%
duration=[]
for r in durr:
    duration.append(r.text)
duration
# Out:
# ['1h 10m',
#  '1h 10m',
#  '1h 15m',
#  '1h 30m',
#  '8h 00m',
#  '13h 40m',
#  '0h 45m',
#  '1h 10m',
#  '1h 10m',
#  '1h 15m',
#  '1h 15m',
#  '1h 15m',
#  '1h 15m',
#  '1h 15m',
#  '1h 10m',
#  '3h 35m',
#  '5h 30m',
#  '1h 20m',
#  '1h 20m',
#  '8h 50m',
#  '6h 40m',
#  '7h 50m',
#  '5h 40m',
#  '9h 15m',
#  '10h 00m',
#  '14h 00m',
#  '6h 40m',
#  '8h 55m',
#  '10h 00m',
#  '11h 20m',
#  '12h 30m',
#  '9h 25m',
#  '12h 25m',
#  '21h 50m',
#  '10h 10m',
#  '23h 10m',
#  '25h 10m',
#  '7h 10m']

# %%
stops=driver.find_elements_by_xpath("//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']")
stops
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="e35c193fe1b213132808b7af45afd4a6", element="a5c3d3d9-d123-4378-b10f-ae5582939b03")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e35c193fe1b213132808b7af45afd4a6", element="9628d8bc-c899-48b7-aa21-f142a12a488f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e35c193fe1b213132808b7af45afd4a6", element="c8ad4f4f-498a-4d88-89a5-0c81e80f8be1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e35c193fe1b213132808b7af45afd4a6", element="25cac3eb-7f82-4b0c-a663-75372ea566a8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e35c193fe1b213132808b7af45afd4a6", element="c799a608-3d2d-4697-99c6-6581f13004d6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e35c193fe1b213132808b7af45afd4a6", element="783e1933-6000-43d7-a65c-b1a682575da4")>,
# ...

# %%
stoppage=[]
for s in stops:
    stoppage.append(s.text)
stoppage
# Out:
# ['Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop']

# %%
flight=driver.find_elements_by_xpath("//span[@class='i-b text ellipsis']")
flight
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="e35c193fe1b213132808b7af45afd4a6", element="694ffcb9-c581-4093-b93f-3d8d2010742b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e35c193fe1b213132808b7af45afd4a6", element="c82548ca-f292-4d22-b340-847ae0bc1482")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e35c193fe1b213132808b7af45afd4a6", element="fcd54f76-f139-40f8-a295-ed9e582a95b6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e35c193fe1b213132808b7af45afd4a6", element="ffa7d19b-9f42-4701-b0b7-6282b9f2cf06")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e35c193fe1b213132808b7af45afd4a6", element="0aaa2500-cd30-4023-ab42-ce6e2de467b2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e35c193fe1b213132808b7af45afd4a6", element="59a8ebc6-992b-4e6a-801c-ed9a2c66ab8b")>,
# ...

# %%
flight_name=[]
for f in flight:
    flight_name.append(f.text)
flight_name
# Out:
# ['Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Vistara',
#  'Vistara',
#  'Air India',
#  'IndiGo',
#  'Air India',
#  'Air India',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India']

# %%
prices=driver.find_elements_by_xpath("//div[@class='i-b tipsy fare-summary-tooltip fs-18']")
prices
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="e35c193fe1b213132808b7af45afd4a6", element="3ebc6cb3-cc7d-4c2a-852f-dcbc2ba167b6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e35c193fe1b213132808b7af45afd4a6", element="9e0572d1-5b71-4c5a-a39d-b4f10bcb83c5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e35c193fe1b213132808b7af45afd4a6", element="763a4670-217d-4967-a2c6-a5765077c841")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e35c193fe1b213132808b7af45afd4a6", element="6bbfa150-de35-477e-8e15-9c3122d3e3fb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e35c193fe1b213132808b7af45afd4a6", element="21890aa4-ff9a-4d98-81ed-ca05d2090450")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e35c193fe1b213132808b7af45afd4a6", element="65937b22-a3f4-4874-bcd2-a6db50cbae6f")>,
# ...

# %%
price=[]
for p in prices:
    price.append(p.text)
price
# Out:
# ['4,312',
#  '4,312',
#  '4,312',
#  '4,312',
#  '4,312',
#  '4,312',
#  '4,313',
#  '4,313',
#  '4,313',
#  '4,313',
#  '4,313',
#  '4,313',
#  '4,313',
#  '4,314',
#  '5,522',
#  '7,307',
#  '7,726',
#  '8,514',
#  '9,354',
#  '10,613',
#  '12,890',
#  '13,468',
#  '14,676',
#  '14,676',
#  '15,075',
#  '15,410',
#  '15,830',
#  '15,830',
#  '15,830',
#  '15,830',
#  '16,408',
#  '17,124',
#  '17,124',
#  '17,124',
#  '18,384',
#  '18,804',
#  '19,224',
#  '19,959']

# %%
source_=driver.find_elements_by_xpath("//p[@class='fs-10 font-lightgrey no-wrap city ellipsis']")
source_
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="e35c193fe1b213132808b7af45afd4a6", element="4ac30980-ecc4-4b55-b91d-d577616e7614")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e35c193fe1b213132808b7af45afd4a6", element="80a81296-b846-40cd-a39c-3c5b1b34e701")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e35c193fe1b213132808b7af45afd4a6", element="4f10e193-180b-4837-9d14-94b0dfd5f777")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e35c193fe1b213132808b7af45afd4a6", element="fc7fd36e-e3c9-4ac7-8920-6b065e9910a9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e35c193fe1b213132808b7af45afd4a6", element="1350becc-f95e-4ffe-b5fa-49f50e58347f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e35c193fe1b213132808b7af45afd4a6", element="4f957803-fc88-4bc8-8cf3-4fd5872494f8")>,
# ...

# %%
source=[]
for s in source_:
    source.append(s.text)
source
# Out:
# ['Lucknow',
#  'New Delhi',
#  'Lucknow',
#  'New Delhi',
#  'Lucknow',
#  'New Delhi',
#  'Lucknow',
#  'New Delhi',
#  'Lucknow',
#  'New Delhi',
#  'Lucknow',
#  'New Delhi',
#  'Lucknow',
#  'New Delhi',
#  'Lucknow',
#  'New Delhi',
#  'Lucknow',
#  'New Delhi',
#  'Lucknow',
#  'New Delhi',
#  'Lucknow',
#  'New Delhi',
#  'Lucknow',
#  'New Delhi',
#  'Lucknow',
#  'New Delhi',
#  'Lucknow',
#  'New Delhi',
#  'Lucknow',
#  'New Delhi',
#  'Lucknow',
#  'New Delhi',
#  'Lucknow',
#  'New Delhi',
#  'Lucknow',
#  'New Delhi',
#  'Lucknow',
#  'New Delhi',
#  'Lucknow',
#  'New Delhi',
#  'Lucknow',
#  'New Delhi',
#  'Lucknow',
#  'New Delhi',
#  'Lucknow',
#  'New Delhi',
#  'Lucknow',
#  'New Delhi',
#  'Lucknow',
#  'New Delhi',
#  'Lucknow',
#  'New Delhi',
#  'Lucknow',
#  'New Delhi',
#  'Lucknow',
#  'New Delhi',
#  'Lucknow',
#  'New Delhi',
#  'Lucknow',
#  'New Delhi',
#  'Lucknow',
#  'New Delhi',
#  'Lucknow',
#  'New Delhi',
#  'Lucknow',
#  'New Delhi',
# ...

# %%
destination=[]
for d in range(1,len(source),2):
    destination.append(source[d])
destination
# Out:
# ['New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi']

# %%
source1=[]
for s in range(0,len(source),2):
    source1.append(source[s])
source1
# Out:
# ['Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow']

# %%
import pandas as pd
df8=pd.DataFrame({})
df8['Departure Time']=departure_time
df8['Arrival Time']=arrival_time
df8['Source']=source1
df8['Destination']=destination
df8['Duration']=duration
df8['Stoppage']=stoppage
df8['Flight Name']=flight_name
df8['Price']=price
df8
# Out:
#    Departure Time    Arrival Time   Source Destination Duration  Stoppage  \
# 0           07:30           08:40  Lucknow   New Delhi   1h 10m  Non Stop
# 1           10:45           11:55  Lucknow   New Delhi   1h 10m  Non Stop
# 2           06:05           07:20  Lucknow   New Delhi   1h 15m  Non Stop
# 3           18:25           19:55  Lucknow   New Delhi   1h 30m  Non Stop
# 4           06:30           14:30  Lucknow   New Delhi   8h 00m    1 Stop
# 5           06:30           20:10  Lucknow   New Delhi  13h 40m    1 Stop
# 6           07:50           08:35  Lucknow   New Delhi   0h 45m  Non Stop
# 7           17:35           18:45  Lucknow   New Delhi   1h 10m  Non Stop
# 8           20:35           21:45  Lucknow   New Delhi   1h 10m  Non Stop
# 9           06:40           07:55  Lucknow   New Delhi   1h 15m  Non Stop
# 10          10:40           11:55  Lucknow   New Delhi   1h 15m  Non Stop
# 11          13:00           14:15  Lucknow   New Delhi   1h 15m  Non Stop
# ...

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 95.0.4638
# Get LATEST driver version for 95.0.4638
# Driver [C:\Users\monish\.wdm\drivers\chromedriver\win32\95.0.4638.17\chromedriver.exe] found in cache

# %%
url ="https://www.yatra.com"
driver.get(url)

# %%
search=driver.find_element_by_xpath("//*[@id='BE_flight_flsearch_btn']")
search.click()

# %%
dept_time=driver.find_elements_by_xpath("//div[@class='i-b pr']")
dept_time
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="36c85ac58bb1677a98b0349f1b2dc8c5", element="c640787b-b71b-4bce-8ea2-2e4e3503b428")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="36c85ac58bb1677a98b0349f1b2dc8c5", element="1d3a3d00-0720-4645-8c2e-b1e15b6baec1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="36c85ac58bb1677a98b0349f1b2dc8c5", element="462d8ff3-c488-4bdb-8210-48bb51086394")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="36c85ac58bb1677a98b0349f1b2dc8c5", element="812d91b8-0fde-46f2-9173-d3ec139cb6d7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="36c85ac58bb1677a98b0349f1b2dc8c5", element="610d3e59-4446-4f2d-81b5-2d533e5dfd7d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="36c85ac58bb1677a98b0349f1b2dc8c5", element="304d3527-fb1b-4f3f-916c-79bbed9d3074")>,
# ...

# %%
departure_time=[]
for d in dept_time:
    departure_time.append(d.text)
departure_time
# Out:
# ['23:15',
#  '08:40',
#  '19:30',
#  '08:15',
#  '08:15',
#  '19:30',
#  '16:40',
#  '17:40',
#  '09:10',
#  '19:00',
#  '19:10',
#  '17:40',
#  '10:50',
#  '08:45',
#  '13:55',
#  '08:45',
#  '15:30',
#  '10:50',
#  '18:50']

# %%
arr_time=driver.find_elements_by_xpath("//p[@class='bold fs-15 mb-2 pr time']")
arr_time
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="36c85ac58bb1677a98b0349f1b2dc8c5", element="25ad104b-2860-4f72-bb0f-dcb111a4d9ab")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="36c85ac58bb1677a98b0349f1b2dc8c5", element="4c025a7c-cb9b-42a1-98c6-7f65ef60442a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="36c85ac58bb1677a98b0349f1b2dc8c5", element="db6185fd-4d08-4c8b-a83f-7ddd08a3134c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="36c85ac58bb1677a98b0349f1b2dc8c5", element="55074c87-6280-44a9-8d6b-899ab8f55ddd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="36c85ac58bb1677a98b0349f1b2dc8c5", element="7e3ec25f-0aa5-480a-962c-3ff3b698cea6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="36c85ac58bb1677a98b0349f1b2dc8c5", element="b4d88b7c-24d8-41cc-bd8a-a54c592542f6")>,
# ...

# %%
arrival_time=[]
for a in arr_time:
    arrival_time.append(a.text)
arrival_time
# Out:
# ['00:35\n+ 1 day',
#  '10:05',
#  '08:05\n+ 1 day',
#  '19:40',
#  '08:05\n+ 1 day',
#  '19:40\n+ 1 day',
#  '18:05',
#  '20:30',
#  '20:55',
#  '08:40\n+ 1 day',
#  '07:30\n+ 1 day',
#  '08:40\n+ 1 day',
#  '17:05',
#  '18:10',
#  '18:15',
#  '20:40',
#  '21:30',
#  '21:30',
#  '20:40\n+ 1 day']

# %%
durr=driver.find_elements_by_xpath("//p[@class='fs-12 bold du mb-2']")
durr
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="36c85ac58bb1677a98b0349f1b2dc8c5", element="49f60877-9081-4357-9549-80c9972198a3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="36c85ac58bb1677a98b0349f1b2dc8c5", element="e075b6ec-762b-4bef-9152-358ce652b3ee")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="36c85ac58bb1677a98b0349f1b2dc8c5", element="e34fc42d-bb6c-42b8-a4f5-5fd1e5052114")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="36c85ac58bb1677a98b0349f1b2dc8c5", element="a555f0ea-2f53-471b-8649-294741a58b87")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="36c85ac58bb1677a98b0349f1b2dc8c5", element="a69c1570-5a43-4428-b8e4-4f9dc3e29a2f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="36c85ac58bb1677a98b0349f1b2dc8c5", element="1cbbc6d3-acca-444d-9fcd-6b1a7f71c1c5")>,
# ...

# %%
duration=[]
for r in durr:
    duration.append(r.text)
duration
# Out:
# ['1h 20m',
#  '1h 25m',
#  '12h 35m',
#  '11h 25m',
#  '23h 50m',
#  '24h 10m',
#  '1h 25m',
#  '2h 50m',
#  '11h 45m',
#  '13h 40m',
#  '12h 20m',
#  '15h 00m',
#  '6h 15m',
#  '9h 25m',
#  '4h 20m',
#  '11h 55m',
#  '6h 00m',
#  '10h 40m',
#  '25h 50m']

# %%
stops=driver.find_elements_by_xpath("//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']")
stops
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="36c85ac58bb1677a98b0349f1b2dc8c5", element="ab824d03-47a9-4750-a0cf-9ce9493fac43")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="36c85ac58bb1677a98b0349f1b2dc8c5", element="f938e31d-81a7-4baf-9f22-90f13984c33d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="36c85ac58bb1677a98b0349f1b2dc8c5", element="7f85a8d6-68b5-4c88-9f99-34882ee29df5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="36c85ac58bb1677a98b0349f1b2dc8c5", element="300b70dc-78e1-46b3-b1be-1a95bdd11793")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="36c85ac58bb1677a98b0349f1b2dc8c5", element="53f36717-23c4-40a1-8af6-cd212a69c856")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="36c85ac58bb1677a98b0349f1b2dc8c5", element="79b68e25-5265-47dc-b51d-2685d4ad8255")>,
# ...

# %%
stoppage=[]
for s in stops:
    stoppage.append(s.text)
stoppage
# Out:
# ['Non Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop']

# %%
flight=driver.find_elements_by_xpath("//span[@class='i-b text ellipsis']")
flight
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="36c85ac58bb1677a98b0349f1b2dc8c5", element="2c5d598f-8044-48fe-b6b4-b8239323b2a1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="36c85ac58bb1677a98b0349f1b2dc8c5", element="2b1cd308-a977-4609-bb3b-b49a3617b1cb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="36c85ac58bb1677a98b0349f1b2dc8c5", element="f39ce5b3-6d30-4b20-87a2-b84955ff219e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="36c85ac58bb1677a98b0349f1b2dc8c5", element="479da664-2502-48b7-b546-08d0ecda6798")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="36c85ac58bb1677a98b0349f1b2dc8c5", element="090ac32d-13f4-43aa-831e-d59fe4ad15d7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="36c85ac58bb1677a98b0349f1b2dc8c5", element="a1f74698-cabd-44a3-bd85-e928a7927f98")>,
# ...

# %%
flight_name=[]
for f in flight:
    flight_name.append(f.text)
flight_name
# Out:
# ['Go First',
#  'SpiceJet',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'IndiGo',
#  'Air India',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Air India',
#  'IndiGo',
#  'Air India',
#  'Go First',
#  'Go First',
#  'Air India']

# %%
prices=driver.find_elements_by_xpath("//div[@class='i-b tipsy fare-summary-tooltip fs-18']")
prices
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="36c85ac58bb1677a98b0349f1b2dc8c5", element="da8a4333-a178-4f29-b7ee-143fec8b6a69")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="36c85ac58bb1677a98b0349f1b2dc8c5", element="3fe26d0f-8c1d-447e-9c7c-09e167cd38e8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="36c85ac58bb1677a98b0349f1b2dc8c5", element="f92646ba-3a31-4d00-bb75-67d5da96785f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="36c85ac58bb1677a98b0349f1b2dc8c5", element="475048e6-db5a-4c12-a585-7b8fbbb9c0f4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="36c85ac58bb1677a98b0349f1b2dc8c5", element="59675ea9-de78-4a7b-923c-1a837ab006e8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="36c85ac58bb1677a98b0349f1b2dc8c5", element="6ce77965-31a6-434e-baa9-3194a537a3d1")>,
# ...

# %%
price=[]
for p in prices:
    price.append(p.text)
price
# Out:
# ['4,592',
#  '6,062',
#  '6,987',
#  '8,457',
#  '8,457',
#  '8,457',
#  '8,898',
#  '10,211',
#  '11,471',
#  '12,625',
#  '13,385',
#  '13,833',
#  '14,541',
#  '16,353',
#  '20,291',
#  '20,448',
#  '21,785',
#  '21,785',
#  '26,748']

# %%
source_=driver.find_elements_by_xpath("//p[@class='fs-10 font-lightgrey no-wrap city ellipsis']")
source_
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="36c85ac58bb1677a98b0349f1b2dc8c5", element="e291bdf2-7763-4bea-867b-d3de01451fd0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="36c85ac58bb1677a98b0349f1b2dc8c5", element="8adab293-f743-44a2-8c30-07ec4c3764a7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="36c85ac58bb1677a98b0349f1b2dc8c5", element="dc1bd6e5-2717-4e58-9571-72c5dbdc1417")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="36c85ac58bb1677a98b0349f1b2dc8c5", element="acde53c2-2d1f-4035-94bd-3dc1d4479694")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="36c85ac58bb1677a98b0349f1b2dc8c5", element="9fe7a12e-cd10-4de2-a598-2b1fb75f65fd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="36c85ac58bb1677a98b0349f1b2dc8c5", element="67d68394-3cb3-4435-8f47-a2cf8026f480")>,
# ...

# %%
source=[]
for s in source_:
    source.append(s.text)
source
# Out:
# ['Pune',
#  'Ahmedabad',
#  'Pune',
#  'Ahmedabad',
#  'Pune',
#  'Ahmedabad',
#  'Pune',
#  'Ahmedabad',
#  'Pune',
#  'Ahmedabad',
#  'Pune',
#  'Ahmedabad',
#  'Pune',
#  'Ahmedabad',
#  'Pune',
#  'Ahmedabad',
#  'Pune',
#  'Ahmedabad',
#  'Pune',
#  'Ahmedabad',
#  'Pune',
#  'Ahmedabad',
#  'Pune',
#  'Ahmedabad',
#  'Pune',
#  'Ahmedabad',
#  'Pune',
#  'Ahmedabad',
#  'Pune',
#  'Ahmedabad',
#  'Pune',
#  'Ahmedabad',
#  'Pune',
#  'Ahmedabad',
#  'Pune',
#  'Ahmedabad',
#  'Pune',
#  'Ahmedabad']

# %%
destination=[]
for d in range(1,len(source),2):
    destination.append(source[d])
destination
# Out:
# ['Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad']

# %%
source1=[]
for s in range(0,len(source),2):
    source1.append(source[s])
source1
# Out:
# ['Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune']

# %%
import pandas as pd
df9=pd.DataFrame({})
df9['Departure Time']=departure_time
df9['Arrival Time']=arrival_time
df9['Source']=source1
df9['Destination']=destination
df9['Duration']=duration
df9['Stoppage']=stoppage
df9['Flight Name']=flight_name
df9['Price']=price
df9
# Out:
#    Departure Time    Arrival Time Source Destination Duration  Stoppage  \
# 0           23:15  00:35\n+ 1 day   Pune   Ahmedabad   1h 20m  Non Stop
# 1           08:40           10:05   Pune   Ahmedabad   1h 25m  Non Stop
# 2           19:30  08:05\n+ 1 day   Pune   Ahmedabad  12h 35m    1 Stop
# 3           08:15           19:40   Pune   Ahmedabad  11h 25m    1 Stop
# 4           08:15  08:05\n+ 1 day   Pune   Ahmedabad  23h 50m    1 Stop
# 5           19:30  19:40\n+ 1 day   Pune   Ahmedabad  24h 10m    1 Stop
# 6           16:40           18:05   Pune   Ahmedabad   1h 25m  Non Stop
# 7           17:40           20:30   Pune   Ahmedabad   2h 50m    1 Stop
# 8           09:10           20:55   Pune   Ahmedabad  11h 45m    1 Stop
# 9           19:00  08:40\n+ 1 day   Pune   Ahmedabad  13h 40m    1 Stop
# 10          19:10  07:30\n+ 1 day   Pune   Ahmedabad  12h 20m    1 Stop
# 11          17:40  08:40\n+ 1 day   Pune   Ahmedabad  15h 00m    1 Stop
# ...

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 95.0.4638
# Get LATEST driver version for 95.0.4638
# Driver [C:\Users\monish\.wdm\drivers\chromedriver\win32\95.0.4638.17\chromedriver.exe] found in cache

# %%
url ="https://www.yatra.com"
driver.get(url)

# %%
search=driver.find_element_by_xpath("//*[@id='BE_flight_flsearch_btn']")
search.click()

# %%
dept_time=driver.find_elements_by_xpath("//div[@class='i-b pr']")
dept_time
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="bc3f8396eba9219c18a5fa15f7c7c722", element="316e8e67-70a7-4d2e-aabd-fff3f9c91457")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="bc3f8396eba9219c18a5fa15f7c7c722", element="19af6749-e8be-4d7f-bb3e-997785eac674")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="bc3f8396eba9219c18a5fa15f7c7c722", element="b22ee8b1-3839-4886-9557-ead536017937")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="bc3f8396eba9219c18a5fa15f7c7c722", element="38dc2693-d20e-4162-9ca5-d181fbc669c7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="bc3f8396eba9219c18a5fa15f7c7c722", element="599b7dd8-c9cd-41f8-9d45-a48f5001fd25")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="bc3f8396eba9219c18a5fa15f7c7c722", element="b8558853-887c-4583-b223-65416ca3dfe1")>,
# ...

# %%
departure_time=[]
for d in dept_time:
    departure_time.append(d.text)
departure_time
# Out:
# ['06:00',
#  '05:55',
#  '15:00',
#  '18:05',
#  '15:00',
#  '02:00',
#  '15:00',
#  '10:30',
#  '16:45',
#  '05:15',
#  '06:40',
#  '06:30',
#  '20:10',
#  '08:45',
#  '11:25',
#  '18:30',
#  '15:30',
#  '22:15',
#  '13:30',
#  '20:20',
#  '18:00',
#  '21:20',
#  '19:10',
#  '07:15',
#  '06:20',
#  '02:00',
#  '10:50',
#  '14:20',
#  '14:20',
#  '15:00',
#  '18:00',
#  '13:00',
#  '08:30',
#  '12:45',
#  '07:25',
#  '06:05',
#  '22:30',
#  '21:00',
#  '14:50',
#  '07:45',
#  '12:55',
#  '12:55',
#  '19:55',
#  '19:00',
#  '16:35',
#  '21:20',
#  '06:00']

# %%
arr_time=driver.find_elements_by_xpath("//p[@class='bold fs-15 mb-2 pr time']")
arr_time
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="bc3f8396eba9219c18a5fa15f7c7c722", element="0d5a8d12-3100-4311-9d26-5da464e17522")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="bc3f8396eba9219c18a5fa15f7c7c722", element="ad91d6c7-4482-4d16-9e7a-e14064a16220")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="bc3f8396eba9219c18a5fa15f7c7c722", element="cc6fe44a-56d9-41ff-a2b3-7ad26ef84e16")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="bc3f8396eba9219c18a5fa15f7c7c722", element="907ad5f2-27b0-4802-88cc-da420c0b54e4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="bc3f8396eba9219c18a5fa15f7c7c722", element="6df4fb38-4a8a-4c89-afe2-9564078fa620")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="bc3f8396eba9219c18a5fa15f7c7c722", element="aaa8d96e-22e5-4fa9-96e8-5e5f61d19250")>,
# ...

# %%
arrival_time=[]
for a in arr_time:
    arrival_time.append(a.text)
arrival_time
# Out:
# ['07:30',
#  '07:40',
#  '20:25',
#  '00:05\n+ 1 day',
#  '21:55',
#  '10:45',
#  '00:05\n+ 1 day',
#  '20:25',
#  '18:10',
#  '06:50',
#  '08:15',
#  '08:05',
#  '21:50',
#  '10:20',
#  '13:10',
#  '19:55',
#  '17:05',
#  '23:50',
#  '15:05',
#  '22:00',
#  '19:40',
#  '07:45\n+ 1 day',
#  '20:40',
#  '12:25',
#  '12:25',
#  '08:50',
#  '13:15',
#  '20:25',
#  '00:05\n+ 1 day',
#  '20:15',
#  '21:30',
#  '20:15',
#  '14:25',
#  '00:35\n+ 1 day',
#  '14:25',
#  '14:25',
#  '08:50\n+ 1 day',
#  '08:50\n+ 1 day',
#  '22:55',
#  '22:55',
#  '22:55',
#  '18:30',
#  '21:30',
#  '07:55\n+ 1 day',
#  '00:35\n+ 1 day',
#  '07:55\n+ 1 day',
#  '20:30']

# %%
durr=driver.find_elements_by_xpath("//p[@class='fs-12 bold du mb-2']")
durr
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="bc3f8396eba9219c18a5fa15f7c7c722", element="c40a8f45-958c-41ff-b6f1-8ae0f3ef548d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="bc3f8396eba9219c18a5fa15f7c7c722", element="36d7ba93-4b9d-430d-aa53-f3d432587352")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="bc3f8396eba9219c18a5fa15f7c7c722", element="b1dae500-e67c-47e2-b072-3fc172f9ffd6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="bc3f8396eba9219c18a5fa15f7c7c722", element="1baae375-5888-44dc-b7c5-77039f3e972b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="bc3f8396eba9219c18a5fa15f7c7c722", element="23e1b821-1842-4486-88b1-5b8a714b59e1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="bc3f8396eba9219c18a5fa15f7c7c722", element="b6254051-bef4-4cc1-bf56-c8ec6186c8fc")>,
# ...

# %%
duration=[]
for r in durr:
    duration.append(r.text)
duration
# Out:
# ['1h 30m',
#  '1h 45m',
#  '5h 25m',
#  '6h 00m',
#  '6h 55m',
#  '8h 45m',
#  '9h 05m',
#  '9h 55m',
#  '1h 25m',
#  '1h 35m',
#  '1h 35m',
#  '1h 35m',
#  '1h 40m',
#  '1h 35m',
#  '1h 45m',
#  '1h 25m',
#  '1h 35m',
#  '1h 35m',
#  '1h 35m',
#  '1h 40m',
#  '1h 40m',
#  '10h 25m',
#  '1h 30m',
#  '5h 10m',
#  '6h 05m',
#  '6h 50m',
#  '2h 25m',
#  '6h 05m',
#  '9h 45m',
#  '5h 15m',
#  '3h 30m',
#  '7h 15m',
#  '5h 55m',
#  '11h 50m',
#  '7h 00m',
#  '8h 20m',
#  '10h 20m',
#  '11h 50m',
#  '8h 05m',
#  '15h 10m',
#  '10h 00m',
#  '5h 35m',
#  '1h 35m',
#  '12h 55m',
#  '8h 00m',
#  '10h 35m',
#  '14h 30m']

# %%
stops=driver.find_elements_by_xpath("//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']")
stops
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="bc3f8396eba9219c18a5fa15f7c7c722", element="09c05eda-3c44-40f4-bd8a-d18dc83ae010")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="bc3f8396eba9219c18a5fa15f7c7c722", element="02b2d2f3-c8bd-4ba9-b6e8-a3e6e541d652")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="bc3f8396eba9219c18a5fa15f7c7c722", element="cd06dc2c-4e43-4447-ba05-b65adcebb342")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="bc3f8396eba9219c18a5fa15f7c7c722", element="c7c0c150-8f5d-49ff-8edc-250499e23f59")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="bc3f8396eba9219c18a5fa15f7c7c722", element="c282c8ce-4cf1-4872-a81d-cfc963e9bee4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="bc3f8396eba9219c18a5fa15f7c7c722", element="cd382b2d-b62a-4a44-b478-a1c4454e7e30")>,
# ...

# %%
stoppage=[]
for s in stops:
    stoppage.append(s.text)
stoppage
# Out:
# ['Non Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  '1 Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '3 Stop(s)',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)']

# %%
flight=driver.find_elements_by_xpath("//span[@class='i-b text ellipsis']")
flight
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="bc3f8396eba9219c18a5fa15f7c7c722", element="613e8926-85c6-490b-9bab-313ed45e4f7f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="bc3f8396eba9219c18a5fa15f7c7c722", element="7b5913c4-6eda-4ff2-8a57-86e889f153e8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="bc3f8396eba9219c18a5fa15f7c7c722", element="cd903b35-496c-438a-800e-c2d0bc2ecb5d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="bc3f8396eba9219c18a5fa15f7c7c722", element="62d61d7b-cfde-4f43-896f-4633539676bb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="bc3f8396eba9219c18a5fa15f7c7c722", element="ae0b2d79-7dd1-4b02-a227-25553db7b846")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="bc3f8396eba9219c18a5fa15f7c7c722", element="1d0b44c7-fbb4-4e7b-bd2e-f26804f50a21")>,
# ...

# %%
flight_name=[]
for f in flight:
    flight_name.append(f.text)
flight_name
# Out:
# ['Go First',
#  'SpiceJet',
#  'Go First',
#  'Go First',
#  'SpiceJet',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Air India',
#  'IndiGo',
#  'IndiGo',
#  'Vistara',
#  'SpiceJet',
#  'Vistara',
#  'IndiGo',
#  'IndiGo',
#  'Go First',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Vistara',
#  'IndiGo',
#  'Air India',
#  'IndiGo',
#  'IndiGo',
#  'Go First',
#  'Air India',
#  'Go First',
#  'Go First',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Go First',
#  'IndiGo',
#  'IndiGo',
#  'Go First',
#  'Go First',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Go First',
#  'SpiceJet',
#  'Go First',
#  'IndiGo',
#  'Air India']

# %%
prices=driver.find_elements_by_xpath("//div[@class='i-b tipsy fare-summary-tooltip fs-18']")
prices
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="bc3f8396eba9219c18a5fa15f7c7c722", element="5dba5a72-a510-4915-a927-9ffc7069f9e4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="bc3f8396eba9219c18a5fa15f7c7c722", element="e0f687f3-5a54-42b3-9eb6-2d8e8532e16d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="bc3f8396eba9219c18a5fa15f7c7c722", element="02c90774-764a-4248-b26f-3e431f23a27d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="bc3f8396eba9219c18a5fa15f7c7c722", element="8ade3a20-33ca-4c18-83b5-8e84a7e81e16")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="bc3f8396eba9219c18a5fa15f7c7c722", element="74e194e6-a28f-4f71-b752-cc2ab93691c8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="bc3f8396eba9219c18a5fa15f7c7c722", element="c4d89ee9-4db3-43b5-91ec-afaf1821737d")>,
# ...

# %%
price=[]
for p in prices:
    price.append(p.text)
price
# Out:
# ['5,114',
#  '5,114',
#  '5,114',
#  '5,114',
#  '5,114',
#  '5,114',
#  '5,114',
#  '5,114',
#  '5,115',
#  '5,115',
#  '5,115',
#  '5,430',
#  '5,640',
#  '5,693',
#  '5,955',
#  '6,165',
#  '6,270',
#  '6,795',
#  '7,110',
#  '7,110',
#  '8,318',
#  '8,948',
#  '9,210',
#  '9,473',
#  '9,473',
#  '9,704',
#  '9,893',
#  '10,280',
#  '10,280',
#  '10,418',
#  '10,628',
#  '10,628',
#  '10,649',
#  '10,891',
#  '10,943',
#  '10,943',
#  '11,174',
#  '11,750',
#  '12,019',
#  '12,071',
#  '12,098',
#  '12,218',
#  '13,514',
#  '13,699',
#  '15,979',
#  '18,135',
#  '19,028']

# %%
source_=driver.find_elements_by_xpath("//p[@class='fs-10 font-lightgrey no-wrap city ellipsis']")
source_
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="bc3f8396eba9219c18a5fa15f7c7c722", element="063f1e0b-e92f-4bb8-b921-c62999752f1f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="bc3f8396eba9219c18a5fa15f7c7c722", element="626f0678-ecbe-4bc7-920b-f6dd36ae6c1b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="bc3f8396eba9219c18a5fa15f7c7c722", element="86325f1d-6420-4457-95b8-f47e44bd4a32")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="bc3f8396eba9219c18a5fa15f7c7c722", element="b7dbe759-b5d4-4518-8820-024ed111d2d8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="bc3f8396eba9219c18a5fa15f7c7c722", element="4311b6ee-fc41-4691-b612-4501db26fb3b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="bc3f8396eba9219c18a5fa15f7c7c722", element="2f064237-e7b8-4379-afed-c57318969baa")>,
# ...

# %%
source=[]
for s in source_:
    source.append(s.text)
source
# Out:
# ['New Delhi',
#  'Ahmedabad',
#  'New Delhi',
#  'Ahmedabad',
#  'New Delhi',
#  'Ahmedabad',
#  'New Delhi',
#  'Ahmedabad',
#  'New Delhi',
#  'Ahmedabad',
#  'New Delhi',
#  'Ahmedabad',
#  'New Delhi',
#  'Ahmedabad',
#  'New Delhi',
#  'Ahmedabad',
#  'New Delhi',
#  'Ahmedabad',
#  'New Delhi',
#  'Ahmedabad',
#  'New Delhi',
#  'Ahmedabad',
#  'New Delhi',
#  'Ahmedabad',
#  'New Delhi',
#  'Ahmedabad',
#  'New Delhi',
#  'Ahmedabad',
#  'New Delhi',
#  'Ahmedabad',
#  'New Delhi',
#  'Ahmedabad',
#  'New Delhi',
#  'Ahmedabad',
#  'New Delhi',
#  'Ahmedabad',
#  'New Delhi',
#  'Ahmedabad',
#  'New Delhi',
#  'Ahmedabad',
#  'New Delhi',
#  'Ahmedabad',
#  'New Delhi',
#  'Ahmedabad',
#  'New Delhi',
#  'Ahmedabad',
#  'New Delhi',
#  'Ahmedabad',
#  'New Delhi',
#  'Ahmedabad',
#  'New Delhi',
#  'Ahmedabad',
#  'New Delhi',
#  'Ahmedabad',
#  'New Delhi',
#  'Ahmedabad',
#  'New Delhi',
#  'Ahmedabad',
#  'New Delhi',
#  'Ahmedabad',
#  'New Delhi',
#  'Ahmedabad',
# ...

# %%
destination=[]
for d in range(1,len(source),2):
    destination.append(source[d])
destination
# Out:
# ['Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad']

# %%
source1=[]
for s in range(0,len(source),2):
    source1.append(source[s])
source1
# Out:
# ['New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi']

# %%
import pandas as pd
df10=pd.DataFrame({})
df10['Departure Time']=departure_time
df10['Arrival Time']=arrival_time
df10['Source']=source1
df10['Destination']=destination
df10['Duration']=duration
df10['Stoppage']=stoppage
df10['Flight Name']=flight_name
df10['Price']=price
df10
# Out:
#    Departure Time    Arrival Time     Source Destination Duration   Stoppage  \
# 0           06:00           07:30  New Delhi   Ahmedabad   1h 30m   Non Stop
# 1           05:55           07:40  New Delhi   Ahmedabad   1h 45m   Non Stop
# 2           15:00           20:25  New Delhi   Ahmedabad   5h 25m     1 Stop
# 3           18:05  00:05\n+ 1 day  New Delhi   Ahmedabad   6h 00m     1 Stop
# 4           15:00           21:55  New Delhi   Ahmedabad   6h 55m     1 Stop
# 5           02:00           10:45  New Delhi   Ahmedabad   8h 45m     1 Stop
# 6           15:00  00:05\n+ 1 day  New Delhi   Ahmedabad   9h 05m     1 Stop
# 7           10:30           20:25  New Delhi   Ahmedabad   9h 55m     1 Stop
# 8           16:45           18:10  New Delhi   Ahmedabad   1h 25m   Non Stop
# 9           05:15           06:50  New Delhi   Ahmedabad   1h 35m   Non Stop
# 10          06:40           08:15  New Delhi   Ahmedabad   1h 35m   Non Stop
# ...

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 95.0.4638
# Get LATEST driver version for 95.0.4638
# Driver [C:\Users\monish\.wdm\drivers\chromedriver\win32\95.0.4638.17\chromedriver.exe] found in cache

# %%
url ="https://www.yatra.com"
driver.get(url)

# %%
search=driver.find_element_by_xpath("//*[@id='BE_flight_flsearch_btn']")
search.click()

# %%
dept_time=driver.find_elements_by_xpath("//div[@class='i-b pr']")
dept_time
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="9f9d4dd171ea2aeee7895e4658665840", element="a5b75fa4-305a-4512-a15e-ae2fbcf35630")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9f9d4dd171ea2aeee7895e4658665840", element="c87189ad-56e0-49b5-8144-808ac221c5a9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9f9d4dd171ea2aeee7895e4658665840", element="1b329fe5-8530-4575-b8ab-35f09c1da0e0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9f9d4dd171ea2aeee7895e4658665840", element="0bf58a17-f786-4df7-98bf-94cc6f595d3c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9f9d4dd171ea2aeee7895e4658665840", element="43e89336-f262-40ae-b95f-903b1f72da3e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9f9d4dd171ea2aeee7895e4658665840", element="faf013ac-2a20-45c6-83dc-76bf7c471cab")>,
# ...

# %%
departure_time=[]
for d in dept_time:
    departure_time.append(d.text)
departure_time
# Out:
# ['06:05',
#  '05:35',
#  '06:05',
#  '05:35',
#  '08:00',
#  '05:30',
#  '11:00',
#  '07:25',
#  '07:55',
#  '06:45',
#  '23:05',
#  '12:45',
#  '17:45',
#  '17:25',
#  '11:10',
#  '08:00',
#  '16:20',
#  '15:25',
#  '23:05',
#  '08:20',
#  '09:40',
#  '07:25',
#  '06:00',
#  '07:00',
#  '09:15',
#  '16:35',
#  '16:05',
#  '07:45',
#  '11:05',
#  '18:40',
#  '08:30',
#  '11:25',
#  '16:00',
#  '09:55',
#  '20:10',
#  '05:50',
#  '08:35',
#  '21:00',
#  '16:40',
#  '13:30',
#  '15:30']

# %%
arr_time=driver.find_elements_by_xpath("//p[@class='bold fs-15 mb-2 pr time']")
arr_time
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="9f9d4dd171ea2aeee7895e4658665840", element="9f8f6443-5b20-4d2c-af25-f80b634f570d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9f9d4dd171ea2aeee7895e4658665840", element="bfe69704-84d8-4f63-ab74-659b471e7b84")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9f9d4dd171ea2aeee7895e4658665840", element="cd9f8b6c-8493-4302-af44-9103848692d4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9f9d4dd171ea2aeee7895e4658665840", element="2318f522-e7f1-45f8-a76c-9f7d528a2768")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9f9d4dd171ea2aeee7895e4658665840", element="0b2d63ca-302a-47ca-a5b3-be4b9fedbcb5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9f9d4dd171ea2aeee7895e4658665840", element="41d73b1f-373a-45c1-a63d-e7c381ef1367")>,
# ...

# %%
arrival_time=[]
for a in arr_time:
    arrival_time.append(a.text)
arrival_time
# Out:
# ['18:15',
#  '18:15',
#  '19:00',
#  '19:00',
#  '14:25',
#  '13:10',
#  '16:45',
#  '13:25',
#  '16:45',
#  '16:45',
#  '09:20\n+ 1 day',
#  '14:50',
#  '19:55',
#  '19:40',
#  '13:15',
#  '10:15',
#  '18:35',
#  '17:20',
#  '10:35\n+ 1 day',
#  '10:25',
#  '16:45',
#  '17:15',
#  '08:05',
#  '15:10',
#  '15:10',
#  '18:40',
#  '18:05',
#  '17:25',
#  '16:40',
#  '08:30\n+ 1 day',
#  '17:25',
#  '19:40',
#  '18:10',
#  '16:40',
#  '08:15\n+ 1 day',
#  '14:20',
#  '17:15',
#  '11:20\n+ 1 day',
#  '18:45',
#  '19:40',
#  '22:25']

# %%
durr=driver.find_elements_by_xpath("//p[@class='fs-12 bold du mb-2']")
durr
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="9f9d4dd171ea2aeee7895e4658665840", element="2bba1db1-e2b5-48b3-9d17-1a1bb2db5d77")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9f9d4dd171ea2aeee7895e4658665840", element="7e37c0b8-8283-40d1-a0c8-d5100a9ed4fd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9f9d4dd171ea2aeee7895e4658665840", element="6e1d2dca-b18c-4563-9b42-c0d1b579576c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9f9d4dd171ea2aeee7895e4658665840", element="5477e580-496e-466f-823d-912621937bc9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9f9d4dd171ea2aeee7895e4658665840", element="f5461a3e-764d-49ac-b01a-044997ceedd6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9f9d4dd171ea2aeee7895e4658665840", element="e68a9938-aa17-4b4b-a9e0-5bdfbf4c71b8")>,
# ...

# %%
duration=[]
for r in durr:
    duration.append(r.text)
duration
# Out:
# ['12h 10m',
#  '12h 40m',
#  '12h 55m',
#  '13h 25m',
#  '6h 25m',
#  '7h 40m',
#  '5h 45m',
#  '6h 00m',
#  '8h 50m',
#  '10h 00m',
#  '10h 15m',
#  '2h 05m',
#  '2h 10m',
#  '2h 15m',
#  '2h 05m',
#  '2h 15m',
#  '2h 15m',
#  '1h 55m',
#  '11h 30m',
#  '2h 05m',
#  '7h 05m',
#  '9h 50m',
#  '2h 05m',
#  '8h 10m',
#  '5h 55m',
#  '2h 05m',
#  '2h 00m',
#  '9h 40m',
#  '5h 35m',
#  '13h 50m',
#  '8h 55m',
#  '8h 15m',
#  '2h 10m',
#  '6h 45m',
#  '12h 05m',
#  '8h 30m',
#  '8h 40m',
#  '14h 20m',
#  '2h 05m',
#  '6h 10m',
#  '6h 55m']

# %%
stops=driver.find_elements_by_xpath("//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']")
stops
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="9f9d4dd171ea2aeee7895e4658665840", element="d1e02d60-05fc-455f-b2a7-cd029a1cf9e9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9f9d4dd171ea2aeee7895e4658665840", element="e262ba72-a11e-4336-8fc0-dc3dbc6c57ba")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9f9d4dd171ea2aeee7895e4658665840", element="b42714e9-7401-4631-a3c6-53abc529992c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9f9d4dd171ea2aeee7895e4658665840", element="7e2a10c5-92c0-4795-af1a-6a7bd3f7e19e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9f9d4dd171ea2aeee7895e4658665840", element="b8478e58-03b4-4ff9-8fac-a27b651ecdc9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9f9d4dd171ea2aeee7895e4658665840", element="6c63871b-4b6a-4c87-832e-733def72955f")>,
# ...

# %%
stoppage=[]
for s in stops:
    stoppage.append(s.text)
stoppage
# Out:
# ['1 Stop',
#  '2 Stop(s)',
#  '1 Stop',
#  '2 Stop(s)',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  '1 Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  'Non Stop',
#  '2 Stop(s)',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop']

# %%
flight=driver.find_elements_by_xpath("//span[@class='i-b text ellipsis']")
flight
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="9f9d4dd171ea2aeee7895e4658665840", element="7ae6368a-0b5d-46bf-9fc0-e2b3e9e30d11")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9f9d4dd171ea2aeee7895e4658665840", element="eb39c664-a437-4f2e-babf-bd5465e36e39")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9f9d4dd171ea2aeee7895e4658665840", element="525d40aa-a519-45e1-8204-c77335dd5307")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9f9d4dd171ea2aeee7895e4658665840", element="9f3c46ad-3150-4123-b28b-6f3fa626881d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9f9d4dd171ea2aeee7895e4658665840", element="8be7da22-5326-4fb1-ad8e-a558fd637e0f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9f9d4dd171ea2aeee7895e4658665840", element="08118392-1cf6-4233-b63d-701cfa5e7c7f")>,
# ...

# %%
flight_name=[]
for f in flight:
    flight_name.append(f.text)
flight_name
# Out:
# ['Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Air Asia',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Go First',
#  'SpiceJet',
#  'Vistara',
#  'IndiGo',
#  'Go First',
#  'Vistara',
#  'Air Asia',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Air India',
#  'IndiGo',
#  'IndiGo',
#  'Go First',
#  'Air Asia',
#  'IndiGo',
#  'IndiGo',
#  'Go First',
#  'IndiGo',
#  'IndiGo',
#  'Air India',
#  'IndiGo',
#  'SpiceJet',
#  'Go First',
#  'IndiGo',
#  'Air Asia',
#  'IndiGo',
#  'IndiGo',
#  'Go First']

# %%
prices=driver.find_elements_by_xpath("//div[@class='i-b tipsy fare-summary-tooltip fs-18']")
prices
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="9f9d4dd171ea2aeee7895e4658665840", element="0d5bd812-ec85-4be8-9cbd-cf8fb49b150d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9f9d4dd171ea2aeee7895e4658665840", element="89aa966f-c5bf-484a-ad5e-3baed212d229")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9f9d4dd171ea2aeee7895e4658665840", element="d98038e6-68fd-408c-bb5a-58a537563b0c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9f9d4dd171ea2aeee7895e4658665840", element="50346f84-b7fa-4f06-91d5-91317cadc62b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9f9d4dd171ea2aeee7895e4658665840", element="b823b14e-b083-47e0-a173-34de42ef9229")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9f9d4dd171ea2aeee7895e4658665840", element="8feee30d-ab34-46ea-8518-23b3c74a2dd1")>,
# ...

# %%
price=[]
for p in prices:
    price.append(p.text)
price
# Out:
# ['5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '6,270',
#  '6,443',
#  '6,932',
#  '6,932',
#  '6,932',
#  '6,932',
#  '6,932',
#  '7,110',
#  '7,110',
#  '8,055',
#  '8,423',
#  '8,474',
#  '8,790',
#  '8,791',
#  '8,885',
#  '8,895',
#  '9,373',
#  '9,373',
#  '9,525',
#  '9,861',
#  '10,349',
#  '10,500',
#  '10,637',
#  '11,378',
#  '12,302',
#  '12,729',
#  '12,791',
#  '13,767',
#  '14,145',
#  '14,744',
#  '14,959',
#  '15,039',
#  '15,353',
#  '15,510',
#  '15,720',
#  '15,872',
#  '16,639']

# %%
source_=driver.find_elements_by_xpath("//p[@class='fs-10 font-lightgrey no-wrap city ellipsis']")
source_
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="9f9d4dd171ea2aeee7895e4658665840", element="1d266bf5-ca3b-4b19-a4a9-637932c1b45c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9f9d4dd171ea2aeee7895e4658665840", element="af1f01b4-38a7-48f1-ba7c-b7b7b8248963")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9f9d4dd171ea2aeee7895e4658665840", element="d8ae26c9-6e2b-411d-93f5-90ce41b40f8f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9f9d4dd171ea2aeee7895e4658665840", element="962a066d-90a1-4162-b453-0218aba8fd95")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9f9d4dd171ea2aeee7895e4658665840", element="1d3548b3-17be-4f23-ade7-d47c98b79af6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="9f9d4dd171ea2aeee7895e4658665840", element="bb3fb8ba-4869-4f48-bf69-2eccfb81176f")>,
# ...

# %%
source=[]
for s in source_:
    source.append(s.text)
source
# Out:
# ['New Delhi',
#  'Pune',
#  'New Delhi',
#  'Pune',
#  'New Delhi',
#  'Pune',
#  'New Delhi',
#  'Pune',
#  'New Delhi',
#  'Pune',
#  'New Delhi',
#  'Pune',
#  'New Delhi',
#  'Pune',
#  'New Delhi',
#  'Pune',
#  'New Delhi',
#  'Pune',
#  'New Delhi',
#  'Pune',
#  'New Delhi',
#  'Pune',
#  'New Delhi',
#  'Pune',
#  'New Delhi',
#  'Pune',
#  'New Delhi',
#  'Pune',
#  'New Delhi',
#  'Pune',
#  'New Delhi',
#  'Pune',
#  'New Delhi',
#  'Pune',
#  'New Delhi',
#  'Pune',
#  'New Delhi',
#  'Pune',
#  'New Delhi',
#  'Pune',
#  'New Delhi',
#  'Pune',
#  'New Delhi',
#  'Pune',
#  'New Delhi',
#  'Pune',
#  'New Delhi',
#  'Pune',
#  'New Delhi',
#  'Pune',
#  'New Delhi',
#  'Pune',
#  'New Delhi',
#  'Pune',
#  'New Delhi',
#  'Pune',
#  'New Delhi',
#  'Pune',
#  'New Delhi',
#  'Pune',
#  'New Delhi',
#  'Pune',
#  'New Delhi',
#  'Pune',
#  'New Delhi',
#  'Pune',
#  'New Delhi',
#  'Pune',
#  'New Delhi',
#  'Pune',
#  'New Delhi',
#  'Pune',
#  'New Delhi',
#  'Pune',
# ...

# %%
destination=[]
for d in range(1,len(source),2):
    destination.append(source[d])
destination
# Out:
# ['Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune']

# %%
source1=[]
for s in range(0,len(source),2):
    source1.append(source[s])
source1
# Out:
# ['New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi']

# %%
import pandas as pd
df11=pd.DataFrame({})
df11['Departure Time']=departure_time
df11['Arrival Time']=arrival_time
df11['Source']=source1
df11['Destination']=destination
df11['Duration']=duration
df11['Stoppage']=stoppage
df11['Flight Name']=flight_name
df11['Price']=price
df11
# Out:
#    Departure Time    Arrival Time     Source Destination Duration   Stoppage  \
# 0           06:05           18:15  New Delhi        Pune  12h 10m     1 Stop
# 1           05:35           18:15  New Delhi        Pune  12h 40m  2 Stop(s)
# 2           06:05           19:00  New Delhi        Pune  12h 55m     1 Stop
# 3           05:35           19:00  New Delhi        Pune  13h 25m  2 Stop(s)
# 4           08:00           14:25  New Delhi        Pune   6h 25m     1 Stop
# 5           05:30           13:10  New Delhi        Pune   7h 40m     1 Stop
# 6           11:00           16:45  New Delhi        Pune   5h 45m     1 Stop
# 7           07:25           13:25  New Delhi        Pune   6h 00m     1 Stop
# 8           07:55           16:45  New Delhi        Pune   8h 50m     1 Stop
# 9           06:45           16:45  New Delhi        Pune  10h 00m     1 Stop
# 10          23:05  09:20\n+ 1 day  New Delhi        Pune  10h 15m     1 Stop
# ...

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 95.0.4638
# Get LATEST driver version for 95.0.4638
# Driver [C:\Users\monish\.wdm\drivers\chromedriver\win32\95.0.4638.17\chromedriver.exe] found in cache

# %%
url ="https://www.yatra.com"
driver.get(url)

# %%
search=driver.find_element_by_xpath("//*[@id='BE_flight_flsearch_btn']")
search.click()

# %%
dept_time=driver.find_elements_by_xpath("//div[@class='i-b pr']")
dept_time
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="259e2ec5ac0e014c6cf0c00dc20e6073", element="55b25747-2b7b-4e59-b525-5f0ffee86016")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="259e2ec5ac0e014c6cf0c00dc20e6073", element="1b02c259-c266-42b4-ba92-932d62b57d89")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="259e2ec5ac0e014c6cf0c00dc20e6073", element="8f169a25-a3e7-4e08-8705-5c118b74d437")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="259e2ec5ac0e014c6cf0c00dc20e6073", element="d33095aa-92ba-47d4-9411-265cc9b212e1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="259e2ec5ac0e014c6cf0c00dc20e6073", element="a99a5e2e-3e7e-4da5-9256-9396a5022c48")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="259e2ec5ac0e014c6cf0c00dc20e6073", element="3133c91a-6a5c-448c-a84c-1e6d2557db15")>,
# ...

# %%
departure_time=[]
for d in dept_time:
    departure_time.append(d.text)
departure_time
# Out:
# ['19:30',
#  '12:15',
#  '06:05',
#  '09:55',
#  '22:40',
#  '13:30',
#  '21:15',
#  '12:15',
#  '20:15',
#  '22:40',
#  '06:00',
#  '09:55',
#  '15:15',
#  '10:35',
#  '19:35',
#  '08:05',
#  '06:30',
#  '22:45',
#  '21:55',
#  '20:55',
#  '19:45',
#  '18:30',
#  '17:30',
#  '22:45',
#  '21:55']

# %%
arr_time=driver.find_elements_by_xpath("//p[@class='bold fs-15 mb-2 pr time']")
arr_time
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="259e2ec5ac0e014c6cf0c00dc20e6073", element="8c0d960c-3497-4ba7-8034-ea295647eaae")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="259e2ec5ac0e014c6cf0c00dc20e6073", element="c61ed270-ad06-46b6-b762-2ee62401d2b1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="259e2ec5ac0e014c6cf0c00dc20e6073", element="dc31e8ab-78fd-4d5a-b316-f4e4eb9687f9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="259e2ec5ac0e014c6cf0c00dc20e6073", element="37d30e19-c97f-49e9-b60a-5752d511c7e1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="259e2ec5ac0e014c6cf0c00dc20e6073", element="447c3e82-a046-48ff-ad37-344979695d62")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="259e2ec5ac0e014c6cf0c00dc20e6073", element="09a1e08f-8616-444a-b9b6-4571c75bf263")>,
# ...

# %%
arrival_time=[]
for a in arr_time:
    arrival_time.append(a.text)
arrival_time
# Out:
# ['22:10',
#  '17:55',
#  '13:20',
#  '17:55',
#  '07:00\n+ 1 day',
#  '22:15',
#  '07:00\n+ 1 day',
#  '22:15',
#  '07:00\n+ 1 day',
#  '10:15\n+ 1 day',
#  '17:55',
#  '22:15',
#  '17:40',
#  '13:00',
#  '21:50',
#  '10:30',
#  '14:50',
#  '08:40\n+ 1 day',
#  '08:40\n+ 1 day',
#  '08:40\n+ 1 day',
#  '08:40\n+ 1 day',
#  '08:40\n+ 1 day',
#  '08:40\n+ 1 day',
#  '14:50\n+ 1 day',
#  '14:50\n+ 1 day']

# %%
durr=driver.find_elements_by_xpath("//p[@class='fs-12 bold du mb-2']")
durr
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="259e2ec5ac0e014c6cf0c00dc20e6073", element="b3900542-a523-4e24-8b05-ef117a557eec")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="259e2ec5ac0e014c6cf0c00dc20e6073", element="75e8e4a0-4a17-44d1-ab53-c1b0c23f763c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="259e2ec5ac0e014c6cf0c00dc20e6073", element="da8a9913-5bff-424d-8c41-16670057deeb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="259e2ec5ac0e014c6cf0c00dc20e6073", element="bc29b005-4ce8-41fe-aefa-f5e48b659bc1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="259e2ec5ac0e014c6cf0c00dc20e6073", element="3cf44341-e821-49f5-b195-47112a637cb6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="259e2ec5ac0e014c6cf0c00dc20e6073", element="691393d1-6f92-4139-944b-5df8c094165d")>,
# ...

# %%
duration=[]
for r in durr:
    duration.append(r.text)
duration
# Out:
# ['2h 40m',
#  '5h 40m',
#  '7h 15m',
#  '8h 00m',
#  '8h 20m',
#  '8h 45m',
#  '9h 45m',
#  '10h 00m',
#  '10h 45m',
#  '11h 35m',
#  '11h 55m',
#  '12h 20m',
#  '2h 25m',
#  '2h 25m',
#  '2h 15m',
#  '2h 25m',
#  '8h 20m',
#  '9h 55m',
#  '10h 45m',
#  '11h 45m',
#  '12h 55m',
#  '14h 10m',
#  '15h 10m',
#  '16h 05m',
#  '16h 55m']

# %%
stops=driver.find_elements_by_xpath("//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']")
stops
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="259e2ec5ac0e014c6cf0c00dc20e6073", element="e506bcf5-47ec-41f9-beac-1b6fa18ab07f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="259e2ec5ac0e014c6cf0c00dc20e6073", element="936436c1-840e-4937-86d0-80273e409514")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="259e2ec5ac0e014c6cf0c00dc20e6073", element="7e74f64e-47cb-436b-b905-d702c46c07f1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="259e2ec5ac0e014c6cf0c00dc20e6073", element="47950321-e199-40d4-8a4c-4608143685d0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="259e2ec5ac0e014c6cf0c00dc20e6073", element="73c9c840-1307-4068-93b4-40a82cd5f0b4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="259e2ec5ac0e014c6cf0c00dc20e6073", element="8715fccf-0ae0-48ea-b070-ad527b735f31")>,
# ...

# %%
stoppage=[]
for s in stops:
    stoppage.append(s.text)
stoppage
# Out:
# ['Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop']

# %%
flight=driver.find_elements_by_xpath("//span[@class='i-b text ellipsis']")
flight
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="259e2ec5ac0e014c6cf0c00dc20e6073", element="070de333-4826-4db4-9d60-ead88b2fa997")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="259e2ec5ac0e014c6cf0c00dc20e6073", element="b7560fb2-8229-4e3f-864e-bd9b08796c07")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="259e2ec5ac0e014c6cf0c00dc20e6073", element="5729aa22-23e9-4de0-9539-b3d235f494dc")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="259e2ec5ac0e014c6cf0c00dc20e6073", element="1af994dd-63ec-46e0-ab10-0eb5fe85b654")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="259e2ec5ac0e014c6cf0c00dc20e6073", element="e638c327-e66e-467a-9d4c-fe614e46c77c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="259e2ec5ac0e014c6cf0c00dc20e6073", element="1fd64fa7-b25a-4e02-9d58-ba67c21311bd")>,
# ...

# %%
flight_name=[]
for f in flight:
    flight_name.append(f.text)
flight_name
# Out:
# ['Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'IndiGo',
#  'Air India',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara']

# %%
prices=driver.find_elements_by_xpath("//div[@class='i-b tipsy fare-summary-tooltip fs-18']")
prices
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="259e2ec5ac0e014c6cf0c00dc20e6073", element="d4412b56-200a-42ff-bef3-fd4f3f226c6e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="259e2ec5ac0e014c6cf0c00dc20e6073", element="83ff0a45-63be-4b5d-bf1c-8bd515130da9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="259e2ec5ac0e014c6cf0c00dc20e6073", element="f52d3ff2-e5ab-4aca-9ca5-42afcb9613bd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="259e2ec5ac0e014c6cf0c00dc20e6073", element="3917a12d-8a7c-472f-b528-7abebd6340b6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="259e2ec5ac0e014c6cf0c00dc20e6073", element="9648d05f-eb39-44ad-b10a-3a395c2a11e8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="259e2ec5ac0e014c6cf0c00dc20e6073", element="92f3c8b8-8b4d-4fcb-ac3b-b54fbaff74f1")>,
# ...

# %%
price=[]
for p in prices:
    price.append(p.text)
price
# Out:
# ['5,942',
#  '5,942',
#  '5,942',
#  '5,942',
#  '5,942',
#  '5,942',
#  '5,942',
#  '5,942',
#  '5,942',
#  '5,942',
#  '5,942',
#  '5,942',
#  '6,416',
#  '7,629',
#  '7,630',
#  '8,043',
#  '8,451',
#  '8,451',
#  '8,451',
#  '8,451',
#  '8,451',
#  '8,451',
#  '8,451',
#  '8,451',
#  '8,451']

# %%
source_=driver.find_elements_by_xpath("//p[@class='fs-10 font-lightgrey no-wrap city ellipsis']")
source_
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="259e2ec5ac0e014c6cf0c00dc20e6073", element="3f712026-a6d4-4556-8520-2629f5c14d6e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="259e2ec5ac0e014c6cf0c00dc20e6073", element="5e258669-f3f9-4254-b022-8afae638821b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="259e2ec5ac0e014c6cf0c00dc20e6073", element="7386f525-04ac-4d85-95f9-046af6f8a9d5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="259e2ec5ac0e014c6cf0c00dc20e6073", element="26fd51a2-0c9e-40c3-8553-58b572f10780")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="259e2ec5ac0e014c6cf0c00dc20e6073", element="5fe1bdf4-1c1b-4812-af23-02337110a056")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="259e2ec5ac0e014c6cf0c00dc20e6073", element="4814469e-1f83-4b87-b08b-44ae73ed8063")>,
# ...

# %%
source=[]
for s in source_:
    source.append(s.text)
source
# Out:
# ['Mumbai',
#  'Lucknow',
#  'Mumbai',
#  'Lucknow',
#  'Mumbai',
#  'Lucknow',
#  'Mumbai',
#  'Lucknow',
#  'Mumbai',
#  'Lucknow',
#  'Mumbai',
#  'Lucknow',
#  'Mumbai',
#  'Lucknow',
#  'Mumbai',
#  'Lucknow',
#  'Mumbai',
#  'Lucknow',
#  'Mumbai',
#  'Lucknow',
#  'Mumbai',
#  'Lucknow',
#  'Mumbai',
#  'Lucknow',
#  'Mumbai',
#  'Lucknow',
#  'Mumbai',
#  'Lucknow',
#  'Mumbai',
#  'Lucknow',
#  'Mumbai',
#  'Lucknow',
#  'Mumbai',
#  'Lucknow',
#  'Mumbai',
#  'Lucknow',
#  'Mumbai',
#  'Lucknow',
#  'Mumbai',
#  'Lucknow',
#  'Mumbai',
#  'Lucknow',
#  'Mumbai',
#  'Lucknow',
#  'Mumbai',
#  'Lucknow',
#  'Mumbai',
#  'Lucknow',
#  'Mumbai',
#  'Lucknow']

# %%
destination=[]
for d in range(1,len(source),2):
    destination.append(source[d])
destination
# Out:
# ['Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow']

# %%
source1=[]
for s in range(0,len(source),2):
    source1.append(source[s])
source1
# Out:
# ['Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai']

# %%
import pandas as pd
df12=pd.DataFrame({})
df12['Departure Time']=departure_time
df12['Arrival Time']=arrival_time
df12['Source']=source1
df12['Destination']=destination
df12['Duration']=duration
df12['Stoppage']=stoppage
df12['Flight Name']=flight_name
df12['Price']=price
df12
# Out:
#    Departure Time    Arrival Time  Source Destination Duration  Stoppage  \
# 0           19:30           22:10  Mumbai     Lucknow   2h 40m  Non Stop
# 1           12:15           17:55  Mumbai     Lucknow   5h 40m    1 Stop
# 2           06:05           13:20  Mumbai     Lucknow   7h 15m    1 Stop
# 3           09:55           17:55  Mumbai     Lucknow   8h 00m    1 Stop
# 4           22:40  07:00\n+ 1 day  Mumbai     Lucknow   8h 20m    1 Stop
# 5           13:30           22:15  Mumbai     Lucknow   8h 45m    1 Stop
# 6           21:15  07:00\n+ 1 day  Mumbai     Lucknow   9h 45m    1 Stop
# 7           12:15           22:15  Mumbai     Lucknow  10h 00m    1 Stop
# 8           20:15  07:00\n+ 1 day  Mumbai     Lucknow  10h 45m    1 Stop
# 9           22:40  10:15\n+ 1 day  Mumbai     Lucknow  11h 35m    1 Stop
# 10          06:00           17:55  Mumbai     Lucknow  11h 55m    1 Stop
# 11          09:55           22:15  Mumbai     Lucknow  12h 20m    1 Stop
# ...

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 95.0.4638
# Get LATEST driver version for 95.0.4638
# Driver [C:\Users\monish\.wdm\drivers\chromedriver\win32\95.0.4638.17\chromedriver.exe] found in cache

# %%
url ="https://www.yatra.com"
driver.get(url)

# %%
search=driver.find_element_by_xpath("//*[@id='BE_flight_flsearch_btn']")
search.click()

# %%
dept_time=driver.find_elements_by_xpath("//div[@class='i-b pr']")
dept_time
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="54096a3d1848133a3227f68e05f18be6", element="ac74f72e-05db-40b1-b02a-69727e1e1a33")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="54096a3d1848133a3227f68e05f18be6", element="d84cf548-46f7-46be-b8ef-a05b29ec3835")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="54096a3d1848133a3227f68e05f18be6", element="64f61b55-3056-4ca1-9be6-005738111a70")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="54096a3d1848133a3227f68e05f18be6", element="b4ab0ad1-3a2d-40ba-8ba8-e6248c26f787")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="54096a3d1848133a3227f68e05f18be6", element="780b8c49-bc9f-4fb8-bba4-83e9e505f6a4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="54096a3d1848133a3227f68e05f18be6", element="261606eb-76ff-462b-b9e9-11ca8ce65990")>,
# ...

# %%
departure_time=[]
for d in dept_time:
    departure_time.append(d.text)
departure_time
# Out:
# ['02:35',
#  '13:05',
#  '22:55',
#  '21:20',
#  '13:05',
#  '13:05',
#  '05:00',
#  '14:35',
#  '23:45',
#  '22:40',
#  '06:05',
#  '21:15',
#  '20:15',
#  '17:10',
#  '16:20',
#  '16:15',
#  '21:35',
#  '12:45',
#  '19:55',
#  '18:30',
#  '15:05',
#  '21:15',
#  '12:20',
#  '11:10',
#  '12:20',
#  '11:10',
#  '17:30',
#  '15:45',
#  '11:55',
#  '14:40',
#  '10:25',
#  '22:45',
#  '21:55',
#  '08:45',
#  '11:55',
#  '22:45',
#  '20:55',
#  '21:55',
#  '07:30',
#  '10:25',
#  '19:45',
#  '20:55',
#  '06:30',
#  '06:00',
#  '18:30',
#  '19:45',
#  '08:45',
#  '12:45',
#  '11:40',
#  '23:00',
#  '06:15',
#  '21:20',
#  '07:10',
#  '16:55',
#  '13:30',
#  '09:55',
#  '08:00',
#  '07:05',
#  '14:00',
#  '21:30',
#  '19:30',
#  '10:45',
#  '07:00',
#  '13:05',
#  '02:35',
#  '12:15',
#  '21:30',
#  '07:00',
#  '19:20',
#  '06:20',
#  '06:20',
#  '06:20',
#  '06:20',
#  '19:20',
#  '06:20',
#  '06:20',
#  '06:20',
#  '09:50',
#  '10:00',
#  '08:00',
#  '05:45',
#  '13:50',
#  '08:00',
# ...

# %%
arr_time=driver.find_elements_by_xpath("//p[@class='bold fs-15 mb-2 pr time']")
arr_time
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="54096a3d1848133a3227f68e05f18be6", element="e276aac2-ea80-40df-878b-2b7820be301e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="54096a3d1848133a3227f68e05f18be6", element="b9488dad-3511-4e66-ba91-1eebd16c436d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="54096a3d1848133a3227f68e05f18be6", element="56b88170-a7b7-4cd1-90cf-09a38b680591")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="54096a3d1848133a3227f68e05f18be6", element="93852685-ba72-4a61-8a87-7db6f2fb4a60")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="54096a3d1848133a3227f68e05f18be6", element="a287d13b-9985-4e64-99b7-51f983547de3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="54096a3d1848133a3227f68e05f18be6", element="b5b064ab-9c67-47a8-86ae-fc3b11870832")>,
# ...

# %%
arrival_time=[]
for a in arr_time:
    arrival_time.append(a.text)
arrival_time
# Out:
# ['08:05',
#  '21:05',
#  '07:10\n+ 1 day',
#  '08:05\n+ 1 day',
#  '01:25\n+ 1 day',
#  '01:35\n+ 1 day',
#  '07:30',
#  '22:20',
#  '08:00\n+ 1 day',
#  '08:00\n+ 1 day',
#  '16:30',
#  '08:00\n+ 1 day',
#  '08:00\n+ 1 day',
#  '22:40',
#  '22:40',
#  '22:55',
#  '07:25\n+ 1 day',
#  '22:40',
#  '06:05\n+ 1 day',
#  '06:05\n+ 1 day',
#  '22:45',
#  '00:15\n+ 1 day',
#  '19:20',
#  '19:40',
#  '22:25',
#  '21:50',
#  '22:45',
#  '22:45',
#  '19:35',
#  '22:45',
#  '19:35',
#  '08:20\n+ 1 day',
#  '08:20\n+ 1 day',
#  '19:35',
#  '22:45',
#  '09:35\n+ 1 day',
#  '08:20\n+ 1 day',
#  '09:35\n+ 1 day',
#  '19:35',
#  '22:45',
#  '08:20\n+ 1 day',
#  '09:35\n+ 1 day',
#  '19:35',
#  '19:35',
#  '08:20\n+ 1 day',
#  '09:35\n+ 1 day',
#  '22:45',
#  '19:15',
#  '20:55',
#  '01:30\n+ 1 day',
#  '13:20',
#  '00:05\n+ 1 day',
#  '13:20',
#  '22:25',
#  '21:45',
#  '21:45',
#  '21:45',
#  '09:45',
#  '16:55',
#  '19:10\n+ 1 day',
#  '20:50\n+ 1 day',
#  '19:15',
#  '22:20',
#  '19:20',
# ...

# %%
durr=driver.find_elements_by_xpath("//p[@class='fs-12 bold du mb-2']")
durr
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="54096a3d1848133a3227f68e05f18be6", element="81624aa3-2785-40d4-b0ff-6b17c6921685")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="54096a3d1848133a3227f68e05f18be6", element="849206ba-dda8-4817-adba-0a29b54fb8c2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="54096a3d1848133a3227f68e05f18be6", element="4fefb8f4-346f-4c88-9c4d-ac6dc1a9dc84")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="54096a3d1848133a3227f68e05f18be6", element="9a047953-0e9a-4027-bd1d-aa1144754973")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="54096a3d1848133a3227f68e05f18be6", element="62668b17-853b-4f54-8074-9a982d99da40")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="54096a3d1848133a3227f68e05f18be6", element="67c91c34-1516-4578-98c5-90a1aab0e0f5")>,
# ...

# %%
duration=[]
for r in durr:
    duration.append(r.text)
duration
# Out:
# ['5h 30m',
#  '8h 00m',
#  '8h 15m',
#  '10h 45m',
#  '12h 20m',
#  '12h 30m',
#  '2h 30m',
#  '7h 45m',
#  '8h 15m',
#  '9h 20m',
#  '10h 25m',
#  '10h 45m',
#  '11h 45m',
#  '5h 30m',
#  '6h 20m',
#  '6h 40m',
#  '9h 50m',
#  '9h 55m',
#  '10h 10m',
#  '11h 35m',
#  '7h 40m',
#  '3h 00m',
#  '7h 00m',
#  '8h 30m',
#  '10h 05m',
#  '10h 40m',
#  '5h 15m',
#  '7h 00m',
#  '7h 40m',
#  '8h 05m',
#  '9h 10m',
#  '9h 35m',
#  '10h 25m',
#  '10h 50m',
#  '10h 50m',
#  '10h 50m',
#  '11h 25m',
#  '11h 40m',
#  '12h 05m',
#  '12h 20m',
#  '12h 35m',
#  '12h 40m',
#  '13h 05m',
#  '13h 35m',
#  '13h 50m',
#  '13h 50m',
#  '14h 00m',
#  '6h 30m',
#  '9h 15m',
#  '2h 30m',
#  '7h 05m',
#  '2h 45m',
#  '6h 10m',
#  '5h 30m',
#  '8h 15m',
#  '11h 50m',
#  '13h 45m',
#  '2h 40m',
#  '2h 55m',
#  '21h 40m',
#  '25h 20m',
#  '8h 30m',
#  '15h 20m',
#  '6h 15m',
#  '16h 45m',
#  '9h 30m',
#  '11h 30m',
#  '12h 10m',
#  '24h 15m',
#  '26h 00m',
#  '26h 00m',
#  '27h 15m',
#  '27h 15m',
# ...

# %%
stops=driver.find_elements_by_xpath("//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']")
stops
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="54096a3d1848133a3227f68e05f18be6", element="2e23a857-202e-4476-a670-91f2f8b8536b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="54096a3d1848133a3227f68e05f18be6", element="ee330857-8808-482c-84fb-7744baeb7542")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="54096a3d1848133a3227f68e05f18be6", element="92a09c6c-7bd7-4358-82c6-b228d6f1692c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="54096a3d1848133a3227f68e05f18be6", element="9f0a1c3b-8555-4464-857b-5a7ab5e8c65c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="54096a3d1848133a3227f68e05f18be6", element="1f77585d-1b74-43bc-8f67-48bc66c34755")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="54096a3d1848133a3227f68e05f18be6", element="43a82454-3d38-40c2-867c-ef7e58cb9239")>,
# ...

# %%
stoppage=[]
for s in stops:
    stoppage.append(s.text)
stoppage
# Out:
# ['1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  '1 Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
# ...

# %%
flight=driver.find_elements_by_xpath("//span[@class='i-b text ellipsis']")
flight
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="54096a3d1848133a3227f68e05f18be6", element="3a2fea1d-1d45-48ee-8100-67a78af2aa29")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="54096a3d1848133a3227f68e05f18be6", element="fa343bcd-ef37-473c-a9c4-b48485457474")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="54096a3d1848133a3227f68e05f18be6", element="7b2416f5-f05b-4872-a4a3-3d5d9bfe5d82")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="54096a3d1848133a3227f68e05f18be6", element="5269cc9e-9d08-4d35-bd83-8f48d0a47402")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="54096a3d1848133a3227f68e05f18be6", element="294f02ce-e69d-4862-b6e3-9ad63d545305")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="54096a3d1848133a3227f68e05f18be6", element="fa6a2dd8-03cf-4ac2-b4cf-07d4d0e44553")>,
# ...

# %%
flight_name=[]
for f in flight:
    flight_name.append(f.text)
flight_name
# Out:
# ['Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Go First',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'SpiceJet',
#  'IndiGo',
#  'IndiGo',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Vistara',
#  'Vistara',
#  'Air India',
#  'SpiceJet',
#  'IndiGo',
#  'Air India',
#  'Air Asia',
#  'Air Asia',
#  'Go First',
#  'Air India',
#  'Air India',
#  'Vistara',
#  'Vistara',
# ...

# %%
prices=driver.find_elements_by_xpath("//div[@class='i-b tipsy fare-summary-tooltip fs-18']")
prices
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="54096a3d1848133a3227f68e05f18be6", element="c3b5d35b-a2a7-4728-a0e4-19ccbb9b40c9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="54096a3d1848133a3227f68e05f18be6", element="25033869-1bf2-4757-964a-1d7428f9f52b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="54096a3d1848133a3227f68e05f18be6", element="766552dc-ad67-42d6-8a88-4a5eab73a09f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="54096a3d1848133a3227f68e05f18be6", element="52cbb6df-a771-4af8-b623-5077c0f3e8b7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="54096a3d1848133a3227f68e05f18be6", element="576acde5-51ed-4bee-8d75-b5167c7fbced")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="54096a3d1848133a3227f68e05f18be6", element="478ee679-f32b-43d2-9c2f-1adaecf764bb")>,
# ...

# %%
price=[]
for p in prices:
    price.append(p.text)
price
# Out:
# ['7,409',
#  '7,409',
#  '7,409',
#  '7,409',
#  '7,409',
#  '7,409',
#  '7,412',
#  '7,412',
#  '7,412',
#  '7,412',
#  '7,412',
#  '7,412',
#  '7,412',
#  '7,413',
#  '7,413',
#  '7,413',
#  '7,413',
#  '7,413',
#  '7,413',
#  '7,413',
#  '8,059',
#  '8,096',
#  '8,705',
#  '8,705',
#  '8,705',
#  '8,705',
#  '9,879',
#  '9,879',
#  '9,879',
#  '9,879',
#  '9,879',
#  '9,879',
#  '9,879',
#  '9,879',
#  '9,879',
#  '9,879',
#  '9,879',
#  '9,879',
#  '9,879',
#  '9,879',
#  '9,879',
#  '9,879',
#  '9,879',
#  '9,879',
#  '9,879',
#  '9,879',
#  '9,879',
#  '9,996',
#  '9,996',
#  '10,143',
#  '10,773',
#  '10,878',
#  '11,141',
#  '11,288',
#  '11,377',
#  '11,377',
#  '11,377',
#  '12,033',
#  '12,033',
#  '12,348',
#  '12,349',
#  '12,506',
#  '12,768',
#  '13,084',
#  '13,084',
#  '13,161',
#  '13,188',
#  '13,188',
#  '13,222',
#  '13,222',
#  '13,222',
#  '13,222',
#  '13,222',
#  '13,222',
#  '13,390',
#  '13,390',
#  '13,390',
#  '13,411',
#  '13,556',
#  '13,608',
# ...

# %%
source_=driver.find_elements_by_xpath("//p[@class='fs-10 font-lightgrey no-wrap city ellipsis']")
source_
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="54096a3d1848133a3227f68e05f18be6", element="67e5ab53-fe80-4cb6-8e9e-b4f7bc630cda")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="54096a3d1848133a3227f68e05f18be6", element="6171caa1-f984-42e8-9198-ba2e2bcdf6bc")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="54096a3d1848133a3227f68e05f18be6", element="340b332d-5dea-444c-a354-2e7afe9ce4b6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="54096a3d1848133a3227f68e05f18be6", element="59e56838-fa2d-44c6-83a2-1e0d23976b38")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="54096a3d1848133a3227f68e05f18be6", element="194c6d75-3143-4469-ab48-7894697718f7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="54096a3d1848133a3227f68e05f18be6", element="cf7bb71f-f113-4f4b-b581-4400df5a7991")>,
# ...

# %%
source=[]
for s in source_:
    source.append(s.text)
source
# Out:
# ['Mumbai',
#  'Kolkata',
#  'Mumbai',
#  'Kolkata',
#  'Mumbai',
#  'Kolkata',
#  'Mumbai',
#  'Kolkata',
#  'Mumbai',
#  'Kolkata',
#  'Mumbai',
#  'Kolkata',
#  'Mumbai',
#  'Kolkata',
#  'Mumbai',
#  'Kolkata',
#  'Mumbai',
#  'Kolkata',
#  'Mumbai',
#  'Kolkata',
#  'Mumbai',
#  'Kolkata',
#  'Mumbai',
#  'Kolkata',
#  'Mumbai',
#  'Kolkata',
#  'Mumbai',
#  'Kolkata',
#  'Mumbai',
#  'Kolkata',
#  'Mumbai',
#  'Kolkata',
#  'Mumbai',
#  'Kolkata',
#  'Mumbai',
#  'Kolkata',
#  'Mumbai',
#  'Kolkata',
#  'Mumbai',
#  'Kolkata',
#  'Mumbai',
#  'Kolkata',
#  'Mumbai',
#  'Kolkata',
#  'Mumbai',
#  'Kolkata',
#  'Mumbai',
#  'Kolkata',
#  'Mumbai',
#  'Kolkata',
#  'Mumbai',
#  'Kolkata',
#  'Mumbai',
#  'Kolkata',
#  'Mumbai',
#  'Kolkata',
#  'Mumbai',
#  'Kolkata',
#  'Mumbai',
#  'Kolkata',
#  'Mumbai',
#  'Kolkata',
#  'Mumbai',
#  'Kolkata',
#  'Mumbai',
#  'Kolkata',
#  'Mumbai',
#  'Kolkata',
#  'Mumbai',
#  'Kolkata',
#  'Mumbai',
#  'Kolkata',
#  'Mumbai',
#  'Kolkata',
# ...

# %%
destination=[]
for d in range(1,len(source),2):
    destination.append(source[d])
destination
# Out:
# ['Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
# ...

# %%
source1=[]
for s in range(0,len(source),2):
    source1.append(source[s])
source1
# Out:
# ['Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
# ...

# %%
import pandas as pd
df13=pd.DataFrame({})
df13['Departure Time']=departure_time
df13['Arrival Time']=arrival_time
df13['Source']=source1
df13['Destination']=destination
df13['Duration']=duration
df13['Stoppage']=stoppage
df13['Flight Name']=flight_name
df13['Price']=price
df13
# Out:
#     Departure Time    Arrival Time  Source Destination Duration   Stoppage  \
# 0            02:35           08:05  Mumbai     Kolkata   5h 30m     1 Stop
# 1            13:05           21:05  Mumbai     Kolkata   8h 00m     1 Stop
# 2            22:55  07:10\n+ 1 day  Mumbai     Kolkata   8h 15m     1 Stop
# 3            21:20  08:05\n+ 1 day  Mumbai     Kolkata  10h 45m     1 Stop
# 4            13:05  01:25\n+ 1 day  Mumbai     Kolkata  12h 20m     1 Stop
# ..             ...             ...     ...         ...      ...        ...
# 108          16:00           22:20  Mumbai     Kolkata   6h 20m     1 Stop
# 109          19:00  09:00\n+ 1 day  Mumbai     Kolkata  14h 00m     1 Stop
# 110          16:00  09:00\n+ 1 day  Mumbai     Kolkata  17h 00m     1 Stop
# 111          11:25           22:45  Mumbai     Kolkata  11h 20m  2 Stop(s)
# 112          19:00  11:05\n+ 1 day  Mumbai     Kolkata  16h 05m  2 Stop(s)
#
#     Flight Name   Price
# 0      Air Asia   7,409
# ...

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 95.0.4638
# Get LATEST driver version for 95.0.4638
# Driver [C:\Users\monish\.wdm\drivers\chromedriver\win32\95.0.4638.17\chromedriver.exe] found in cache

# %%
url ="https://www.yatra.com"
driver.get(url)

# %%
search=driver.find_element_by_xpath("//*[@id='BE_flight_flsearch_btn']")
search.click()

# %%
dept_time=driver.find_elements_by_xpath("//div[@class='i-b pr']")
dept_time
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="45607678b247ff1bde27d613bc5e9053", element="c0ee2460-06dd-46ad-8ced-41e09c653a53")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="45607678b247ff1bde27d613bc5e9053", element="e4c0be21-987f-407f-920e-45bb10e8e15d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="45607678b247ff1bde27d613bc5e9053", element="18c010ad-e0d4-420a-97e1-60b48874c79a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="45607678b247ff1bde27d613bc5e9053", element="367ab0fc-7d43-4bd0-81d7-2c016f05ece7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="45607678b247ff1bde27d613bc5e9053", element="086015c5-d3ab-4cc6-9427-554e9577aa95")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="45607678b247ff1bde27d613bc5e9053", element="9b61bc08-4f1c-43bf-902d-5affe5207634")>,
# ...

# %%
departure_time=[]
for d in dept_time:
    departure_time.append(d.text)
departure_time
# Out:
# ['08:30',
#  '07:45',
#  '07:05',
#  '06:00',
#  '05:00',
#  '05:00',
#  '10:40',
#  '03:05',
#  '00:10',
#  '08:30',
#  '07:45',
#  '13:40',
#  '10:05',
#  '09:20',
#  '10:05',
#  '09:20',
#  '06:00',
#  '11:45',
#  '16:05',
#  '20:00',
#  '17:05',
#  '05:00',
#  '11:55',
#  '10:25',
#  '08:45',
#  '07:30',
#  '06:30',
#  '06:00',
#  '22:45',
#  '21:55',
#  '20:55',
#  '19:45',
#  '18:30',
#  '17:30',
#  '15:45',
#  '15:35',
#  '09:40',
#  '07:10',
#  '06:15',
#  '22:15',
#  '10:25',
#  '08:45',
#  '07:30',
#  '08:35',
#  '07:00',
#  '21:30',
#  '07:00',
#  '08:00',
#  '05:50',
#  '08:00',
#  '19:20',
#  '06:20',
#  '06:20',
#  '06:20',
#  '06:20',
#  '21:30',
#  '15:50',
#  '15:50',
#  '13:40',
#  '11:45',
#  '19:20',
#  '06:20',
#  '21:30',
#  '10:00',
#  '07:30',
#  '10:00',
#  '09:45',
#  '21:00',
#  '07:05',
#  '14:05',
#  '11:30',
#  '10:15',
#  '09:45',
#  '07:05',
#  '09:25',
#  '17:50',
#  '19:20',
#  '06:20',
#  '09:45',
#  '05:45',
#  '07:00',
#  '06:00',
#  '07:00',
# ...

# %%
arr_time=driver.find_elements_by_xpath("//p[@class='bold fs-15 mb-2 pr time']")
arr_time
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="45607678b247ff1bde27d613bc5e9053", element="f206df87-b54b-4494-a94a-24861c79ff82")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="45607678b247ff1bde27d613bc5e9053", element="b009e2f2-735c-4822-a63a-b5ba54bddf4e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="45607678b247ff1bde27d613bc5e9053", element="d14523b9-7436-47b3-982c-761599ca8466")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="45607678b247ff1bde27d613bc5e9053", element="ecd612f0-d822-49a4-88ba-fd53f29a0747")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="45607678b247ff1bde27d613bc5e9053", element="05f5f828-53fb-4fdf-8fe1-c7f488c4933c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="45607678b247ff1bde27d613bc5e9053", element="cb74de14-c1ad-4e4e-bd03-9ee06b534ebf")>,
# ...

# %%
arrival_time=[]
for a in arr_time:
    arrival_time.append(a.text)
arrival_time
# Out:
# ['15:45',
#  '15:45',
#  '15:45',
#  '15:45',
#  '15:45',
#  '09:25',
#  '16:50',
#  '09:25',
#  '10:10',
#  '18:40',
#  '18:40',
#  '18:40',
#  '15:45',
#  '15:45',
#  '18:40',
#  '18:40',
#  '08:20',
#  '18:40',
#  '18:30',
#  '22:25',
#  '19:25',
#  '07:30',
#  '18:15',
#  '18:15',
#  '18:15',
#  '18:15',
#  '18:15',
#  '18:15',
#  '18:15\n+ 1 day',
#  '18:15\n+ 1 day',
#  '18:15\n+ 1 day',
#  '18:15\n+ 1 day',
#  '18:15\n+ 1 day',
#  '18:15\n+ 1 day',
#  '18:15\n+ 1 day',
#  '17:50',
#  '11:55',
#  '12:35',
#  '12:35',
#  '00:35\n+ 1 day',
#  '14:45',
#  '14:45',
#  '14:45',
#  '11:00',
#  '19:55',
#  '19:55\n+ 1 day',
#  '18:55',
#  '19:55',
#  '15:15',
#  '18:55',
#  '18:15\n+ 1 day',
#  '18:15\n+ 1 day',
#  '18:15\n+ 1 day',
#  '18:15\n+ 1 day',
#  '18:15',
#  '07:40\n+ 1 day',
#  '22:00',
#  '23:55',
#  '22:00',
#  '22:00',
#  '18:15\n+ 1 day',
#  '14:45',
#  '10:35\n+ 1 day',
#  '19:55',
#  '19:50',
#  '18:55',
#  '18:15\n+ 1 day',
#  '18:15\n+ 1 day',
#  '18:15',
# ...

# %%
durr=driver.find_elements_by_xpath("//p[@class='fs-12 bold du mb-2']")
durr
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="45607678b247ff1bde27d613bc5e9053", element="c1e3da5a-00f4-45c7-a6e5-17ebff9e67de")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="45607678b247ff1bde27d613bc5e9053", element="41f42df0-7d23-495d-bcf7-2cc555bd8a6d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="45607678b247ff1bde27d613bc5e9053", element="d216fd5a-2fc3-4bf3-a626-b21016078399")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="45607678b247ff1bde27d613bc5e9053", element="1c1dc446-be7f-47fc-b8ad-7509318cf3be")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="45607678b247ff1bde27d613bc5e9053", element="0a82b439-d090-4db1-b984-16a80ea48f91")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="45607678b247ff1bde27d613bc5e9053", element="d5908470-2035-4c52-ae6e-c5e662f644ae")>,
# ...

# %%
duration=[]
for r in durr:
    duration.append(r.text)
duration
# Out:
# ['7h 15m',
#  '8h 00m',
#  '8h 40m',
#  '9h 45m',
#  '10h 45m',
#  '4h 25m',
#  '6h 10m',
#  '6h 20m',
#  '10h 00m',
#  '10h 10m',
#  '10h 55m',
#  '5h 00m',
#  '5h 40m',
#  '6h 25m',
#  '8h 35m',
#  '9h 20m',
#  '2h 20m',
#  '6h 55m',
#  '2h 25m',
#  '2h 25m',
#  '2h 20m',
#  '2h 30m',
#  '6h 20m',
#  '7h 50m',
#  '9h 30m',
#  '10h 45m',
#  '11h 45m',
#  '12h 15m',
#  '19h 30m',
#  '20h 20m',
#  '21h 20m',
#  '22h 30m',
#  '23h 45m',
#  '24h 45m',
#  '26h 30m',
#  '2h 15m',
#  '2h 15m',
#  '5h 25m',
#  '6h 20m',
#  '2h 20m',
#  '4h 20m',
#  '6h 00m',
#  '7h 15m',
#  '2h 25m',
#  '12h 55m',
#  '22h 25m',
#  '11h 55m',
#  '11h 55m',
#  '9h 25m',
#  '10h 55m',
#  '22h 55m',
#  '35h 55m',
#  '35h 55m',
#  '35h 55m',
#  '11h 55m',
#  '10h 10m',
#  '6h 10m',
#  '8h 05m',
#  '8h 20m',
#  '10h 15m',
#  '22h 55m',
#  '8h 25m',
#  '13h 05m',
#  '9h 55m',
#  '12h 20m',
#  '8h 55m',
#  '32h 30m',
#  '21h 15m',
#  '11h 10m',
#  '6h 25m',
#  '9h 00m',
#  '10h 15m',
#  '32h 30m',
#  '35h 10m',
# ...

# %%
stops=driver.find_elements_by_xpath("//div[@class=' font-lightgrey fs-10 tipsy i-b fs-10']")
stops
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="45607678b247ff1bde27d613bc5e9053", element="88c891ed-5a05-462a-8ef9-7ef25bd1fa65")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="45607678b247ff1bde27d613bc5e9053", element="4c23a96a-3eee-4b4d-b0c1-f98a97b63cad")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="45607678b247ff1bde27d613bc5e9053", element="f1d3af51-19d9-4b1e-8257-660843478653")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="45607678b247ff1bde27d613bc5e9053", element="39d62770-c24a-4904-bda4-5f537855a758")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="45607678b247ff1bde27d613bc5e9053", element="618a46b4-a74e-42a2-bdf7-a88acc17bccc")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="45607678b247ff1bde27d613bc5e9053", element="a13b3c80-5da0-4035-9a6d-505733fdd474")>,
# ...

# %%
stoppage=[]
for s in stops:
    stoppage.append(s.text)
stoppage
# Out:
# ['1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  '1 Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
# ...

# %%
flight=driver.find_elements_by_xpath("//span[@class='i-b text ellipsis']")
flight
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="45607678b247ff1bde27d613bc5e9053", element="b5577e87-1db4-436b-b0e0-d7de07fed87d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="45607678b247ff1bde27d613bc5e9053", element="e24e88ad-e3ec-46ad-bffe-6973b86ee78e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="45607678b247ff1bde27d613bc5e9053", element="54b47d4a-e636-4ef0-8403-ae2d53f3fba5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="45607678b247ff1bde27d613bc5e9053", element="a13a58ee-dcac-4b46-9994-e355e9d4dc65")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="45607678b247ff1bde27d613bc5e9053", element="33149729-0ea5-4deb-9ee4-33c5c585695d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="45607678b247ff1bde27d613bc5e9053", element="a14c652c-38bf-4c33-a4fd-1209bdc5db7f")>,
# ...

# %%
flight_name=[]
for f in flight:
    flight_name.append(f.text)
flight_name
# Out:
# ['IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Go First',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Vistara',
#  'IndiGo',
#  'Vistara',
#  'IndiGo',
#  'Go First',
#  'Go First',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Go First',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'IndiGo',
#  'Air India',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Air India',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Vistara',
#  'Vistara',
#  'Air India',
#  'Air India',
#  'Go First',
#  'Air India',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'IndiGo',
#  'IndiGo',
# ...

# %%
prices=driver.find_elements_by_xpath("//div[@class='i-b tipsy fare-summary-tooltip fs-18']")
prices
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="45607678b247ff1bde27d613bc5e9053", element="7d1737c4-f8bf-45e7-b71c-816258b0ed24")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="45607678b247ff1bde27d613bc5e9053", element="1144b54a-d936-4631-9d68-ab5c6d31595e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="45607678b247ff1bde27d613bc5e9053", element="8f3c3de4-3fc5-46f7-9b10-f3c0d0471fa2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="45607678b247ff1bde27d613bc5e9053", element="bd7d3b32-577a-4fd5-91b8-0da72702c49c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="45607678b247ff1bde27d613bc5e9053", element="3bc9ef9a-d375-4815-b710-95c4d988b26b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="45607678b247ff1bde27d613bc5e9053", element="8fb6a468-12f1-45ba-8d4b-81e6dc1a36e4")>,
# ...

# %%
price=[]
for p in prices:
    price.append(p.text)
price
# Out:
# ['5,943',
#  '5,943',
#  '5,943',
#  '5,943',
#  '5,943',
#  '6,431',
#  '6,431',
#  '6,431',
#  '6,431',
#  '6,431',
#  '6,431',
#  '6,920',
#  '6,920',
#  '6,920',
#  '6,920',
#  '6,920',
#  '6,993',
#  '7,408',
#  '7,518',
#  '7,623',
#  '7,728',
#  '7,728',
#  '7,737',
#  '7,737',
#  '7,737',
#  '7,737',
#  '7,737',
#  '7,737',
#  '7,737',
#  '7,737',
#  '7,737',
#  '7,737',
#  '7,737',
#  '7,737',
#  '7,737',
#  '7,991',
#  '8,358',
#  '8,384',
#  '8,384',
#  '8,726',
#  '9,255',
#  '9,255',
#  '9,255',
#  '9,356',
#  '9,776',
#  '9,776',
#  '10,301',
#  '10,616',
#  '10,826',
#  '11,141',
#  '11,622',
#  '11,622',
#  '11,622',
#  '11,622',
#  '11,757',
#  '11,771',
#  '11,802',
#  '11,802',
#  '11,802',
#  '11,802',
#  '12,158',
#  '13,140',
#  '13,241',
#  '13,346',
#  '13,687',
#  '13,871',
#  '14,062',
#  '14,167',
#  '14,188',
#  '14,243',
#  '14,243',
#  '14,243',
#  '14,566',
#  '14,566',
#  '14,737',
#  '14,986',
#  '15,002',
#  '15,002',
#  '15,070',
#  '15,341',
# ...

# %%
source_=driver.find_elements_by_xpath("//p[@class='fs-10 font-lightgrey no-wrap city ellipsis']")
source_
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="45607678b247ff1bde27d613bc5e9053", element="b19c249b-00da-4946-90a9-7b613891e14e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="45607678b247ff1bde27d613bc5e9053", element="a3b44334-405f-46fa-9ea5-8ef45ac32b82")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="45607678b247ff1bde27d613bc5e9053", element="bc29e41e-1b7b-4be2-bcd6-6a4744801005")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="45607678b247ff1bde27d613bc5e9053", element="26c4ff85-0639-4df8-a5a0-c13cbf02175e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="45607678b247ff1bde27d613bc5e9053", element="63ab1a5b-5812-42c4-8bd1-fa0df4a8c830")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="45607678b247ff1bde27d613bc5e9053", element="026da5e0-80e7-44e2-b22d-a208e51928c7")>,
# ...

# %%
source=[]
for s in source_:
    source.append(s.text)
source
# Out:
# ['Mumbai',
#  'Chandigarh',
#  'Mumbai',
#  'Chandigarh',
#  'Mumbai',
#  'Chandigarh',
#  'Mumbai',
#  'Chandigarh',
#  'Mumbai',
#  'Chandigarh',
#  'Mumbai',
#  'Chandigarh',
#  'Mumbai',
#  'Chandigarh',
#  'Mumbai',
#  'Chandigarh',
#  'Mumbai',
#  'Chandigarh',
#  'Mumbai',
#  'Chandigarh',
#  'Mumbai',
#  'Chandigarh',
#  'Mumbai',
#  'Chandigarh',
#  'Mumbai',
#  'Chandigarh',
#  'Mumbai',
#  'Chandigarh',
#  'Mumbai',
#  'Chandigarh',
#  'Mumbai',
#  'Chandigarh',
#  'Mumbai',
#  'Chandigarh',
#  'Mumbai',
#  'Chandigarh',
#  'Mumbai',
#  'Chandigarh',
#  'Mumbai',
#  'Chandigarh',
#  'Mumbai',
#  'Chandigarh',
#  'Mumbai',
#  'Chandigarh',
#  'Mumbai',
#  'Chandigarh',
#  'Mumbai',
#  'Chandigarh',
#  'Mumbai',
#  'Chandigarh',
#  'Mumbai',
#  'Chandigarh',
#  'Mumbai',
#  'Chandigarh',
#  'Mumbai',
#  'Chandigarh',
#  'Mumbai',
#  'Chandigarh',
#  'Mumbai',
#  'Chandigarh',
#  'Mumbai',
#  'Chandigarh',
#  'Mumbai',
#  'Chandigarh',
#  'Mumbai',
#  'Chandigarh',
# ...

# %%
destination=[]
for d in range(1,len(source),2):
    destination.append(source[d])
destination
# Out:
# ['Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
#  'Chandigarh',
# ...

# %%
source1=[]
for s in range(0,len(source),2):
    source1.append(source[s])
source1
# Out:
# ['Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
# ...

# %%
import pandas as pd
df14=pd.DataFrame({})
df14['Departure Time']=departure_time
df14['Arrival Time']=arrival_time
df14['Source']=source1
df14['Destination']=destination
df14['Duration']=duration
df14['Stoppage']=stoppage
df14['Flight Name']=flight_name
df14['Price']=price
df14
# Out:
#    Departure Time    Arrival Time  Source Destination Duration   Stoppage  \
# 0           08:30           15:45  Mumbai  Chandigarh   7h 15m     1 Stop
# 1           07:45           15:45  Mumbai  Chandigarh   8h 00m     1 Stop
# 2           07:05           15:45  Mumbai  Chandigarh   8h 40m     1 Stop
# 3           06:00           15:45  Mumbai  Chandigarh   9h 45m     1 Stop
# 4           05:00           15:45  Mumbai  Chandigarh  10h 45m     1 Stop
# ..            ...             ...     ...         ...      ...        ...
# 95          14:00  14:45\n+ 1 day  Mumbai  Chandigarh  24h 45m  2 Stop(s)
# 96          19:00  07:40\n+ 1 day  Mumbai  Chandigarh  12h 40m     1 Stop
# 97          16:00  07:40\n+ 1 day  Mumbai  Chandigarh  15h 40m     1 Stop
# 98          19:00  10:35\n+ 1 day  Mumbai  Chandigarh  15h 35m  2 Stop(s)
# 99          16:00  10:35\n+ 1 day  Mumbai  Chandigarh  18h 35m  2 Stop(s)
#
#    Flight Name   Price
# 0       IndiGo   5,943
# 1       IndiGo   5,943
# ...

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 95.0.4638
# Get LATEST driver version for 95.0.4638
# Driver [C:\Users\monish\.wdm\drivers\chromedriver\win32\95.0.4638.17\chromedriver.exe] found in cache

# %%
url ="https://www.easemytrip.com/"
driver.get(url)

# %%
search=driver.find_element_by_xpath("//div[@class='s_col_v4 ripplen']")
search.click()

# %%
dept=driver.find_elements_by_xpath("//span[@class='txt-r2-n ng-binding']")
dept
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="64d3fdab8a354e0fdf51505b1f273905", element="45c84012-bf03-4cb7-afbc-8b40781895e3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="64d3fdab8a354e0fdf51505b1f273905", element="5b9c2db8-b7bb-4605-8d3a-f49c847bbfb1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="64d3fdab8a354e0fdf51505b1f273905", element="7a14f81b-b765-4390-98a1-5c9fbd35446d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="64d3fdab8a354e0fdf51505b1f273905", element="cffd1ad5-9ba5-4626-8e93-28324d7f24fc")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="64d3fdab8a354e0fdf51505b1f273905", element="5d0a3354-8a65-4155-9dfa-0a90ad02896c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="64d3fdab8a354e0fdf51505b1f273905", element="7bc82add-4195-48f2-b371-f9f6c9fbb046")>,
# ...

# %%
departure=[]
for d in dept:
    departure.append(d.text)
departure
# Out:
# ['23:10',
#  '00:50',
#  '17:30',
#  '19:15',
#  '21:20',
#  '23:05',
#  '17:55',
#  '19:35',
#  '18:10',
#  '19:45',
#  '18:15',
#  '19:55',
#  '18:35',
#  '20:15',
#  '19:35',
#  '11:00',
#  '05:15',
#  '14:25',
#  '07:25',
#  '09:00',
#  '13:00',
#  '17:15',
#  '07:50',
#  '17:15',
#  '08:55',
#  '10:30',
#  '06:05',
#  '07:45',
#  '09:00',
#  '10:40',
#  '13:15',
#  '15:00',
#  '20:00',
#  '21:50',
#  '14:50',
#  '21:20',
#  '15:10',
#  '16:55',
#  '20:15',
#  '14:10',
#  '16:55',
#  '14:10',
#  '16:05',
#  '17:45',
#  '06:50',
#  '14:10',
#  '16:45',
#  '18:25',
#  '13:55',
#  '15:35',
#  '12:20',
#  '14:00',
#  '06:25',
#  '07:55',
#  '11:30',
#  '13:10',
#  '10:35',
#  '12:10',
#  '13:30',
#  '20:10',
#  '09:45',
#  '20:10',
#  '06:10',
#  '20:10',
#  '05:25',
#  '14:10',
#  '16:05',
#  '09:55',
#  '14:15',
#  '09:55',
#  '08:05',
#  '09:55',
#  '06:15',
#  '09:55',
#  '21:10',
#  '14:10',
#  '09:45',
#  '14:10',
#  '08:10',
#  '14:10',
#  '08:00',
#  '13:45',
#  '07:00',
# ...

# %%
arr=driver.find_elements_by_xpath("//span[@class='txt-r2-n ng-binding']")
arr
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="64d3fdab8a354e0fdf51505b1f273905", element="45c84012-bf03-4cb7-afbc-8b40781895e3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="64d3fdab8a354e0fdf51505b1f273905", element="5b9c2db8-b7bb-4605-8d3a-f49c847bbfb1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="64d3fdab8a354e0fdf51505b1f273905", element="7a14f81b-b765-4390-98a1-5c9fbd35446d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="64d3fdab8a354e0fdf51505b1f273905", element="cffd1ad5-9ba5-4626-8e93-28324d7f24fc")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="64d3fdab8a354e0fdf51505b1f273905", element="5d0a3354-8a65-4155-9dfa-0a90ad02896c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="64d3fdab8a354e0fdf51505b1f273905", element="7bc82add-4195-48f2-b371-f9f6c9fbb046")>,
# ...

# %%
arrival=[]
for a in arr:
    arrival.append(a.text)
arrival
# Out:
# ['23:10',
#  '00:50',
#  '17:30',
#  '19:15',
#  '21:20',
#  '23:05',
#  '17:55',
#  '19:35',
#  '18:10',
#  '19:45',
#  '18:15',
#  '19:55',
#  '18:35',
#  '20:15',
#  '19:35',
#  '11:00',
#  '05:15',
#  '14:25',
#  '07:25',
#  '09:00',
#  '13:00',
#  '17:15',
#  '07:50',
#  '17:15',
#  '08:55',
#  '10:30',
#  '06:05',
#  '07:45',
#  '09:00',
#  '10:40',
#  '13:15',
#  '15:00',
#  '20:00',
#  '21:50',
#  '14:50',
#  '21:20',
#  '15:10',
#  '16:55',
#  '20:15',
#  '14:10',
#  '16:55',
#  '14:10',
#  '16:05',
#  '17:45',
#  '06:50',
#  '14:10',
#  '16:45',
#  '18:25',
#  '13:55',
#  '15:35',
#  '12:20',
#  '14:00',
#  '06:25',
#  '07:55',
#  '11:30',
#  '13:10',
#  '10:35',
#  '12:10',
#  '13:30',
#  '20:10',
#  '09:45',
#  '20:10',
#  '06:10',
#  '20:10',
#  '05:25',
#  '14:10',
#  '16:05',
#  '09:55',
#  '14:15',
#  '09:55',
#  '08:05',
#  '09:55',
#  '06:15',
#  '09:55',
#  '21:10',
#  '14:10',
#  '09:45',
#  '14:10',
#  '08:10',
#  '14:10',
#  '08:00',
#  '13:45',
#  '07:00',
# ...

# %%
source1=driver.find_elements_by_xpath("//span[@class='txt-r3-n ng-binding']")
source1
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="64d3fdab8a354e0fdf51505b1f273905", element="9f21c423-75dc-4f50-a390-cca77c2383e6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="64d3fdab8a354e0fdf51505b1f273905", element="31d61e15-8f4a-405d-a6db-6946cbea4396")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="64d3fdab8a354e0fdf51505b1f273905", element="b2fdd5e3-8864-4b9c-830d-c234d7106a06")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="64d3fdab8a354e0fdf51505b1f273905", element="b59bbf15-9292-4ab3-8973-14bcc39a6803")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="64d3fdab8a354e0fdf51505b1f273905", element="a3a1cf91-0303-4aec-b769-2deaf6a32d35")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="64d3fdab8a354e0fdf51505b1f273905", element="30319690-0f23-491f-a2c5-b61ff03a2066")>,
# ...

# %%
source_=[]
for s in source1:
    source_.append(s.text)
source_
# Out:
# ['Delhi',
#  'Patna',
#  'Delhi',
#  'Patna',
#  'Delhi',
#  'Patna',
#  'Delhi',
#  'Patna',
#  'Delhi',
#  'Patna',
#  'Delhi',
#  'Patna',
#  'Delhi',
#  'Patna',
#  'Delhi',
#  'Patna',
#  'Delhi',
#  'Patna',
#  'Delhi',
#  'Patna',
#  'Delhi',
#  'Patna',
#  'Delhi',
#  'Patna',
#  'Delhi',
#  'Patna',
#  'Delhi',
#  'Patna',
#  'Delhi',
#  'Patna',
#  'Delhi',
#  'Patna',
#  'Delhi',
#  'Patna',
#  'Delhi',
#  'Patna',
#  'Delhi',
#  'Patna',
#  'Delhi',
#  'Patna',
#  'Delhi',
#  'Patna',
#  'Delhi',
#  'Patna',
#  'Delhi',
#  'Patna',
#  'Delhi',
#  'Patna',
#  'Delhi',
#  'Patna',
#  'Delhi',
#  'Patna',
#  'Delhi',
#  'Patna',
#  'Delhi',
#  'Patna',
#  'Delhi',
#  'Patna',
#  'Delhi',
#  'Patna',
#  'Delhi',
#  'Patna',
#  'Delhi',
#  'Patna',
#  'Delhi',
#  'Patna',
#  'Delhi',
#  'Patna',
#  'Delhi',
#  'Patna',
#  'Delhi',
#  'Patna',
#  'Delhi',
#  'Patna',
#  'Delhi',
#  'Patna',
#  'Delhi',
#  'Patna',
#  'Delhi',
#  'Patna',
#  'Delhi',
#  'Patna',
#  'Delhi',
# ...

# %%
source=[]
for s in range(0,len(source_),2):
    source.append(source_[s])
source
# Out:
# ['Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi']

# %%
destination=[]
for d in range(1,len(source_),2):
    destination.append(source_[d])
destination
# Out:
# ['Patna',
#  'Patna',
#  'Patna',
#  'Patna',
#  'Patna',
#  'Patna',
#  'Patna',
#  'Patna',
#  'Patna',
#  'Patna',
#  'Patna',
#  'Patna',
#  'Patna',
#  'Patna',
#  'Patna',
#  'Patna',
#  'Patna',
#  'Patna',
#  'Patna',
#  'Patna',
#  'Patna',
#  'Patna',
#  'Patna',
#  'Patna',
#  'Patna',
#  'Patna',
#  'Patna',
#  'Patna',
#  'Patna',
#  'Patna',
#  'Patna',
#  'Patna',
#  'Patna',
#  'Patna',
#  'Patna',
#  'Patna',
#  'Patna',
#  'Patna',
#  'Patna',
#  'Patna',
#  'Patna',
#  'Patna',
#  'Patna',
#  'Patna',
#  'Patna',
#  'Patna',
#  'Patna',
#  'Patna',
#  'Patna',
#  'Patna',
#  'Patna',
#  'Patna',
#  'Patna',
#  'Patna',
#  'Patna',
#  'Patna',
#  'Patna',
#  'Patna',
#  'Patna',
#  'Patna',
#  'Patna',
#  'Patna',
#  'Patna',
#  'Patna',
#  'Patna',
#  'Patna',
#  'Patna',
#  'Patna']

# %%
durr=driver.find_elements_by_xpath("//span[@class='dura_md ng-binding']")
durr
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="64d3fdab8a354e0fdf51505b1f273905", element="406220d1-56c0-4e55-aff6-3d553ddbdbbf")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="64d3fdab8a354e0fdf51505b1f273905", element="31aa5653-2296-4463-83da-19402ffb18bb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="64d3fdab8a354e0fdf51505b1f273905", element="828f87c5-c680-49c8-8de3-3e639e442cdd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="64d3fdab8a354e0fdf51505b1f273905", element="a4509f40-b412-472a-a4d9-f4b37340195c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="64d3fdab8a354e0fdf51505b1f273905", element="9c0f8f01-bfa0-4a32-85bd-f4affdd11051")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="64d3fdab8a354e0fdf51505b1f273905", element="b2bdc702-af77-41c9-84d7-7ca606b19501")>,
# ...

# %%
duration=[]
for d in durr:
    duration.append(d.text)
duration
# Out:
# ['01h 40m',
#  '01h 45m',
#  '01h 45m',
#  '01h 40m',
#  '01h 35m',
#  '01h 40m',
#  '01h 40m',
#  '15h 25m',
#  '09h 10m',
#  '01h 35m',
#  '04h 15m',
#  '09h 25m',
#  '01h 35m',
#  '01h 40m',
#  '01h 40m',
#  '01h 45m',
#  '01h 50m',
#  '06h 30m',
#  '01h 45m',
#  '17h 55m',
#  '21h 15m',
#  '01h 40m',
#  '07h 20m',
#  '01h 40m',
#  '01h 40m',
#  '01h 40m',
#  '01h 30m',
#  '01h 40m',
#  '01h 35m',
#  '06h 40m',
#  '10h 25m',
#  '14h 00m',
#  '32h 45m',
#  '17h 50m',
#  '19h 40m',
#  '25h 50m',
#  '27h 40m',
#  '17h 00m',
#  '28h 25m',
#  '30h 00m',
#  '05h 45m',
#  '06h 45m',
#  '11h 45m',
#  '21h 05m',
#  '22h 15m',
#  '21h 05m',
#  '22h 15m',
#  '08h 05m',
#  '37h 20m',
#  '50h 50m',
#  '22h 55m',
#  '26h 50m',
#  '34h 25m',
#  '36h 00m',
#  '14h 20m',
#  '15h 20m',
#  '16h 30m',
#  '19h 15m',
#  '23h 40m',
#  '26h 20m',
#  '27h 20m',
#  '28h 25m',
#  '21h 00m',
#  '22h 25m',
#  '28h 15m',
#  '25h 40m',
#  '21h 30m',
#  '27h 15m']

# %%
flight=driver.find_elements_by_xpath("//span[@class='txt-r4 ng-binding']")
flight
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="64d3fdab8a354e0fdf51505b1f273905", element="140ba110-8c7f-437a-9e30-1422984e919c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="64d3fdab8a354e0fdf51505b1f273905", element="6c30e718-9704-4c40-a391-4f9eaacf1c47")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="64d3fdab8a354e0fdf51505b1f273905", element="77d88cfd-220b-490c-9497-5ebcb8059b86")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="64d3fdab8a354e0fdf51505b1f273905", element="0472003a-117b-4b32-acea-c53378ca0a5e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="64d3fdab8a354e0fdf51505b1f273905", element="33e3a9c9-9c5e-497e-a28f-153e4a8aba88")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="64d3fdab8a354e0fdf51505b1f273905", element="1e8668ec-8cc5-4cc5-b24e-9ea65d148d30")>,
# ...

# %%
flight_name=[]
for f in flight:
    flight_name.append(f.text)
flight_name
# Out:
# ['Indigo',
#  'Indigo',
#  'Indigo',
#  'GO FIRST',
#  'Indigo',
#  'Vistara',
#  'SpiceJet',
#  'GO FIRST',
#  'Indigo',
#  'SpiceJet',
#  'Indigo',
#  'Indigo',
#  'Indigo',
#  'GO FIRST',
#  'GO FIRST',
#  'Indigo',
#  'Indigo',
#  'Indigo',
#  'SpiceJet',
#  'Air India',
#  'Air India',
#  'Indigo',
#  'Air India',
#  'Air India',
#  'GO FIRST',
#  'Indigo',
#  'Indigo',
#  'GO FIRST',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Air India',
#  'Air India',
#  'Air India',
#  'GO FIRST',
#  'GO FIRST',
#  'GO FIRST',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'GO FIRST',
#  'Vistara',
#  'Vistara',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
# ...

# %%
stop=driver.find_elements_by_xpath("//span[@class='dura_md2 ng-scope']")
stop
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="64d3fdab8a354e0fdf51505b1f273905", element="a49ef5a9-adcb-44b8-8f58-b438b5d0b440")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="64d3fdab8a354e0fdf51505b1f273905", element="2df92faf-0cdc-4942-9012-499eb9a1da2e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="64d3fdab8a354e0fdf51505b1f273905", element="083ff85f-20cd-4043-aa9d-52ee8ddded20")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="64d3fdab8a354e0fdf51505b1f273905", element="b82643e5-d9a7-49db-ad1e-38664571ff0e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="64d3fdab8a354e0fdf51505b1f273905", element="2d61daec-504a-4ab4-ab44-7c57b5fca8ab")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="64d3fdab8a354e0fdf51505b1f273905", element="91417b4c-2ec2-411b-a9cb-7f2b33ed516f")>,
# ...

# %%
stoppage=[]
for s in stop:
    stoppage.append(s.text)
stoppage
# Out:
# ['non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  '1-stop',
#  '1-stop',
#  'non-stop',
#  '1-stop',
#  '1-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  '1-stop',
#  'non-stop',
#  '1-stop',
#  '1-stop',
#  'non-stop',
#  '1-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '2+-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '2+-stop',
#  '2+-stop',
#  '2+-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '2+-stop',
#  '2+-stop',
#  '2+-stop',
#  '2+-stop',
#  '1-stop',
#  '2+-stop',
#  '2+-stop',
#  '1-stop',
#  '1-stop',
#  '2+-stop',
#  '2+-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '2+-stop',
#  '2+-stop',
#  '2+-stop',
#  '2+-stop',
#  '2+-stop',
#  '2+-stop',
#  '2+-stop']

# %%
price=driver.find_elements_by_xpath("//div[@class='col-md-8 col-sm-8 col-xs-9 txt-r6-n ng-binding']")
price
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="64d3fdab8a354e0fdf51505b1f273905", element="7bc54c35-0c29-4f4b-a2f0-e363bbb08b4c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="64d3fdab8a354e0fdf51505b1f273905", element="19f018fe-3006-400c-adc9-3fc50f31f8eb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="64d3fdab8a354e0fdf51505b1f273905", element="18c012f3-9b26-4ab4-85a2-752249d38172")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="64d3fdab8a354e0fdf51505b1f273905", element="f44851e3-cf7e-4168-be69-ff9c1788f884")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="64d3fdab8a354e0fdf51505b1f273905", element="4cb241d9-c0bc-4ed6-9a35-744e081b48d1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="64d3fdab8a354e0fdf51505b1f273905", element="fd9ff872-56d5-4260-8b06-c4e09fbed0cc")>,
# ...

# %%
prices=[]
for p in price:
    prices.append(p.text)
prices
# Out:
# ['5,115',
#  '5,115',
#  '5,115',
#  '5,114',
#  '5,115',
#  '5,220',
#  '5,430',
#  '5,621',
#  '8,003',
#  '7,320',
#  '8,265',
#  '8,265',
#  '7,478',
#  '7,478',
#  '7,478',
#  '7,478',
#  '7,583',
#  '8,895',
#  '9,944',
#  '10,785',
#  '10,785',
#  '11,100',
#  '11,100',
#  '12,675',
#  '13,514',
#  '13,830',
#  '14,250',
#  '14,250',
#  '14,250',
#  '15,300',
#  '15,300',
#  '15,300',
#  '15,448',
#  '15,825',
#  '15,825',
#  '15,825',
#  '15,825',
#  '16,455',
#  '16,455',
#  '16,455',
#  '17,684',
#  '17,684',
#  '17,684',
#  '19,080',
#  '19,080',
#  '19,395',
#  '19,395',
#  '21,495',
#  '21,495',
#  '21,495',
#  '21,915',
#  '21,915',
#  '24,330',
#  '24,330',
#  '25,905',
#  '25,905',
#  '25,905',
#  '25,905',
#  '25,905',
#  '25,905',
#  '25,905',
#  '27,418',
#  '28,110',
#  '28,110',
#  '28,110',
#  '28,363',
#  '29,938',
#  '33,990']

# %%
len(prices)
# Out:
# 68

# %%
import pandas as pd
df15=pd.DataFrame({})
df15['Departure Time']=departure[:68]
df15['Arrival Time']=arrival[:68]
df15['Source']=source[:68]
df15['Destination']=destination[:68]
df15['Duration']=duration[:68]
df15['Stoppage']=stoppage[:68]
df15['Flight Name']=flight_name[:68]
df15['Price']=prices[:68]
df15
# Out:
#    Departure Time Arrival Time Source Destination Duration  Stoppage  \
# 0           23:10        23:10  Delhi       Patna  01h 40m  non-stop
# 1           00:50        00:50  Delhi       Patna  01h 45m  non-stop
# 2           17:30        17:30  Delhi       Patna  01h 45m  non-stop
# 3           19:15        19:15  Delhi       Patna  01h 40m  non-stop
# 4           21:20        21:20  Delhi       Patna  01h 35m  non-stop
# ..            ...          ...    ...         ...      ...       ...
# 63          20:10        20:10  Delhi       Patna  22h 25m   2+-stop
# 64          05:25        05:25  Delhi       Patna  28h 15m   2+-stop
# 65          14:10        14:10  Delhi       Patna  25h 40m   2+-stop
# 66          16:05        16:05  Delhi       Patna  21h 30m   2+-stop
# 67          09:55        09:55  Delhi       Patna  27h 15m   2+-stop
#
#    Flight Name   Price
# 0       Indigo   5,115
# 1       Indigo   5,115
# 2       Indigo   5,115
# 3     GO FIRST   5,114
# ...

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 95.0.4638
# Get LATEST driver version for 95.0.4638
# Driver [C:\Users\monish\.wdm\drivers\chromedriver\win32\95.0.4638.17\chromedriver.exe] found in cache

# %%
url ="https://www.easemytrip.com/"
driver.get(url)

# %%
search=driver.find_element_by_xpath("//div[@class='s_col_v4 ripplen']")
search.click()

# %%
dept=driver.find_elements_by_xpath("//span[@class='txt-r2-n ng-binding']")
dept
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="075050fb73a27487caf548ea0b488856", element="6ef77812-c9e7-4f23-834b-4d66b1da875e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="075050fb73a27487caf548ea0b488856", element="146b0cf9-6ebc-414c-ad16-fe905e7b9e1d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="075050fb73a27487caf548ea0b488856", element="01e22fe8-b1e6-4061-94f9-e2a780a40f84")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="075050fb73a27487caf548ea0b488856", element="5a2f3c14-43a5-4611-8bc4-8f05e58d5309")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="075050fb73a27487caf548ea0b488856", element="be4f0d77-ec32-4abb-8316-9c03449ccc7b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="075050fb73a27487caf548ea0b488856", element="9ec91492-21c1-4356-9f99-1d752b520b12")>,
# ...

# %%
departure=[]
for d in dept:
    departure.append(d.text)
departure
# Out:
# ['13:05',
#  '20:40',
#  '02:35',
#  '10:15',
#  '02:35',
#  '10:20',
#  '13:05',
#  '20:55',
#  '22:55',
#  '08:25',
#  '22:55',
#  '09:25',
#  '21:20',
#  '10:15',
#  '21:20',
#  '10:20',
#  '07:20',
#  '21:10',
#  '02:35',
#  '18:30',
#  '22:55',
#  '15:10',
#  '23:05',
#  '09:10',
#  '00:30',
#  '05:55',
#  '00:30',
#  '07:00',
#  '08:00',
#  '15:20',
#  '06:00',
#  '15:20',
#  '07:10',
#  '11:45',
#  '06:15',
#  '11:45',
#  '13:40',
#  '19:55',
#  '03:05',
#  '09:30',
#  '10:05',
#  '17:50',
#  '17:10',
#  '01:10',
#  '11:45',
#  '19:55',
#  '10:30',
#  '19:05',
#  '10:05',
#  '19:55',
#  '07:20',
#  '12:35',
#  '18:40',
#  '08:10',
#  '18:40',
#  '18:40',
#  '09:05',
#  '17:00',
#  '07:00',
#  '17:00',
#  '06:00',
#  '17:00',
#  '21:10',
#  '00:15',
#  '08:20',
#  '18:30',
#  '06:00',
#  '12:05',
#  '08:45',
#  '17:30',
#  '07:30',
#  '17:30',
#  '06:00',
#  '17:30',
#  '04:50',
#  '10:55',
#  '01:15',
#  '10:55',
#  '19:50',
#  '15:40',
#  '21:20',
#  '05:55',
#  '21:20',
# ...

# %%
arr=driver.find_elements_by_xpath("//span[@class='txt-r2-n ng-binding']")
arr
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="075050fb73a27487caf548ea0b488856", element="6ef77812-c9e7-4f23-834b-4d66b1da875e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="075050fb73a27487caf548ea0b488856", element="146b0cf9-6ebc-414c-ad16-fe905e7b9e1d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="075050fb73a27487caf548ea0b488856", element="01e22fe8-b1e6-4061-94f9-e2a780a40f84")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="075050fb73a27487caf548ea0b488856", element="5a2f3c14-43a5-4611-8bc4-8f05e58d5309")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="075050fb73a27487caf548ea0b488856", element="be4f0d77-ec32-4abb-8316-9c03449ccc7b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="075050fb73a27487caf548ea0b488856", element="9ec91492-21c1-4356-9f99-1d752b520b12")>,
# ...

# %%
arrival=[]
for a in arr:
    arrival.append(a.text)
arrival
# Out:
# ['13:05',
#  '20:40',
#  '02:35',
#  '10:15',
#  '02:35',
#  '10:20',
#  '13:05',
#  '20:55',
#  '22:55',
#  '08:25',
#  '22:55',
#  '09:25',
#  '21:20',
#  '10:15',
#  '21:20',
#  '10:20',
#  '07:20',
#  '21:10',
#  '02:35',
#  '18:30',
#  '22:55',
#  '15:10',
#  '23:05',
#  '09:10',
#  '00:30',
#  '05:55',
#  '00:30',
#  '07:00',
#  '08:00',
#  '15:20',
#  '06:00',
#  '15:20',
#  '07:10',
#  '11:45',
#  '06:15',
#  '11:45',
#  '13:40',
#  '19:55',
#  '03:05',
#  '09:30',
#  '10:05',
#  '17:50',
#  '17:10',
#  '01:10',
#  '11:45',
#  '19:55',
#  '10:30',
#  '19:05',
#  '10:05',
#  '19:55',
#  '07:20',
#  '12:35',
#  '18:40',
#  '08:10',
#  '18:40',
#  '18:40',
#  '09:05',
#  '17:00',
#  '07:00',
#  '17:00',
#  '06:00',
#  '17:00',
#  '21:10',
#  '00:15',
#  '08:20',
#  '18:30',
#  '06:00',
#  '12:05',
#  '08:45',
#  '17:30',
#  '07:30',
#  '17:30',
#  '06:00',
#  '17:30',
#  '04:50',
#  '10:55',
#  '01:15',
#  '10:55',
#  '19:50',
#  '15:40',
#  '21:20',
#  '05:55',
#  '21:20',
# ...

# %%
source1=driver.find_elements_by_xpath("//span[@class='txt-r3-n ng-binding']")
source1
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="075050fb73a27487caf548ea0b488856", element="fc333ef8-6846-4952-99cc-35c2827dcbe3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="075050fb73a27487caf548ea0b488856", element="885fb19f-a7c5-47ac-bce8-4d33b96a800b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="075050fb73a27487caf548ea0b488856", element="f12f1f88-44f9-4301-8d4c-cb4865286417")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="075050fb73a27487caf548ea0b488856", element="1332c7b2-5067-4ce5-bafb-61146dd18018")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="075050fb73a27487caf548ea0b488856", element="b71703ce-bbd6-4cdf-b29e-3114d1a23f69")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="075050fb73a27487caf548ea0b488856", element="f16641ed-94a2-40fd-a99c-1330cf5b2eb1")>,
# ...

# %%
source=[]
for s in source1:
    source.append(s.text)
source
# Out:
# ['Mumbai',
#  'Guwahati',
#  'Mumbai',
#  'Guwahati',
#  'Mumbai',
#  'Guwahati',
#  'Mumbai',
#  'Guwahati',
#  'Mumbai',
#  'Guwahati',
#  'Mumbai',
#  'Guwahati',
#  'Mumbai',
#  'Guwahati',
#  'Mumbai',
#  'Guwahati',
#  'Mumbai',
#  'Guwahati',
#  'Mumbai',
#  'Guwahati',
#  'Mumbai',
#  'Guwahati',
#  'Mumbai',
#  'Guwahati',
#  'Mumbai',
#  'Guwahati',
#  'Mumbai',
#  'Guwahati',
#  'Mumbai',
#  'Guwahati',
#  'Mumbai',
#  'Guwahati',
#  'Mumbai',
#  'Guwahati',
#  'Mumbai',
#  'Guwahati',
#  'Mumbai',
#  'Guwahati',
#  'Mumbai',
#  'Guwahati',
#  'Mumbai',
#  'Guwahati',
#  'Mumbai',
#  'Guwahati',
#  'Mumbai',
#  'Guwahati',
#  'Mumbai',
#  'Guwahati',
#  'Mumbai',
#  'Guwahati',
#  'Mumbai',
#  'Guwahati',
#  'Mumbai',
#  'Guwahati',
#  'Mumbai',
#  'Guwahati',
#  'Mumbai',
#  'Guwahati',
#  'Mumbai',
#  'Guwahati',
#  'Mumbai',
#  'Guwahati',
#  'Mumbai',
#  'Guwahati',
#  'Mumbai',
#  'Guwahati',
#  'Mumbai',
#  'Guwahati',
#  'Mumbai',
#  'Guwahati',
#  'Mumbai',
# ...

# %%
source_=[]
for e in range(0,len(source),2):
    source_.append(source[e])
source_
# Out:
# ['Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
# ...

# %%
destination=[]
for d in range(1,len(source),2):
    destination.append(source[d])
destination
# Out:
# ['Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
#  'Guwahati',
# ...

# %%
durr=driver.find_elements_by_xpath("//span[@class='dura_md ng-binding']")
durr
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="075050fb73a27487caf548ea0b488856", element="20bab76c-5a3e-4dbb-b350-fe7fcc296852")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="075050fb73a27487caf548ea0b488856", element="f95f78bc-4db9-47df-85c6-8105afdac13c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="075050fb73a27487caf548ea0b488856", element="ac74a8b2-f0d3-4849-8827-64dfcc69a6d5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="075050fb73a27487caf548ea0b488856", element="f97e707e-24b4-4bd0-b4c2-65c5e69f86cd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="075050fb73a27487caf548ea0b488856", element="5de78878-8422-4b62-82a9-0295faa59c6b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="075050fb73a27487caf548ea0b488856", element="ce20c252-5ead-4e76-a631-30fd7490408e")>,
# ...

# %%
duration=[]
for d in durr:
    duration.append(d.text)
duration
# Out:
# ['07h 35m',
#  '07h 40m',
#  '07h 45m',
#  '07h 50m',
#  '09h 30m',
#  '10h 30m',
#  '12h 55m',
#  '13h 00m',
#  '13h 50m',
#  '15h 55m',
#  '16h 15m',
#  '10h 05m',
#  '05h 25m',
#  '06h 30m',
#  '07h 20m',
#  '09h 20m',
#  '04h 35m',
#  '05h 30m',
#  '06h 15m',
#  '06h 25m',
#  '07h 45m',
#  '08h 00m',
#  '08h 10m',
#  '08h 35m',
#  '09h 50m',
#  '05h 15m',
#  '13h 30m',
#  '24h 00m',
#  '07h 55m',
#  '10h 00m',
#  '11h 00m',
#  '03h 05m',
#  '10h 10m',
#  '06h 05m',
#  '08h 45m',
#  '10h 00m',
#  '11h 30m',
#  '06h 05m',
#  '09h 40m',
#  '19h 50m',
#  '08h 35m',
#  '09h 40m',
#  '08h 30m',
#  '05h 35m',
#  '05h 35m',
#  '07h 05m',
#  '07h 50m',
#  '11h 00m',
#  '09h 20m',
#  '10h 05m',
#  '10h 30m',
#  '13h 30m',
#  '11h 45m',
#  '13h 20m',
#  '14h 10m',
#  '15h 10m',
#  '16h 20m',
#  '17h 35m',
#  '18h 35m',
#  '18h 45m',
#  '19h 35m',
#  '20h 20m',
#  '20h 35m',
#  '21h 25m',
#  '21h 45m',
#  '23h 00m',
#  '24h 00m',
#  '24h 10m',
#  '25h 45m',
#  '26h 50m',
#  '03h 00m',
# ...

# %%
flight=driver.find_elements_by_xpath("//span[@class='txt-r4 ng-binding']")
flight
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="075050fb73a27487caf548ea0b488856", element="55011cd1-d86b-4c96-b719-5a949d248220")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="075050fb73a27487caf548ea0b488856", element="773f5e24-8a68-4321-86aa-3582e6ba07bb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="075050fb73a27487caf548ea0b488856", element="e4984c58-8ae3-4dca-a98d-62c94adcd759")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="075050fb73a27487caf548ea0b488856", element="84482c0c-1082-4538-9f71-eb35465fad49")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="075050fb73a27487caf548ea0b488856", element="0a649681-8af3-4e72-a799-8bcc4a2dd4b2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="075050fb73a27487caf548ea0b488856", element="9e0698ea-4cd2-4146-86de-a933006d9868")>,
# ...

# %%
flight_name=[]
for f in flight:
    flight_name.append(f.text)
flight_name
# Out:
# ['AirAsia',
#  'AirAsia',
#  'AirAsia',
#  'AirAsia',
#  'AirAsia',
#  'AirAsia',
#  'AirAsia',
#  'AirAsia',
#  'AirAsia',
#  'AirAsia',
#  'AirAsia',
#  'Indigo',
#  'Indigo',
#  'Indigo',
#  'GO FIRST',
#  'GO FIRST',
#  'Indigo',
#  'Indigo',
#  'Indigo',
#  'Indigo',
#  'Indigo',
#  'Indigo',
#  'Indigo',
#  'Indigo',
#  'Indigo',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Indigo',
#  'AirAsia',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Indigo',
#  'Indigo',
#  'SpiceJet',
#  'Indigo',
#  'Indigo',
#  'Indigo',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'AirAsia',
#  'Vistara',
#  'Indigo',
#  'Indigo',
#  'GO FIRST',
#  'GO FIRST',
#  'Air India',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Indigo',
#  'Air India',
# ...

# %%
stop=driver.find_elements_by_xpath("//span[@class='dura_md2 ng-scope']")
stop
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="075050fb73a27487caf548ea0b488856", element="5f2ebe8a-1d46-4739-836f-d88a80b829b7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="075050fb73a27487caf548ea0b488856", element="ca96e925-437d-4a66-a07e-7d7323e8f1be")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="075050fb73a27487caf548ea0b488856", element="55b497e6-2172-4f76-93b5-f86568c7ceab")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="075050fb73a27487caf548ea0b488856", element="49305568-0d10-473a-8de8-81ac52ebec92")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="075050fb73a27487caf548ea0b488856", element="92bd0542-be37-4285-b541-b1b37b0d81a2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="075050fb73a27487caf548ea0b488856", element="9cb24edc-d153-4772-b3d7-9eac4390af84")>,
# ...

# %%
stoppage=[]
for s in stop:
    stoppage.append(s.text)
stoppage
# Out:
# ['1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  'non-stop',
#  '2+-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  'non-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
# ...

# %%
price=driver.find_elements_by_xpath("//div[@class='col-md-8 col-sm-8 col-xs-9 txt-r6-n ng-binding']")
price
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="075050fb73a27487caf548ea0b488856", element="ce0d6220-9eed-4451-a7c8-6e4cfac1c495")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="075050fb73a27487caf548ea0b488856", element="d984ca14-c9b6-4680-9ed5-eaac20841d1b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="075050fb73a27487caf548ea0b488856", element="93fac0e7-7f1f-4a61-96bf-69099ec6cbf4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="075050fb73a27487caf548ea0b488856", element="fe0b1495-7cfa-461b-beb1-ccc6c4a017b6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="075050fb73a27487caf548ea0b488856", element="2641305e-270a-4601-89c1-46863926b7eb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="075050fb73a27487caf548ea0b488856", element="6cadc3db-49e2-46c5-a7f4-00eb7460447e")>,
# ...

# %%
prices=[]
for p in price:
    prices.append(p.text)
prices
# Out:
# ['8,680',
#  '8,680',
#  '8,680',
#  '8,680',
#  '8,680',
#  '8,680',
#  '8,680',
#  '8,680',
#  '8,680',
#  '8,680',
#  '8,680',
#  '8,728',
#  '8,728',
#  '8,728',
#  '8,680',
#  '8,680',
#  '8,728',
#  '8,728',
#  '8,728',
#  '8,728',
#  '8,728',
#  '8,728',
#  '8,728',
#  '8,728',
#  '8,728',
#  '8,978',
#  '8,978',
#  '8,978',
#  '10,670',
#  '10,670',
#  '10,670',
#  '9,178',
#  '9,178',
#  '10,610',
#  '10,610',
#  '10,610',
#  '10,610',
#  '9,463',
#  '9,463',
#  '9,578',
#  '10,198',
#  '10,198',
#  '11,668',
#  '10,610',
#  '10,610',
#  '10,610',
#  '10,610',
#  '10,610',
#  '12,278',
#  '12,278',
#  '10,679',
#  '10,679',
#  '10,768',
#  '10,780',
#  '10,780',
#  '10,780',
#  '10,780',
#  '10,780',
#  '10,780',
#  '10,780',
#  '10,780',
#  '10,780',
#  '10,780',
#  '10,780',
#  '10,780',
#  '10,780',
#  '10,780',
#  '10,780',
#  '10,780',
#  '10,780',
#  '11,178',
#  '11,318',
#  '12,253',
#  '13,028',
#  '13,028',
#  '11,953',
#  '12,198',
#  '12,379',
#  '13,028',
# ...

# %%
import pandas as pd
df16=pd.DataFrame({})
df16['Departure Time']=departure[:117]
df16['Arrival Time']=arrival[:117]
df16['Source']=source[:117]
df16['Destination']=destination[:117]
df16['Duration']=duration[:117]
df16['Stoppage']=stoppage[:117]
df16['Flight Name']=flight_name[:117]
df16['Price']=prices[:117]
df16
# Out:
#     Departure Time Arrival Time    Source Destination Duration Stoppage  \
# 0            13:05        13:05    Mumbai    Guwahati  07h 35m   1-stop
# 1            20:40        20:40  Guwahati    Guwahati  07h 40m   1-stop
# 2            02:35        02:35    Mumbai    Guwahati  07h 45m   1-stop
# 3            10:15        10:15  Guwahati    Guwahati  07h 50m   1-stop
# 4            02:35        02:35    Mumbai    Guwahati  09h 30m   1-stop
# ..             ...          ...       ...         ...      ...      ...
# 112          19:45        19:45    Mumbai    Guwahati  16h 05m  2+-stop
# 113          12:05        12:05  Guwahati    Guwahati  20h 30m  2+-stop
# 114          18:30        18:30    Mumbai    Guwahati  14h 40m  2+-stop
# 115          12:05        12:05  Guwahati    Guwahati  18h 10m  2+-stop
# 116          17:30        17:30    Mumbai    Guwahati  17h 10m  2+-stop
#
#     Flight Name   Price
# 0       AirAsia   8,680
# 1       AirAsia   8,680
# 2       AirAsia   8,680
# ...

# %%
# !pip install webdriver-manager

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 95.0.4638
# Get LATEST driver version for 95.0.4638
# Driver [C:\Users\monish\.wdm\drivers\chromedriver\win32\95.0.4638.17\chromedriver.exe] found in cache

# %%
url ="https://www.easemytrip.com/"
driver.get(url)

# %%
search=driver.find_element_by_xpath("//div[@class='s_col_v4 ripplen']")
search.click()

# %%
dept=driver.find_elements_by_xpath("//span[@class='txt-r2-n ng-binding']")
dept
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="3412f23cff86f30a969b24861cb72886", element="f7ed4fae-2144-4ced-befd-b162cc1988ba")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="3412f23cff86f30a969b24861cb72886", element="5ab14f57-7115-4ba7-bd97-de4ab4c61336")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="3412f23cff86f30a969b24861cb72886", element="ce6179a1-066a-4646-a535-0e2676cc2585")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="3412f23cff86f30a969b24861cb72886", element="542d2374-2a7a-4338-bb20-4bd99a8336d5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="3412f23cff86f30a969b24861cb72886", element="990cfb0a-4b03-45f6-9421-60ebef784dc9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="3412f23cff86f30a969b24861cb72886", element="ff773759-8c94-48d2-aa4b-4167a86aff37")>,
# ...

# %%
departure=[]
for d in dept:
    departure.append(d.text)
departure
# Out:
# ['20:00',
#  '22:20',
#  '18:00',
#  '20:40',
#  '05:35',
#  '08:05',
#  '22:55',
#  '01:25',
#  '18:30',
#  '21:05',
#  '00:45',
#  '07:10',
#  '00:10',
#  '07:10',
#  '11:20',
#  '19:15',
#  '22:10',
#  '07:10',
#  '06:25',
#  '15:45',
#  '11:20',
#  '23:10',
#  '06:25',
#  '19:20',
#  '06:15',
#  '19:15',
#  '17:30',
#  '08:25',
#  '16:25',
#  '08:25',
#  '07:00',
#  '17:25',
#  '21:00',
#  '08:00',
#  '08:15',
#  '22:10',
#  '11:00',
#  '11:40',
#  '12:25',
#  '16:55',
#  '22:55',
#  '07:15',
#  '20:35',
#  '07:25',
#  '17:20',
#  '22:25',
#  '21:55',
#  '07:55',
#  '23:10',
#  '01:35',
#  '21:45',
#  '00:10',
#  '23:25',
#  '01:55',
#  '03:30',
#  '06:10',
#  '20:05',
#  '22:45',
#  '17:05',
#  '19:35',
#  '05:40',
#  '08:15',
#  '18:45',
#  '06:05',
#  '06:35',
#  '09:15',
#  '15:15',
#  '17:45',
#  '23:45',
#  '07:55',
#  '08:00',
#  '17:00',
#  '08:00',
#  '18:40',
#  '23:00',
#  '10:05',
#  '13:15',
#  '15:50',
#  '16:55',
#  '21:50',
#  '23:45',
#  '06:05',
#  '05:30',
# ...

# %%
arr=driver.find_elements_by_xpath("//span[@class='txt-r2-n ng-binding']")
arr
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="3412f23cff86f30a969b24861cb72886", element="f7ed4fae-2144-4ced-befd-b162cc1988ba")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="3412f23cff86f30a969b24861cb72886", element="5ab14f57-7115-4ba7-bd97-de4ab4c61336")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="3412f23cff86f30a969b24861cb72886", element="ce6179a1-066a-4646-a535-0e2676cc2585")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="3412f23cff86f30a969b24861cb72886", element="542d2374-2a7a-4338-bb20-4bd99a8336d5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="3412f23cff86f30a969b24861cb72886", element="990cfb0a-4b03-45f6-9421-60ebef784dc9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="3412f23cff86f30a969b24861cb72886", element="ff773759-8c94-48d2-aa4b-4167a86aff37")>,
# ...

# %%
arrival=[]
for a in arr:
    arrival.append(a.text)
arrival
# Out:
# ['20:00',
#  '22:20',
#  '18:00',
#  '20:40',
#  '05:35',
#  '08:05',
#  '22:55',
#  '01:25',
#  '18:30',
#  '21:05',
#  '00:45',
#  '07:10',
#  '00:10',
#  '07:10',
#  '11:20',
#  '19:15',
#  '22:10',
#  '07:10',
#  '06:25',
#  '15:45',
#  '11:20',
#  '23:10',
#  '06:25',
#  '19:20',
#  '06:15',
#  '19:15',
#  '17:30',
#  '08:25',
#  '16:25',
#  '08:25',
#  '07:00',
#  '17:25',
#  '21:00',
#  '08:00',
#  '08:15',
#  '22:10',
#  '11:00',
#  '11:40',
#  '12:25',
#  '16:55',
#  '22:55',
#  '07:15',
#  '20:35',
#  '07:25',
#  '17:20',
#  '22:25',
#  '21:55',
#  '07:55',
#  '23:10',
#  '01:35',
#  '21:45',
#  '00:10',
#  '23:25',
#  '01:55',
#  '03:30',
#  '06:10',
#  '20:05',
#  '22:45',
#  '17:05',
#  '19:35',
#  '05:40',
#  '08:15',
#  '18:45',
#  '06:05',
#  '06:35',
#  '09:15',
#  '15:15',
#  '17:45',
#  '23:45',
#  '07:55',
#  '08:00',
#  '17:00',
#  '08:00',
#  '18:40',
#  '23:00',
#  '10:05',
#  '13:15',
#  '15:50',
#  '16:55',
#  '21:50',
#  '23:45',
#  '06:05',
#  '05:30',
# ...

# %%
source1=driver.find_elements_by_xpath("//span[@class='txt-r3-n ng-binding']")
source1
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="3412f23cff86f30a969b24861cb72886", element="c9c10f7e-10c7-4c92-99d3-5037c6d1f7b4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="3412f23cff86f30a969b24861cb72886", element="d41d4526-7236-414e-9ca7-55c50d4d58c2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="3412f23cff86f30a969b24861cb72886", element="c7ecbde5-bc40-44e3-83a4-aabd6fda7aef")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="3412f23cff86f30a969b24861cb72886", element="c3556400-7874-4f00-8c45-65e1795d80a0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="3412f23cff86f30a969b24861cb72886", element="4baba686-905c-4b09-bd1e-e0389cf4d933")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="3412f23cff86f30a969b24861cb72886", element="2273b9f9-6a1e-4065-ac30-a7375cc88475")>,
# ...

# %%
source=[]
for s in source1:
    source.append(s.text)
source
# Out:
# ['Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
# ...

# %%
source_=[]
for s in range(0,len(source),2):
    source_.append(source[s])
source_
# Out:
# ['Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
# ...

# %%
destination=[]
for d in range(1,len(source),2):
    destination.append(source[d])
destination
# Out:
# ['Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
# ...

# %%
durr=driver.find_elements_by_xpath("//span[@class='dura_md ng-binding']")
durr
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="3412f23cff86f30a969b24861cb72886", element="bf65d2dd-902f-41bd-a0bb-735cee391cdc")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="3412f23cff86f30a969b24861cb72886", element="ebe53bc1-fcb6-45aa-87bc-7c0cb33420ca")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="3412f23cff86f30a969b24861cb72886", element="15f9d90d-49ef-47e7-be3c-3993627cbd51")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="3412f23cff86f30a969b24861cb72886", element="f9bb7349-c9d6-4467-9ac1-164f32a75f96")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="3412f23cff86f30a969b24861cb72886", element="f9322d5f-8f0b-4528-abab-38d8f976838f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="3412f23cff86f30a969b24861cb72886", element="e3141a19-6253-4598-834b-a7a57264f993")>,
# ...

# %%
duration=[]
for d in durr:
    duration.append(d.text)
duration
# Out:
# ['02h 20m',
#  '02h 40m',
#  '02h 30m',
#  '02h 30m',
#  '02h 35m',
#  '06h 25m',
#  '07h 00m',
#  '07h 55m',
#  '09h 00m',
#  '09h 20m',
#  '11h 50m',
#  '12h 55m',
#  '13h 00m',
#  '14h 55m',
#  '16h 00m',
#  '10h 25m',
#  '11h 00m',
#  '13h 55m',
#  '24h 40m',
#  '04h 30m',
#  '08h 20m',
#  '10h 50m',
#  '05h 05m',
#  '10h 00m',
#  '02h 25m',
#  '02h 25m',
#  '02h 30m',
#  '02h 40m',
#  '02h 40m',
#  '02h 30m',
#  '02h 35m',
#  '11h 20m',
#  '02h 40m',
#  '02h 30m',
#  '08h 10m',
#  '09h 00m',
#  '10h 40m',
#  '11h 05m',
#  '02h 35m',
#  '04h 55m',
#  '06h 20m',
#  '07h 25m',
#  '08h 10m',
#  '09h 50m',
#  '03h 40m',
#  '02h 40m',
#  '02h 40m',
#  '05h 15m',
#  '05h 55m',
#  '06h 20m',
#  '08h 25m',
#  '09h 20m',
#  '09h 20m',
#  '09h 35m',
#  '02h 35m',
#  '06h 10m',
#  '06h 10m',
#  '07h 10m',
#  '07h 45m',
#  '08h 40m',
#  '09h 30m',
#  '12h 15m',
#  '08h 55m',
#  '09h 10m',
#  '10h 10m',
#  '10h 00m',
#  '09h 55m',
#  '10h 05m',
#  '22h 15m',
#  '24h 00m',
#  '25h 30m',
# ...

# %%
flight=driver.find_elements_by_xpath("//span[@class='txt-r4 ng-binding']")
flight
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="3412f23cff86f30a969b24861cb72886", element="180a828d-99ed-4f79-8ea4-e0b5e1d59c3e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="3412f23cff86f30a969b24861cb72886", element="71507f8d-dbba-4445-8c28-6acc2904fea7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="3412f23cff86f30a969b24861cb72886", element="d2f839df-943e-4144-b1de-20656a44419d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="3412f23cff86f30a969b24861cb72886", element="356635ae-cc66-4335-9901-4d5688c1cf00")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="3412f23cff86f30a969b24861cb72886", element="620cce07-69b6-4cf2-92e6-16698aa048ff")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="3412f23cff86f30a969b24861cb72886", element="02cf72b7-f1f2-4c78-b7be-1ee1b7e98e6a")>,
# ...

# %%
flight_name=[]
for f in flight:
    flight_name.append(f.text)
flight_name
# Out:
# ['GO FIRST',
#  'Indigo',
#  'AirAsia',
#  'AirAsia',
#  'AirAsia',
#  'AirAsia',
#  'AirAsia',
#  'AirAsia',
#  'AirAsia',
#  'AirAsia',
#  'AirAsia',
#  'AirAsia',
#  'AirAsia',
#  'AirAsia',
#  'AirAsia',
#  'GO FIRST',
#  'GO FIRST',
#  'GO FIRST',
#  'SpiceJet',
#  'Indigo',
#  'Indigo',
#  'Indigo',
#  'Indigo',
#  'Indigo',
#  'AirAsia',
#  'Indigo',
#  'Indigo',
#  'Indigo',
#  'Indigo',
#  'SpiceJet',
#  'SpiceJet',
#  'Indigo',
#  'Indigo',
#  'Indigo',
#  'Indigo',
#  'Indigo',
#  'Indigo',
#  'Indigo',
#  'Indigo',
#  'Indigo',
#  'Indigo',
#  'AirAsia',
#  'Indigo',
#  'Indigo',
#  'AirAsia',
#  'Indigo',
#  'Indigo',
#  'AirAsia',
#  'Indigo',
#  'Indigo',
#  'Indigo',
#  'Indigo',
#  'Indigo',
#  'Indigo',
#  'Air India',
#  'Indigo',
#  'Indigo',
#  'Indigo',
#  'Indigo',
#  'AirAsia',
#  'AirAsia',
#  'AirAsia',
#  'Indigo',
#  'Indigo',
#  'Indigo',
#  'SpiceJet',
#  'Indigo',
#  'Indigo',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'GO FIRST',
#  'Indigo',
# ...

# %%
stop=driver.find_elements_by_xpath("//span[@class='dura_md2 ng-scope']")
stop
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="3412f23cff86f30a969b24861cb72886", element="7581d531-e92d-4d14-a562-3ae340224f7e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="3412f23cff86f30a969b24861cb72886", element="2cc67bac-0b26-4f49-b80f-451390069ab1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="3412f23cff86f30a969b24861cb72886", element="ca3190e6-0034-4d9b-9d90-fcfc52f6a047")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="3412f23cff86f30a969b24861cb72886", element="e24f2d64-e6c1-4fdd-b843-62ff24680ff0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="3412f23cff86f30a969b24861cb72886", element="baef3dbd-bfa6-4e2a-9eec-b57778b217e7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="3412f23cff86f30a969b24861cb72886", element="f223227e-5558-4bc2-b19e-c32996ca7651")>,
# ...

# %%
stoppage=[]
for s in stop:
    stoppage.append(s.text)
stoppage
# Out:
# ['non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '2+-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  '1-stop',
#  'non-stop',
#  'non-stop',
#  '1-stop',
#  '2+-stop',
#  '2+-stop',
#  '1-stop',
#  'non-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  'non-stop',
#  'non-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  'non-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '2+-stop',
#  '2+-stop',
#  '2+-stop',
#  '2+-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  'non-stop',
#  '1-stop',
# ...

# %%
price=driver.find_elements_by_xpath("//div[@class='col-md-8 col-sm-8 col-xs-9 txt-r6-n ng-binding']")
price
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="3412f23cff86f30a969b24861cb72886", element="c8f15c3d-ed63-4a3c-acd3-4ae101bccb7b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="3412f23cff86f30a969b24861cb72886", element="886963d0-56d3-4711-92fa-27ea55af8097")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="3412f23cff86f30a969b24861cb72886", element="12a194ae-9167-4b66-a731-7b9f02dbdf9e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="3412f23cff86f30a969b24861cb72886", element="11afa63d-882d-4e95-96cf-6cf2ef892429")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="3412f23cff86f30a969b24861cb72886", element="8d14a3d6-33d9-4616-a3c4-f21b1ee3f829")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="3412f23cff86f30a969b24861cb72886", element="317c186b-f3b5-47db-b67d-6521247c8a5f")>,
# ...

# %%
prices=[]
for p in price:
    prices.append(p.text)
prices
# Out:
# ['5,177',
#  '5,178',
#  '5,802',
#  '5,802',
#  '5,179',
#  '5,176',
#  '5,176',
#  '5,176',
#  '5,176',
#  '5,176',
#  '5,176',
#  '5,176',
#  '5,176',
#  '5,176',
#  '5,176',
#  '5,177',
#  '5,177',
#  '5,177',
#  '5,177',
#  '5,178',
#  '5,178',
#  '5,178',
#  '5,635',
#  '5,635',
#  '5,802',
#  '5,802',
#  '5,802',
#  '5,802',
#  '5,802',
#  '5,913',
#  '5,913',
#  '6,092',
#  '6,225',
#  '6,438',
#  '6,548',
#  '6,548',
#  '6,548',
#  '6,548',
#  '6,753',
#  '7,005',
#  '7,005',
#  '7,005',
#  '7,005',
#  '7,005',
#  '7,146',
#  '7,278',
#  '7,278',
#  '7,462',
#  '7,462',
#  '7,462',
#  '7,462',
#  '7,462',
#  '7,462',
#  '7,462',
#  '7,699',
#  '7,919',
#  '7,919',
#  '7,919',
#  '8,375',
#  '8,768',
#  '8,768',
#  '8,768',
#  '8,832',
#  '8,832',
#  '8,832',
#  '8,955',
#  '9,746',
#  '9,746',
#  '9,917',
#  '9,917',
#  '9,917',
#  '10,007',
#  '10,202',
#  '10,589',
#  '10,589',
#  '10,589',
#  '10,589',
#  '10,589',
#  '10,589',
#  '10,589',
#  '10,589',
#  '10,589',
# ...

# %%
len(prices)
# Out:
# 136

# %%
import pandas as pd
df17=pd.DataFrame({})
df17['Departure Time']=departure[:136]
df17['Arrival Time']=arrival[:136]
df17['Source']=source_[:136]
df17['Destination']=destination[:136]
df17['Duration']=duration[:136]
df17['Stoppage']=stoppage[:136]
df17['Flight Name']=flight_name[:136]
df17['Price']=prices[:136]
df17
# Out:
#     Departure Time Arrival Time     Source Destination Duration  Stoppage  \
# 0            20:00        20:00  Bangalore     Kolkata  02h 20m  non-stop
# 1            22:20        22:20  Bangalore     Kolkata  02h 40m  non-stop
# 2            18:00        18:00  Bangalore     Kolkata  02h 30m  non-stop
# 3            20:40        20:40  Bangalore     Kolkata  02h 30m  non-stop
# 4            05:35        05:35  Bangalore     Kolkata  02h 35m  non-stop
# ..             ...          ...        ...         ...      ...       ...
# 131          16:25        16:25  Bangalore     Kolkata  17h 45m    1-stop
# 132          09:20        09:20  Bangalore     Kolkata  10h 25m   2+-stop
# 133          19:15        19:15  Bangalore     Kolkata  09h 30m    1-stop
# 134          12:50        12:50  Bangalore     Kolkata  11h 30m    1-stop
# 135          22:55        22:55  Bangalore     Kolkata  13h 40m    1-stop
#
#     Flight Name   Price
# 0      GO FIRST   5,177
# 1        Indigo   5,178
# ...

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 95.0.4638
# Get LATEST driver version for 95.0.4638
# Driver [C:\Users\monish\.wdm\drivers\chromedriver\win32\95.0.4638.17\chromedriver.exe] found in cache

# %%
url ="https://www.easemytrip.com/"
driver.get(url)

# %%
search=driver.find_element_by_xpath("//div[@class='s_col_v4 ripplen']")
search.click()

# %%
dept=driver.find_elements_by_xpath("//span[@class='txt-r2-n ng-binding']")
dept
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="4736e3ff2e0319a41d4bf2e7b6307f94", element="39fc1c97-e4b0-436d-917b-5117456feaa3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4736e3ff2e0319a41d4bf2e7b6307f94", element="2d06d9ca-5a9b-48a6-b5b9-7b69334657ab")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4736e3ff2e0319a41d4bf2e7b6307f94", element="2d712713-08d1-4395-a722-3da6ea5e2fb6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4736e3ff2e0319a41d4bf2e7b6307f94", element="75b004e9-3e10-4d04-bf2b-5031679bb6b1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4736e3ff2e0319a41d4bf2e7b6307f94", element="a593cfa9-4431-4936-8eeb-3d52108cf6eb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4736e3ff2e0319a41d4bf2e7b6307f94", element="8e7b4081-2bd3-4847-9456-34e61dab28e5")>,
# ...

# %%
departure=[]
for d in dept:
    departure.append(d.text)
departure
# Out:
# ['06:05',
#  '18:15',
#  '05:35',
#  '18:15',
#  '06:05',
#  '19:00',
#  '05:35',
#  '19:00',
#  '08:00',
#  '14:25',
#  '05:30',
#  '13:10',
#  '23:05',
#  '09:20',
#  '11:00',
#  '16:45',
#  '07:25',
#  '13:25',
#  '07:55',
#  '16:45',
#  '06:45',
#  '16:45',
#  '08:00',
#  '10:15',
#  '12:45',
#  '14:50',
#  '17:45',
#  '19:55',
#  '17:25',
#  '19:40',
#  '11:10',
#  '13:15',
#  '15:25',
#  '17:20',
#  '16:20',
#  '18:35',
#  '08:20',
#  '10:25',
#  '23:05',
#  '10:35',
#  '09:40',
#  '16:45',
#  '07:25',
#  '17:15',
#  '06:00',
#  '08:05',
#  '07:00',
#  '15:10',
#  '16:05',
#  '18:05',
#  '09:15',
#  '15:10',
#  '07:45',
#  '17:25',
#  '11:05',
#  '16:40',
#  '18:40',
#  '08:30',
#  '08:30',
#  '17:25',
#  '11:25',
#  '19:40',
#  '16:00',
#  '18:10',
#  '09:55',
#  '16:40',
#  '20:10',
#  '08:15',
#  '05:50',
#  '14:20',
#  '08:35',
#  '17:15',
#  '21:00',
#  '11:20',
#  '16:35',
#  '18:40',
#  '16:40',
#  '18:45',
#  '13:30',
#  '19:40',
#  '15:30',
#  '22:25']

# %%
arr=driver.find_elements_by_xpath("//span[@class='txt-r2-n ng-binding']")
arr
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="4736e3ff2e0319a41d4bf2e7b6307f94", element="39fc1c97-e4b0-436d-917b-5117456feaa3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4736e3ff2e0319a41d4bf2e7b6307f94", element="2d06d9ca-5a9b-48a6-b5b9-7b69334657ab")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4736e3ff2e0319a41d4bf2e7b6307f94", element="2d712713-08d1-4395-a722-3da6ea5e2fb6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4736e3ff2e0319a41d4bf2e7b6307f94", element="75b004e9-3e10-4d04-bf2b-5031679bb6b1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4736e3ff2e0319a41d4bf2e7b6307f94", element="a593cfa9-4431-4936-8eeb-3d52108cf6eb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4736e3ff2e0319a41d4bf2e7b6307f94", element="8e7b4081-2bd3-4847-9456-34e61dab28e5")>,
# ...

# %%
arrival=[]
for a in arr:
    arrival.append(a.text)
arrival
# Out:
# ['06:05',
#  '18:15',
#  '05:35',
#  '18:15',
#  '06:05',
#  '19:00',
#  '05:35',
#  '19:00',
#  '08:00',
#  '14:25',
#  '05:30',
#  '13:10',
#  '23:05',
#  '09:20',
#  '11:00',
#  '16:45',
#  '07:25',
#  '13:25',
#  '07:55',
#  '16:45',
#  '06:45',
#  '16:45',
#  '08:00',
#  '10:15',
#  '12:45',
#  '14:50',
#  '17:45',
#  '19:55',
#  '17:25',
#  '19:40',
#  '11:10',
#  '13:15',
#  '15:25',
#  '17:20',
#  '16:20',
#  '18:35',
#  '08:20',
#  '10:25',
#  '23:05',
#  '10:35',
#  '09:40',
#  '16:45',
#  '07:25',
#  '17:15',
#  '06:00',
#  '08:05',
#  '07:00',
#  '15:10',
#  '16:05',
#  '18:05',
#  '09:15',
#  '15:10',
#  '07:45',
#  '17:25',
#  '11:05',
#  '16:40',
#  '18:40',
#  '08:30',
#  '08:30',
#  '17:25',
#  '11:25',
#  '19:40',
#  '16:00',
#  '18:10',
#  '09:55',
#  '16:40',
#  '20:10',
#  '08:15',
#  '05:50',
#  '14:20',
#  '08:35',
#  '17:15',
#  '21:00',
#  '11:20',
#  '16:35',
#  '18:40',
#  '16:40',
#  '18:45',
#  '13:30',
#  '19:40',
#  '15:30',
#  '22:25']

# %%
source1=driver.find_elements_by_xpath("//span[@class='txt-r3-n ng-binding']")
source1
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="4736e3ff2e0319a41d4bf2e7b6307f94", element="aabf6b5c-10cb-4853-a568-85a4ef4b11ba")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4736e3ff2e0319a41d4bf2e7b6307f94", element="2c311fad-b9e2-4338-9a0f-b44568f43c4f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4736e3ff2e0319a41d4bf2e7b6307f94", element="5ac10e42-28dc-48ee-bffc-bf1936b5222b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4736e3ff2e0319a41d4bf2e7b6307f94", element="fe0f7514-119b-45c6-80cc-c750176df997")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4736e3ff2e0319a41d4bf2e7b6307f94", element="075fb1cd-fc8c-4baa-a44e-3fd946281a58")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4736e3ff2e0319a41d4bf2e7b6307f94", element="9e5f7990-1cc6-4fb7-a51b-9c6d3b9ab10e")>,
# ...

# %%
source_=[]
for s in source1:
    source_.append(s.text)
source_
# Out:
# ['Delhi',
#  'Pune',
#  'Delhi',
#  'Pune',
#  'Delhi',
#  'Pune',
#  'Delhi',
#  'Pune',
#  'Delhi',
#  'Pune',
#  'Delhi',
#  'Pune',
#  'Delhi',
#  'Pune',
#  'Delhi',
#  'Pune',
#  'Delhi',
#  'Pune',
#  'Delhi',
#  'Pune',
#  'Delhi',
#  'Pune',
#  'Delhi',
#  'Pune',
#  'Delhi',
#  'Pune',
#  'Delhi',
#  'Pune',
#  'Delhi',
#  'Pune',
#  'Delhi',
#  'Pune',
#  'Delhi',
#  'Pune',
#  'Delhi',
#  'Pune',
#  'Delhi',
#  'Pune',
#  'Delhi',
#  'Pune',
#  'Delhi',
#  'Pune',
#  'Delhi',
#  'Pune',
#  'Delhi',
#  'Pune',
#  'Delhi',
#  'Pune',
#  'Delhi',
#  'Pune',
#  'Delhi',
#  'Pune',
#  'Delhi',
#  'Pune',
#  'Delhi',
#  'Pune',
#  'Delhi',
#  'Pune',
#  'Delhi',
#  'Pune',
#  'Delhi',
#  'Pune',
#  'Delhi',
#  'Pune',
#  'Delhi',
#  'Pune',
#  'Delhi',
#  'Pune',
#  'Delhi',
#  'Pune',
#  'Delhi',
#  'Pune',
#  'Delhi',
#  'Pune',
#  'Delhi',
#  'Pune',
#  'Delhi',
#  'Pune',
#  'Delhi',
#  'Pune',
#  'Delhi',
#  'Pune']

# %%
source=[]
for s in range(0,len(source_),2):
    source.append(source_[s])
source
# Out:
# ['Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi']

# %%
destination=[]
for d in range(1,len(source_),2):
    destination.append(source_[d])
destination
# Out:
# ['Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune']

# %%
durr=driver.find_elements_by_xpath("//span[@class='dura_md ng-binding']")
durr
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="4736e3ff2e0319a41d4bf2e7b6307f94", element="8b0c4ae7-c9ef-425f-bd77-a785a9a01de3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4736e3ff2e0319a41d4bf2e7b6307f94", element="659b6973-1350-4db8-8d47-0c979daf161c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4736e3ff2e0319a41d4bf2e7b6307f94", element="fc311442-87a7-4d1d-b011-9e39adbbe8d3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4736e3ff2e0319a41d4bf2e7b6307f94", element="dc289afa-384a-4a43-9b99-2caf7cbd6ef9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4736e3ff2e0319a41d4bf2e7b6307f94", element="f5d56d2e-76e1-419e-b8a2-f3dc755d8aa1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4736e3ff2e0319a41d4bf2e7b6307f94", element="72560700-282d-46fa-8fdf-8c771b62450f")>,
# ...

# %%
duration=[]
for d in durr:
    duration.append(d.text)
duration
# Out:
# ['12h 10m',
#  '12h 40m',
#  '12h 55m',
#  '13h 25m',
#  '06h 25m',
#  '07h 40m',
#  '10h 15m',
#  '05h 45m',
#  '06h 00m',
#  '08h 50m',
#  '10h 00m',
#  '02h 15m',
#  '02h 05m',
#  '02h 10m',
#  '02h 15m',
#  '02h 05m',
#  '01h 55m',
#  '02h 15m',
#  '02h 05m',
#  '11h 30m',
#  '07h 05m',
#  '09h 50m',
#  '02h 05m',
#  '08h 10m',
#  '02h 00m',
#  '05h 55m',
#  '09h 40m',
#  '05h 35m',
#  '13h 50m',
#  '08h 55m',
#  '08h 15m',
#  '02h 10m',
#  '06h 45m',
#  '12h 05m',
#  '08h 30m',
#  '08h 40m',
#  '14h 20m',
#  '02h 05m',
#  '02h 05m',
#  '06h 10m',
#  '06h 55m']

# %%
flight=driver.find_elements_by_xpath("//span[@class='txt-r4 ng-binding']")
flight
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="4736e3ff2e0319a41d4bf2e7b6307f94", element="3bc2dae0-484e-4b14-8710-2bea441f6658")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4736e3ff2e0319a41d4bf2e7b6307f94", element="1b95e08c-e35e-4b54-b9d3-363c34ac40b8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4736e3ff2e0319a41d4bf2e7b6307f94", element="d13d7bb6-2e83-45a0-bec5-b829a8741c77")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4736e3ff2e0319a41d4bf2e7b6307f94", element="d46a8e79-fe48-491e-8ef3-6ae0e400d514")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4736e3ff2e0319a41d4bf2e7b6307f94", element="8eb9569c-22f9-4d79-b05d-f05e4ca0b81d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4736e3ff2e0319a41d4bf2e7b6307f94", element="4bb7b4b5-e7ee-4546-9d72-0d02f703f52b")>,
# ...

# %%
flight_name=[]
for f in flight:
    flight_name.append(f.text)
flight_name
# Out:
# ['GO FIRST',
#  'GO FIRST',
#  'GO FIRST',
#  'GO FIRST',
#  'AirAsia',
#  'Indigo',
#  'Indigo',
#  'Indigo',
#  'Indigo',
#  'Indigo',
#  'Indigo',
#  'GO FIRST',
#  'GO FIRST',
#  'SpiceJet',
#  'Vistara',
#  'Indigo',
#  'AirAsia',
#  'Vistara',
#  'Indigo',
#  'Indigo',
#  'Indigo',
#  'Indigo',
#  'Air India',
#  'Indigo',
#  'AirAsia',
#  'Indigo',
#  'Indigo',
#  'Indigo',
#  'GO FIRST',
#  'Indigo',
#  'Indigo',
#  'Air India',
#  'Indigo',
#  'SpiceJet',
#  'GO FIRST',
#  'Indigo',
#  'AirAsia',
#  'GO FIRST',
#  'Indigo',
#  'Indigo',
#  'GO FIRST']

# %%
stop=driver.find_elements_by_xpath("//span[@class='dura_md2 ng-scope']")
stop
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="4736e3ff2e0319a41d4bf2e7b6307f94", element="8d526c5b-2d32-45a1-97f7-9fec1841b911")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4736e3ff2e0319a41d4bf2e7b6307f94", element="27238c65-017c-43a4-8c33-746a9d74bfc9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4736e3ff2e0319a41d4bf2e7b6307f94", element="0a652f51-e5d4-43c4-b611-e6ef5c40be7f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4736e3ff2e0319a41d4bf2e7b6307f94", element="40ad10bc-bb6a-4e45-b70f-3019a47050e5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4736e3ff2e0319a41d4bf2e7b6307f94", element="9362567a-a5b9-4397-a6a3-2cae473ff40e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4736e3ff2e0319a41d4bf2e7b6307f94", element="9fd79707-1458-4719-ba81-6d07a51d72bb")>,
# ...

# %%
stoppage=[]
for s in stop:
    stoppage.append(s.text)
stoppage
# Out:
# ['1-stop',
#  '2+-stop',
#  '1-stop',
#  '2+-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  'non-stop',
#  '1-stop',
#  'non-stop',
#  '1-stop',
#  '2+-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  'non-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '2+-stop',
#  'non-stop',
#  'non-stop',
#  '1-stop',
#  '1-stop']

# %%
price=driver.find_elements_by_xpath("//div[@class='col-md-8 col-sm-8 col-xs-9 txt-r6-n ng-binding']")
price
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="4736e3ff2e0319a41d4bf2e7b6307f94", element="7a2c7df6-9066-4a89-ae61-61bade034817")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4736e3ff2e0319a41d4bf2e7b6307f94", element="d7a7c07c-d098-473e-bd57-b09eca786c14")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4736e3ff2e0319a41d4bf2e7b6307f94", element="0b3ae460-f6f0-4645-815e-7bdae54c55b0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4736e3ff2e0319a41d4bf2e7b6307f94", element="b02acaab-a74b-4c9a-b4d7-9b4c905f690c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4736e3ff2e0319a41d4bf2e7b6307f94", element="cc7ef203-a033-437d-b3ad-c8589f788d7c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4736e3ff2e0319a41d4bf2e7b6307f94", element="5212006c-9517-4943-a635-fb51153e9edd")>,
# ...

# %%
prices=[]
for p in price:
    prices.append(p.text)
prices
# Out:
# ['5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '6,270',
#  '6,443',
#  '6,932',
#  '6,932',
#  '6,932',
#  '6,932',
#  '6,932',
#  '8,474',
#  '7,110',
#  '7,110',
#  '8,055',
#  '8,423',
#  '8,791',
#  '8,790',
#  '8,895',
#  '8,885',
#  '9,373',
#  '9,373',
#  '9,525',
#  '9,861',
#  '10,637',
#  '10,838',
#  '11,378',
#  '12,302',
#  '12,729',
#  '12,791',
#  '13,767',
#  '14,145',
#  '14,744',
#  '14,959',
#  '15,039',
#  '15,353',
#  '15,510',
#  '15,720',
#  '15,720',
#  '15,872',
#  '16,639']

# %%
len(prices)
# Out:
# 41

# %%
import pandas as pd
df18=pd.DataFrame({})
df18['Departure Time']=departure[:41]
df18['Arrival Time']=arrival[:41]
df18['Source']=source[:41]
df18['Destination']=destination[:41]
df18['Duration']=duration[:41]
df18['Stoppage']=stoppage[:41]
df18['Flight Name']=flight_name[:41]
df18['Price']=prices[:41]
df18
# Out:
#    Departure Time Arrival Time Source Destination Duration  Stoppage  \
# 0           06:05        06:05  Delhi        Pune  12h 10m    1-stop
# 1           18:15        18:15  Delhi        Pune  12h 40m   2+-stop
# 2           05:35        05:35  Delhi        Pune  12h 55m    1-stop
# 3           18:15        18:15  Delhi        Pune  13h 25m   2+-stop
# 4           06:05        06:05  Delhi        Pune  06h 25m    1-stop
# 5           19:00        19:00  Delhi        Pune  07h 40m    1-stop
# 6           05:35        05:35  Delhi        Pune  10h 15m    1-stop
# 7           19:00        19:00  Delhi        Pune  05h 45m    1-stop
# 8           08:00        08:00  Delhi        Pune  06h 00m    1-stop
# 9           14:25        14:25  Delhi        Pune  08h 50m    1-stop
# 10          05:30        05:30  Delhi        Pune  10h 00m    1-stop
# 11          13:10        13:10  Delhi        Pune  02h 15m  non-stop
# 12          23:05        23:05  Delhi        Pune  02h 05m  non-stop
# ...

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 95.0.4638
# Get LATEST driver version for 95.0.4638
# Driver [C:\Users\monish\.wdm\drivers\chromedriver\win32\95.0.4638.17\chromedriver.exe] found in cache

# %%
url ="https://www.easemytrip.com/"
driver.get(url)

# %%
search=driver.find_element_by_xpath("//div[@class='s_col_v4 ripplen']")
search.click()

# %%
dept=driver.find_elements_by_xpath("//span[@class='txt-r2-n ng-binding']")
dept
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="88e8eeeab90055f87d466f224bfc5e58", element="fc9cb018-75c7-4b4f-9b08-c5ff8e22d7d0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="88e8eeeab90055f87d466f224bfc5e58", element="70a6466b-c36c-49f6-a3ba-d475d2f7f865")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="88e8eeeab90055f87d466f224bfc5e58", element="46b52772-6a42-4273-9df8-ad6efbd36ec6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="88e8eeeab90055f87d466f224bfc5e58", element="621c7990-78e4-49d7-ba7d-3b959a85da2b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="88e8eeeab90055f87d466f224bfc5e58", element="a3d75f14-457e-46a2-b375-edd7f93b0f3b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="88e8eeeab90055f87d466f224bfc5e58", element="14a33975-a96b-49b2-9bc4-9f41a07480f6")>,
# ...

# %%
departure=[]
for d in dept:
    departure.append(d.text)
departure
# Out:
# ['16:35',
#  '00:35',
#  '22:30',
#  '08:50',
#  '12:45',
#  '00:35',
#  '21:00',
#  '08:50',
#  '22:30',
#  '10:45',
#  '19:40',
#  '08:50',
#  '21:00',
#  '10:45',
#  '18:05',
#  '08:50',
#  '19:40',
#  '10:45',
#  '06:00',
#  '07:30',
#  '06:40',
#  '08:15',
#  '05:55',
#  '07:40',
#  '07:15',
#  '12:25',
#  '06:20',
#  '12:25',
#  '05:15',
#  '06:50',
#  '13:30',
#  '15:05',
#  '21:20',
#  '07:55',
#  '11:25',
#  '13:10',
#  '15:00',
#  '20:15',
#  '12:55',
#  '18:30',
#  '13:00',
#  '20:15',
#  '21:20',
#  '07:45',
#  '06:30',
#  '08:05',
#  '22:15',
#  '23:50',
#  '19:00',
#  '07:55',
#  '19:55',
#  '21:30',
#  '08:45',
#  '10:20',
#  '20:10',
#  '21:50',
#  '20:20',
#  '22:00',
#  '15:30',
#  '17:05',
#  '18:00',
#  '21:30',
#  '18:05',
#  '00:05',
#  '02:00',
#  '08:50',
#  '02:00',
#  '10:45',
#  '15:00',
#  '00:05',
#  '10:30',
#  '00:05',
#  '15:00',
#  '20:25',
#  '10:30',
#  '20:25',
#  '08:00',
#  '20:25',
#  '07:00',
#  '20:25',
#  '14:20',
#  '00:05',
#  '15:00',
# ...

# %%
arr=driver.find_elements_by_xpath("//span[@class='txt-r2-n ng-binding']")
arr
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="88e8eeeab90055f87d466f224bfc5e58", element="fc9cb018-75c7-4b4f-9b08-c5ff8e22d7d0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="88e8eeeab90055f87d466f224bfc5e58", element="70a6466b-c36c-49f6-a3ba-d475d2f7f865")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="88e8eeeab90055f87d466f224bfc5e58", element="46b52772-6a42-4273-9df8-ad6efbd36ec6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="88e8eeeab90055f87d466f224bfc5e58", element="621c7990-78e4-49d7-ba7d-3b959a85da2b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="88e8eeeab90055f87d466f224bfc5e58", element="a3d75f14-457e-46a2-b375-edd7f93b0f3b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="88e8eeeab90055f87d466f224bfc5e58", element="14a33975-a96b-49b2-9bc4-9f41a07480f6")>,
# ...

# %%
arrival=[]
for a in arr:
    arrival.append(a.text)
arrival
# Out:
# ['16:35',
#  '00:35',
#  '22:30',
#  '08:50',
#  '12:45',
#  '00:35',
#  '21:00',
#  '08:50',
#  '22:30',
#  '10:45',
#  '19:40',
#  '08:50',
#  '21:00',
#  '10:45',
#  '18:05',
#  '08:50',
#  '19:40',
#  '10:45',
#  '06:00',
#  '07:30',
#  '06:40',
#  '08:15',
#  '05:55',
#  '07:40',
#  '07:15',
#  '12:25',
#  '06:20',
#  '12:25',
#  '05:15',
#  '06:50',
#  '13:30',
#  '15:05',
#  '21:20',
#  '07:55',
#  '11:25',
#  '13:10',
#  '15:00',
#  '20:15',
#  '12:55',
#  '18:30',
#  '13:00',
#  '20:15',
#  '21:20',
#  '07:45',
#  '06:30',
#  '08:05',
#  '22:15',
#  '23:50',
#  '19:00',
#  '07:55',
#  '19:55',
#  '21:30',
#  '08:45',
#  '10:20',
#  '20:10',
#  '21:50',
#  '20:20',
#  '22:00',
#  '15:30',
#  '17:05',
#  '18:00',
#  '21:30',
#  '18:05',
#  '00:05',
#  '02:00',
#  '08:50',
#  '02:00',
#  '10:45',
#  '15:00',
#  '00:05',
#  '10:30',
#  '00:05',
#  '15:00',
#  '20:25',
#  '10:30',
#  '20:25',
#  '08:00',
#  '20:25',
#  '07:00',
#  '20:25',
#  '14:20',
#  '00:05',
#  '15:00',
# ...

# %%
source1=driver.find_elements_by_xpath("//span[@class='txt-r3-n ng-binding']")
source1
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="88e8eeeab90055f87d466f224bfc5e58", element="5c9831c5-50ee-4b42-9227-1f851a74c653")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="88e8eeeab90055f87d466f224bfc5e58", element="29171e20-d4e2-4986-b655-377f0f45e514")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="88e8eeeab90055f87d466f224bfc5e58", element="c088434d-d712-4321-9083-ff1737f18421")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="88e8eeeab90055f87d466f224bfc5e58", element="6068355c-2df8-4d91-ab30-bdf1c465c519")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="88e8eeeab90055f87d466f224bfc5e58", element="4b98973d-f6b9-4e42-ac59-d9a79fd43ae1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="88e8eeeab90055f87d466f224bfc5e58", element="2720d5b9-6008-4114-88ed-b0d9c5db68bd")>,
# ...

# %%
source_=[]
for s in source1:
    source_.append(s.text)
source_
# Out:
# ['Delhi',
#  'Ahmedabad',
#  'Delhi',
#  'Ahmedabad',
#  'Delhi',
#  'Ahmedabad',
#  'Delhi',
#  'Ahmedabad',
#  'Delhi',
#  'Ahmedabad',
#  'Delhi',
#  'Ahmedabad',
#  'Delhi',
#  'Ahmedabad',
#  'Delhi',
#  'Ahmedabad',
#  'Delhi',
#  'Ahmedabad',
#  'Delhi',
#  'Ahmedabad',
#  'Delhi',
#  'Ahmedabad',
#  'Delhi',
#  'Ahmedabad',
#  'Delhi',
#  'Ahmedabad',
#  'Delhi',
#  'Ahmedabad',
#  'Delhi',
#  'Ahmedabad',
#  'Delhi',
#  'Ahmedabad',
#  'Delhi',
#  'Ahmedabad',
#  'Delhi',
#  'Ahmedabad',
#  'Delhi',
#  'Ahmedabad',
#  'Delhi',
#  'Ahmedabad',
#  'Delhi',
#  'Ahmedabad',
#  'Delhi',
#  'Ahmedabad',
#  'Delhi',
#  'Ahmedabad',
#  'Delhi',
#  'Ahmedabad',
#  'Delhi',
#  'Ahmedabad',
#  'Delhi',
#  'Ahmedabad',
#  'Delhi',
#  'Ahmedabad',
#  'Delhi',
#  'Ahmedabad',
#  'Delhi',
#  'Ahmedabad',
#  'Delhi',
#  'Ahmedabad',
#  'Delhi',
#  'Ahmedabad',
#  'Delhi',
#  'Ahmedabad',
#  'Delhi',
#  'Ahmedabad',
#  'Delhi',
#  'Ahmedabad',
#  'Delhi',
#  'Ahmedabad',
#  'Delhi',
# ...

# %%
source=[]
for s in range(0,len(source_),2):
    source.append(source_[s])
source
# Out:
# ['Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi']

# %%
destination=[]
for d in range(1,len(source_),2):
    destination.append(source_[d])
destination
# Out:
# ['Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
#  'Ahmedabad',
# ...

# %%
durr=driver.find_elements_by_xpath("//span[@class='dura_md ng-binding']")
durr
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="88e8eeeab90055f87d466f224bfc5e58", element="1d564102-c1a9-4960-9f63-f971fcdbeb01")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="88e8eeeab90055f87d466f224bfc5e58", element="86c76ece-002b-4927-88da-f53f15b1a681")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="88e8eeeab90055f87d466f224bfc5e58", element="15226369-753f-4ff2-9135-d8dde242090c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="88e8eeeab90055f87d466f224bfc5e58", element="cfc61bb8-79cc-45de-b31d-0c7b28595d52")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="88e8eeeab90055f87d466f224bfc5e58", element="70ce34f6-b404-4ef4-a5b9-0b772c61195e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="88e8eeeab90055f87d466f224bfc5e58", element="ed43bfc3-f959-4475-a5ba-6f6a245a7656")>,
# ...

# %%
duration=[]
for d in durr:
    duration.append(d.text)
duration
# Out:
# ['08h 00m',
#  '10h 20m',
#  '11h 50m',
#  '11h 50m',
#  '12h 15m',
#  '13h 10m',
#  '13h 45m',
#  '14h 45m',
#  '15h 05m',
#  '01h 30m',
#  '01h 35m',
#  '01h 45m',
#  '05h 10m',
#  '06h 05m',
#  '01h 35m',
#  '01h 35m',
#  '10h 35m',
#  '01h 45m',
#  '05h 15m',
#  '05h 35m',
#  '07h 15m',
#  '10h 25m',
#  '01h 35m',
#  '01h 35m',
#  '12h 55m',
#  '01h 35m',
#  '01h 35m',
#  '01h 40m',
#  '01h 40m',
#  '01h 35m',
#  '03h 30m',
#  '06h 00m',
#  '06h 50m',
#  '08h 45m',
#  '09h 05m',
#  '13h 35m',
#  '05h 25m',
#  '09h 55m',
#  '12h 25m',
#  '13h 25m',
#  '09h 45m',
#  '06h 55m',
#  '06h 05m',
#  '01h 25m',
#  '14h 50m',
#  '01h 40m',
#  '07h 10m',
#  '10h 50m',
#  '09h 50m',
#  '44h 40m',
#  '02h 15m',
#  '07h 00m',
#  '08h 20m',
#  '10h 00m',
#  '05h 55m',
#  '08h 05m',
#  '18h 10m',
#  '05h 55m',
#  '11h 45m',
#  '10h 45m',
#  '12h 35m',
#  '14h 00m',
#  '07h 35m',
#  '13h 40m']

# %%
flight=driver.find_elements_by_xpath("//span[@class='txt-r4 ng-binding']")
flight
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="88e8eeeab90055f87d466f224bfc5e58", element="4d5b4aee-fa1a-4aa6-89df-a42d8dad426b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="88e8eeeab90055f87d466f224bfc5e58", element="80468538-e4bd-4cd5-8fe4-8b771f646ca9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="88e8eeeab90055f87d466f224bfc5e58", element="ddee4074-9066-49c5-b2b0-51c95275212f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="88e8eeeab90055f87d466f224bfc5e58", element="417897d8-85b7-4862-a261-19d8c991de08")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="88e8eeeab90055f87d466f224bfc5e58", element="abb61e86-0eaf-4308-8f0e-616b561a5ed3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="88e8eeeab90055f87d466f224bfc5e58", element="d1432d64-0db0-4a3e-8f46-9c3dc5159556")>,
# ...

# %%
flight_name=[]
for f in flight:
    flight_name.append(f.text)
flight_name
# Out:
# ['GO FIRST',
#  'GO FIRST',
#  'GO FIRST',
#  'GO FIRST',
#  'GO FIRST',
#  'GO FIRST',
#  'GO FIRST',
#  'GO FIRST',
#  'GO FIRST',
#  'GO FIRST',
#  'Indigo',
#  'SpiceJet',
#  'Indigo',
#  'Indigo',
#  'Indigo',
#  'Indigo',
#  'Indigo',
#  'Indigo',
#  'Indigo',
#  'Indigo',
#  'Indigo',
#  'Indigo',
#  'Vistara',
#  'Indigo',
#  'SpiceJet',
#  'GO FIRST',
#  'Vistara',
#  'SpiceJet',
#  'Indigo',
#  'GO FIRST',
#  'Indigo',
#  'GO FIRST',
#  'GO FIRST',
#  'GO FIRST',
#  'GO FIRST',
#  'GO FIRST',
#  'GO FIRST',
#  'GO FIRST',
#  'GO FIRST',
#  'GO FIRST',
#  'GO FIRST',
#  'SpiceJet',
#  'GO FIRST',
#  'Indigo',
#  'GO FIRST',
#  'Vistara',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Indigo',
#  'Indigo',
#  'Indigo',
#  'Indigo',
#  'Indigo',
#  'SpiceJet',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'GO FIRST',
#  'Air India',
#  'GO FIRST']

# %%
stop=driver.find_elements_by_xpath("//span[@class='dura_md2 ng-scope']")
stop
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="88e8eeeab90055f87d466f224bfc5e58", element="bc7cb8c8-c024-47c6-a0f4-0f7b611c9de4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="88e8eeeab90055f87d466f224bfc5e58", element="cd233a15-a25d-4738-b1d4-62cd3ca80dea")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="88e8eeeab90055f87d466f224bfc5e58", element="b7641da6-c5df-4f06-af4d-34943d1c077d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="88e8eeeab90055f87d466f224bfc5e58", element="c999dfb6-418d-4517-bd20-a64136ef6c62")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="88e8eeeab90055f87d466f224bfc5e58", element="39127c00-0aba-4d10-815f-aa41d166a87e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="88e8eeeab90055f87d466f224bfc5e58", element="f9707ce5-7065-4be2-a10f-8971bdf021b2")>,
# ...

# %%
stoppage=[]
for s in stop:
    stoppage.append(s.text)
stoppage
# Out:
# ['1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  '1-stop',
#  '1-stop',
#  'non-stop',
#  'non-stop',
#  '1-stop',
#  'non-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  'non-stop',
#  'non-stop',
#  '1-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  'non-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  'non-stop',
#  '1-stop',
#  'non-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '2+-stop',
#  'non-stop',
#  '1-stop',
#  '1-stop',
#  '1-stop',
#  '2+-stop',
#  '2+-stop',
#  '1-stop',
#  '2+-stop',
#  '2+-stop',
#  '2+-stop',
#  '1-stop',
#  '1-stop',
#  '2+-stop',
#  '1-stop']

# %%
price=driver.find_elements_by_xpath("//div[@class='col-md-8 col-sm-8 col-xs-9 txt-r6-n ng-binding']")
price
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="88e8eeeab90055f87d466f224bfc5e58", element="e563f244-dbdf-40b0-9682-18fe4ce1647a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="88e8eeeab90055f87d466f224bfc5e58", element="c7ee3cca-123f-4160-9823-124dda5d6a36")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="88e8eeeab90055f87d466f224bfc5e58", element="3176e902-43b0-4295-a9e1-9c705b879e0b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="88e8eeeab90055f87d466f224bfc5e58", element="603a7dae-b2d5-4f80-8643-8f4d1881e530")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="88e8eeeab90055f87d466f224bfc5e58", element="ec78627e-f1f6-4a31-b31e-f6b36215d52e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="88e8eeeab90055f87d466f224bfc5e58", element="91876cab-ce1a-42a1-832f-6cefa691a48a")>,
# ...

# %%
prices=[]
for p in price:
    prices.append(p.text)
prices
# Out:
# ['5,114',
#  '5,114',
#  '5,114',
#  '5,114',
#  '5,114',
#  '5,114',
#  '5,114',
#  '5,114',
#  '5,114',
#  '5,692',
#  '5,955',
#  '6,164',
#  '6,380',
#  '6,380',
#  '6,480',
#  '6,480',
#  '6,485',
#  '6,795',
#  '7,399',
#  '7,399',
#  '7,399',
#  '7,399',
#  '7,583',
#  '7,635',
#  '7,923',
#  '8,264',
#  '8,318',
#  '8,370',
#  '8,895',
#  '9,104',
#  '9,226',
#  '10,018',
#  '10,018',
#  '10,018',
#  '10,018',
#  '10,018',
#  '10,386',
#  '10,386',
#  '10,386',
#  '10,386',
#  '10,596',
#  '10,784',
#  '10,964',
#  '11,310',
#  '12,885',
#  '11,888',
#  '12,360',
#  '12,360',
#  '12,780',
#  '14,194',
#  '14,250',
#  '14,250',
#  '14,250',
#  '14,250',
#  '14,303',
#  '14,303',
#  '15,563',
#  '17,820',
#  '17,820',
#  '17,834',
#  '19,763',
#  '20,131',
#  '20,259',
#  '21,601']

# %%
import pandas as pd
df19=pd.DataFrame({})
df19['Departure Time']=departure[:64]
df19['Arrival Time']=arrival[:64]
df19['Source']=source[:64]
df19['Destination']=destination[:64]
df19['Duration']=duration[:64]
df19['Stoppage']=stoppage[:64]
df19['Flight Name']=flight_name[:64]
df19['Price']=prices[:64]
df19
# Out:
#    Departure Time Arrival Time Source Destination Duration Stoppage  \
# 0           16:35        16:35  Delhi   Ahmedabad  08h 00m   1-stop
# 1           00:35        00:35  Delhi   Ahmedabad  10h 20m   1-stop
# 2           22:30        22:30  Delhi   Ahmedabad  11h 50m   1-stop
# 3           08:50        08:50  Delhi   Ahmedabad  11h 50m   1-stop
# 4           12:45        12:45  Delhi   Ahmedabad  12h 15m   1-stop
# ..            ...          ...    ...         ...      ...      ...
# 59          17:05        17:05  Delhi   Ahmedabad  10h 45m  2+-stop
# 60          18:00        18:00  Delhi   Ahmedabad  12h 35m   1-stop
# 61          21:30        21:30  Delhi   Ahmedabad  14h 00m   1-stop
# 62          18:05        18:05  Delhi   Ahmedabad  07h 35m  2+-stop
# 63          00:05        00:05  Delhi   Ahmedabad  13h 40m   1-stop
#
#    Flight Name   Price
# 0     GO FIRST   5,114
# 1     GO FIRST   5,114
# 2     GO FIRST   5,114
# 3     GO FIRST   5,114
# 4     GO FIRST   5,114
# ...

# %%
Data=df1.append([flight_detail,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18,df19])
Data
# Out:
#    Departure Time Arrival Time     Source Destination Duration Stoppage  \
# 0           16:05        20:40  New Delhi   Bangalore   4h 35m   1 Stop
# 1           09:25        14:40  New Delhi   Bangalore   5h 15m   1 Stop
# 2           15:25        20:40  New Delhi   Bangalore   5h 15m   1 Stop
# 3           15:40        21:30  New Delhi   Bangalore   5h 50m   1 Stop
# 4           05:00        11:35  New Delhi   Bangalore   6h 35m   1 Stop
# ..            ...          ...        ...         ...      ...      ...
# 59          17:05        17:05      Delhi   Ahmedabad  10h 45m  2+-stop
# 60          18:00        18:00      Delhi   Ahmedabad  12h 35m   1-stop
# 61          21:30        21:30      Delhi   Ahmedabad  14h 00m   1-stop
# 62          18:05        18:05      Delhi   Ahmedabad  07h 35m  2+-stop
# 63          00:05        00:05      Delhi   Ahmedabad  13h 40m   1-stop
#
#    Flight Name   Price
# 0     Air Asia   7,423
# 1     Air Asia   7,423
# 2     Air Asia   7,423
# ...

# %%
import joblib
joblib.dump(Data,"flight_price_prediction.xlsx")
# Out:
# ['flight_price_prediction.xlsx']
