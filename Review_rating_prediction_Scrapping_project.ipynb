# %%
# Importing Libraries
import selenium
import pandas as pd
import time
from bs4 import BeautifulSoup

# Importing selenium webdriver 
from selenium import webdriver

# Importing required Exceptions which needs to handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

#Importing requests
import requests

# importing regex
import re

# %%
# !pip install webdriver-manager

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 95.0.4638
# Get LATEST driver version for 95.0.4638
# Driver [C:\Users\monish\.wdm\drivers\chromedriver\win32\95.0.4638.69\chromedriver.exe] found in cache

# %%
url = "https://www.amazon.in/"
driver.get(url)

time.sleep(2)
# Asking the user to input the keywords he/she wants to search
user_inp = input('Enter the product you want to search : ')
# Out:
# Enter the product you want to search : laptop

# %%
search_bar = driver.find_element_by_id("twotabsearchtextbox")    # Locating searc_bar by id
search_bar.clear()                                               # clearing search_bar
search_bar.send_keys(user_inp)                                   # sending user input to search bar
search_button = driver.find_element_by_xpath('//div[@class="nav-search-submit nav-sprite"]/span/input')       # Locating search_button by xpath
search_button.click()

# %%
# scrape all product urls
product_urls = []
start=0
end=20
for page in range(start,end):#for loop for scrapping 3 page
    url=driver.find_elements_by_xpath('//a[@class="a-link-normal a-text-normal"]')       #scraping urls
    for i in url:
        product_urls.append(i.get_attribute("href"))                        #appending the urls in product_urls list
    nxt_button=driver.find_element_by_xpath("//li[@class='a-normal'][1]/a")     #scraping the list of buttons from the page
    nxt_button.click()
    time.sleep(2)

Rating = []
Review=[]

for url in product_urls:
    driver.get(url)
    time.sleep(2)
    
    try:
        rating = driver.find_element_by_xpath('//span[@class="a-size-base a-nowrap"]//span')  
        Rating.append(rating.text)
    except NoSuchElementException:
        Rating.append('-')


    time.sleep(1)
    
    try:
        review=driver.find_element_by_xpath('//div[@class="a-expander-content reviewText review-text-content a-expander-partial-collapse-content"]')
        Review.append(review.text)
    except NoSuchElementException:
        Review.append('-')

# %%
df = pd.DataFrame({'Rating':Rating,'Reviews':Review})
df
# Out:
#            Rating                                            Reviews
# 0    4.5 out of 5  It heats a lot for basic tasks , i5 i a piece ...
# 1      4 out of 5  Very impressed with the laptop. Looks extremel...
# 2    3.6 out of 5  BAD PACKAGING/ SCRATCHES ON THE SCREEN/ LOOKS ...
# 3    3.9 out of 5  Bought this laptop for online classes for my d...
# 4    3.5 out of 5  Very nice laptop and many functions and easy t...
# ..            ...                                                ...
# 485             -                                                  -
# 486    4 out of 5                                                  -
# 487  4.4 out of 5  1. Great performance on heavy audio editing so...
# 488             -                                                  -
# 489  3.9 out of 5  This review is based on my purchase of Microso...
#
# [490 rows x 2 columns]

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 95.0.4638
# Get LATEST driver version for 95.0.4638
# Driver [C:\Users\monish\.wdm\drivers\chromedriver\win32\95.0.4638.69\chromedriver.exe] found in cache

# %%
url = "https://www.amazon.in/"
driver.get(url)

time.sleep(2)
# Asking the user to input the keywords he/she wants to search
user_inp = input('Enter the product you want to search : ')
# Out:
# Enter the product you want to search : smartphone

# %%
search_bar = driver.find_element_by_id("twotabsearchtextbox")    # Locating searc_bar by id
search_bar.clear()                                               # clearing search_bar
search_bar.send_keys(user_inp)                                   # sending user input to search bar
search_button = driver.find_element_by_xpath('//div[@class="nav-search-submit nav-sprite"]/span/input')       # Locating search_button by xpath
search_button.click()

# %%
# scrape all product urls
product_urls = []
start=0
end=20
for page in range(start,end):#for loop for scrapping 3 page
    url=driver.find_elements_by_xpath('//a[@class="a-link-normal a-text-normal"]')       #scraping urls
    for i in url:
        product_urls.append(i.get_attribute("href"))                        #appending the urls in product_urls list
    nxt_button=driver.find_element_by_xpath("//li[@class='a-normal'][1]/a")     #scraping the list of buttons from the page
    nxt_button.click()
    time.sleep(2)

Rating = []
Review=[]

for url in product_urls:
    driver.get(url)
    time.sleep(2)
    
    try:
        rating = driver.find_element_by_xpath('//span[@class="a-size-base a-nowrap"]//span')  
        Rating.append(rating.text)
    except NoSuchElementException:
        Rating.append('-')


    time.sleep(1)
    
    try:
        review=driver.find_element_by_xpath('//div[@class="a-expander-content reviewText review-text-content a-expander-partial-collapse-content"]')
        Review.append(review.text)
    except NoSuchElementException:
        Review.append('-')

# %%
df1 = pd.DataFrame({'Rating':Rating,'Reviews':Review})
df1
# Out:
#            Rating                                            Reviews
# 0    4.1 out of 5  Very disappointed with the overall performance...
# 1    4.2 out of 5  Brilliant camera, huge battery life and brilli...
# 2    4.2 out of 5  In my first review given within 24 hrs l found...
# 3    4.1 out of 5     Received damaged product. really disappointed.
# 4      4 out of 5                               Front camara worrest
# ..            ...                                                ...
# 465  4.2 out of 5  Don’t buy this product .\nImage quality is bel...
# 466  4.3 out of 5  Camera not upto the mark, fast charging, sound...
# 467  4.1 out of 5     Received damaged product. really disappointed.
# 468  4.2 out of 5  Brilliant camera, huge battery life and brilli...
# 469  4.1 out of 5  Everything ok but they make fool and cheated t...
#
# [470 rows x 2 columns]

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 95.0.4638
# Get LATEST driver version for 95.0.4638
# Driver [C:\Users\monish\.wdm\drivers\chromedriver\win32\95.0.4638.69\chromedriver.exe] found in cache

# %%
url = "https://www.amazon.in/"
driver.get(url)

time.sleep(2)
# Asking the user to input the keywords he/she wants to search
user_inp = input('Enter the product you want to search : ')
# Out:
# Enter the product you want to search : camera

# %%
search_bar = driver.find_element_by_id("twotabsearchtextbox")    # Locating searc_bar by id
search_bar.clear()                                               # clearing search_bar
search_bar.send_keys(user_inp)                                   # sending user input to search bar
search_button = driver.find_element_by_xpath('//div[@class="nav-search-submit nav-sprite"]/span/input')       # Locating search_button by xpath
search_button.click()

# %%
# scrape all product urls
product_urls = []
start=0
end=20
for page in range(start,end):#for loop for scrapping 3 page
    url=driver.find_elements_by_xpath('//a[@class="a-link-normal a-text-normal"]')       #scraping urls
    for i in url:
        product_urls.append(i.get_attribute("href"))                        #appending the urls in product_urls list
    nxt_button=driver.find_element_by_xpath("//li[@class='a-normal'][1]/a")     #scraping the list of buttons from the page
    nxt_button.click()
    time.sleep(2)

Rating = []
Review=[]

for url in product_urls:
    driver.get(url)
    time.sleep(2)
    
    try:
        rating = driver.find_element_by_xpath('//span[@class="a-size-base a-nowrap"]//span')  
        Rating.append(rating.text)
    except NoSuchElementException:
        Rating.append('-')


    time.sleep(1)
    
    try:
        review=driver.find_element_by_xpath('//div[@class="a-expander-content reviewText review-text-content a-expander-partial-collapse-content"]')
        Review.append(review.text)
    except NoSuchElementException:
        Review.append('-')

# %%
df2 = pd.DataFrame({'Rating':Rating,'Reviews':Review})
df2
# Out:
#            Rating                                            Reviews
# 0    3.6 out of 5  Play Video\n This camera is superb. Its got gr...
# 1               -                                                  -
# 2    4.4 out of 5  Ok the DSLR Giant Canon have launched 1 more e...
# 3    3.8 out of 5  This is good for click photos any time and pho...
# 4    4.3 out of 5  It consumes around 10gb of storage in 24hours ...
# ..            ...                                                ...
# 488    4 out of 5  Most of the reviews have already mentioned the...
# 489             -                                                  -
# 490             -                                                  -
# 491             -                                                  -
# 492  4.2 out of 5  The texture is like butter. Application is so ...
#
# [493 rows x 2 columns]

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 95.0.4638
# Get LATEST driver version for 95.0.4638
# Driver [C:\Users\monish\.wdm\drivers\chromedriver\win32\95.0.4638.69\chromedriver.exe] found in cache

# %%
url = "https://www.amazon.in/"
driver.get(url)

time.sleep(2)
# Asking the user to input the keywords he/she wants to search
user_inp = input('Enter the product you want to search : ')
# Out:
# Enter the product you want to search : Router

# %%
search_bar = driver.find_element_by_id("twotabsearchtextbox")    # Locating searc_bar by id
search_bar.clear()                                               # clearing search_bar
search_bar.send_keys(user_inp)                                   # sending user input to search bar
search_button = driver.find_element_by_xpath('//div[@class="nav-search-submit nav-sprite"]/span/input')       # Locating search_button by xpath
search_button.click()

# %%
# scrape all product urls
product_urls = []
start=0
end=20
for page in range(start,end):#for loop for scrapping 3 page
    url=driver.find_elements_by_xpath('//a[@class="a-link-normal a-text-normal"]')       #scraping urls
    for i in url:
        product_urls.append(i.get_attribute("href"))                        #appending the urls in product_urls list
    nxt_button=driver.find_element_by_xpath("//li[@class='a-normal'][1]/a")     #scraping the list of buttons from the page
    nxt_button.click()
    time.sleep(2)

Rating = []
Review=[]

for url in product_urls:
    driver.get(url)
    time.sleep(2)
    
    try:
        rating = driver.find_element_by_xpath('//span[@class="a-size-base a-nowrap"]//span')  
        Rating.append(rating.text)
    except NoSuchElementException:
        Rating.append('-')


    time.sleep(1)

    
    try:
        review=driver.find_element_by_xpath('//div[@class="a-expander-content reviewText review-text-content a-expander-partial-collapse-content"]')
        Review.append(review.text)
    except NoSuchElementException:
        Review.append('-')

# %%
df3 = pd.DataFrame({'Rating':Rating,'Reviews':Review})
df3
# Out:
#            Rating                                            Reviews
# 0    3.7 out of 5  Router is looking good and working fine.\nLot ...
# 1    4.2 out of 5  Router stop working from 10.04.2019, sent to R...
# 2    4.4 out of 5  Checked my 100mbps speed getting 100mbps downl...
# 3    4.2 out of 5  Package was half sealed by Amazon and on the t...
# 4      4 out of 5  The router description saying it can support u...
# ..            ...                                                ...
# 485  4.1 out of 5  Bought this product with an assumption that it...
# 486  3.8 out of 5  Sim card showing but no internet showing .and ...
# 487  4.2 out of 5  Asus RT-AX55 is a very cheap and capable Wi-Fi...
# 488    4 out of 5  gigabit ac1900 at the price of a ac1200 if you...
# 489  3.9 out of 5  Bought it to improve Wi-F coverage but disappo...
#
# [490 rows x 2 columns]

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 95.0.4638
# Get LATEST driver version for 95.0.4638
# Driver [C:\Users\monish\.wdm\drivers\chromedriver\win32\95.0.4638.69\chromedriver.exe] found in cache

# %%
url = "https://www.amazon.in/"
driver.get(url)

time.sleep(2)
# Asking the user to input the keywords he/she wants to search
user_inp = input('Enter the product you want to search : ')
# Out:
# Enter the product you want to search : Monitor

# %%
search_bar = driver.find_element_by_id("twotabsearchtextbox")    # Locating searc_bar by id
search_bar.clear()                                               # clearing search_bar
search_bar.send_keys(user_inp)                                   # sending user input to search bar
search_button = driver.find_element_by_xpath('//div[@class="nav-search-submit nav-sprite"]/span/input')       # Locating search_button by xpath
search_button.click()

# %%
# scrape all product urls
product_urls = []
start=0
end=20
for page in range(start,end):#for loop for scrapping 3 page
    url=driver.find_elements_by_xpath('//a[@class="a-link-normal a-text-normal"]')       #scraping urls
    for i in url:
        product_urls.append(i.get_attribute("href"))                        #appending the urls in product_urls list
    nxt_button=driver.find_element_by_xpath("//li[@class='a-normal'][1]/a")     #scraping the list of buttons from the page
    nxt_button.click()
    time.sleep(2)

Rating = []
Review=[]

for url in product_urls:
    driver.get(url)
    time.sleep(2)
    
    try:
        rating = driver.find_element_by_xpath('//span[@class="a-size-base a-nowrap"]//span')  
        Rating.append(rating.text)
    except NoSuchElementException:
        Rating.append('-')


    time.sleep(1)
    
    try:
        review=driver.find_element_by_xpath('//div[@class="a-expander-content reviewText review-text-content a-expander-partial-collapse-content"]')
        Review.append(review.text)
    except NoSuchElementException:
        Review.append('-')

# %%
df4 = pd.DataFrame({'Rating':Rating,'Reviews':Review})
df4
# Out:
#            Rating                                            Reviews
# 0    3.8 out of 5  Product discription is missleading. Its not a ...
# 1      4 out of 5  What a great gaming monitor. The refresh rate ...
# 2    4.3 out of 5  It has backlight bleeding issue and 2 corners ...
# 3    4.4 out of 5  I bought this product because I edit videos fo...
# 4    4.4 out of 5  Being a gamer...i needed a monitor and this ca...
# ..            ...                                                ...
# 625  4.2 out of 5  # Resolution is not suitable considering the s...
# 626  4.5 out of 5  It’s very good looks wise & also buttons are r...
# 627  3.8 out of 5  For those who are confused about the fragrance...
# 628  4.6 out of 5  I received defective product double click issu...
# 629    4 out of 5  Actually the main reasons to choose amoung man...
#
# [630 rows x 2 columns]

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 95.0.4638
# Get LATEST driver version for 95.0.4638
# Driver [C:\Users\monish\.wdm\drivers\chromedriver\win32\95.0.4638.69\chromedriver.exe] found in cache

# %%
url = "https://www.amazon.in/"
driver.get(url)

time.sleep(2)
# Asking the user to input the keywords he/she wants to search
user_inp = input('Enter the product you want to search : ')
# Out:
# Enter the product you want to search : printer

# %%
search_bar = driver.find_element_by_id("twotabsearchtextbox")    # Locating searc_bar by id
search_bar.clear()                                               # clearing search_bar
search_bar.send_keys(user_inp)                                   # sending user input to search bar
search_button = driver.find_element_by_xpath('//div[@class="nav-search-submit nav-sprite"]/span/input')       # Locating search_button by xpath
search_button.click()

# %%
# scrape all product urls
product_urls = []
start=0
end=20
for page in range(start,end):#for loop for scrapping 3 page
    url=driver.find_elements_by_xpath('//a[@class="a-link-normal a-text-normal"]')       #scraping urls
    for i in url:
        product_urls.append(i.get_attribute("href"))                        #appending the urls in product_urls list
    nxt_button=driver.find_element_by_xpath("//li[@class='a-normal'][1]/a")     #scraping the list of buttons from the page
    nxt_button.click()
    time.sleep(2)

Rating = []
Review=[]

for url in product_urls:
    driver.get(url)
    time.sleep(2)
    
    try:
        rating = driver.find_element_by_xpath('//span[@class="a-size-base a-nowrap"]//span')  
        Rating.append(rating.text)
    except NoSuchElementException:
        Rating.append('-')


    time.sleep(1)
    
    try:
        review=driver.find_element_by_xpath('//div[@class="a-expander-content reviewText review-text-content a-expander-partial-collapse-content"]')
        Review.append(review.text)
    except NoSuchElementException:
        Review.append('-')

# %%
df5 = pd.DataFrame({'Rating':Rating,'Reviews':Review})
df5
# Out:
#            Rating                                            Reviews
# 0               -                                                  -
# 1    4.2 out of 5  The machine has more RAM than comparable model...
# 2    3.4 out of 5  its only print 3 to 4 page properly then start...
# 3    3.6 out of 5  I was looking for scanner and printer for home...
# 4    3.7 out of 5  A little about this printer:\n1) Build quality...
# ..            ...                                                ...
# 565  3.3 out of 5  Bought for Rs.2099.00. Print quality is good. ...
# 566    4 out of 5  Play Video\n Print quality is pathetic colours...
# 567  3.8 out of 5  This product was rcvd a month back but due to ...
# 568             -                                                  -
# 569  4.4 out of 5  This products is not fit for purpose. Each car...
#
# [570 rows x 2 columns]

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 95.0.4638
# Get LATEST driver version for 95.0.4638
# Driver [C:\Users\monish\.wdm\drivers\chromedriver\win32\95.0.4638.69\chromedriver.exe] found in cache

# %%
url = "https://www.amazon.in/"
driver.get(url)

time.sleep(2)
# Asking the user to input the keywords he/she wants to search
user_inp = input('Enter the product you want to search : ')
# Out:
# Enter the product you want to search : headphone

# %%
search_bar = driver.find_element_by_id("twotabsearchtextbox")    # Locating searc_bar by id
search_bar.clear()                                               # clearing search_bar
search_bar.send_keys(user_inp)                                   # sending user input to search bar
search_button = driver.find_element_by_xpath('//div[@class="nav-search-submit nav-sprite"]/span/input')       # Locating search_button by xpath
search_button.click()

# %%
# scrape all product urls
product_urls = []
start=0
end=20
for page in range(start,end):#for loop for scrapping 3 page
    url=driver.find_elements_by_xpath('//a[@class="a-link-normal a-text-normal"]')       #scraping urls
    for i in url:
        product_urls.append(i.get_attribute("href"))                        #appending the urls in product_urls list
    nxt_button=driver.find_element_by_xpath("//li[@class='a-normal'][1]/a")     #scraping the list of buttons from the page
    nxt_button.click()
    time.sleep(2)

Rating = []
Review=[]

for url in product_urls:
    driver.get(url)
    time.sleep(2)
    
    try:
        rating = driver.find_element_by_xpath('//span[@class="a-size-base a-nowrap"]//span')  
        Rating.append(rating.text)
    except NoSuchElementException:
        Rating.append('-')


    time.sleep(1)
    
    try:
        review=driver.find_element_by_xpath('//div[@class="a-expander-content reviewText review-text-content a-expander-partial-collapse-content"]')
        Review.append(review.text)
    except NoSuchElementException:
        Review.append('-')

# %%
df6 = pd.DataFrame({'Rating':Rating,'Reviews':Review})
df6
# Out:
#            Rating                                            Reviews
# 0    3.6 out of 5  I was searching a earphone got many but not ha...
# 1    4.2 out of 5            Great sound quality and looks good too.
# 2    4.2 out of 5  This is my honest review after using it for 20...
# 3    4.1 out of 5  It has great sound quality and bass but after ...
# 4      4 out of 5  Guys, guys do not buy this product its a scam ...
# ..            ...                                                ...
# 495  4.1 out of 5  It has great sound quality and bass but after ...
# 496  3.9 out of 5  Play Video\n Lots of request floating in @ Wha...
# 497  4.2 out of 5  First, I was mainly purchasing these headphone...
# 498  3.8 out of 5  They are really a beast . Vocals are crisp eve...
# 499    4 out of 5  Play Video\n In this headset if you are trying...
#
# [500 rows x 2 columns]

# %%
frames=[df1,df3,df4,df6]
Data=pd.concat(frames)
Data.reset_index(drop=True, inplace=True)

# %%
Data
# Out:
#             Rating                                            Reviews
# 0     4.1 out of 5  Very disappointed with the overall performance...
# 1     4.2 out of 5  Brilliant camera, huge battery life and brilli...
# 2     4.2 out of 5  In my first review given within 24 hrs l found...
# 3     4.1 out of 5     Received damaged product. really disappointed.
# 4       4 out of 5                               Front camara worrest
# ...            ...                                                ...
# 2085  4.1 out of 5  It has great sound quality and bass but after ...
# 2086  3.9 out of 5  Play Video\n Lots of request floating in @ Wha...
# 2087  4.2 out of 5  First, I was mainly purchasing these headphone...
# 2088  3.8 out of 5  They are really a beast . Vocals are crisp eve...
# 2089    4 out of 5  Play Video\n In this headset if you are trying...
#
# [2090 rows x 2 columns]

# %%
import joblib
joblib.dump(Data,"Rating_Review_prediction.xlsx")
# Out:
# ['Rating_Review_prediction.xlsx']

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# INFO:WDM:
#
# ====== WebDriver manager ======
# INFO:WDM:====== WebDriver manager ======
# Current google-chrome version is 95.0.4638
# INFO:WDM:Current google-chrome version is 95.0.4638
# Get LATEST driver version for 95.0.4638
# INFO:WDM:Get LATEST driver version for 95.0.4638
# Driver [C:\Users\monish\.wdm\drivers\chromedriver\win32\95.0.4638.69\chromedriver.exe] found in cache
# INFO:WDM:Driver [C:\Users\monish\.wdm\drivers\chromedriver\win32\95.0.4638.69\chromedriver.exe] found in cache

# %%
url = "https://www.amazon.in/"
driver.get(url)

time.sleep(2)
# Asking the user to input the keywords he/she wants to search
user_inp = input('Enter the product you want to search : ')
# Out:
# Enter the product you want to search : charger

# %%
search_bar = driver.find_element_by_id("twotabsearchtextbox")    # Locating searc_bar by id
search_bar.clear()                                               # clearing search_bar
search_bar.send_keys(user_inp)                                   # sending user input to search bar
search_button = driver.find_element_by_xpath('//div[@class="nav-search-submit nav-sprite"]/span/input')       # Locating search_button by xpath
search_button.click()

# %%
# scrape all product urls
product_urls = []
start=0
end=20
for page in range(start,end):#for loop for scrapping 3 page
    url=driver.find_elements_by_xpath('//a[@class="a-link-normal a-text-normal"]')       #scraping urls
    for i in url:
        product_urls.append(i.get_attribute("href"))                        #appending the urls in product_urls list
    nxt_button=driver.find_element_by_xpath("//li[@class='a-normal'][1]/a")     #scraping the list of buttons from the page
    nxt_button.click()
    time.sleep(2)

Rating = []
Review=[]

for url in product_urls:
    driver.get(url)
    time.sleep(2)
    
    try:
        rating = driver.find_element_by_xpath('//span[@class="a-size-base a-nowrap"]//span')  
        Rating.append(rating.text)
    except NoSuchElementException:
        Rating.append('-')


    time.sleep(1)
    
    try:
        review=driver.find_element_by_xpath('//div[@class="a-expander-content reviewText review-text-content a-expander-partial-collapse-content"]')
        Review.append(review.text)
    except NoSuchElementException:
        Review.append('-')

# %%
df7 = pd.DataFrame({'Rating':Rating,'Reviews':Review})
df7
# Out:
#            Rating  No. of ratings  \
# 0    4.3 out of 5   3,236 ratings
# 1               -               -
# 2    4.2 out of 5  14,823 ratings
# 3    3.7 out of 5   1,374 ratings
# 4    4.1 out of 5   5,678 ratings
# ..            ...             ...
# 435  4.2 out of 5     131 ratings
# 436  1.4 out of 5       3 ratings
# 437  4.6 out of 5      36 ratings
# 438    4 out of 5     572 ratings
# 439             -               -
#
#                                                Reviews
# 0    ---UPDATE---\nBased on my personal experience ...
# 1                                                    -
# 2    Friends, be careful it is not a Fast Charger. ...
# 3    wow product .Best charger it really charges my...
# 4    Original from HTC . 1 Amp rating means don't e...
# ..                                                 ...
# 435  This is really not acceptable I paid for new i...
# 436  I bought it thinking that it would be a fast c...
# ...

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# INFO:WDM:
#
# ====== WebDriver manager ======
# INFO:WDM:====== WebDriver manager ======
# Current google-chrome version is 95.0.4638
# INFO:WDM:Current google-chrome version is 95.0.4638
# Get LATEST driver version for 95.0.4638
# INFO:WDM:Get LATEST driver version for 95.0.4638
# Driver [C:\Users\monish\.wdm\drivers\chromedriver\win32\95.0.4638.69\chromedriver.exe] found in cache
# INFO:WDM:Driver [C:\Users\monish\.wdm\drivers\chromedriver\win32\95.0.4638.69\chromedriver.exe] found in cache

# %%
url = "https://www.flipkart.com/"
driver.get(url)

time.sleep(2)
# Asking the user to input the keywords he/she wants to search
user_inp = input('Enter the product you want to search : ')
# Out:
# Enter the product you want to search : phone

# %%
search_bar = driver.find_element_by_xpath('//*[@class="_3704LK"]')    # Locating searc_bar by id
search_bar.clear()                                               # clearing search_bar
search_bar.send_keys(user_inp)                                   # sending user input to search bar
search_button = driver.find_element_by_xpath('//*[@class="L0Z3Pu"]')       # Locating search_button by xpath
search_button.click()

# %%
# scrape all product urls
product_urls = []
start=0
end=20
for page in range(start,end):#for loop for scrapping 3 page
    url=driver.find_elements_by_xpath('//a[@class="_1fQZEK"]')       #scraping urls
    for i in url:
        product_urls.append(i.get_attribute("href"))                        #appending the urls in product_urls list
    nxt_button=driver.find_element_by_xpath("//a[@class='ge-49M']")     #scraping the list of buttons from the page
    nxt_button.click()
    time.sleep(2)

Rating = []
Review=[]

for url in product_urls:
    driver.get(url)
    time.sleep(2)
    
    try:
        rating = driver.find_element_by_xpath('//div[@class="_2d4LTz"]')  
        Rating.append(rating.text)
    except NoSuchElementException:
        Rating.append('-')


    time.sleep(1)
    
    try:
        review=driver.find_element_by_xpath('//div[@class="t-ZTKy"]')
        Review.append(review.text)
    except NoSuchElementException:
        Review.append('-')

# %%
df8 = pd.DataFrame({'Rating':Rating,'No. of ratings':no_of_ratings,'Reviews':Review})
df8
# Out:
#     Rating      No. of ratings  \
# 0      4.3  4,24,480 Ratings &
# 1      4.4    87,894 Ratings &
# 2      4.4    87,894 Ratings &
# 3      3.2       123 Ratings &
# 4      4.4  2,30,116 Ratings &
# ..     ...                 ...
# 475    3.8        66 Ratings &
# 476    4.3    44,185 Ratings &
# 477    4.4    40,788 Ratings &
# 478    4.4    40,788 Ratings &
# 479      3       609 Ratings &
#
#                                                Reviews
# 0    Great Phone at this Price point. Superb cool D...
# 1    Thanks again Flipkart team the wonderful deliv...
# 2    Thanks again Flipkart team the wonderful deliv...
# 3    It's not good and performance very bad\nRefund...
# 4    Good handy phone with decent performance. Good...
# ..                                                 ...
# 475  Super all performance nice battery is good sou...
# 476  Such a awesome handset in this segment.\nPro's...
# 477  Writing review after using for a week\nBought ...
# ...

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# INFO:WDM:
#
# ====== WebDriver manager ======
# INFO:WDM:====== WebDriver manager ======
# Current google-chrome version is 95.0.4638
# INFO:WDM:Current google-chrome version is 95.0.4638
# Get LATEST driver version for 95.0.4638
# INFO:WDM:Get LATEST driver version for 95.0.4638
# Driver [C:\Users\monish\.wdm\drivers\chromedriver\win32\95.0.4638.69\chromedriver.exe] found in cache
# INFO:WDM:Driver [C:\Users\monish\.wdm\drivers\chromedriver\win32\95.0.4638.69\chromedriver.exe] found in cache

# %%
url = "https://www.flipkart.com/"
driver.get(url)

time.sleep(2)
# Asking the user to input the keywords he/she wants to search
user_inp = input('Enter the product you want to search : ')
# Out:
# Enter the product you want to search : laptop

# %%
search_bar = driver.find_element_by_xpath('//*[@class="_3704LK"]')    # Locating searc_bar by id
search_bar.clear()                                               # clearing search_bar
search_bar.send_keys(user_inp)                                   # sending user input to search bar
search_button = driver.find_element_by_xpath('//*[@class="L0Z3Pu"]')       # Locating search_button by xpath
search_button.click()

# %%
# scrape all product urls
product_urls = []
start=0
end=20
for page in range(start,end):#for loop for scrapping 3 page
    url=driver.find_elements_by_xpath('//a[@class="_1fQZEK"]')       #scraping urls
    for i in url:
        product_urls.append(i.get_attribute("href"))                        #appending the urls in product_urls list
    nxt_button=driver.find_element_by_xpath("//a[@class='ge-49M']")     #scraping the list of buttons from the page
    nxt_button.click()
    time.sleep(2)

Rating = []
Review=[]

for url in product_urls:
    driver.get(url)
    time.sleep(2)
    
    try:
        rating = driver.find_element_by_xpath('//div[@class="_2d4LTz"]')  
        Rating.append(rating.text)
    except NoSuchElementException:
        Rating.append('-')


    time.sleep(1)
    
    try:
        review=driver.find_element_by_xpath('//div[@class="t-ZTKy"]')
        Review.append(review.text)
    except NoSuchElementException:
        Review.append('-')

# %%
df9 = pd.DataFrame({'Rating':Rating,'No. of ratings':no_of_ratings,'Reviews':Review})
df9
# Out:
#     Rating   No. of ratings                                            Reviews
# 0      4.5    519 Ratings &  What a great Product from HP INDIA The pavilli...
# 1      4.2     13 Ratings &  The best performing gaming laptop with a beaut...
# 2      4.4    588 Ratings &  Bought for 36k with SBI credit card discount.\...
# 3      4.4  5,614 Ratings &  Good Product, I am satisfied all of the featur...
# 4      4.6     16 Ratings &  Awesome product work and start like mcbook. Ca...
# ..     ...              ...                                                ...
# 475    4.6    155 Ratings &  Wait for the right price. I got it for almost ...
# 476      -                -                                                  -
# 477    4.3     33 Ratings &  Bought this laptop for 52K. Total value for mo...
# 478      4      5 Ratings &                                                  -
# 479      -                -                                                  -
#
# [480 rows x 3 columns]

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# INFO:WDM:
#
# ====== WebDriver manager ======
# INFO:WDM:====== WebDriver manager ======
# Current google-chrome version is 95.0.4638
# INFO:WDM:Current google-chrome version is 95.0.4638
# Get LATEST driver version for 95.0.4638
# INFO:WDM:Get LATEST driver version for 95.0.4638
# Get LATEST driver version for 95.0.4638
# INFO:WDM:Get LATEST driver version for 95.0.4638
# Trying to download new driver from https://chromedriver.storage.googleapis.com/95.0.4638.69/chromedriver_win32.zip
# INFO:WDM:Trying to download new driver from https://chromedriver.storage.googleapis.com/95.0.4638.69/chromedriver_win32.zip
# Driver has been saved in cache [C:\Users\monish\.wdm\drivers\chromedriver\win32\95.0.4638.69]
# INFO:WDM:Driver has been saved in cache [C:\Users\monish\.wdm\drivers\chromedriver\win32\95.0.4638.69]

# %%
url = "https://www.flipkart.com/"
driver.get(url)

time.sleep(2)
# Asking the user to input the keywords he/she wants to search
user_inp = input('Enter the product you want to search : ')
# Out:
# Enter the product you want to search : monitor

# %%
search_bar = driver.find_element_by_xpath('//*[@class="_3704LK"]')    # Locating searc_bar by id
search_bar.clear()                                               # clearing search_bar
search_bar.send_keys(user_inp)                                   # sending user input to search bar
search_button = driver.find_element_by_xpath('//*[@class="L0Z3Pu"]')       # Locating search_button by xpath
search_button.click()

# %%
# scrape all product urls
product_urls = []
start=0
end=20
for page in range(start,end):#for loop for scrapping 3 page
    url=driver.find_elements_by_xpath('//a[@class="_1fQZEK"]')       #scraping urls
    for i in url:
        product_urls.append(i.get_attribute("href"))                        #appending the urls in product_urls list
    nxt_button=driver.find_element_by_xpath("//a[@class='ge-49M']")     #scraping the list of buttons from the page
    nxt_button.click()
    time.sleep(2)

Rating = []
Review=[]

for url in product_urls:
    driver.get(url)
    time.sleep(2)
    
    try:
        rating = driver.find_element_by_xpath('//div[@class="_2d4LTz"]')  
        Rating.append(rating.text)
    except NoSuchElementException:
        Rating.append('-')


    time.sleep(1)
    
    try:
        review=driver.find_element_by_xpath('//div[@class="t-ZTKy"]')
        Review.append(review.text)
    except NoSuchElementException:
        Review.append('-')

# %%
df10 = pd.DataFrame({'Rating':Rating,'Reviews':Review})
df10
# Out:
#     Rating   No. of ratings                                            Reviews
# 0      4.4     34 Ratings &  I have to change the resolution back to full h...
# 1        -                -                                                  -
# 2      4.2    705 Ratings &  Worth it ,Good HD monitor fully happy satisfie...
# 3      4.3  4,654 Ratings &  well.....Ist of all package was mind blowing s...
# 4      4.6    413 Ratings &  Monitor is better then I expected!!!!\n\n- Bri...
# ..     ...              ...                                                ...
# 475    4.5  1,775 Ratings &  This is the good one which I have choose from ...
# 476      -                -                                                  -
# 477    4.6     41 Ratings &  Good product. No backlight bleed. Happy. Thoug...
# 478    4.5     92 Ratings &  Totally awesome product just I love the displa...
# 479    4.6     55 Ratings &  Clear crystal picture quality.... Awesome prod...
#
# [480 rows x 3 columns]

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# INFO:WDM:
#
# ====== WebDriver manager ======
# INFO:WDM:====== WebDriver manager ======
# Current google-chrome version is 95.0.4638
# INFO:WDM:Current google-chrome version is 95.0.4638
# Get LATEST driver version for 95.0.4638
# INFO:WDM:Get LATEST driver version for 95.0.4638
# Driver [C:\Users\monish\.wdm\drivers\chromedriver\win32\95.0.4638.69\chromedriver.exe] found in cache
# INFO:WDM:Driver [C:\Users\monish\.wdm\drivers\chromedriver\win32\95.0.4638.69\chromedriver.exe] found in cache

# %%
url = "https://www.amazon.in/"
driver.get(url)

time.sleep(2)
# Asking the user to input the keywords he/she wants to search
user_inp = input('Enter the product you want to search : ')
# Out:
# Enter the product you want to search : watches

# %%
search_bar = driver.find_element_by_id("twotabsearchtextbox")    # Locating searc_bar by id
search_bar.clear()                                               # clearing search_bar
search_bar.send_keys(user_inp)                                   # sending user input to search bar
search_button = driver.find_element_by_xpath('//div[@class="nav-search-submit nav-sprite"]/span/input')       # Locating search_button by xpath
search_button.click()

# %%
# scrape all product urls
product_urls = []
start=0
end=20
for page in range(start,end):#for loop for scrapping 3 page
    url=driver.find_elements_by_xpath('//a[@class="a-link-normal a-text-normal"]')       #scraping urls
    for i in url:
        product_urls.append(i.get_attribute("href"))                        #appending the urls in product_urls list
    nxt_button=driver.find_element_by_xpath("//li[@class='a-normal'][1]/a")     #scraping the list of buttons from the page
    nxt_button.click()
    time.sleep(2)

Rating = []

Review=[]

for url in product_urls:
    driver.get(url)
    time.sleep(2)
    
    try:
        rating = driver.find_element_by_xpath('//span[@class="a-size-base a-nowrap"]//span')  
        Rating.append(rating.text)
    except NoSuchElementException:
        Rating.append('-')


    time.sleep(1)
    try:
        review=driver.find_element_by_xpath('//div[@class="a-expander-content reviewText review-text-content a-expander-partial-collapse-content"]')
        Review.append(review.text)
    except NoSuchElementException:
        Review.append('-')

# %%
df11 = pd.DataFrame({'Rating':Rating,'Reviews':Review})
df11
# Out:
#            Rating  No. of ratings  \
# 0    3.4 out of 5      14 ratings
# 1    3.5 out of 5     549 ratings
# 2               -               -
# 3    3.7 out of 5      12 ratings
# 4    3.6 out of 5  14,158 ratings
# ..            ...             ...
# 496  4.1 out of 5     211 ratings
# 497  3.7 out of 5   1,143 ratings
# 498  4.1 out of 5   1,774 ratings
# 499  4.2 out of 5  13,679 ratings
# 500  4.2 out of 5     115 ratings
#
#                                                Reviews
# 0                            Overall OK. No comments 😕
# 1    decent look, suitable on all types wear . Weig...
# 2                                                    -
# 3                                                    -
# 4    i bought this watch to gift someone but the da...
# ..                                                 ...
# 496  Nice watch, good design, beautiful look but la...
# 497  Value for money. Received on 2nd August,2021. ...
# ...

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# INFO:WDM:
#
# ====== WebDriver manager ======
# INFO:WDM:====== WebDriver manager ======
# Current google-chrome version is 95.0.4638
# INFO:WDM:Current google-chrome version is 95.0.4638
# Get LATEST driver version for 95.0.4638
# INFO:WDM:Get LATEST driver version for 95.0.4638
# Driver [C:\Users\monish\.wdm\drivers\chromedriver\win32\95.0.4638.69\chromedriver.exe] found in cache
# INFO:WDM:Driver [C:\Users\monish\.wdm\drivers\chromedriver\win32\95.0.4638.69\chromedriver.exe] found in cache

# %%
url = "https://www.flipkart.com/"
driver.get(url)

time.sleep(2)
# Asking the user to input the keywords he/she wants to search
user_inp = input('Enter the product you want to search : ')
# Out:
# Enter the product you want to search : headphone

# %%
search_bar = driver.find_element_by_xpath('//*[@class="_3704LK"]')    # Locating searc_bar by id
search_bar.clear()                                               # clearing search_bar
search_bar.send_keys(user_inp)                                   # sending user input to search bar
search_button = driver.find_element_by_xpath('//*[@class="L0Z3Pu"]')       # Locating search_button by xpath
search_button.click()

# %%
# scrape all product urls
product_urls = []
start=0
end=20
for page in range(start,end):#for loop for scrapping 3 page
    url=driver.find_elements_by_xpath('//a[@class="s1Q9rs"]')       #scraping urls
    for i in url:
        product_urls.append(i.get_attribute("href"))                        #appending the urls in product_urls list
    nxt_button=driver.find_element_by_xpath("//a[@class='ge-49M']")     #scraping the list of buttons from the page
    nxt_button.click()
    time.sleep(2)

Rating = []
Review=[]

for url in product_urls:
    driver.get(url)
    time.sleep(2)
    
    try:
        rating = driver.find_element_by_xpath('//div[@class="_2d4LTz"]')  
        Rating.append(rating.text)
    except NoSuchElementException:
        Rating.append('-')


    time.sleep(1)
    
    try:
        review=driver.find_element_by_xpath('//div[@class="t-ZTKy"]')
        Review.append(review.text)
    except NoSuchElementException:
        Review.append('-')

# %%
df12 = pd.DataFrame({'Rating':Rating,'Reviews':Review})
df12
# Out:
#     Rating No. of ratings                                            Reviews
# 0      3.9              -  Nice product and lovely design of ear bud powe...
# 1        4              -  I'm Reviewing this Amazing Product After 5 mon...
# 2      3.5              -     Nice product , worth dude and value fore money
# 3        4              -  Awsome service by flipkart... Got delivery wit...
# 4      3.4              -  Super design fit for ears, Mike is awesome com...
# ..     ...            ...                                                ...
# 795    3.8              -  Good and value for money, best at this price. ...
# 796    3.4              -  This is a good product but I give it 4 Stars ....
# 797      4              -  I needed good quality and a nice looking neck ...
# 798    4.2              -  Amazing sound quality with boosted Bass. But i...
# 799    3.6              -  Awesome earbuds. Sound experience is good. Cry...
#
# [800 rows x 3 columns]

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# INFO:WDM:
#
# ====== WebDriver manager ======
# INFO:WDM:====== WebDriver manager ======
# Current google-chrome version is 95.0.4638
# INFO:WDM:Current google-chrome version is 95.0.4638
# Get LATEST driver version for 95.0.4638
# INFO:WDM:Get LATEST driver version for 95.0.4638
# Driver [C:\Users\monish\.wdm\drivers\chromedriver\win32\95.0.4638.69\chromedriver.exe] found in cache
# INFO:WDM:Driver [C:\Users\monish\.wdm\drivers\chromedriver\win32\95.0.4638.69\chromedriver.exe] found in cache

# %%
url = "https://www.amazon.in/"
driver.get(url)

time.sleep(2)
# Asking the user to input the keywords he/she wants to search
user_inp = input('Enter the product you want to search : ')
# Out:
# Enter the product you want to search : home theater

# %%
search_bar = driver.find_element_by_id("twotabsearchtextbox")    # Locating searc_bar by id
search_bar.clear()                                               # clearing search_bar
search_bar.send_keys(user_inp)                                   # sending user input to search bar
search_button = driver.find_element_by_xpath('//div[@class="nav-search-submit nav-sprite"]/span/input')       # Locating search_button by xpath
search_button.click()

# %%
# scrape all product urls
product_urls = []
start=0
end=20
for page in range(start,end):#for loop for scrapping 3 page
    url=driver.find_elements_by_xpath('//a[@class="a-link-normal a-text-normal"]')       #scraping urls
    for i in url:
        product_urls.append(i.get_attribute("href"))                        #appending the urls in product_urls list
    nxt_button=driver.find_element_by_xpath("//li[@class='a-normal'][1]/a")     #scraping the list of buttons from the page
    nxt_button.click()
    time.sleep(2)

Rating = []
Review=[]

for url in product_urls:
    driver.get(url)
    time.sleep(2)
    
    try:
        rating = driver.find_element_by_xpath('//span[@class="a-size-base a-nowrap"]//span')  
        Rating.append(rating.text)
    except NoSuchElementException:
        Rating.append('-')


    time.sleep(1)
    
    try:
        review=driver.find_element_by_xpath('//div[@class="a-expander-content reviewText review-text-content a-expander-partial-collapse-content"]')
        Review.append(review.text)
    except NoSuchElementException:
        Review.append('-')

# %%
df13 = pd.DataFrame({'Rating':Rating,'Reviews':Review})
df13
# Out:
#            Rating  No. of ratings  \
# 0               -               -
# 1      1 out of 5        1 rating
# 2    3.8 out of 5   6,165 ratings
# 3    3.8 out of 5   2,338 ratings
# 4    3.4 out of 5   3,138 ratings
# ..            ...             ...
# 575  3.8 out of 5   7,997 ratings
# 576  4.1 out of 5     431 ratings
# 577    4 out of 5   3,744 ratings
# 578  4.1 out of 5  13,154 ratings
# 579    4 out of 5     619 ratings
#
#                                                Reviews
# 0                                                    -
# 1    Delivered defective piece ..Is ther any Qualit...
# 2     Awesome sound quality and bass value for money..
# 3    The system is not good, sound and bass both of...
# 4    Wonderful product by Tronica, sound quality is...
# ..                                                 ...
# 575                                      Super quality
# 576  Amazing fit. It is ideal for a guy less than 5...
# ...

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# INFO:WDM:
#
# ====== WebDriver manager ======
# INFO:WDM:====== WebDriver manager ======
# Current google-chrome version is 95.0.4638
# INFO:WDM:Current google-chrome version is 95.0.4638
# Get LATEST driver version for 95.0.4638
# INFO:WDM:Get LATEST driver version for 95.0.4638
# Driver [C:\Users\monish\.wdm\drivers\chromedriver\win32\95.0.4638.69\chromedriver.exe] found in cache
# INFO:WDM:Driver [C:\Users\monish\.wdm\drivers\chromedriver\win32\95.0.4638.69\chromedriver.exe] found in cache

# %%
url = "https://www.flipkart.com/"
driver.get(url)

time.sleep(2)
# Asking the user to input the keywords he/she wants to search
user_inp = input('Enter the product you want to search : ')
# Out:
# Enter the product you want to search : printer

# %%
search_bar = driver.find_element_by_xpath('//*[@class="_3704LK"]')    # Locating searc_bar by id
search_bar.clear()                                               # clearing search_bar
search_bar.send_keys(user_inp)                                   # sending user input to search bar
search_button = driver.find_element_by_xpath('//*[@class="L0Z3Pu"]')       # Locating search_button by xpath
search_button.click()

# %%
# scrape all product urls
product_urls = []
start=0
end=10
for page in range(start,end):#for loop for scrapping 3 page
    url=driver.find_elements_by_xpath('//a[@class="s1Q9rs"]')       #scraping urls
    for i in url:
        product_urls.append(i.get_attribute("href"))                        #appending the urls in product_urls list
    nxt_button=driver.find_element_by_xpath("//a[@class='ge-49M']")     #scraping the list of buttons from the page
    nxt_button.click()
    time.sleep(2)

Rating = []
Review=[]

for url in product_urls:
    driver.get(url)
    time.sleep(2)
    
    try:
        rating = driver.find_element_by_xpath('//div[@class="_2d4LTz"]')  
        Rating.append(rating.text)
    except NoSuchElementException:
        Rating.append('-')


    time.sleep(1)    
    try:
        review=driver.find_element_by_xpath('//div[@class="t-ZTKy"]')
        Review.append(review.text)
    except NoSuchElementException:
        Review.append('-')

# %%
df14 = pd.DataFrame({'Rating':Rating,'Reviews':Review})
df14
# Out:
#     Rating No. of ratings                                            Reviews
# 0      3.7              -  Very nice printer, is worth the purchase. Idea...
# 1      3.9              -  Well product is good as we all know canon prin...
# 2      3.8              -  VERY VERY NICE 👍👍 AND VERY GOOD PRINT QUALITY ...
# 3      4.3              -  Great printer from HP. Excellent quality low c...
# 4        -              -                                                  -
# ..     ...            ...                                                ...
# 395      -              -                                                  -
# 396      -              -                                                  -
# 397      -              -                                                  -
# 398    4.4              -  Flipkart again exceeded my expectations, The d...
# 399    4.4              -  A very good printer for moderate business or p...
#
# [400 rows x 3 columns]

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# INFO:WDM:
#
# ====== WebDriver manager ======
# INFO:WDM:====== WebDriver manager ======
# Current google-chrome version is 95.0.4638
# INFO:WDM:Current google-chrome version is 95.0.4638
# Get LATEST driver version for 95.0.4638
# INFO:WDM:Get LATEST driver version for 95.0.4638
# Driver [C:\Users\monish\.wdm\drivers\chromedriver\win32\95.0.4638.69\chromedriver.exe] found in cache
# INFO:WDM:Driver [C:\Users\monish\.wdm\drivers\chromedriver\win32\95.0.4638.69\chromedriver.exe] found in cache

# %%
url = "https://www.flipkart.com/"
driver.get(url)

time.sleep(2)
# Asking the user to input the keywords he/she wants to search
user_inp = input('Enter the product you want to search : ')
# Out:
# Enter the product you want to search : smart watches

# %%
search_bar = driver.find_element_by_xpath('//*[@class="_3704LK"]')    # Locating searc_bar by id
search_bar.clear()                                               # clearing search_bar
search_bar.send_keys(user_inp)                                   # sending user input to search bar
search_button = driver.find_element_by_xpath('//*[@class="L0Z3Pu"]')       # Locating search_button by xpath
search_button.click()

# %%
# scrape all product urls
product_urls = []
start=0
end=10
for page in range(start,end):#for loop for scrapping 3 page
    url=driver.find_elements_by_xpath('//a[@class="_1fQZEK"]')       #scraping urls
    for i in url:
        product_urls.append(i.get_attribute("href"))                        #appending the urls in product_urls list
    nxt_button=driver.find_element_by_xpath("//a[@class='ge-49M']")     #scraping the list of buttons from the page
    nxt_button.click()
    time.sleep(2)

Rating = []
Review=[]

for url in product_urls:
    driver.get(url)
    time.sleep(2)
    
    try:
        rating = driver.find_element_by_xpath('//div[@class="_2d4LTz"]')  
        Rating.append(rating.text)
    except NoSuchElementException:
        Rating.append('-')


    time.sleep(1)
    
    try:
        review=driver.find_element_by_xpath('//div[@class="t-ZTKy"]')
        Review.append(review.text)
    except NoSuchElementException:
        Review.append('-')

# %%
df14 = pd.DataFrame({'Rating':Rating,'Reviews':Review})
df14
# Out:
#     Rating No. of ratings                                            Reviews
# 0      3.1              -  Awesome Watch , More better than I ve expected...
# 1      3.2              -  Good product\nSometimes lost bluetooth signal\...
# 2        -              -                                                  -
# 3      3.3              -                      Sufficient in this price good
# 4        -              -                                                  -
# ..     ...            ...                                                ...
# 235    4.1              -  Superb quality amazing watch i like it so much...
# 236    4.1              -  Superb quality amazing watch i like it so much...
# 237    3.5              -  Best product to buy . Worth every panny.\nLook...
# 238    4.2              -  Awesome - 3rd Gen from the noise is as expecte...
# 239    3.8              -  Good display size\nVery Good Value for Money.\...
#
# [240 rows x 3 columns]

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# INFO:WDM:
#
# ====== WebDriver manager ======
# INFO:WDM:====== WebDriver manager ======
# Current google-chrome version is 95.0.4638
# INFO:WDM:Current google-chrome version is 95.0.4638
# Get LATEST driver version for 95.0.4638
# INFO:WDM:Get LATEST driver version for 95.0.4638
# Driver [C:\Users\monish\.wdm\drivers\chromedriver\win32\95.0.4638.69\chromedriver.exe] found in cache
# INFO:WDM:Driver [C:\Users\monish\.wdm\drivers\chromedriver\win32\95.0.4638.69\chromedriver.exe] found in cache

# %%
url = "https://www.flipkart.com/"
driver.get(url)

time.sleep(2)
# Asking the user to input the keywords he/she wants to search
user_inp = input('Enter the product you want to search : ')
# Out:
# Enter the product you want to search : printer

# %%
search_bar = driver.find_element_by_xpath('//*[@class="_3704LK"]')    # Locating searc_bar by id
search_bar.clear()                                               # clearing search_bar
search_bar.send_keys(user_inp)                                   # sending user input to search bar
search_button = driver.find_element_by_xpath('//*[@class="L0Z3Pu"]')       # Locating search_button by xpath
search_button.click()

# %%
# scrape all product urls
product_urls = []
start=0
end=15
for page in range(start,end):#for loop for scrapping 3 page
    url=driver.find_elements_by_xpath('//a[@class="s1Q9rs"]')       #scraping urls
    for i in url:
        product_urls.append(i.get_attribute("href"))                        #appending the urls in product_urls list
    nxt_button=driver.find_element_by_xpath("//a[@class='ge-49M']")     #scraping the list of buttons from the page
    nxt_button.click()
    time.sleep(2)

Rating = []
Review=[]

for url in product_urls:
    driver.get(url)
    time.sleep(2)
    
    try:
        rating = driver.find_element_by_xpath('//div[@class="_2d4LTz"]')  
        Rating.append(rating.text)
    except NoSuchElementException:
        Rating.append('-')


    time.sleep(1)
    
    try:
        review=driver.find_element_by_xpath('//div[@class="t-ZTKy"]')
        Review.append(review.text)
    except NoSuchElementException:
        Review.append('-')

# %%
df15 = pd.DataFrame({'Rating':Rating,'Reviews':Review})
df15
# Out:
#     Rating No. of ratings                                            Reviews
# 0      4.3              -  This is a fantastic Lazer Printer and works as...
# 1        -              -                                                  -
# 2      4.3              -  Great printer from HP. Excellent quality low c...
# 3      3.8              -  VERY VERY NICE 👍👍 AND VERY GOOD PRINT QUALITY ...
# 4        -              -                                                  -
# ..     ...            ...                                                ...
# 395      -              -                                                  -
# 396    2.5              -  Android printing doesn't work. Waste spending ...
# 397    4.4              -  A very good printer for moderate business or p...
# 398    3.7              -  Very nice printer, is worth the purchase. Idea...
# 399    3.7              -  The product is not worth buying. There are few...
#
# [400 rows x 3 columns]

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# INFO:WDM:
#
# ====== WebDriver manager ======
# INFO:WDM:====== WebDriver manager ======
# Current google-chrome version is 95.0.4638
# INFO:WDM:Current google-chrome version is 95.0.4638
# Get LATEST driver version for 95.0.4638
# INFO:WDM:Get LATEST driver version for 95.0.4638
# Driver [C:\Users\monish\.wdm\drivers\chromedriver\win32\95.0.4638.69\chromedriver.exe] found in cache
# INFO:WDM:Driver [C:\Users\monish\.wdm\drivers\chromedriver\win32\95.0.4638.69\chromedriver.exe] found in cache

# %%
url = "https://www.flipkart.com/"
driver.get(url)

time.sleep(2)
# Asking the user to input the keywords he/she wants to search
user_inp = input('Enter the product you want to search : ')
# Out:
# Enter the product you want to search : Home theater

# %%
search_bar = driver.find_element_by_xpath('//*[@class="_3704LK"]')    # Locating searc_bar by id
search_bar.clear()                                               # clearing search_bar
search_bar.send_keys(user_inp)                                   # sending user input to search bar
search_button = driver.find_element_by_xpath('//*[@class="L0Z3Pu"]')       # Locating search_button by xpath
search_button.click()

# %%
# scrape all product urls
product_urls = []
start=0
end=15
for page in range(start,end):#for loop for scrapping 3 page
    url=driver.find_elements_by_xpath('//a[@class="s1Q9rs"]')       #scraping urls
    for i in url:
        product_urls.append(i.get_attribute("href"))                        #appending the urls in product_urls list
    nxt_button=driver.find_element_by_xpath("//a[@class='ge-49M']")     #scraping the list of buttons from the page
    nxt_button.click()
    time.sleep(2)

Rating = []
Review=[]

for url in product_urls:
    driver.get(url)
    time.sleep(2)
    
    try:
        rating = driver.find_element_by_xpath('//div[@class="_2d4LTz"]')  
        Rating.append(rating.text)
    except NoSuchElementException:
        Rating.append('-')


    time.sleep(1)
    
    try:
        review=driver.find_element_by_xpath('//div[@class="t-ZTKy"]')
        Review.append(review.text)
    except NoSuchElementException:
        Review.append('-')

# %%
df16 = pd.DataFrame({'Rating':Rating,'Reviews':Review})
df16
# Out:
#     Rating No. of ratings                                            Reviews
# 0      4.2              -  Very Good Product. Please don't go for other c...
# 1      4.2              -  I waited for the last 1 month for proper ratin...
# 2      4.1              -  the best product in low price osm the sound qu...
# 3      4.4              -                                                  -
# 4      3.8              -  Excellent product in budget .i m loving it.i p...
# ..     ...            ...                                                ...
# 395      -              -                                                  -
# 396      -              -                                                  -
# 397    3.8              -  Its a vintage looking speaker with good batter...
# 398      -              -                                                  -
# 399    3.6              -  It is too amazing and delivery is so fast befo...
#
# [400 rows x 3 columns]

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(ChromeDriverManager().install())

# %%
url = "https://www.flipkart.com/"
driver.get(url)

time.sleep(2)
# Asking the user to input the keywords he/she wants to search
user_inp = input('Enter the product you want to search : ')

# %%
search_bar = driver.find_element_by_xpath('//*[@class="_3704LK"]')    # Locating searc_bar by id
search_bar.clear()                                               # clearing search_bar
search_bar.send_keys(user_inp)                                   # sending user input to search bar
search_button = driver.find_element_by_xpath('//*[@class="L0Z3Pu"]')       # Locating search_button by xpath
search_button.click()

# %%
# scrape all product urls
product_urls = []
start=0
end=15
for page in range(start,end):#for loop for scrapping 3 page
    url=driver.find_elements_by_xpath('//a[@class="s1Q9rs"]')       #scraping urls
    for i in url:
        product_urls.append(i.get_attribute("href"))                        #appending the urls in product_urls list
    nxt_button=driver.find_element_by_xpath("//a[@class='ge-49M']")     #scraping the list of buttons from the page
    nxt_button.click()
    time.sleep(2)

Rating = []

Review=[]

for url in product_urls:
    driver.get(url)
    time.sleep(2)
    
    try:
        rating = driver.find_element_by_xpath('//div[@class="_2d4LTz"]')  
        Rating.append(rating.text)
    except NoSuchElementException:
        Rating.append('-')


    time.sleep(1)
    
    try:
        review=driver.find_element_by_xpath('//div[@class="t-ZTKy"]')
        Review.append(review.text)
    except NoSuchElementException:
        Review.append('-')

# %%
df17 = pd.DataFrame({'Rating':Rating,Reviews':Review})
df17
# Out:
#     Rating No. of ratings                                            Reviews
# 0      4.4              -  in love with this little beast..sound is cryst...
# 1      4.4              -  Hi Guys,\nI am writing this review post 2 days...
# 2      4.4              -                                                  -
# 3      4.1              -  the best product in low price osm the sound qu...
# 4      3.8              -  Excellent product in budget .i m loving it.i p...
# ..     ...            ...                                                ...
# 395      -              -                                                  -
# 396      5              -  GOOD Packard ; nice sound sub hi bass sound l ...
# 397      -              -                                                  -
# 398    4.1              -                                             thanks
# 399      -              -                                                  -
#
# [400 rows x 3 columns]

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# INFO:WDM:
#
# ====== WebDriver manager ======
# INFO:WDM:====== WebDriver manager ======
# Current google-chrome version is 95.0.4638
# INFO:WDM:Current google-chrome version is 95.0.4638
# Get LATEST driver version for 95.0.4638
# INFO:WDM:Get LATEST driver version for 95.0.4638
# Driver [C:\Users\monish\.wdm\drivers\chromedriver\win32\95.0.4638.69\chromedriver.exe] found in cache
# INFO:WDM:Driver [C:\Users\monish\.wdm\drivers\chromedriver\win32\95.0.4638.69\chromedriver.exe] found in cache

# %%
url = "https://www.flipkart.com/"
driver.get(url)

time.sleep(2)
# Asking the user to input the keywords he/she wants to search
user_inp = input('Enter the product you want to search : ')
# Out:
# Enter the product you want to search : charger

# %%
search_bar = driver.find_element_by_xpath('//*[@class="_3704LK"]')    # Locating searc_bar by id
search_bar.clear()                                               # clearing search_bar
search_bar.send_keys(user_inp)                                   # sending user input to search bar
search_button = driver.find_element_by_xpath('//*[@class="L0Z3Pu"]')       # Locating search_button by xpath
search_button.click()

# %%
# scrape all product urls
product_urls = []
start=0
end=15
for page in range(start,end):#for loop for scrapping 3 page
    url=driver.find_elements_by_xpath('//a[@class="s1Q9rs"]')       #scraping urls
    for i in url:
        product_urls.append(i.get_attribute("href"))                        #appending the urls in product_urls list
    nxt_button=driver.find_element_by_xpath("//a[@class='ge-49M']")     #scraping the list of buttons from the page
    nxt_button.click()
    time.sleep(2)

Rating = []
no_of_ratings = []
Review=[]

for url in product_urls:
    driver.get(url)
    time.sleep(2)
    
    try:
        rating = driver.find_element_by_xpath('//div[@class="_2d4LTz"]')  
        Rating.append(rating.text)
    except NoSuchElementException:
        Rating.append('-')


    time.sleep(1)
    
    try:
        review=driver.find_element_by_xpath('//div[@class="t-ZTKy"]')
        Review.append(review.text)
    except NoSuchElementException:
        Review.append('-')

# %%
df18 = pd.DataFrame({'Rating':Rating,'Reviews':Review})
df18
# Out:
#     Rating No. of ratings                                            Reviews
# 0      4.1              -  Flipkart always amaze me with their before tim...
# 1      4.1              -                                               Good
# 2      3.7              -  Product is good and delivery is awesome and th...
# 3        -              -                                                  -
# 4      4.1              -  Decent product.\nBest thing is, in this price ...
# ..     ...            ...                                                ...
# 595    4.3              -                                                  -
# 596    3.5              -                                       demaged item
# 597    4.2              -  Good quality charger but quite big in size. Ho...
# 598    3.9              -                                               Nice
# 599    4.5              -                                               Good
#
# [600 rows x 3 columns]

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# INFO:WDM:
#
# ====== WebDriver manager ======
# INFO:WDM:====== WebDriver manager ======
# Current google-chrome version is 95.0.4638
# INFO:WDM:Current google-chrome version is 95.0.4638
# Get LATEST driver version for 95.0.4638
# INFO:WDM:Get LATEST driver version for 95.0.4638
# Driver [C:\Users\monish\.wdm\drivers\chromedriver\win32\95.0.4638.69\chromedriver.exe] found in cache
# INFO:WDM:Driver [C:\Users\monish\.wdm\drivers\chromedriver\win32\95.0.4638.69\chromedriver.exe] found in cache

# %%
url = "https://www.flipkart.com/"
driver.get(url)

time.sleep(2)
# Asking the user to input the keywords he/she wants to search
user_inp = input('Enter the product you want to search : ')
# Out:
# Enter the product you want to search : Router

# %%
search_bar = driver.find_element_by_xpath('//*[@class="_3704LK"]')    # Locating searc_bar by id
search_bar.clear()                                               # clearing search_bar
search_bar.send_keys(user_inp)                                   # sending user input to search bar
search_button = driver.find_element_by_xpath('//*[@class="L0Z3Pu"]')       # Locating search_button by xpath
search_button.click()

# %%
# scrape all product urls
product_urls = []
start=0
end=15
for page in range(start,end):#for loop for scrapping 3 page
    url=driver.find_elements_by_xpath('//a[@class="s1Q9rs"]')       #scraping urls
    for i in url:
        product_urls.append(i.get_attribute("href"))                        #appending the urls in product_urls list
    nxt_button=driver.find_element_by_xpath("//a[@class='ge-49M']")     #scraping the list of buttons from the page
    nxt_button.click()
    time.sleep(2)

Rating = []
Review=[]

for url in product_urls:
    driver.get(url)
    time.sleep(2)
    
    try:
        rating = driver.find_element_by_xpath('//div[@class="_2d4LTz"]')  
        Rating.append(rating.text)
    except NoSuchElementException:
        Rating.append('-')


    time.sleep(1)
    
    try:
        review=driver.find_element_by_xpath('//div[@class="t-ZTKy"]')
        Review.append(review.text)
    except NoSuchElementException:
        Review.append('-')

# %%
df19 = pd.DataFrame({'Rating':Rating,'Reviews':Review})
df19
# Out:
#     Rating No. of ratings                                            Reviews
# 0      4.3              -  This is the best WiFi router in this price ran...
# 1        -              -                                                  -
# 2      4.3              -  This router it seems is a basic gigabit router...
# 3        4              -  the signal area not good at all , its same as ...
# 4      4.2              -  I have bought this product in a hurry since I ...
# ..     ...            ...                                                ...
# 595    4.2              -  Everything works as expected but for a 3 anten...
# 596      4              -  It's just been 2 days since I've started using...
# 597    4.1              -  Not enough range for 2bhk infact my old wifi r...
# 598    4.4              -          Very gud device, much better then netgear
# 599      4              -  So okay listen there were so many options avai...
#
# [600 rows x 3 columns]

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# INFO:WDM:
#
# ====== WebDriver manager ======
# INFO:WDM:====== WebDriver manager ======
# Current google-chrome version is 95.0.4638
# INFO:WDM:Current google-chrome version is 95.0.4638
# Get LATEST driver version for 95.0.4638
# INFO:WDM:Get LATEST driver version for 95.0.4638
# Driver [C:\Users\monish\.wdm\drivers\chromedriver\win32\95.0.4638.69\chromedriver.exe] found in cache
# INFO:WDM:Driver [C:\Users\monish\.wdm\drivers\chromedriver\win32\95.0.4638.69\chromedriver.exe] found in cache

# %%
url = "https://www.flipkart.com/"
driver.get(url)

time.sleep(2)
# Asking the user to input the keywords he/she wants to search
user_inp = input('Enter the product you want to search : ')
# Out:
# Enter the product you want to search : Monitor

# %%
search_bar = driver.find_element_by_xpath('//*[@class="_3704LK"]')    # Locating searc_bar by id
search_bar.clear()                                               # clearing search_bar
search_bar.send_keys(user_inp)                                   # sending user input to search bar
search_button = driver.find_element_by_xpath('//*[@class="L0Z3Pu"]')       # Locating search_button by xpath
search_button.click()

# %%
# scrape all product urls
product_urls = []
start=0
end=15
for page in range(start,end):#for loop for scrapping 3 page
    url=driver.find_elements_by_xpath('//a[@class="_1fQZEK"]')       #scraping urls
    for i in url:
        product_urls.append(i.get_attribute("href"))                        #appending the urls in product_urls list
    nxt_button=driver.find_element_by_xpath("//a[@class='ge-49M']")     #scraping the list of buttons from the page
    nxt_button.click()
    time.sleep(2)

Rating = []
no_of_ratings = []
Review=[]

for url in product_urls:
    driver.get(url)
    time.sleep(2)
    
    try:
        rating = driver.find_element_by_xpath('//div[@class="_2d4LTz"]')  
        Rating.append(rating.text)
    except NoSuchElementException:
        Rating.append('-')


    time.sleep(1)
    
    try:
        review=driver.find_element_by_xpath('//div[@class="t-ZTKy"]')
        Review.append(review.text)
    except NoSuchElementException:
        Review.append('-')

# %%
df20 = pd.DataFrame({'Rating':Rating,'Reviews':Review})
df20
# Out:
#     Rating No. of ratings                                            Reviews
# 0      4.3              -                                                  -
# 1      4.4              -  Used for a week. no bleeding edges. Overall v....
# 2      4.5              -  1 Own 3 of these and I must say.....Benq is be...
# 3      4.5              -  THIS IS A MUST BUY FOR ANYBODY WANTS PERFECT S...
# 4      4.5              -  Awesome monitor from HP. Loved it to the core....
# ..     ...            ...                                                ...
# 355    4.1              -                                  Excellent monitor
# 356      -              -                                                  -
# 357    4.5              -  Nice monitor from acer. I love it.. Slim and w...
# 358    4.2              -                                       Very nice👏👏👏
# 359    4.5              -  This one is absolutely perfect for work produc...
#
# [360 rows x 3 columns]

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# INFO:WDM:
#
# ====== WebDriver manager ======
# INFO:WDM:====== WebDriver manager ======
# Current google-chrome version is 95.0.4638
# INFO:WDM:Current google-chrome version is 95.0.4638
# Get LATEST driver version for 95.0.4638
# INFO:WDM:Get LATEST driver version for 95.0.4638
# Driver [C:\Users\monish\.wdm\drivers\chromedriver\win32\95.0.4638.69\chromedriver.exe] found in cache
# INFO:WDM:Driver [C:\Users\monish\.wdm\drivers\chromedriver\win32\95.0.4638.69\chromedriver.exe] found in cache

# %%
url = "https://www.flipkart.com/"
driver.get(url)

time.sleep(2)
# Asking the user to input the keywords he/she wants to search
user_inp = input('Enter the product you want to search : ')
# Out:
# Enter the product you want to search : camera

# %%
search_bar = driver.find_element_by_xpath('//*[@class="_3704LK"]')    # Locating searc_bar by id
search_bar.clear()                                               # clearing search_bar
search_bar.send_keys(user_inp)                                   # sending user input to search bar
search_button = driver.find_element_by_xpath('//*[@class="L0Z3Pu"]')       # Locating search_button by xpath
search_button.click()

# %%
# scrape all product urls
product_urls = []
start=0
end=15
for page in range(start,end):#for loop for scrapping 3 page
    url=driver.find_elements_by_xpath('//a[@class="_1fQZEK"]')       #scraping urls
    for i in url:
        product_urls.append(i.get_attribute("href"))                        #appending the urls in product_urls list
    nxt_button=driver.find_element_by_xpath("//a[@class='ge-49M']")     #scraping the list of buttons from the page
    nxt_button.click()
    time.sleep(2)

Rating = []
Review=[]

for url in product_urls:
    driver.get(url)
    time.sleep(2)
    
    try:
        rating = driver.find_element_by_xpath('//div[@class="_2d4LTz"]')  
        Rating.append(rating.text)
    except NoSuchElementException:
        Rating.append('-')


    time.sleep(1)
    
    try:
        review=driver.find_element_by_xpath('//div[@class="t-ZTKy"]')
        Review.append(review.text)
    except NoSuchElementException:
        Review.append('-')

# %%
df21 = pd.DataFrame({'Rating':Rating,'Reviews':Review})
df21
# Out:
#     Rating No. of ratings                                            Reviews
# 0      3.2              -                                       Poor product
# 1      4.6              -                    It’s amazing and perfect camera
# 2        -              -                                                  -
# 3      4.1              -  Picture quality is good. I satisfied with pict...
# 4      4.3              -                              Super Deal Everytime.
# ..     ...            ...                                                ...
# 355    4.6              -                    It’s amazing and perfect camera
# 356      -              -                                                  -
# 357    4.1              -  Video Quality is good and Wifi sharing is even...
# 358    3.8              -  Brilliant Camera. Value for money. Add a exter...
# 359    4.6              -                    It’s amazing and perfect camera
#
# [360 rows x 3 columns]

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# INFO:WDM:
#
# ====== WebDriver manager ======
# INFO:WDM:====== WebDriver manager ======
# Current google-chrome version is 95.0.4638
# INFO:WDM:Current google-chrome version is 95.0.4638
# Get LATEST driver version for 95.0.4638
# INFO:WDM:Get LATEST driver version for 95.0.4638
# Driver [C:\Users\monish\.wdm\drivers\chromedriver\win32\95.0.4638.69\chromedriver.exe] found in cache
# INFO:WDM:Driver [C:\Users\monish\.wdm\drivers\chromedriver\win32\95.0.4638.69\chromedriver.exe] found in cache

# %%
url = "https://www.snapdeal.com/"
driver.get(url)

time.sleep(2)
# Asking the user to input the keywords he/she wants to search
user_inp = input('Enter the product you want to search : ')
# Out:
# Enter the product you want to search : camera

# %%
search_bar = driver.find_element_by_id("inputValEnter")    # Locating searc_bar by id
search_bar.clear()                                               # clearing search_bar
search_bar.send_keys(user_inp)                                   # sending user input to search bar
search_button = driver.find_element_by_xpath('//button[@class="searchformButton col-xs-4 rippleGrey"]')       # Locating search_button by xpath
search_button.click()

# %%
# scrape all product urls
product_urls = []
start=0
end=15
for page in range(start,end):#for loop for scrapping 3 page
    url=driver.find_elements_by_xpath('//a[@class="dp-widget-link noUdLine hashAdded"]')       #scraping urls
    for i in url:
        product_urls.append(i.get_attribute("href"))                        #appending the urls in product_urls list
    nxt_button=driver.find_element_by_id("see-more-products")     #scraping the list of buttons from the page
    nxt_button.click()
    time.sleep(2)

Rating = []
Review=[]

for url in product_urls:
    driver.get(url)
    time.sleep(2)
    
    try:
        rating = driver.find_element_by_xpath('//span[@class="rating"]')  
        Rating.append(rating.text)
    except NoSuchElementException:
        Rating.append('-')


    time.sleep(1)
    
    try:
        review=driver.find_element_by_xpath('//div[@class="head"]')
        Review.append(review.text)
    except NoSuchElementException:
        Review.append('-')

# %%
df22 = pd.DataFrame({'Rating':Rating,'Reviews':Review})
df22
# Out:
#     Rating            No. of ratings                          Reviews
# 0      4.2   107 Ratings & 3 Reviews               Amazing i loved it
# 1      4.2   107 Ratings & 3 Reviews               Amazing i loved it
# 2      3.8   186 Ratings & 3 Reviews          Value for money product
# 3      3.8   186 Ratings & 3 Reviews          Value for money product
# 4      3.8  264 Ratings & 43 Reviews                          Perfect
# ..     ...                       ...                              ...
# 595    3.9     15 Ratings & 1 Review                    Grate product
# 596    4.2     47 Ratings & 0 Review                                -
# 597    4.2     47 Ratings & 0 Review                                -
# 598    4.8      6 Ratings & 1 Review  Best quality at the best price!
# 599    4.8      6 Ratings & 1 Review  Best quality at the best price!
#
# [600 rows x 3 columns]

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# INFO:WDM:
#
# ====== WebDriver manager ======
# INFO:WDM:====== WebDriver manager ======
# Current google-chrome version is 95.0.4638
# INFO:WDM:Current google-chrome version is 95.0.4638
# Get LATEST driver version for 95.0.4638
# INFO:WDM:Get LATEST driver version for 95.0.4638
# Driver [C:\Users\monish\.wdm\drivers\chromedriver\win32\95.0.4638.69\chromedriver.exe] found in cache
# INFO:WDM:Driver [C:\Users\monish\.wdm\drivers\chromedriver\win32\95.0.4638.69\chromedriver.exe] found in cache

# %%
url = "https://www.snapdeal.com/"
driver.get(url)

time.sleep(2)
# Asking the user to input the keywords he/she wants to search
user_inp = input('Enter the product you want to search : ')
# Out:
# Enter the product you want to search : monitor

# %%
search_bar = driver.find_element_by_id("inputValEnter")    # Locating searc_bar by id
search_bar.clear()                                               # clearing search_bar
search_bar.send_keys(user_inp)                                   # sending user input to search bar
search_button = driver.find_element_by_xpath('//button[@class="searchformButton col-xs-4 rippleGrey"]')       # Locating search_button by xpath
search_button.click()

# %%
 # scrape all product urls
product_urls = []
start=0
end=15
for page in range(start,end):#for loop for scrapping 3 page
    url=driver.find_elements_by_xpath('//a[@class="dp-widget-link noUdLine hashAdded"]')       #scraping urls
    for i in url:
        product_urls.append(i.get_attribute("href"))                        #appending the urls in product_urls list
    nxt_button=driver.find_element_by_id("see-more-products")     #scraping the list of buttons from the page
    nxt_button.click()
    time.sleep(2)

Rating = []
Review=[]

for url in product_urls:
    driver.get(url)
    time.sleep(2)
    
    try:
        rating = driver.find_element_by_xpath('//span[@class="rating"]')  
        Rating.append(rating.text)
    except NoSuchElementException:
        Rating.append('-')


    time.sleep(1)
    
    try:
        review=driver.find_element_by_xpath('//div[@class="head"]')
        Review.append(review.text)
    except NoSuchElementException:
        Review.append('-')

# %%
df23 = pd.DataFrame({'Rating':Rating,'Reviews':Review})
df23
# Out:
#     Rating              No. of ratings                        Reviews
# 0      4.0         1 Rating & 0 Review                              -
# 1      4.0         1 Rating & 0 Review                              -
# 2      4.3       17 Ratings & 0 Review                              -
# 3      4.3       17 Ratings & 0 Review                              -
# 4      3.9      22 Ratings & 3 Reviews            Nice BPL BP MACHINE
# ..     ...                         ...                            ...
# 595    4.4        5 Ratings & 0 Review                              -
# 596    3.5       17 Ratings & 1 Review  Chal hi nahi raha hai monitor
# 597    3.5       17 Ratings & 1 Review  Chal hi nahi raha hai monitor
# 598    4.0  2615 Ratings & 363 Reviews                     BP monitor
# 599    4.0  2615 Ratings & 363 Reviews                     BP monitor
#
# [600 rows x 3 columns]

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# INFO:WDM:
#
# ====== WebDriver manager ======
# INFO:WDM:====== WebDriver manager ======
# Current google-chrome version is 95.0.4638
# INFO:WDM:Current google-chrome version is 95.0.4638
# Get LATEST driver version for 95.0.4638
# INFO:WDM:Get LATEST driver version for 95.0.4638
# Driver [C:\Users\monish\.wdm\drivers\chromedriver\win32\95.0.4638.69\chromedriver.exe] found in cache
# INFO:WDM:Driver [C:\Users\monish\.wdm\drivers\chromedriver\win32\95.0.4638.69\chromedriver.exe] found in cache

# %%
url = "https://www.snapdeal.com/"
driver.get(url)

time.sleep(2)
# Asking the user to input the keywords he/she wants to search
user_inp = input('Enter the product you want to search : ')
# Out:
# Enter the product you want to search : laptop

# %%
search_bar = driver.find_element_by_id("inputValEnter")    # Locating searc_bar by id
search_bar.clear()                                               # clearing search_bar
search_bar.send_keys(user_inp)                                   # sending user input to search bar
search_button = driver.find_element_by_xpath('//button[@class="searchformButton col-xs-4 rippleGrey"]')       # Locating search_button by xpath
search_button.click()

# %%
# scrape all product urls
product_urls = []
start=0
end=15
for page in range(start,end):#for loop for scrapping 3 page
    url=driver.find_elements_by_xpath('//a[@class="dp-widget-link noUdLine hashAdded"]')       #scraping urls
    for i in url:
        product_urls.append(i.get_attribute("href"))                        #appending the urls in product_urls list
    nxt_button=driver.find_element_by_id("see-more-products")     #scraping the list of buttons from the page
    nxt_button.click()
    time.sleep(2)

Rating = []
no_of_ratings = []
Review=[]

for url in product_urls:
    driver.get(url)
    time.sleep(2)
    
    try:
        rating = driver.find_element_by_xpath('//span[@class="rating"]')  
        Rating.append(rating.text)
    except NoSuchElementException:
        Rating.append('-')


    time.sleep(1)
    
    try:
        review=driver.find_element_by_xpath('//div[@class="head"]')
        Review.append(review.text)
    except NoSuchElementException:
        Review.append('-')

# %%
df24 = pd.DataFrame({'Rating':Rating,'Reviews':Review})
df24
# Out:
#     Rating              No. of ratings        Reviews
# 0      4.1    507 Ratings & 21 Reviews       Verygood
# 1      4.1    507 Ratings & 21 Reviews       Verygood
# 2      4.1   1915 Ratings & 68 Reviews          Supar
# 3      4.1   1915 Ratings & 68 Reviews          Supar
# 4      4.1     101 Ratings & 8 Reviews     Good 😀👌❤️🔊
# ..     ...                         ...            ...
# 595    4.1       63 Ratings & 1 Review      Air dopes
# 596      -                           -              -
# 597      -                           -              -
# 598    3.7  2743 Ratings & 201 Reviews  bhavi hbs 730
# 599    3.7  2743 Ratings & 201 Reviews  bhavi hbs 730
#
# [600 rows x 3 columns]

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# INFO:WDM:
#
# ====== WebDriver manager ======
# INFO:WDM:====== WebDriver manager ======
# Current google-chrome version is 95.0.4638
# INFO:WDM:Current google-chrome version is 95.0.4638
# Get LATEST driver version for 95.0.4638
# INFO:WDM:Get LATEST driver version for 95.0.4638
# Driver [C:\Users\monish\.wdm\drivers\chromedriver\win32\95.0.4638.69\chromedriver.exe] found in cache
# INFO:WDM:Driver [C:\Users\monish\.wdm\drivers\chromedriver\win32\95.0.4638.69\chromedriver.exe] found in cache

# %%
url = "https://www.snapdeal.com/"
driver.get(url)

time.sleep(2)
# Asking the user to input the keywords he/she wants to search
user_inp = input('Enter the product you want to search : ')
# Out:
# Enter the product you want to search : headphone

# %%
search_bar = driver.find_element_by_id("inputValEnter")    # Locating searc_bar by id
search_bar.clear()                                               # clearing search_bar
search_bar.send_keys(user_inp)                                   # sending user input to search bar
search_button = driver.find_element_by_xpath('//button[@class="searchformButton col-xs-4 rippleGrey"]')       # Locating search_button by xpath
search_button.click()

# %%
# scrape all product urls
product_urls = []
start=0
end=15
for page in range(start,end):#for loop for scrapping 3 page
    url=driver.find_elements_by_xpath('//a[@class="dp-widget-link noUdLine hashAdded"]')       #scraping urls
    for i in url:
        product_urls.append(i.get_attribute("href"))                        #appending the urls in product_urls list
    nxt_button=driver.find_element_by_id("see-more-products")     #scraping the list of buttons from the page
    nxt_button.click()
    time.sleep(2)

Rating = []
Review=[]

for url in product_urls:
    driver.get(url)
    time.sleep(2)
    
    try:
        rating = driver.find_element_by_xpath('//span[@class="rating"]')  
        Rating.append(rating.text)
    except NoSuchElementException:
        Rating.append('-')


    time.sleep(1)
    
    try:
        review=driver.find_element_by_xpath('//div[@class="head"]')
        Review.append(review.text)
    except NoSuchElementException:
        Review.append('-')

# %%
df25 = pd.DataFrame({'Rating':Rating,'Reviews':Review})
df25
# Out:
#     Rating            No. of ratings                         Reviews
# 0      4.1   101 Ratings & 8 Reviews                      Good 😀👌❤️🔊
# 1      4.1   101 Ratings & 8 Reviews                      Good 😀👌❤️🔊
# 2
# 3
# 4
# ..     ...                       ...                             ...
# 595    3.5     27 Ratings & 1 Review                       Satisfied
# 596    4.2    73 Ratings & 2 Reviews  I am so happy and good product
# 597    4.2    73 Ratings & 2 Reviews  I am so happy and good product
# 598    4.0  376 Ratings & 20 Reviews                 Awesome pruduct
# 599    4.0  376 Ratings & 20 Reviews                 Awesome pruduct
#
# [600 rows x 3 columns]

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# INFO:WDM:
#
# ====== WebDriver manager ======
# INFO:WDM:====== WebDriver manager ======
# Current google-chrome version is 95.0.4638
# INFO:WDM:Current google-chrome version is 95.0.4638
# Get LATEST driver version for 95.0.4638
# INFO:WDM:Get LATEST driver version for 95.0.4638
# Driver [C:\Users\monish\.wdm\drivers\chromedriver\win32\95.0.4638.69\chromedriver.exe] found in cache
# INFO:WDM:Driver [C:\Users\monish\.wdm\drivers\chromedriver\win32\95.0.4638.69\chromedriver.exe] found in cache

# %%
url = "https://www.snapdeal.com/"
driver.get(url)

time.sleep(2)
# Asking the user to input the keywords he/she wants to search
user_inp = input('Enter the product you want to search : ')
# Out:
# Enter the product you want to search : watches

# %%
search_bar = driver.find_element_by_id("inputValEnter")    # Locating searc_bar by id
search_bar.clear()                                               # clearing search_bar
search_bar.send_keys(user_inp)                                   # sending user input to search bar
search_button = driver.find_element_by_xpath('//button[@class="searchformButton col-xs-4 rippleGrey"]')       # Locating search_button by xpath
search_button.click()

# %%
# scrape all product urls
product_urls = []
start=0
end=15
for page in range(start,end):#for loop for scrapping 3 page
    url=driver.find_elements_by_xpath('//a[@class="dp-widget-link noUdLine hashAdded"]')       #scraping urls
    for i in url:
        product_urls.append(i.get_attribute("href"))                        #appending the urls in product_urls list
    nxt_button=driver.find_element_by_id("see-more-products")     #scraping the list of buttons from the page
    nxt_button.click()
    time.sleep(2)

Rating = []
Review=[]

for url in product_urls:
    driver.get(url)
    time.sleep(2)
    
    try:
        rating = driver.find_element_by_xpath('//span[@class="rating"]')  
        Rating.append(rating.text)
    except NoSuchElementException:
        Rating.append('-')


    time.sleep(1)
    
    try:
        review=driver.find_element_by_xpath('//div[@class="head"]')
        Review.append(review.text)
    except NoSuchElementException:
        Review.append('-')

# %%
df26 = pd.DataFrame({'Rating':Ratings,'Reviews':Review})
df26
# Out:
#     Rating             No. of ratings        Reviews
# 0      4.2   606 Ratings & 14 Reviews   Good looking
# 1      4.2   606 Ratings & 14 Reviews   Good looking
# 2      4.0  1133 Ratings & 17 Reviews        Jhakash
# 3      4.0  1133 Ratings & 17 Reviews        Jhakash
# 4      4.5      12 Ratings & 0 Review              -
# ..     ...                        ...            ...
# 595    4.6       7 Ratings & 0 Review              -
# 596      -                          -              -
# 597      -                          -              -
# 598    4.2    652 Ratings & 9 Reviews  Same as shown
# 599    4.2    652 Ratings & 9 Reviews  Same as shown
#
# [600 rows x 3 columns]

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# INFO:WDM:
#
# ====== WebDriver manager ======
# INFO:WDM:====== WebDriver manager ======
# Current google-chrome version is 95.0.4638
# INFO:WDM:Current google-chrome version is 95.0.4638
# Get LATEST driver version for 95.0.4638
# INFO:WDM:Get LATEST driver version for 95.0.4638
# Get LATEST driver version for 95.0.4638
# INFO:WDM:Get LATEST driver version for 95.0.4638
# Trying to download new driver from https://chromedriver.storage.googleapis.com/95.0.4638.69/chromedriver_win32.zip
# INFO:WDM:Trying to download new driver from https://chromedriver.storage.googleapis.com/95.0.4638.69/chromedriver_win32.zip
# Driver has been saved in cache [C:\Users\monish\.wdm\drivers\chromedriver\win32\95.0.4638.69]
# INFO:WDM:Driver has been saved in cache [C:\Users\monish\.wdm\drivers\chromedriver\win32\95.0.4638.69]

# %%
url = "https://www.snapdeal.com/"
driver.get(url)

time.sleep(2)
# Asking the user to input the keywords he/she wants to search
user_inp = input('Enter the product you want to search : ')
# Out:
# Enter the product you want to search : home theater

# %%
search_bar = driver.find_element_by_id("inputValEnter")    # Locating searc_bar by id
search_bar.clear()                                               # clearing search_bar
search_bar.send_keys(user_inp)                                   # sending user input to search bar
search_button = driver.find_element_by_xpath('//button[@class="searchformButton col-xs-4 rippleGrey"]')       # Locating search_button by xpath
search_button.click()

# %%
# scrape all product urls
product_urls = []
start=0
end=15
for page in range(start,end):#for loop for scrapping 3 page
    url=driver.find_elements_by_xpath('//a[@class="dp-widget-link noUdLine hashAdded"]')       #scraping urls
    for i in url:
        product_urls.append(i.get_attribute("href"))                        #appending the urls in product_urls list
    #nxt_button=driver.find_element_by_id("see-more-products")     #scraping the list of buttons from the page
    #nxt_button.click()
    time.sleep(2)

Rating = []
no_of_ratings = []
Review=[]

for url in product_urls:
    driver.get(url)
    time.sleep(2)
    
    try:
        rating = driver.find_element_by_xpath('//span[@class="rating"]')  
        Rating.append(rating.text)
    except NoSuchElementException:
        Rating.append('-')


    time.sleep(1)
    
    try:
        review=driver.find_element_by_xpath('//div[@class="head"]')
        Review.append(review.text)
    except NoSuchElementException:
        Review.append('-')

# %%
df27 = pd.DataFrame({'Rating':Rating,'Reviews':Review})
df27
# Out:
#     Rating          No. of ratings       Reviews
# 0      5.0     1 Rating & 0 Review             -
# 1      5.0     1 Rating & 0 Review             -
# 2        -                       -             -
# 3        -                       -             -
# 4      3.0    2 Ratings & 1 Review  Nice product
# ..     ...                     ...           ...
# 595      -                       -             -
# 596    4.0  25 Ratings & 8 Reviews  Superb deal.
# 597    4.0  25 Ratings & 8 Reviews  Superb deal.
# 598      -                       -             -
# 599      -                       -             -
#
# [600 rows x 3 columns]

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# INFO:WDM:
#
# ====== WebDriver manager ======
# INFO:WDM:====== WebDriver manager ======
# Current google-chrome version is 95.0.4638
# INFO:WDM:Current google-chrome version is 95.0.4638
# Get LATEST driver version for 95.0.4638
# INFO:WDM:Get LATEST driver version for 95.0.4638
# Driver [C:\Users\monish\.wdm\drivers\chromedriver\win32\95.0.4638.69\chromedriver.exe] found in cache
# INFO:WDM:Driver [C:\Users\monish\.wdm\drivers\chromedriver\win32\95.0.4638.69\chromedriver.exe] found in cache

# %%
url = "https://www.snapdeal.com/"
driver.get(url)

time.sleep(2)
# Asking the user to input the keywords he/she wants to search
user_inp = input('Enter the product you want to search : ')
# Out:
# Enter the product you want to search : printer

# %%
search_bar = driver.find_element_by_id("inputValEnter")    # Locating searc_bar by id
search_bar.clear()                                               # clearing search_bar
search_bar.send_keys(user_inp)                                   # sending user input to search bar
search_button = driver.find_element_by_xpath('//button[@class="searchformButton col-xs-4 rippleGrey"]')       # Locating search_button by xpath
search_button.click()

# %%
# scrape all product urls
product_urls = []
start=0
end=15
for page in range(start,end):#for loop for scrapping 3 page
    url=driver.find_elements_by_xpath('//a[@class="dp-widget-link noUdLine hashAdded"]')       #scraping urls
    for i in url:
        product_urls.append(i.get_attribute("href"))                        #appending the urls in product_urls list
    nxt_button=driver.find_element_by_id("see-more-products")     #scraping the list of buttons from the page
    nxt_button.click()
    time.sleep(2)

Rating = []
no_of_ratings = []
Review=[]

for url in product_urls:
    driver.get(url)
    time.sleep(2)
    
    try:
        rating = driver.find_element_by_xpath('//span[@class="rating"]')  
        Rating.append(rating.text)
    except NoSuchElementException:
        Rating.append('-')


    time.sleep(1)
    
    try:
        review=driver.find_element_by_xpath('//div[@class="head"]')
        Review.append(review.text)
    except NoSuchElementException:
        Review.append('-')

# %%
df28 = pd.DataFrame({'Rating':Rating,'Reviews':Review})
df28
# Out:
#      Rating           No. of ratings                         Reviews
# 0       4.0  143 Ratings & 3 Reviews  Size is not ok pls take return
# 1       4.0  143 Ratings & 3 Reviews  Size is not ok pls take return
# 2       4.6    15 Ratings & 1 Review               Very Good Product
# 3       4.6    15 Ratings & 1 Review               Very Good Product
# 4       3.6    42 Ratings & 0 Review                               -
# ...     ...                      ...                             ...
# 2395    5.0      1 Rating & 0 Review                               -
# 2396      -                        -                               -
# 2397      -                        -                               -
# 2398    4.0      1 Rating & 0 Review                               -
# 2399    4.0      1 Rating & 0 Review                               -
#
# [2400 rows x 3 columns]

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# INFO:WDM:
#
# ====== WebDriver manager ======
# INFO:WDM:====== WebDriver manager ======
# Current google-chrome version is 95.0.4638
# INFO:WDM:Current google-chrome version is 95.0.4638
# Get LATEST driver version for 95.0.4638
# INFO:WDM:Get LATEST driver version for 95.0.4638
# Driver [C:\Users\monish\.wdm\drivers\chromedriver\win32\95.0.4638.69\chromedriver.exe] found in cache
# INFO:WDM:Driver [C:\Users\monish\.wdm\drivers\chromedriver\win32\95.0.4638.69\chromedriver.exe] found in cache

# %%
url = "https://www.snapdeal.com/"
driver.get(url)

time.sleep(2)
# Asking the user to input the keywords he/she wants to search
user_inp = input('Enter the product you want to search : ')
# Out:
# Enter the product you want to search : charger

# %%
search_bar = driver.find_element_by_id("inputValEnter")    # Locating searc_bar by id
search_bar.clear()                                               # clearing search_bar
search_bar.send_keys(user_inp)                                   # sending user input to search bar
search_button = driver.find_element_by_xpath('//button[@class="searchformButton col-xs-4 rippleGrey"]')       # Locating search_button by xpath
search_button.click()

# %%
# scrape all product urls
product_urls = []
start=0
end=15
for page in range(start,end):#for loop for scrapping 3 page
    url=driver.find_elements_by_xpath('//a[@class="dp-widget-link noUdLine hashAdded"]')       #scraping urls
    for i in url:
        product_urls.append(i.get_attribute("href"))                        #appending the urls in product_urls list
    nxt_button=driver.find_element_by_id("see-more-products")     #scraping the list of buttons from the page
    nxt_button.click()
    time.sleep(2)

Rating = []
Review=[]

for url in product_urls:
    driver.get(url)
    time.sleep(2)
    
    try:
        rating = driver.find_element_by_xpath('//span[@class="rating"]')  
        Rating.append(rating.text)
    except NoSuchElementException:
        Rating.append('-')


    time.sleep(1)
    
    try:
        review=driver.find_element_by_xpath('//div[@class="head"]')
        Review.append(review.text)
    except NoSuchElementException:
        Review.append('-')

# %%
df29 = pd.DataFrame({'Rating':Rating,'Reviews':Review})
df29
# Out:
#     Rating              No. of ratings                 Reviews
# 0      3.8   1376 Ratings & 47 Reviews       Very good service
# 1      3.8   1376 Ratings & 47 Reviews       Very good service
# 2      3.9       44 Ratings & 0 Review                       -
# 3      3.9       44 Ratings & 0 Review                       -
# 4      4.1    489 Ratings & 26 Reviews  best and fast Charging
# ..     ...                         ...                     ...
# 595    3.9    830 Ratings & 20 Reviews            Good product
# 596    3.8  9436 Ratings & 331 Reviews                  Amzing
# 597    3.8  9436 Ratings & 331 Reviews                  Amzing
# 598    4.6       15 Ratings & 0 Review                       -
# 599    4.6       15 Ratings & 0 Review                       -
#
# [600 rows x 3 columns]

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# INFO:WDM:
#
# ====== WebDriver manager ======
# INFO:WDM:====== WebDriver manager ======
# Current google-chrome version is 95.0.4638
# INFO:WDM:Current google-chrome version is 95.0.4638
# Get LATEST driver version for 95.0.4638
# INFO:WDM:Get LATEST driver version for 95.0.4638
# Driver [C:\Users\monish\.wdm\drivers\chromedriver\win32\95.0.4638.69\chromedriver.exe] found in cache
# INFO:WDM:Driver [C:\Users\monish\.wdm\drivers\chromedriver\win32\95.0.4638.69\chromedriver.exe] found in cache

# %%
url = "https://www.snapdeal.com/"
driver.get(url)

time.sleep(2)
# Asking the user to input the keywords he/she wants to search
user_inp = input('Enter the product you want to search : ')
# Out:
# Enter the product you want to search : phone

# %%
search_bar = driver.find_element_by_id("inputValEnter")    # Locating searc_bar by id
search_bar.clear()                                               # clearing search_bar
search_bar.send_keys(user_inp)                                   # sending user input to search bar
search_button = driver.find_element_by_xpath('//button[@class="searchformButton col-xs-4 rippleGrey"]')       # Locating search_button by xpath
search_button.click()

# %%
# scrape all product urls
product_urls = []
start=0
end=15
for page in range(start,end):#for loop for scrapping 3 page
    url=driver.find_elements_by_xpath('//a[@class="dp-widget-link noUdLine hashAdded"]')       #scraping urls
    for i in url:
        product_urls.append(i.get_attribute("href"))                        #appending the urls in product_urls list
    nxt_button=driver.find_element_by_id("see-more-products")     #scraping the list of buttons from the page
    nxt_button.click()
    time.sleep(2)

Rating = []
Review=[]

for url in product_urls:
    driver.get(url)
    time.sleep(2)
    
    try:
        rating = driver.find_element_by_xpath('//span[@class="rating"]')  
        Rating.append(rating.text)
    except NoSuchElementException:
        Rating.append('-')


    time.sleep(1)
    
    try:
        review=driver.find_element_by_xpath('//div[@class="head"]')
        Review.append(review.text)
    except NoSuchElementException:
        Review.append('-')

# %%
df30 = pd.DataFrame({'Rating':Rating,'Reviews':Review})
df30
# Out:
#     Rating            No. of ratings  \
# 0      5.0     6 Ratings & 2 Reviews
# 1      5.0     6 Ratings & 2 Reviews
# 2      3.5     29 Ratings & 0 Review
# 3      3.5     29 Ratings & 0 Review
# 4      5.0      2 Ratings & 0 Review
# ..     ...                       ...
# 595    3.2  309 Ratings & 17 Reviews
# 596      -                         -
# 597      -                         -
# 598    5.0       1 Rating & 1 Review
# 599    5.0       1 Rating & 1 Review
#
#                                                Reviews
# 0                                              Awesome
# 1                                              Awesome
# 2                                                    -
# 3                                                    -
# 4                                                    -
# ..                                                 ...
# 595                                       Good product
# 596                                                  -
# ...

# %%
frames=[df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18,df19,df20,df21,df22,df23,df24,df25,df26,df27,df28,df29,df30]
Data=df.concat(frames)
Data.reset_index(drop=True, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7923ca2f9b4e> in <module>
# ----> 1 Data=df.append([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18,df19,df20,df21,df22,df23,df24,df25,df26,df27,df28,df29,df30])
#       2 Data.reset_index(1,inplace=True)
#
# NameError: name 'df' is not defined

# %%
import joblib
joblib.dump(Data,"Rating_prediction.xlsx")
# Out:
# ['Rating_prediction.xlsx']
